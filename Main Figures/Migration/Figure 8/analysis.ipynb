# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
    df=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_countryflows_enriched_new.csv")

# %%
x=df[(df['iso3codefrom']=='YEM')&(df['iso3codeto']=='SAU')][['year', 'n_migrations']].sort_values(by='year')

# %%
plt.figure(figsize=(10,6))
plt.bar(x['year'], x['n_migrations'], color='skyblue')
# Out:
# <BarContainer object of 14 artists>

# %%
x
# Out:
#          year  n_migrations
# 57004  1998.0            26
# 66632  1999.0            19
# 643    2000.0            24
# 4395   2001.0            49
# 61607  2002.0            37
# 835    2003.0            52
# 8512   2004.0            41
# 54063  2005.0            47
# 57668  2006.0            72
# 54149  2007.0            93
# 4030   2008.0            95
# 2158   2009.0           165
# 4947   2010.0           227
# 1962   2011.0           269
# 53156  2012.0           267
# 1678   2013.0           291
# 5271   2014.0           299
# 4270   2015.0           277
# 3386   2016.0           287
# 2660   2017.0           284
# 2879   2018.0           320

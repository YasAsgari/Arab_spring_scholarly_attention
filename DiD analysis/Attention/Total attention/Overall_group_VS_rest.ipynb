# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
import re

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
df = pd.read_csv(r"C:\Users\Yasaman\Downloads\Attention-fractional counting.csv")
df.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'affiliation_country': 'Aff_country'}, inplace=True)
df=df[(df['Mention_country'].isin(possible_iso))&(df['Aff_country'].isin(possible_iso))]
df = df[df['year'].isin(np.arange(2002, 2020))]
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df=df[~df['subjarea'].isin(physical_sciences)]
df=df.groupby(['year', 'Mention_country'])['count'].sum().reset_index()


data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))


# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# 0

# %%
df_complete['hue']=df_complete['treated_CW']*2 +df_complete['treated_GC']*3+df_complete['treated_GO']

# %%
df_p=df_complete[df_complete['year']<2011].reset_index(drop=True)
df_p['time']=df_p['year']-2011

# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ time+treated_GC * time + treated_GO * time +treated_CW * time +log_gdp+log_Rpop+log_population+ C(Mention_country)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     179.5
# Date:                Tue, 18 Mar 2025   Prob (F-statistic):           7.87e-68
# Time:                        14:01:06   Log-Likelihood:                 704.42
# No. Observations:                1305   AIC:                            -1105.
# Df Residuals:                    1153   BIC:                            -318.4
# Df Model:                         151
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     4.3887      2.641      1.662      0.097      -0.788       9.565
# C(Mention_country)[T.ago]    -0.9604      0.078    -12.244      0.000      -1.114      -0.807
# C(Mention_country)[T.alb]    -2.1400      0.394     -5.428      0.000      -2.913      -1.367
# C(Mention_country)[T.are]    -1.9150      0.409     -4.677      0.000      -2.717      -1.113
# C(Mention_country)[T.arg]    -1.1114      0.361     -3.083      0.002      -1.818      -0.405
# C(Mention_country)[T.arm]    -3.3978      0.474     -7.169      0.000      -4.327      -2.469
# C(Mention_country)[T.aus]    -0.6867      0.483     -1.423      0.155      -1.633       0.259
# C(Mention_country)[T.aut]    -2.4474      0.501     -4.881      0.000      -3.430      -1.465
# C(Mention_country)[T.aze]    -2.8714      0.320     -8.975      0.000      -3.498      -2.244
# C(Mention_country)[T.bdi]    -1.9996      0.174    -11.479      0.000      -2.341      -1.658
# C(Mention_country)[T.bel]    -2.4342      0.493     -4.938      0.000      -3.400      -1.468
# C(Mention_country)[T.ben]    -1.7247      0.270     -6.391      0.000      -2.254      -1.196
# C(Mention_country)[T.bfa]    -1.2523      0.224     -5.583      0.000      -1.692      -0.813
# C(Mention_country)[T.bgd]    -0.6459      0.276     -2.341      0.019      -1.187      -0.105
# C(Mention_country)[T.bgr]    -2.3081      0.430     -5.373      0.000      -3.150      -1.466
# C(Mention_country)[T.bhr]    -1.2122      0.254     -4.765      0.000      -1.711      -0.714
# C(Mention_country)[T.bih]    -2.2969      0.419     -5.485      0.000      -3.118      -1.476
# C(Mention_country)[T.blr]    -3.2168      0.364     -8.842      0.000      -3.930      -2.504
# C(Mention_country)[T.bol]    -0.7593      0.240     -3.165      0.002      -1.230      -0.289
# C(Mention_country)[T.bra]    -0.3520      0.430     -0.818      0.413      -1.195       0.491
# C(Mention_country)[T.bwa]    -1.5881      0.496     -3.204      0.001      -2.560      -0.617
# C(Mention_country)[T.caf]    -2.1256      0.295     -7.214      0.000      -2.703      -1.548
# C(Mention_country)[T.can]    -1.0977      0.475     -2.313      0.021      -2.028      -0.167
# C(Mention_country)[T.che]    -2.2869      0.544     -4.201      0.000      -3.354      -1.220
# C(Mention_country)[T.chl]    -1.2629      0.383     -3.301      0.001      -2.013      -0.513
# C(Mention_country)[T.chn]    -0.2189      0.609     -0.359      0.719      -1.413       0.975
# C(Mention_country)[T.civ]    -4.1624      0.213    -19.539      0.000      -4.580      -3.745
# C(Mention_country)[T.cmr]    -1.0756      0.246     -4.364      0.000      -1.559      -0.593
# C(Mention_country)[T.col]    -1.2975      0.273     -4.747      0.000      -1.833      -0.762
# C(Mention_country)[T.cri]    -1.0218      0.398     -2.569      0.010      -1.801      -0.242
# C(Mention_country)[T.cub]    -2.1378      0.384     -5.573      0.000      -2.890      -1.386
# C(Mention_country)[T.cyp]    -2.2446      0.610     -3.679      0.000      -3.440      -1.049
# C(Mention_country)[T.cze]    -1.9814      0.468     -4.230      0.000      -2.900      -1.063
# C(Mention_country)[T.deu]    -1.3757      0.471     -2.922      0.003      -2.299      -0.453
# C(Mention_country)[T.dji]    -2.4654      0.503     -4.906      0.000      -3.450      -1.481
# C(Mention_country)[T.dnk]    -2.0745      0.547     -3.792      0.000      -3.147      -1.002
# C(Mention_country)[T.dom]    -1.3359      0.189     -7.078      0.000      -1.706      -0.966
# C(Mention_country)[T.dza]    -2.1694      0.268     -8.103      0.000      -2.694      -1.645
# C(Mention_country)[T.ecu]    -0.9852      0.222     -4.434      0.000      -1.421      -0.550
# C(Mention_country)[T.egy]    -0.1777      0.163     -1.090      0.276      -0.497       0.142
# C(Mention_country)[T.eri]    -1.7849      0.352     -5.068      0.000      -2.475      -1.095
# C(Mention_country)[T.esp]    -1.2539      0.461     -2.723      0.006      -2.157      -0.351
# C(Mention_country)[T.est]    -2.3850      0.625     -3.817      0.000      -3.610      -1.160
# C(Mention_country)[T.eth]    -0.2285      0.204     -1.123      0.262      -0.627       0.170
# C(Mention_country)[T.fin]    -1.7768      0.555     -3.204      0.001      -2.864      -0.690
# C(Mention_country)[T.fra]    -1.5635      0.465     -3.365      0.001      -2.474      -0.653
# C(Mention_country)[T.gab]    -2.1478      0.498     -4.311      0.000      -3.124      -1.171
# C(Mention_country)[T.gbr]    -0.5691      0.481     -1.183      0.237      -1.512       0.373
# C(Mention_country)[T.gha]    -0.8023      0.211     -3.801      0.000      -1.216      -0.389
# C(Mention_country)[T.gmb]    -2.9247      0.474     -6.169      0.000      -3.854      -1.996
# C(Mention_country)[T.grc]    -1.7382      0.475     -3.656      0.000      -2.670      -0.806
# C(Mention_country)[T.gtm]    -0.9859      0.167     -5.919      0.000      -1.312      -0.659
# C(Mention_country)[T.hkg]    -1.2878      0.492     -2.616      0.009      -2.252      -0.323
# C(Mention_country)[T.hnd]    -1.1337      0.202     -5.599      0.000      -1.530      -0.737
# C(Mention_country)[T.hrv]    -2.0472      0.530     -3.860      0.000      -3.087      -1.008
# C(Mention_country)[T.hti]    -1.3958      0.170     -8.197      0.000      -1.730      -1.062
# C(Mention_country)[T.hun]    -2.0412      0.451     -4.522      0.000      -2.926      -1.156
# C(Mention_country)[T.idn]    -0.4162      0.324     -1.283      0.200      -1.052       0.220
# C(Mention_country)[T.ind]    -0.0446      0.567     -0.079      0.937      -1.156       1.066
# C(Mention_country)[T.irn]    -1.0769      0.350     -3.080      0.002      -1.762      -0.392
# C(Mention_country)[T.irq]    -0.9113      0.162     -5.642      0.000      -1.228      -0.595
# C(Mention_country)[T.isr]    -1.8020      0.528     -3.412      0.001      -2.837      -0.767
# C(Mention_country)[T.ita]    -1.3682      0.462     -2.964      0.003      -2.273      -0.463
# C(Mention_country)[T.jam]    -1.7930      0.449     -3.997      0.000      -2.672      -0.914
# C(Mention_country)[T.jor]     0.3034      0.076      4.005      0.000       0.155       0.452
# C(Mention_country)[T.jpn]    -1.1393      0.485     -2.351      0.019      -2.089      -0.189
# C(Mention_country)[T.kaz]    -1.9158      0.244     -7.849      0.000      -2.394      -1.437
# C(Mention_country)[T.ken]    -0.4924      0.233     -2.115      0.034      -0.949      -0.036
# C(Mention_country)[T.kgz]    -1.8989      0.292     -6.501      0.000      -2.471      -1.326
# C(Mention_country)[T.khm]    -1.0990      0.178     -6.187      0.000      -1.447      -0.751
# C(Mention_country)[T.kor]    -1.6512      0.432     -3.821      0.000      -2.498      -0.804
# C(Mention_country)[T.kwt]    -0.5932      0.163     -3.649      0.000      -0.912      -0.275
# C(Mention_country)[T.lao]    -1.7135      0.277     -6.178      0.000      -2.257      -1.170
# C(Mention_country)[T.lbn]    -2.1927      0.427     -5.134      0.000      -3.030      -1.356
# C(Mention_country)[T.lbr]    -1.3474      0.282     -4.771      0.000      -1.901      -0.794
# C(Mention_country)[T.lby]    -0.8192      0.170     -4.829      0.000      -1.152      -0.487
# C(Mention_country)[T.lka]    -1.1476      0.226     -5.077      0.000      -1.591      -0.705
# C(Mention_country)[T.lso]    -1.5397      0.392     -3.927      0.000      -2.308      -0.771
# C(Mention_country)[T.ltu]    -2.4625      0.524     -4.696      0.000      -3.490      -1.435
# C(Mention_country)[T.lva]    -3.0212      0.521     -5.796      0.000      -4.043      -2.000
# C(Mention_country)[T.mar]     0.0557      0.240      0.232      0.817      -0.416       0.527
# C(Mention_country)[T.mda]    -3.1979      0.435     -7.357      0.000      -4.050      -2.346
# C(Mention_country)[T.mdg]    -0.3497      0.167     -2.092      0.036      -0.677      -0.022
# C(Mention_country)[T.mex]    -0.4805      0.361     -1.331      0.183      -1.188       0.227
# C(Mention_country)[T.mkd]    -2.8008      0.509     -5.501      0.000      -3.799      -1.803
# C(Mention_country)[T.mli]    -1.2863      0.199     -6.476      0.000      -1.676      -0.897
# C(Mention_country)[T.mmr]    -0.8978      0.094     -9.599      0.000      -1.081      -0.714
# C(Mention_country)[T.mng]    -0.3720      0.422     -0.881      0.378      -1.200       0.456
# C(Mention_country)[T.moz]    -0.7162      0.115     -6.235      0.000      -0.941      -0.491
# C(Mention_country)[T.mrt]    -1.8111      0.326     -5.560      0.000      -2.449      -1.173
# C(Mention_country)[T.mus]    -2.0980      0.519     -4.044      0.000      -3.115      -1.081
# C(Mention_country)[T.mwi]    -0.8484      0.219     -3.881      0.000      -1.277      -0.420
# C(Mention_country)[T.mys]    -1.3417      0.333     -4.025      0.000      -1.995      -0.688
# C(Mention_country)[T.nam]    -1.0801      0.442     -2.445      0.014      -1.946      -0.214
# C(Mention_country)[T.ner]    -1.8707      0.144    -13.006      0.000      -2.153      -1.589
# C(Mention_country)[T.nga]    -0.2409      0.310     -0.777      0.437      -0.849       0.367
# C(Mention_country)[T.nic]    -1.1781      0.277     -4.245      0.000      -1.722      -0.634
# C(Mention_country)[T.nld]    -1.7513      0.490     -3.575      0.000      -2.711      -0.791
# C(Mention_country)[T.nor]    -1.4132      0.558     -2.533      0.011      -2.507      -0.320
# C(Mention_country)[T.npl]    -0.6588      0.208     -3.170      0.002      -1.066      -0.252
# C(Mention_country)[T.nzl]    -0.5874      0.555     -1.058      0.290      -1.675       0.500
# C(Mention_country)[T.omn]    -0.2411      0.124     -1.950      0.051      -0.483       0.001
# C(Mention_country)[T.pak]    -0.7299      0.328     -2.225      0.026      -1.373      -0.087
# C(Mention_country)[T.pan]    -1.0554      0.381     -2.767      0.006      -1.803      -0.308
# C(Mention_country)[T.per]    -0.7898      0.222     -3.561      0.000      -1.224      -0.355
# C(Mention_country)[T.phl]    -0.7002      0.224     -3.126      0.002      -1.139      -0.261
# C(Mention_country)[T.pol]    -1.4942      0.410     -3.645      0.000      -2.298      -0.691
# C(Mention_country)[T.pri]    -1.9015      0.445     -4.275      0.000      -2.773      -1.030
# C(Mention_country)[T.prt]    -1.9848      0.458     -4.337      0.000      -2.882      -1.088
# C(Mention_country)[T.pry]    -1.6684      0.280     -5.962      0.000      -2.217      -1.120
# C(Mention_country)[T.pse]    -1.8408      0.390     -4.722      0.000      -2.605      -1.077
# C(Mention_country)[T.qat]    -3.0265      0.595     -5.088      0.000      -4.192      -1.861
# C(Mention_country)[T.rou]    -2.3604      0.361     -6.532      0.000      -3.069      -1.652
# C(Mention_country)[T.rus]    -1.7475      0.417     -4.187      0.000      -2.565      -0.930
# C(Mention_country)[T.rwa]    -1.2555      0.187     -6.723      0.000      -1.622      -0.890
# C(Mention_country)[T.sau]    -1.4806      0.307     -4.830      0.000      -2.081      -0.880
# C(Mention_country)[T.sen]    -1.4489      0.280     -5.177      0.000      -1.997      -0.900
# C(Mention_country)[T.sgp]    -2.1530      0.541     -3.977      0.000      -3.214      -1.092
# C(Mention_country)[T.sle]    -1.1708      0.226     -5.171      0.000      -1.615      -0.727
# C(Mention_country)[T.slv]    -1.7037      0.247     -6.885      0.000      -2.189      -1.219
# C(Mention_country)[T.som]    -0.0674      0.134     -0.504      0.614      -0.330       0.195
# C(Mention_country)[T.svk]    -2.2417      0.487     -4.601      0.000      -3.197      -1.287
# C(Mention_country)[T.svn]    -2.5113      0.609     -4.125      0.000      -3.704      -1.318
# C(Mention_country)[T.swe]    -1.5428      0.526     -2.932      0.003      -2.574      -0.511
# C(Mention_country)[T.syr]    -0.4636      0.069     -6.766      0.000      -0.598      -0.329
# C(Mention_country)[T.tcd]    -1.1717      0.135     -8.672      0.000      -1.437      -0.907
# C(Mention_country)[T.tgo]    -2.2997      0.289     -7.944      0.000      -2.867      -1.732
# C(Mention_country)[T.tha]    -0.9921      0.312     -3.175      0.001      -1.604      -0.380
# C(Mention_country)[T.tjk]    -2.2981      0.234     -9.818      0.000      -2.757      -1.839
# C(Mention_country)[T.tkm]    -1.9362      0.236     -8.210      0.000      -2.398      -1.474
# C(Mention_country)[T.tto]    -3.2043      0.548     -5.849      0.000      -4.278      -2.131
# C(Mention_country)[T.tun]    -0.8224      0.223     -3.693      0.000      -1.259      -0.386
# C(Mention_country)[T.tur]    -0.5878      0.390     -1.506      0.132      -1.353       0.177
# C(Mention_country)[T.tza]    -0.3047      0.184     -1.653      0.098      -0.666       0.057
# C(Mention_country)[T.uga]    -0.5287      0.200     -2.647      0.008      -0.920      -0.137
# C(Mention_country)[T.ukr]    -2.5756      0.325     -7.934      0.000      -3.212      -1.939
# C(Mention_country)[T.ury]    -2.3154      0.469     -4.938      0.000      -3.234      -1.396
# C(Mention_country)[T.usa]    -0.2783      0.557     -0.500      0.617      -1.370       0.813
# C(Mention_country)[T.uzb]    -2.4983      0.199    -12.581      0.000      -2.888      -2.109
# C(Mention_country)[T.ven]    -1.4930      0.295     -5.063      0.000      -2.071      -0.915
# C(Mention_country)[T.vnm]    -0.4559      0.220     -2.072      0.038      -0.887      -0.025
# C(Mention_country)[T.yem]    -0.0729      0.058     -1.264      0.206      -0.186       0.040
# C(Mention_country)[T.zaf]    -0.4686      0.325     -1.440      0.150      -1.106       0.169
# C(Mention_country)[T.zmb]    -1.1210      0.207     -5.408      0.000      -1.527      -0.715
# C(Mention_country)[T.zwe]    -0.8614      0.250     -3.443      0.001      -1.352      -0.371
# time                          0.0412      0.006      6.736      0.000       0.029       0.053
# treated_GC                   -1.6873      0.362     -4.667      0.000      -2.396      -0.979
# treated_GC:time              -0.0059      0.012     -0.508      0.612      -0.029       0.017
# treated_GO                   -1.0001      0.243     -4.119      0.000      -1.476      -0.524
# treated_GO:time               0.0347      0.026      1.355      0.175      -0.015       0.085
# treated_CW                   -1.3557      0.148     -9.181      0.000      -1.645      -1.066
# treated_CW:time               0.0013      0.007      0.182      0.855      -0.012       0.015
# log_gdp                       0.1049      0.039      2.668      0.008       0.028       0.182
# log_Rpop                      0.5303      0.065      8.119      0.000       0.402       0.658
# log_population               -0.1305      0.160     -0.818      0.413      -0.443       0.182
# ==============================================================================
# Omnibus:                      131.072   Durbin-Watson:                   1.764
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              909.298
# Skew:                          -0.118   Prob(JB):                    3.54e-198
# Kurtosis:                       7.083   Cond. No.                     2.14e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.2e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 154, but rank is 7
#   warnings.warn('covariance of constraints does not have full '

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='hue')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foreign attention')
# Out:
# Text(0, 0.5, 'log Foreign attention')

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * post + treated_GO * post +treated_CW * post+log_population +log_gdp+log_Rpop+C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     134.1
# Date:                Tue, 18 Mar 2025   Prob (F-statistic):           2.10e-85
# Time:                        14:01:14   Log-Likelihood:                 952.31
# No. Observations:                2610   AIC:                            -1569.
# Df Residuals:                    2442   BIC:                            -583.0
# Df Model:                         167
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     9.2633      3.116      2.973      0.003       3.156      15.370
# C(Mention_country)[T.ago]    -1.0358      0.080    -13.020      0.000      -1.192      -0.880
# C(Mention_country)[T.alb]    -2.7869      0.447     -6.241      0.000      -3.662      -1.912
# C(Mention_country)[T.are]    -2.2238      0.359     -6.199      0.000      -2.927      -1.521
# C(Mention_country)[T.arg]    -1.0143      0.253     -4.014      0.000      -1.510      -0.519
# C(Mention_country)[T.arm]    -3.8247      0.480     -7.969      0.000      -4.765      -2.884
# C(Mention_country)[T.aus]    -0.7494      0.351     -2.132      0.033      -1.438      -0.060
# C(Mention_country)[T.aut]    -2.7629      0.410     -6.746      0.000      -3.566      -1.960
# C(Mention_country)[T.aze]    -2.9601      0.285    -10.389      0.000      -3.519      -2.402
# C(Mention_country)[T.bdi]    -2.2391      0.209    -10.700      0.000      -2.649      -1.829
# C(Mention_country)[T.bel]    -2.6782      0.387     -6.920      0.000      -3.437      -1.920
# C(Mention_country)[T.ben]    -2.0604      0.253     -8.156      0.000      -2.556      -1.565
# C(Mention_country)[T.bfa]    -1.4991      0.180     -8.351      0.000      -1.851      -1.147
# C(Mention_country)[T.bgd]    -0.1568      0.286     -0.549      0.583      -0.717       0.403
# C(Mention_country)[T.bgr]    -2.6458      0.373     -7.092      0.000      -3.377      -1.915
# C(Mention_country)[T.bhr]    -1.6545      0.306     -5.415      0.000      -2.253      -1.056
# C(Mention_country)[T.bih]    -2.9404      0.436     -6.737      0.000      -3.796      -2.085
# C(Mention_country)[T.blr]    -3.4713      0.306    -11.344      0.000      -4.071      -2.872
# C(Mention_country)[T.bol]    -1.1694      0.224     -5.220      0.000      -1.608      -0.730
# C(Mention_country)[T.bra]     0.2262      0.389      0.581      0.561      -0.536       0.989
# C(Mention_country)[T.bwa]    -2.4177      0.515     -4.695      0.000      -3.427      -1.408
# C(Mention_country)[T.caf]    -2.6671      0.339     -7.872      0.000      -3.331      -2.003
# C(Mention_country)[T.can]    -1.0126      0.338     -3.000      0.003      -1.674      -0.351
# C(Mention_country)[T.che]    -2.6190      0.443     -5.915      0.000      -3.487      -1.751
# C(Mention_country)[T.chl]    -1.3578      0.291     -4.668      0.000      -1.928      -0.788
# C(Mention_country)[T.chn]     0.9584      0.665      1.442      0.149      -0.345       2.261
# C(Mention_country)[T.civ]    -4.4639      0.150    -29.702      0.000      -4.758      -4.169
# C(Mention_country)[T.cmr]    -1.2955      0.184     -7.046      0.000      -1.656      -0.935
# C(Mention_country)[T.col]    -1.0095      0.207     -4.875      0.000      -1.415      -0.604
# C(Mention_country)[T.cri]    -1.7349      0.390     -4.446      0.000      -2.500      -0.970
# C(Mention_country)[T.cub]    -2.3710      0.307     -7.727      0.000      -2.972      -1.770
# C(Mention_country)[T.cyp]    -3.1716      0.646     -4.910      0.000      -4.438      -1.906
# C(Mention_country)[T.cze]    -2.2251      0.376     -5.923      0.000      -2.961      -1.489
# C(Mention_country)[T.deu]    -1.0472      0.355     -2.951      0.003      -1.743      -0.352
# C(Mention_country)[T.dji]    -3.5609      0.604     -5.899      0.000      -4.744      -2.378
# C(Mention_country)[T.dnk]    -2.4976      0.470     -5.312      0.000      -3.419      -1.576
# C(Mention_country)[T.dom]    -1.7614      0.211     -8.334      0.000      -2.176      -1.347
# C(Mention_country)[T.dza]    -1.9585      0.195    -10.025      0.000      -2.341      -1.576
# C(Mention_country)[T.ecu]    -1.2628      0.200     -6.313      0.000      -1.655      -0.871
# C(Mention_country)[T.egy]     0.0606      0.180      0.336      0.737      -0.293       0.414
# C(Mention_country)[T.eri]    -2.5431      0.402     -6.330      0.000      -3.330      -1.756
# C(Mention_country)[T.esp]    -1.0409      0.329     -3.165      0.002      -1.685      -0.396
# C(Mention_country)[T.est]    -3.3451      0.640     -5.228      0.000      -4.599      -2.091
# C(Mention_country)[T.eth]     0.0892      0.206      0.432      0.665      -0.315       0.493
# C(Mention_country)[T.fin]    -2.2615      0.474     -4.776      0.000      -3.190      -1.333
# C(Mention_country)[T.fra]    -1.2942      0.339     -3.815      0.000      -1.959      -0.629
# C(Mention_country)[T.gab]    -2.9769      0.530     -5.620      0.000      -4.015      -1.939
# C(Mention_country)[T.gbr]    -0.3315      0.350     -0.948      0.343      -1.017       0.354
# C(Mention_country)[T.gha]    -0.7995      0.157     -5.092      0.000      -1.107      -0.492
# C(Mention_country)[T.gmb]    -3.7418      0.512     -7.313      0.000      -4.745      -2.739
# C(Mention_country)[T.grc]    -1.9732      0.374     -5.279      0.000      -2.706      -1.241
# C(Mention_country)[T.gtm]    -1.2412      0.158     -7.869      0.000      -1.550      -0.932
# C(Mention_country)[T.hkg]    -1.7253      0.414     -4.165      0.000      -2.537      -0.913
# C(Mention_country)[T.hnd]    -1.6776      0.226     -7.422      0.000      -2.121      -1.235
# C(Mention_country)[T.hrv]    -2.6036      0.481     -5.408      0.000      -3.547      -1.660
# C(Mention_country)[T.hti]    -1.4624      0.199     -7.342      0.000      -1.853      -1.072
# C(Mention_country)[T.hun]    -2.3454      0.365     -6.426      0.000      -3.061      -1.630
# C(Mention_country)[T.idn]     0.1326      0.370      0.359      0.720      -0.592       0.857
# C(Mention_country)[T.ind]     1.0567      0.638      1.657      0.098      -0.193       2.307
# C(Mention_country)[T.irn]    -0.5405      0.281     -1.922      0.055      -1.092       0.011
# C(Mention_country)[T.irq]    -1.0835      0.141     -7.704      0.000      -1.359      -0.808
# C(Mention_country)[T.isr]    -2.1944      0.425     -5.158      0.000      -3.028      -1.361
# C(Mention_country)[T.ita]    -1.0588      0.334     -3.166      0.002      -1.714      -0.403
# C(Mention_country)[T.jam]    -2.5403      0.467     -5.445      0.000      -3.455      -1.626
# C(Mention_country)[T.jor]     0.3024      0.063      4.835      0.000       0.180       0.425
# C(Mention_country)[T.jpn]    -0.6792      0.384     -1.768      0.077      -1.432       0.074
# C(Mention_country)[T.kaz]    -1.9802      0.220     -9.013      0.000      -2.411      -1.550
# C(Mention_country)[T.ken]    -0.4196      0.161     -2.602      0.009      -0.736      -0.104
# C(Mention_country)[T.kgz]    -2.2605      0.319     -7.094      0.000      -2.885      -1.636
# C(Mention_country)[T.khm]    -1.2271      0.167     -7.363      0.000      -1.554      -0.900
# C(Mention_country)[T.kor]    -1.2901      0.315     -4.093      0.000      -1.908      -0.672
# C(Mention_country)[T.kwt]    -0.8299      0.156     -5.314      0.000      -1.136      -0.524
# C(Mention_country)[T.lao]    -2.0995      0.297     -7.063      0.000      -2.682      -1.517
# C(Mention_country)[T.lbn]    -2.6301      0.396     -6.640      0.000      -3.407      -1.854
# C(Mention_country)[T.lbr]    -1.9963      0.348     -5.737      0.000      -2.678      -1.314
# C(Mention_country)[T.lby]    -1.0509      0.194     -5.415      0.000      -1.431      -0.671
# C(Mention_country)[T.lka]    -1.2962      0.173     -7.511      0.000      -1.634      -0.958
# C(Mention_country)[T.lso]    -2.4012      0.472     -5.085      0.000      -3.327      -1.476
# C(Mention_country)[T.ltu]    -3.1044      0.510     -6.089      0.000      -4.104      -2.105
# C(Mention_country)[T.lva]    -3.6018      0.546     -6.599      0.000      -4.672      -2.532
# C(Mention_country)[T.mar]     0.4939      0.267      1.849      0.064      -0.030       1.017
# C(Mention_country)[T.mda]    -3.6339      0.462     -7.858      0.000      -4.540      -2.728
# C(Mention_country)[T.mdg]    -0.5895      0.121     -4.861      0.000      -0.827      -0.352
# C(Mention_country)[T.mex]    -0.1128      0.306     -0.368      0.713      -0.713       0.487
# C(Mention_country)[T.mkd]    -3.4009      0.536     -6.347      0.000      -4.451      -2.351
# C(Mention_country)[T.mli]    -1.5142      0.161     -9.432      0.000      -1.829      -1.200
# C(Mention_country)[T.mmr]    -0.6292      0.094     -6.700      0.000      -0.813      -0.445
# C(Mention_country)[T.mng]    -1.0741      0.457     -2.350      0.019      -1.970      -0.178
# C(Mention_country)[T.moz]    -0.8114      0.086     -9.391      0.000      -0.981      -0.642
# C(Mention_country)[T.mrt]    -2.5560      0.377     -6.775      0.000      -3.295      -1.817
# C(Mention_country)[T.mus]    -3.0458      0.586     -5.199      0.000      -4.194      -1.898
# C(Mention_country)[T.mwi]    -1.0243      0.187     -5.472      0.000      -1.391      -0.657
# C(Mention_country)[T.mys]    -1.1617      0.254     -4.578      0.000      -1.659      -0.664
# C(Mention_country)[T.nam]    -1.9949      0.490     -4.068      0.000      -2.956      -1.034
# C(Mention_country)[T.ner]    -1.9860      0.122    -16.242      0.000      -2.226      -1.746
# C(Mention_country)[T.nga]     0.2537      0.312      0.814      0.416      -0.357       0.865
# C(Mention_country)[T.nic]    -1.6851      0.299     -5.645      0.000      -2.270      -1.100
# C(Mention_country)[T.nld]    -1.8488      0.366     -5.057      0.000      -2.565      -1.132
# C(Mention_country)[T.nor]    -1.9454      0.484     -4.021      0.000      -2.894      -0.997
# C(Mention_country)[T.npl]    -0.7290      0.152     -4.794      0.000      -1.027      -0.431
# C(Mention_country)[T.nzl]    -1.1899      0.488     -2.439      0.015      -2.146      -0.234
# C(Mention_country)[T.omn]    -0.3963      0.133     -2.980      0.003      -0.657      -0.136
# C(Mention_country)[T.pak]    -0.1267      0.338     -0.375      0.708      -0.789       0.535
# C(Mention_country)[T.pan]    -1.8100      0.405     -4.475      0.000      -2.603      -1.017
# C(Mention_country)[T.per]    -0.8316      0.163     -5.112      0.000      -1.151      -0.513
# C(Mention_country)[T.phl]    -0.3894      0.221     -1.765      0.078      -0.822       0.043
# C(Mention_country)[T.pol]    -1.3555      0.290     -4.671      0.000      -1.924      -0.787
# C(Mention_country)[T.pri]    -2.4393      0.443     -5.502      0.000      -3.308      -1.570
# C(Mention_country)[T.prt]    -2.1563      0.374     -5.767      0.000      -2.889      -1.424
# C(Mention_country)[T.pry]    -2.1863      0.308     -7.101      0.000      -2.790      -1.583
# C(Mention_country)[T.pse]    -2.3921      0.406     -5.898      0.000      -3.187      -1.597
# C(Mention_country)[T.qat]    -3.6587      0.584     -6.267      0.000      -4.803      -2.514
# C(Mention_country)[T.rou]    -2.1877      0.273     -8.009      0.000      -2.723      -1.652
# C(Mention_country)[T.rus]    -1.0732      0.353     -3.044      0.002      -1.764      -0.382
# C(Mention_country)[T.rwa]    -1.5373      0.212     -7.253      0.000      -1.953      -1.122
# C(Mention_country)[T.sau]    -1.3724      0.232     -5.922      0.000      -1.827      -0.918
# C(Mention_country)[T.sen]    -1.7321      0.229     -7.571      0.000      -2.180      -1.284
# C(Mention_country)[T.sgp]    -2.6237      0.471     -5.571      0.000      -3.547      -1.701
# C(Mention_country)[T.sle]    -1.6761      0.275     -6.101      0.000      -2.215      -1.138
# C(Mention_country)[T.slv]    -2.2279      0.285     -7.805      0.000      -2.787      -1.668
# C(Mention_country)[T.som]    -0.6409      0.150     -4.273      0.000      -0.935      -0.347
# C(Mention_country)[T.svk]    -2.6502      0.434     -6.100      0.000      -3.502      -1.799
# C(Mention_country)[T.svn]    -3.1765      0.589     -5.397      0.000      -4.330      -2.023
# C(Mention_country)[T.swe]    -1.8354      0.416     -4.412      0.000      -2.651      -1.020
# C(Mention_country)[T.syr]    -0.3024      0.042     -7.130      0.000      -0.385      -0.219
# C(Mention_country)[T.tcd]    -1.4881      0.151     -9.878      0.000      -1.783      -1.193
# C(Mention_country)[T.tgo]    -2.7132      0.298     -9.102      0.000      -3.297      -2.129
# C(Mention_country)[T.tha]    -0.7876      0.242     -3.261      0.001      -1.261      -0.314
# C(Mention_country)[T.tjk]    -2.4730      0.251     -9.847      0.000      -2.965      -1.981
# C(Mention_country)[T.tkm]    -2.1328      0.291     -7.317      0.000      -2.704      -1.562
# C(Mention_country)[T.tto]    -4.0155      0.583     -6.885      0.000      -5.159      -2.872
# C(Mention_country)[T.tun]    -1.1761      0.216     -5.440      0.000      -1.600      -0.752
# C(Mention_country)[T.tur]    -0.3413      0.294     -1.160      0.246      -0.918       0.235
# C(Mention_country)[T.tza]    -0.2167      0.133     -1.629      0.103      -0.477       0.044
# C(Mention_country)[T.uga]    -0.5110      0.139     -3.670      0.000      -0.784      -0.238
# C(Mention_country)[T.ukr]    -2.1500      0.230     -9.350      0.000      -2.601      -1.699
# C(Mention_country)[T.ury]    -2.9255      0.465     -6.293      0.000      -3.837      -2.014
# C(Mention_country)[T.usa]     0.5035      0.497      1.013      0.311      -0.470       1.477
# C(Mention_country)[T.uzb]    -2.5066      0.123    -20.363      0.000      -2.748      -2.265
# C(Mention_country)[T.ven]    -1.6138      0.197     -8.197      0.000      -2.000      -1.228
# C(Mention_country)[T.vnm]    -0.2864      0.213     -1.345      0.179      -0.704       0.131
# C(Mention_country)[T.yem]    -0.1171      0.069     -1.688      0.091      -0.253       0.019
# C(Mention_country)[T.zaf]    -0.2255      0.236     -0.956      0.339      -0.688       0.237
# C(Mention_country)[T.zmb]    -1.3327      0.181     -7.365      0.000      -1.687      -0.978
# C(Mention_country)[T.zwe]    -1.1546      0.212     -5.448      0.000      -1.570      -0.739
# C(year)[T.2003.0]            -0.0023      0.016     -0.143      0.887      -0.033       0.029
# C(year)[T.2004.0]             0.0010      0.021      0.048      0.962      -0.041       0.043
# C(year)[T.2005.0]             0.0392      0.025      1.562      0.118      -0.010       0.088
# C(year)[T.2006.0]             0.1349      0.029      4.697      0.000       0.079       0.191
# C(year)[T.2007.0]             0.1734      0.035      5.025      0.000       0.106       0.241
# C(year)[T.2008.0]             0.2227      0.039      5.652      0.000       0.145       0.300
# C(year)[T.2009.0]             0.3131      0.042      7.465      0.000       0.231       0.395
# C(year)[T.2010.0]             0.3445      0.045      7.657      0.000       0.256       0.433
# C(year)[T.2011.0]            -0.0920      0.016     -5.725      0.000      -0.124      -0.061
# C(year)[T.2012.0]            -0.0610      0.013     -4.564      0.000      -0.087      -0.035
# C(year)[T.2013.0]             0.0113      0.011      1.066      0.286      -0.009       0.032
# C(year)[T.2014.0]             0.0379      0.010      3.775      0.000       0.018       0.058
# C(year)[T.2015.0]             0.0510      0.010      5.081      0.000       0.031       0.071
# C(year)[T.2016.0]             0.0814      0.013      6.369      0.000       0.056       0.106
# C(year)[T.2017.0]             0.0903      0.015      6.027      0.000       0.061       0.120
# C(year)[T.2018.0]             0.1337      0.018      7.608      0.000       0.099       0.168
# C(year)[T.2019.0]             0.2301      0.023      9.865      0.000       0.184       0.276
# treated_GC                   -2.0843      0.350     -5.953      0.000      -2.771      -1.398
# post                          0.4826      0.053      9.117      0.000       0.379       0.586
# treated_GC:post               0.0195      0.052      0.377      0.706      -0.082       0.121
# treated_GO                   -1.1154      0.153     -7.268      0.000      -1.416      -0.815
# treated_GO:post               0.1785      0.026      6.954      0.000       0.128       0.229
# treated_CW                   -1.4703      0.130    -11.350      0.000      -1.724      -1.216
# treated_CW:post               0.2549      0.096      2.642      0.008       0.066       0.444
# log_population               -0.4278      0.184     -2.320      0.020      -0.789      -0.066
# log_gdp                       0.0709      0.042      1.682      0.093      -0.012       0.154
# log_Rpop                      0.5468      0.051     10.823      0.000       0.448       0.646
# ==============================================================================
# Omnibus:                      223.495   Durbin-Watson:                   0.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1149.574
# Skew:                          -0.224   Prob(JB):                    2.36e-250
# Kurtosis:                       6.220   Cond. No.                     8.83e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.37e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 171, but rank is 23
#   warnings.warn('covariance of constraints does not have full '

# %%
from linearmodels.panel import PanelOLS

panel_data = df_complete.set_index(['Mention_country', 'year'])

model = PanelOLS.from_formula(
    'log_count ~ treated_GO : post+treated_CW : post+treated_GC : post +log_population +log_gdp+log_Rpop+ EntityEffects + TimeEffects',
    data=panel_data
)
results = model.fit(cov_type='clustered', cluster_entity=True)
print(results)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              log_count   R-squared:                        0.4290
# Estimator:                   PanelOLS   R-squared (Between):             -0.7329
# No. Observations:                2610   R-squared (Within):               0.7090
# Date:                Tue, Mar 18 2025   R-squared (Overall):             -0.7219
# Time:                        14:18:56   Log-likelihood                    952.31
# Cov. Estimator:             Clustered
#                                         F-statistic:                      305.83
# Entities:                         145   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(6,2442)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             51.372
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(6,2442)
# Avg Obs:                       145.00
# Min Obs:                       145.00
# Max Obs:                       145.00
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# log_population     -0.4278     0.1836    -2.3299     0.0199     -0.7878     -0.0677
# log_gdp             0.0709     0.0420     1.6891     0.0913     -0.0114      0.1533
# log_Rpop            0.5468     0.0503     10.868     0.0000      0.4482      0.6455
# treated_GO:post     0.1785     0.0256     6.9827     0.0000      0.1284      0.2286
# treated_CW:post     0.2549     0.0961     2.6524     0.0080      0.0664      0.4433
# treated_GC:post     0.0195     0.0515     0.3784     0.7051     -0.0815      0.1205
# ===================================================================================
#
# F-test for Poolability: 184.67
# P-value: 0.0000
# Distribution: F(161,2442)
#
# Included effects: Entity, Time

# %%
df_complete['relative_time'] = df_complete['year'] - 2011
df_complete['rel_time_cat'] = df_complete['relative_time'].astype('category')
model = smf.ols("log_count ~C(rel_time_cat)*treated_GO *C(rel_time_cat)*treated_GC +C(rel_time_cat)*treated_CW+ log_gdp + log_Rpop + log_population + C(Mention_country)", 
                data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})


# Get all parameter names, coefficients, and standard errors
params = model.params
bse = model.bse

fig, ax=plt.subplots(nrows=1, ncols=3, figsize=(18,4))
for i, cat in enumerate(['GO', 'CW', 'GC']):
    # Filter for rel_time_cat coefficients (excluding the reference period)
    rel_time_coefs = {}
    rel_time_ses = {}

    for param, coef in params.items():
        match = re.match(r"C\(rel_time_cat\)\[T\.(\-?\d+\.?\d*)\]:treated_%s"%cat, param)
        if match:
            rel_time = float(match.group(1))
            rel_time_coefs[rel_time] = coef
            rel_time_ses[rel_time] = bse[param]


    # Sort by relative time
    rel_times = sorted(rel_time_coefs.keys())
    coefs = [rel_time_coefs[t] for t in rel_times]
    ses = [rel_time_ses[t] for t in rel_times]

    ax[i].errorbar(rel_times, coefs, yerr=[1.96*s for s in ses], fmt='o', capsize=4, label='Estimate ± 95% CI')

    ax[i].axhline(0, linestyle='--', color='gray')
    ax[i].axvline(0, linestyle=':', color='red', label='Treatment Time')
    ax[i].grid(True)
    ax[i].set_ylabel("Estimated Treatment Effect")
    ax[i].set_xlabel("Years Relative to Treatment")
    ax[i].set_xlim(-5.25,5.25)
    
    ax[i].set_title(f"Dynamic DiD for log attention ({cat})")


ax[0].set_ylim(-1e-15, 1e-15)



plt.tight_layout()
plt.show()

# %%
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(model.summary())
#
# NameError: name 'model' is not defined

# %%
params
# Out:
# Intercept                            9.338268
# C(rel_time_cat)[T.-8.0]             -0.004855
# C(rel_time_cat)[T.-7.0]             -0.001767
# C(rel_time_cat)[T.-6.0]              0.039449
# C(rel_time_cat)[T.-5.0]              0.133450
#                                        ...
# C(rel_time_cat)[T.7.0]:treated_CW    0.175176
# C(rel_time_cat)[T.8.0]:treated_CW    0.154680
# log_gdp                              0.071539
# log_Rpop                             0.546495
# log_population                      -0.432156
# Length: 237, dtype: float64

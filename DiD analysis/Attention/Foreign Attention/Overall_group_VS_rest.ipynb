# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
df = pd.read_csv(r"C:\Users\Yasaman\Downloads\Attention-fractional counting.csv")
df.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'affiliation_country': 'Aff_country'}, inplace=True)
df=df[(df['Mention_country'].isin(possible_iso))&(df['Aff_country'].isin(possible_iso))]
df = df[df['year'].isin(np.arange(2002, 2020))]
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df=df[~df['subjarea'].isin(physical_sciences)]
df=df[df['Mention_country']!=df['Aff_country']]
df=df.groupby(['year', 'Mention_country'])['count'].sum().reset_index()


data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))


# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# 0

# %%
df_complete['hue']=df_complete['treated_CW']*2 +df_complete['treated_GC']*3+df_complete['treated_GO']

# %%
df_p=df_complete[df_complete['year']<=2011].reset_index(drop=True)
df_p['time']=df_p['year']-2011
df_p=df_p[df_p['time']<-1]
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * time + treated_GO * time +treated_CW * time+log_population +log_gdp+ C(Mention_country) + C(year)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                 2.050e+04
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):          3.44e-226
# Time:                        14:38:21   Log-Likelihood:                 592.97
# No. Observations:                1160   AIC:                            -871.9
# Df Residuals:                    1003   BIC:                            -78.13
# Df Model:                         156
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -4.2676      1.468     -2.907      0.004      -7.144      -1.391
# C(Mention_country)[T.ago]    -0.8850      0.095     -9.284      0.000      -1.072      -0.698
# C(Mention_country)[T.alb]    -0.1870      0.301     -0.622      0.534      -0.776       0.402
# C(Mention_country)[T.are]     0.2940      0.313      0.940      0.347      -0.319       0.907
# C(Mention_country)[T.arg]     0.3164      0.152      2.078      0.038       0.018       0.615
# C(Mention_country)[T.arm]    -0.5624      0.293     -1.923      0.055      -1.136       0.011
# C(Mention_country)[T.aus]     1.3835      0.226      6.124      0.000       0.941       1.826
# C(Mention_country)[T.aut]     0.2183      0.273      0.799      0.424      -0.317       0.754
# C(Mention_country)[T.aze]    -0.9379      0.169     -5.539      0.000      -1.270      -0.606
# C(Mention_country)[T.bdi]    -1.4770      0.163     -9.074      0.000      -1.796      -1.158
# C(Mention_country)[T.bel]    -0.0207      0.255     -0.081      0.935      -0.520       0.479
# C(Mention_country)[T.ben]    -0.1871      0.154     -1.214      0.225      -0.489       0.115
# C(Mention_country)[T.bfa]     0.0773      0.077      0.998      0.318      -0.075       0.229
# C(Mention_country)[T.bgd]    -0.3138      0.237     -1.324      0.186      -0.778       0.151
# C(Mention_country)[T.bgr]     0.0416      0.201      0.207      0.836      -0.352       0.435
# C(Mention_country)[T.bhr]    -0.8836      0.244     -3.615      0.000      -1.363      -0.405
# C(Mention_country)[T.bih]     0.1134      0.264      0.429      0.668      -0.405       0.632
# C(Mention_country)[T.blr]    -0.9541      0.169     -5.645      0.000      -1.285      -0.623
# C(Mention_country)[T.bol]     0.8286      0.144      5.762      0.000       0.547       1.110
# C(Mention_country)[T.bra]     0.2079      0.307      0.677      0.498      -0.394       0.809
# C(Mention_country)[T.bwa]     0.7952      0.366      2.176      0.030       0.079       1.512
# C(Mention_country)[T.caf]    -0.8513      0.236     -3.614      0.000      -1.313      -0.390
# C(Mention_country)[T.can]     1.0833      0.231      4.680      0.000       0.630       1.537
# C(Mention_country)[T.che]     0.7188      0.295      2.434      0.015       0.140       1.298
# C(Mention_country)[T.chl]     0.8138      0.164      4.966      0.000       0.493       1.135
# C(Mention_country)[T.chn]     0.3277      0.543      0.604      0.546      -0.736       1.392
# C(Mention_country)[T.civ]    -3.2577      0.080    -40.624      0.000      -3.415      -3.101
# C(Mention_country)[T.cmr]     0.3887      0.080      4.856      0.000       0.232       0.546
# C(Mention_country)[T.col]    -0.2607      0.142     -1.841      0.066      -0.538       0.017
# C(Mention_country)[T.cri]     1.3559      0.268      5.057      0.000       0.830       1.882
# C(Mention_country)[T.cub]    -0.0745      0.162     -0.460      0.646      -0.392       0.243
# C(Mention_country)[T.cyp]     0.8921      0.471      1.893      0.058      -0.032       1.816
# C(Mention_country)[T.cze]    -0.0774      0.217     -0.357      0.721      -0.503       0.348
# C(Mention_country)[T.deu]     0.5835      0.281      2.074      0.038       0.032       1.135
# C(Mention_country)[T.dji]    -0.7880      0.457     -1.725      0.085      -1.683       0.107
# C(Mention_country)[T.dnk]     0.6882      0.314      2.191      0.028       0.073       1.304
# C(Mention_country)[T.dom]    -0.5234      0.178     -2.947      0.003      -0.871      -0.175
# C(Mention_country)[T.dza]    -0.7741      0.121     -6.421      0.000      -1.010      -0.538
# C(Mention_country)[T.ecu]     0.4686      0.136      3.444      0.001       0.202       0.735
# C(Mention_country)[T.egy]    -0.0989      0.149     -0.665      0.506      -0.390       0.193
# C(Mention_country)[T.eri]    -0.2601      0.290     -0.897      0.370      -0.829       0.308
# C(Mention_country)[T.esp]     0.4041      0.229      1.766      0.077      -0.044       0.853
# C(Mention_country)[T.est]     0.5485      0.423      1.296      0.195      -0.281       1.378
# C(Mention_country)[T.eth]     0.2051      0.157      1.305      0.192      -0.103       0.513
# C(Mention_country)[T.fin]     0.7888      0.310      2.548      0.011       0.182       1.396
# C(Mention_country)[T.fra]     0.4882      0.262      1.865      0.062      -0.025       1.001
# C(Mention_country)[T.gab]     0.2700      0.402      0.671      0.502      -0.519       1.059
# C(Mention_country)[T.gbr]     1.3179      0.265      4.979      0.000       0.799       1.837
# C(Mention_country)[T.gha]     0.5022      0.039     12.822      0.000       0.425       0.579
# C(Mention_country)[T.gmb]    -0.4814      0.360     -1.336      0.182      -1.188       0.225
# C(Mention_country)[T.grc]     0.6326      0.233      2.717      0.007       0.176       1.089
# C(Mention_country)[T.gtm]    -0.0010      0.127     -0.008      0.994      -0.250       0.248
# C(Mention_country)[T.hkg]     1.3489      0.274      4.931      0.000       0.813       1.885
# C(Mention_country)[T.hnd]    -0.1563      0.173     -0.905      0.365      -0.495       0.182
# C(Mention_country)[T.hrv]    -0.1020      0.288     -0.354      0.723      -0.667       0.463
# C(Mention_country)[T.hti]    -0.6876      0.141     -4.884      0.000      -0.964      -0.412
# C(Mention_country)[T.hun]     0.0871      0.208      0.418      0.676      -0.322       0.496
# C(Mention_country)[T.idn]    -0.1929      0.311     -0.620      0.536      -0.803       0.417
# C(Mention_country)[T.ind]    -0.1244      0.521     -0.239      0.811      -1.145       0.896
# C(Mention_country)[T.irn]    -0.3551      0.186     -1.907      0.056      -0.720       0.010
# C(Mention_country)[T.irq]     0.0430      0.095      0.452      0.651      -0.143       0.229
# C(Mention_country)[T.isr]     0.9647      0.265      3.636      0.000       0.445       1.485
# C(Mention_country)[T.ita]     0.3240      0.253      1.283      0.199      -0.171       0.819
# C(Mention_country)[T.jam]     0.4461      0.322      1.386      0.166      -0.185       1.077
# C(Mention_country)[T.jor]     0.8061      0.037     21.703      0.000       0.733       0.879
# C(Mention_country)[T.jpn]     0.3857      0.321      1.202      0.229      -0.243       1.015
# C(Mention_country)[T.kaz]    -0.2223      0.140     -1.583      0.113      -0.498       0.053
# C(Mention_country)[T.ken]     0.8521      0.066     12.987      0.000       0.723       0.981
# C(Mention_country)[T.kgz]    -0.2922      0.211     -1.388      0.165      -0.705       0.121
# C(Mention_country)[T.khm]     0.0331      0.086      0.385      0.701      -0.135       0.202
# C(Mention_country)[T.kor]    -0.1112      0.218     -0.511      0.610      -0.538       0.316
# C(Mention_country)[T.kwt]    -0.5317      0.146     -3.639      0.000      -0.818      -0.245
# C(Mention_country)[T.lao]    -0.1112      0.193     -0.576      0.565      -0.490       0.267
# C(Mention_country)[T.lbn]     0.0545      0.259      0.210      0.833      -0.453       0.562
# C(Mention_country)[T.lbr]    -0.6994      0.270     -2.586      0.010      -1.230      -0.169
# C(Mention_country)[T.lby]    -0.0968      0.145     -0.667      0.505      -0.381       0.187
# C(Mention_country)[T.lka]     0.0808      0.079      1.025      0.305      -0.074       0.235
# C(Mention_country)[T.lso]     0.0769      0.339      0.227      0.821      -0.588       0.742
# C(Mention_country)[T.ltu]    -0.2718      0.311     -0.873      0.383      -0.882       0.338
# C(Mention_country)[T.lva]    -0.3252      0.358     -0.908      0.364      -1.027       0.376
# C(Mention_country)[T.mar]     0.0775      0.234      0.331      0.741      -0.382       0.537
# C(Mention_country)[T.mda]    -0.5795      0.294     -1.973      0.049      -1.155      -0.004
# C(Mention_country)[T.mdg]     0.9257      0.036     25.762      0.000       0.855       0.996
# C(Mention_country)[T.mex]     1.0234      0.256      3.995      0.000       0.521       1.526
# C(Mention_country)[T.mkd]    -0.0505      0.352     -0.144      0.886      -0.740       0.639
# C(Mention_country)[T.mli]     0.0084      0.085      0.099      0.921      -0.158       0.175
# C(Mention_country)[T.mmr]    -0.8323      0.090     -9.242      0.000      -1.009      -0.656
# C(Mention_country)[T.mng]     2.1266      0.309      6.892      0.000       1.522       2.731
# C(Mention_country)[T.moz]     0.0744      0.032      2.309      0.021       0.011       0.138
# C(Mention_country)[T.mrt]    -0.3999      0.286     -1.400      0.162      -0.960       0.160
# C(Mention_country)[T.mus]     0.1434      0.425      0.338      0.735      -0.689       0.976
# C(Mention_country)[T.mwi]     0.5242      0.089      5.917      0.000       0.351       0.698
# C(Mention_country)[T.mys]     0.1052      0.143      0.735      0.462      -0.175       0.385
# C(Mention_country)[T.nam]     1.1793      0.357      3.307      0.001       0.480       1.878
# C(Mention_country)[T.ner]    -0.8956      0.074    -12.037      0.000      -1.041      -0.750
# C(Mention_country)[T.nga]    -0.4134      0.248     -1.667      0.096      -0.900       0.073
# C(Mention_country)[T.nic]     0.3293      0.211      1.559      0.119      -0.085       0.743
# C(Mention_country)[T.nld]     0.3134      0.242      1.293      0.196      -0.162       0.788
# C(Mention_country)[T.nor]     1.8200      0.338      5.377      0.000       1.157       2.483
# C(Mention_country)[T.npl]     0.6337      0.013     50.317      0.000       0.609       0.658
# C(Mention_country)[T.nzl]     2.7346      0.318      8.610      0.000       2.112       3.357
# C(Mention_country)[T.omn]     0.5222      0.114      4.592      0.000       0.299       0.745
# C(Mention_country)[T.pak]    -0.6467      0.270     -2.392      0.017      -1.177      -0.117
# C(Mention_country)[T.pan]     0.9992      0.300      3.327      0.001       0.411       1.588
# C(Mention_country)[T.per]     0.6290      0.112      5.611      0.000       0.409       0.849
# C(Mention_country)[T.phl]    -0.0780      0.187     -0.418      0.676      -0.444       0.288
# C(Mention_country)[T.pol]    -0.0857      0.171     -0.500      0.617      -0.422       0.250
# C(Mention_country)[T.pri]     0.5810      0.322      1.805      0.071      -0.050       1.212
# C(Mention_country)[T.prt]     0.2207      0.228      0.970      0.332      -0.225       0.667
# C(Mention_country)[T.pry]    -0.1769      0.223     -0.793      0.428      -0.614       0.260
# C(Mention_country)[T.pse]     0.3001      0.278      1.081      0.280      -0.244       0.844
# C(Mention_country)[T.qat]    -0.7390      0.490     -1.507      0.132      -1.700       0.222
# C(Mention_country)[T.rou]    -0.3761      0.137     -2.751      0.006      -0.644      -0.108
# C(Mention_country)[T.rus]     0.1442      0.277      0.520      0.603      -0.399       0.688
# C(Mention_country)[T.rwa]    -0.2581      0.133     -1.947      0.051      -0.518       0.002
# C(Mention_country)[T.sau]    -0.5215      0.180     -2.897      0.004      -0.874      -0.169
# C(Mention_country)[T.sen]     0.2977      0.122      2.443      0.015       0.059       0.537
# C(Mention_country)[T.sgp]     0.6368      0.317      2.009      0.045       0.015       1.258
# C(Mention_country)[T.sle]    -0.2004      0.195     -1.025      0.305      -0.583       0.183
# C(Mention_country)[T.slv]    -0.5700      0.213     -2.671      0.008      -0.988      -0.152
# C(Mention_country)[T.som]    -0.3578      0.121     -2.960      0.003      -0.595      -0.121
# C(Mention_country)[T.svk]     0.0592      0.268      0.221      0.825      -0.467       0.585
# C(Mention_country)[T.svn]     0.1177      0.388      0.303      0.762      -0.643       0.878
# C(Mention_country)[T.swe]     1.0539      0.271      3.892      0.000       0.523       1.585
# C(Mention_country)[T.syr]    -0.3395      0.076     -4.442      0.000      -0.489      -0.190
# C(Mention_country)[T.tcd]    -0.6361      0.123     -5.190      0.000      -0.876      -0.396
# C(Mention_country)[T.tgo]    -1.0000      0.195     -5.135      0.000      -1.382      -0.618
# C(Mention_country)[T.tha]     0.3309      0.176      1.883      0.060      -0.013       0.675
# C(Mention_country)[T.tjk]    -0.9970      0.169     -5.905      0.000      -1.328      -0.666
# C(Mention_country)[T.tkm]    -1.5478      0.232     -6.659      0.000      -2.003      -1.092
# C(Mention_country)[T.tto]    -0.8674      0.423     -2.051      0.040      -1.696      -0.038
# C(Mention_country)[T.tun]     0.0492      0.141      0.350      0.726      -0.226       0.325
# C(Mention_country)[T.tur]     0.5209      0.207      2.522      0.012       0.116       0.926
# C(Mention_country)[T.tza]     0.7194      0.072     10.035      0.000       0.579       0.860
# C(Mention_country)[T.uga]     0.6810      0.023     29.222      0.000       0.635       0.727
# C(Mention_country)[T.ukr]    -0.5739      0.127     -4.508      0.000      -0.823      -0.324
# C(Mention_country)[T.ury]     0.3040      0.302      1.006      0.314      -0.288       0.896
# C(Mention_country)[T.usa]     1.4309      0.413      3.466      0.001       0.622       2.240
# C(Mention_country)[T.uzb]    -1.1729      0.040    -29.168      0.000      -1.252      -1.094
# C(Mention_country)[T.ven]    -0.2707      0.146     -1.855      0.064      -0.557       0.015
# C(Mention_country)[T.vnm]     0.3913      0.171      2.286      0.022       0.056       0.727
# C(Mention_country)[T.yem]    -0.2139      0.065     -3.292      0.001      -0.341      -0.087
# C(Mention_country)[T.zaf]     0.7688      0.167      4.591      0.000       0.441       1.097
# C(Mention_country)[T.zmb]     0.1516      0.109      1.391      0.164      -0.062       0.365
# C(Mention_country)[T.zwe]     0.7502      0.096      7.841      0.000       0.563       0.938
# C(year)[T.2003.0]            -0.3089      0.093     -3.327      0.001      -0.491      -0.127
# C(year)[T.2004.0]            -0.6209      0.184     -3.383      0.001      -0.981      -0.261
# C(year)[T.2005.0]            -0.8926      0.281     -3.181      0.001      -1.442      -0.343
# C(year)[T.2006.0]            -1.1045      0.376     -2.940      0.003      -1.841      -0.368
# C(year)[T.2007.0]            -1.3672      0.468     -2.923      0.003      -2.284      -0.451
# C(year)[T.2008.0]            -1.6408      0.563     -2.912      0.004      -2.745      -0.536
# C(year)[T.2009.0]            -1.8230      0.657     -2.773      0.006      -3.111      -0.535
# treated_GC                   -0.0095      0.262     -0.036      0.971      -0.523       0.504
# time                          0.3197      0.092      3.462      0.001       0.139       0.501
# treated_GC:time              -0.0103      0.018     -0.572      0.567      -0.046       0.025
# treated_GO                   -0.0496      0.089     -0.559      0.576      -0.224       0.124
# treated_GO:time              -0.0009      0.016     -0.053      0.957      -0.032       0.030
# treated_CW                   -0.6502      0.123     -5.275      0.000      -0.892      -0.409
# treated_CW:time               0.0143      0.016      0.893      0.372      -0.017       0.046
# log_population                0.6089      0.134      4.536      0.000       0.346       0.872
# log_gdp                       0.1975      0.047      4.208      0.000       0.106       0.289
# ==============================================================================
# Omnibus:                      256.878   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2988.759
# Skew:                          -0.669   Prob(JB):                         0.00
# Kurtosis:                      10.749   Cond. No.                     1.24e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 2.77e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 160, but rank is 12
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ### Notice: Pre-parallel trend test is significant at the Civil War level.

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='hue')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foreign attention')
# Out:
# Text(0, 0.5, 'log Foreign attention')

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * post + treated_GO * post +treated_CW * post+log_population +log_gdp+ C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     63.26
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           7.92e-63
# Time:                        11:28:15   Log-Likelihood:                 805.63
# No. Observations:                2610   AIC:                            -1277.
# Df Residuals:                    2443   BIC:                            -297.5
# Df Model:                         166
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -5.7348      2.417     -2.373      0.018     -10.472      -0.998
# C(Mention_country)[T.ago]    -1.0770      0.092    -11.736      0.000      -1.257      -0.897
# C(Mention_country)[T.alb]    -0.3421      0.328     -1.042      0.297      -0.985       0.301
# C(Mention_country)[T.are]     0.1406      0.288      0.488      0.626      -0.424       0.706
# C(Mention_country)[T.arg]     0.1390      0.158      0.878      0.380      -0.171       0.449
# C(Mention_country)[T.arm]    -0.6267      0.324     -1.932      0.053      -1.263       0.009
# C(Mention_country)[T.aus]     1.2402      0.229      5.423      0.000       0.792       1.688
# C(Mention_country)[T.aut]     0.1621      0.274      0.591      0.554      -0.375       0.699
# C(Mention_country)[T.aze]    -0.8525      0.186     -4.581      0.000      -1.217      -0.488
# C(Mention_country)[T.bdi]    -1.5302      0.169     -9.038      0.000      -1.862      -1.198
# C(Mention_country)[T.bel]    -0.0932      0.253     -0.369      0.712      -0.589       0.402
# C(Mention_country)[T.ben]    -0.4460      0.157     -2.849      0.004      -0.753      -0.139
# C(Mention_country)[T.bfa]    -0.2251      0.080     -2.817      0.005      -0.382      -0.069
# C(Mention_country)[T.bgd]    -0.2895      0.235     -1.233      0.218      -0.750       0.171
# C(Mention_country)[T.bgr]    -0.2043      0.222     -0.920      0.358      -0.640       0.231
# C(Mention_country)[T.bhr]    -0.8680      0.249     -3.483      0.000      -1.357      -0.379
# C(Mention_country)[T.bih]    -0.0746      0.297     -0.251      0.802      -0.656       0.507
# C(Mention_country)[T.blr]    -1.1587      0.188     -6.175      0.000      -1.527      -0.791
# C(Mention_country)[T.bol]     0.4416      0.157      2.811      0.005       0.134       0.750
# C(Mention_country)[T.bra]     0.2052      0.312      0.657      0.511      -0.407       0.817
# C(Mention_country)[T.bwa]     0.4220      0.377      1.119      0.263      -0.317       1.161
# C(Mention_country)[T.caf]    -1.1427      0.257     -4.445      0.000      -1.647      -0.639
# C(Mention_country)[T.can]     0.9675      0.228      4.251      0.000       0.521       1.414
# C(Mention_country)[T.che]     0.5787      0.298      1.944      0.052      -0.005       1.162
# C(Mention_country)[T.chl]     0.6945      0.170      4.092      0.000       0.362       1.027
# C(Mention_country)[T.chn]     0.4693      0.556      0.845      0.398      -0.620       1.558
# C(Mention_country)[T.civ]    -3.5156      0.076    -46.034      0.000      -3.665      -3.366
# C(Mention_country)[T.cmr]     0.0885      0.073      1.218      0.223      -0.054       0.231
# C(Mention_country)[T.col]    -0.1625      0.142     -1.147      0.251      -0.440       0.115
# C(Mention_country)[T.cri]     0.8378      0.283      2.960      0.003       0.283       1.393
# C(Mention_country)[T.cub]    -0.2742      0.175     -1.566      0.117      -0.617       0.069
# C(Mention_country)[T.cyp]     0.6724      0.483      1.394      0.163      -0.273       1.618
# C(Mention_country)[T.cze]    -0.2507      0.222     -1.129      0.259      -0.686       0.184
# C(Mention_country)[T.deu]     0.6493      0.275      2.360      0.018       0.110       1.188
# C(Mention_country)[T.dji]    -1.1628      0.480     -2.422      0.015      -2.104      -0.222
# C(Mention_country)[T.dnk]     0.5279      0.317      1.664      0.096      -0.094       1.150
# C(Mention_country)[T.dom]    -0.7670      0.187     -4.109      0.000      -1.133      -0.401
# C(Mention_country)[T.dza]    -0.8341      0.116     -7.200      0.000      -1.061      -0.607
# C(Mention_country)[T.ecu]     0.2843      0.141      2.013      0.044       0.008       0.561
# C(Mention_country)[T.egy]    -0.1430      0.151     -0.949      0.343      -0.438       0.152
# C(Mention_country)[T.eri]    -0.8081      0.311     -2.599      0.009      -1.417      -0.199
# C(Mention_country)[T.esp]     0.5026      0.219      2.299      0.022       0.074       0.931
# C(Mention_country)[T.est]     0.1938      0.450      0.430      0.667      -0.689       1.076
# C(Mention_country)[T.eth]     0.0892      0.159      0.562      0.574      -0.222       0.400
# C(Mention_country)[T.fin]     0.6240      0.314      1.989      0.047       0.009       1.239
# C(Mention_country)[T.fra]     0.5146      0.255      2.021      0.043       0.015       1.014
# C(Mention_country)[T.gab]    -0.1671      0.406     -0.412      0.680      -0.962       0.628
# C(Mention_country)[T.gbr]     1.3465      0.256      5.251      0.000       0.844       1.849
# C(Mention_country)[T.gha]     0.3918      0.050      7.791      0.000       0.293       0.490
# C(Mention_country)[T.gmb]    -0.9414      0.374     -2.516      0.012      -1.675      -0.208
# C(Mention_country)[T.grc]     0.6366      0.227      2.802      0.005       0.191       1.082
# C(Mention_country)[T.gtm]    -0.2310      0.131     -1.757      0.079      -0.489       0.027
# C(Mention_country)[T.hkg]     1.2353      0.280      4.419      0.000       0.687       1.783
# C(Mention_country)[T.hnd]    -0.5559      0.180     -3.083      0.002      -0.909      -0.202
# C(Mention_country)[T.hrv]    -0.1858      0.303     -0.612      0.540      -0.781       0.409
# C(Mention_country)[T.hti]    -0.4201      0.153     -2.738      0.006      -0.721      -0.119
# C(Mention_country)[T.hun]    -0.0419      0.214     -0.196      0.845      -0.462       0.378
# C(Mention_country)[T.idn]    -0.2312      0.316     -0.731      0.465      -0.851       0.389
# C(Mention_country)[T.ind]    -0.0319      0.531     -0.060      0.952      -1.073       1.009
# C(Mention_country)[T.irn]    -0.1143      0.185     -0.617      0.537      -0.477       0.248
# C(Mention_country)[T.irq]    -0.1038      0.106     -0.980      0.327      -0.311       0.104
# C(Mention_country)[T.isr]     0.7651      0.268      2.859      0.004       0.241       1.290
# C(Mention_country)[T.ita]     0.4240      0.242      1.749      0.080      -0.051       0.899
# C(Mention_country)[T.jam]     0.0497      0.341      0.146      0.884      -0.618       0.718
# C(Mention_country)[T.jor]     0.7594      0.031     24.115      0.000       0.698       0.821
# C(Mention_country)[T.jpn]     0.4486      0.314      1.426      0.154      -0.168       1.065
# C(Mention_country)[T.kaz]    -0.3672      0.153     -2.407      0.016      -0.666      -0.068
# C(Mention_country)[T.ken]     0.6628      0.069      9.598      0.000       0.527       0.798
# C(Mention_country)[T.kgz]    -0.3840      0.230     -1.673      0.094      -0.834       0.066
# C(Mention_country)[T.khm]     0.0192      0.100      0.192      0.848      -0.177       0.215
# C(Mention_country)[T.kor]     0.0063      0.215      0.029      0.977      -0.416       0.429
# C(Mention_country)[T.kwt]    -0.5411      0.134     -4.024      0.000      -0.805      -0.278
# C(Mention_country)[T.lao]    -0.2437      0.213     -1.145      0.252      -0.661       0.173
# C(Mention_country)[T.lbn]    -0.0755      0.264     -0.286      0.775      -0.594       0.443
# C(Mention_country)[T.lbr]    -0.6850      0.278     -2.463      0.014      -1.230      -0.140
# C(Mention_country)[T.lby]    -0.1285      0.162     -0.795      0.427      -0.445       0.188
# C(Mention_country)[T.lka]    -0.1472      0.094     -1.567      0.117      -0.331       0.037
# C(Mention_country)[T.lso]    -0.2751      0.368     -0.748      0.454      -0.996       0.445
# C(Mention_country)[T.ltu]    -0.4401      0.341     -1.291      0.197      -1.108       0.228
# C(Mention_country)[T.lva]    -0.5241      0.389     -1.348      0.178      -1.286       0.238
# C(Mention_country)[T.mar]     0.1156      0.222      0.521      0.603      -0.319       0.551
# C(Mention_country)[T.mda]    -0.6780      0.327     -2.075      0.038      -1.319      -0.037
# C(Mention_country)[T.mdg]     0.5388      0.038     14.044      0.000       0.464       0.614
# C(Mention_country)[T.mex]     0.8974      0.253      3.545      0.000       0.401       1.394
# C(Mention_country)[T.mkd]    -0.1961      0.377     -0.519      0.603      -0.936       0.544
# C(Mention_country)[T.mli]    -0.2787      0.086     -3.247      0.001      -0.447      -0.110
# C(Mention_country)[T.mmr]    -0.7441      0.081     -9.182      0.000      -0.903      -0.585
# C(Mention_country)[T.mng]     1.8848      0.331      5.696      0.000       1.236       2.533
# C(Mention_country)[T.moz]    -0.0595      0.029     -2.047      0.041      -0.117      -0.003
# C(Mention_country)[T.mrt]    -0.8296      0.296     -2.801      0.005      -1.410      -0.249
# C(Mention_country)[T.mus]    -0.2012      0.451     -0.446      0.655      -1.085       0.682
# C(Mention_country)[T.mwi]     0.3927      0.092      4.267      0.000       0.212       0.573
# C(Mention_country)[T.mys]     0.0892      0.144      0.621      0.535      -0.192       0.371
# C(Mention_country)[T.nam]     0.7465      0.373      2.002      0.045       0.016       1.478
# C(Mention_country)[T.ner]    -1.0970      0.074    -14.881      0.000      -1.241      -0.952
# C(Mention_country)[T.nga]    -0.2958      0.257     -1.149      0.251      -0.800       0.209
# C(Mention_country)[T.nic]    -0.0169      0.226     -0.075      0.940      -0.459       0.426
# C(Mention_country)[T.nld]     0.3111      0.237      1.313      0.189      -0.153       0.776
# C(Mention_country)[T.nor]     1.5019      0.341      4.410      0.000       0.834       2.169
# C(Mention_country)[T.npl]     0.5154      0.017     29.704      0.000       0.481       0.549
# C(Mention_country)[T.nzl]     2.3998      0.325      7.376      0.000       1.762       3.037
# C(Mention_country)[T.omn]     0.4203      0.109      3.842      0.000       0.206       0.635
# C(Mention_country)[T.pak]    -0.5221      0.273     -1.911      0.056      -1.058       0.013
# C(Mention_country)[T.pan]     0.5692      0.314      1.812      0.070      -0.046       1.185
# C(Mention_country)[T.per]     0.4495      0.116      3.870      0.000       0.222       0.677
# C(Mention_country)[T.phl]    -0.2374      0.189     -1.255      0.210      -0.608       0.134
# C(Mention_country)[T.pol]    -0.1624      0.167     -0.973      0.331      -0.490       0.165
# C(Mention_country)[T.pri]     0.4293      0.340      1.262      0.207      -0.237       1.096
# C(Mention_country)[T.prt]     0.2672      0.228      1.171      0.241      -0.180       0.714
# C(Mention_country)[T.pry]    -0.4341      0.241     -1.805      0.071      -0.906       0.037
# C(Mention_country)[T.pse]     0.1280      0.289      0.444      0.657      -0.438       0.694
# C(Mention_country)[T.qat]    -0.7755      0.457     -1.696      0.090      -1.671       0.120
# C(Mention_country)[T.rou]    -0.3941      0.144     -2.729      0.006      -0.677      -0.111
# C(Mention_country)[T.rus]     0.0623      0.277      0.225      0.822      -0.481       0.605
# C(Mention_country)[T.rwa]    -0.1941      0.142     -1.365      0.172      -0.473       0.085
# C(Mention_country)[T.sau]    -0.3322      0.182     -1.830      0.067      -0.688       0.024
# C(Mention_country)[T.sen]    -0.0090      0.122     -0.074      0.941      -0.248       0.230
# C(Mention_country)[T.sgp]     0.4789      0.321      1.491      0.136      -0.150       1.108
# C(Mention_country)[T.sle]    -0.3031      0.208     -1.458      0.145      -0.711       0.104
# C(Mention_country)[T.slv]    -0.8481      0.230     -3.681      0.000      -1.300      -0.397
# C(Mention_country)[T.som]    -0.7334      0.127     -5.766      0.000      -0.983      -0.484
# C(Mention_country)[T.svk]    -0.0822      0.281     -0.293      0.770      -0.633       0.469
# C(Mention_country)[T.svn]    -0.0923      0.403     -0.229      0.819      -0.883       0.698
# C(Mention_country)[T.swe]     0.8829      0.270      3.269      0.001       0.353       1.412
# C(Mention_country)[T.syr]    -0.1420      0.042     -3.388      0.001      -0.224      -0.060
# C(Mention_country)[T.tcd]    -0.9870      0.122     -8.061      0.000      -1.227      -0.747
# C(Mention_country)[T.tgo]    -1.2639      0.205     -6.171      0.000      -1.665      -0.862
# C(Mention_country)[T.tha]     0.1151      0.173      0.665      0.506      -0.224       0.454
# C(Mention_country)[T.tjk]    -1.0297      0.183     -5.628      0.000      -1.388      -0.671
# C(Mention_country)[T.tkm]    -1.6863      0.251     -6.714      0.000      -2.179      -1.194
# C(Mention_country)[T.tto]    -1.1006      0.442     -2.488      0.013      -1.967      -0.234
# C(Mention_country)[T.tun]     0.0261      0.147      0.177      0.859      -0.262       0.314
# C(Mention_country)[T.tur]     0.4986      0.206      2.421      0.015       0.095       0.902
# C(Mention_country)[T.tza]     0.5141      0.072      7.116      0.000       0.372       0.656
# C(Mention_country)[T.uga]     0.5371      0.025     21.582      0.000       0.488       0.586
# C(Mention_country)[T.ukr]    -0.5490      0.113     -4.848      0.000      -0.771      -0.327
# C(Mention_country)[T.ury]     0.0460      0.328      0.140      0.888      -0.597       0.689
# C(Mention_country)[T.usa]     1.6087      0.419      3.840      0.000       0.788       2.430
# C(Mention_country)[T.uzb]    -1.4942      0.054    -27.741      0.000      -1.600      -1.389
# C(Mention_country)[T.ven]    -0.5722      0.154     -3.714      0.000      -0.874      -0.270
# C(Mention_country)[T.vnm]     0.2848      0.171      1.663      0.096      -0.051       0.620
# C(Mention_country)[T.yem]    -0.5373      0.064     -8.430      0.000      -0.662      -0.412
# C(Mention_country)[T.zaf]     0.6959      0.161      4.324      0.000       0.380       1.011
# C(Mention_country)[T.zmb]    -0.0358      0.109     -0.328      0.743      -0.250       0.178
# C(Mention_country)[T.zwe]     0.3868      0.112      3.455      0.001       0.167       0.606
# C(year)[T.2003.0]             0.0166      0.019      0.890      0.374      -0.020       0.053
# C(year)[T.2004.0]             0.0312      0.022      1.388      0.165      -0.013       0.075
# C(year)[T.2005.0]             0.0852      0.027      3.137      0.002       0.032       0.138
# C(year)[T.2006.0]             0.1988      0.031      6.374      0.000       0.138       0.260
# C(year)[T.2007.0]             0.2633      0.039      6.767      0.000       0.187       0.340
# C(year)[T.2008.0]             0.3167      0.045      7.071      0.000       0.229       0.404
# C(year)[T.2009.0]             0.4525      0.043     10.566      0.000       0.369       0.536
# C(year)[T.2010.0]             0.5143      0.048     10.692      0.000       0.420       0.609
# C(year)[T.2011.0]            -0.1609      0.011    -14.615      0.000      -0.183      -0.139
# C(year)[T.2012.0]            -0.1091      0.012     -9.322      0.000      -0.132      -0.086
# C(year)[T.2013.0]            -0.0059      0.011     -0.550      0.582      -0.027       0.015
# C(year)[T.2014.0]             0.0364      0.011      3.337      0.001       0.015       0.058
# C(year)[T.2015.0]             0.0986      0.010      9.471      0.000       0.078       0.119
# C(year)[T.2016.0]             0.1414      0.011     12.638      0.000       0.119       0.163
# C(year)[T.2017.0]             0.1746      0.011     15.420      0.000       0.152       0.197
# C(year)[T.2018.0]             0.2337      0.014     16.845      0.000       0.207       0.261
# C(year)[T.2019.0]             0.3269      0.017     18.850      0.000       0.293       0.361
# treated_GC                   -0.1138      0.250     -0.455      0.649      -0.604       0.376
# post                          0.7356      0.052     14.259      0.000       0.634       0.837
# treated_GC:post              -0.1258      0.057     -2.194      0.028      -0.238      -0.013
# treated_GO                   -0.1169      0.066     -1.764      0.078      -0.247       0.013
# treated_GO:post               0.1462      0.071      2.072      0.038       0.008       0.285
# treated_CW                   -0.8079      0.125     -6.463      0.000      -1.053      -0.563
# treated_CW:post               0.5770      0.206      2.798      0.005       0.173       0.981
# log_population                0.5514      0.140      3.952      0.000       0.278       0.825
# log_gdp                       0.1552      0.049      3.195      0.001       0.060       0.250
# ==============================================================================
# Omnibus:                      223.560   Durbin-Watson:                   0.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1109.356
# Skew:                          -0.244   Prob(JB):                    1.28e-241
# Kurtosis:                       6.156   Cond. No.                     7.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.41e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 170, but rank is 22
#   warnings.warn('covariance of constraints does not have full '

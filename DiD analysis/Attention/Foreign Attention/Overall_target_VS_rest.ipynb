# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
df = pd.read_csv(r"C:\Users\Yasaman\Downloads\Attention-fractional counting.csv")
df.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'affiliation_country': 'Aff_country'}, inplace=True)
df=df[(df['Mention_country'].isin(possible_iso))&(df['Aff_country'].isin(possible_iso))]
df = df[df['year'].isin(np.arange(2002, 2020))]
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df=df[~df['subjarea'].isin(physical_sciences)]
df=df[df['Mention_country']!=df['Aff_country']]
df=df.groupby(['year', 'Mention_country'])['count'].sum().reset_index()


data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))


# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# 0

# %%
from linearmodels.panel import PanelOLS

panel_data = df_complete.set_index(['Mention_country', 'year'])

model = PanelOLS.from_formula(
    'log_count ~ treated : post  +log_gdp+log_population+ EntityEffects + TimeEffects',
    data=panel_data
)
results = model.fit(cov_type='clustered', cluster_entity=True)
print(results)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              log_count   R-squared:                        0.0655
# Estimator:                   PanelOLS   R-squared (Between):              0.5248
# No. Observations:                2610   R-squared (Within):               0.2767
# Date:                Tue, Mar 18 2025   R-squared (Overall):              0.5227
# Time:                        14:26:03   Log-likelihood                    745.59
# Cov. Estimator:             Clustered
#                                         F-statistic:                      57.159
# Entities:                         145   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(3,2445)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             6.4774
#                                         P-value                           0.0002
# Time periods:                      18   Distribution:                  F(3,2445)
# Avg Obs:                       145.00
# Min Obs:                       145.00
# Max Obs:                       145.00
#
#                                Parameter Estimates
# ==================================================================================
#                 Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------
# log_gdp            0.1215     0.0697     1.7437     0.0813     -0.0151      0.2582
# log_population     0.4588     0.1584     2.8962     0.0038      0.1482      0.7695
# treated:post       0.1355     0.1055     1.2851     0.1989     -0.0713      0.3424
# ==================================================================================
#
# F-test for Poolability: 226.81
# P-value: 0.0000
# Distribution: F(161,2445)
#
# Included effects: Entity, Time

# %%
df_p=df_complete[df_complete['year']<2011].reset_index(drop=True)
df_p['time']=df_p['year']-2011

# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ time+treated * time +log_gdp+log_population+ C(Mention_country)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     120.6
# Date:                Tue, 18 Mar 2025   Prob (F-statistic):           6.09e-45
# Time:                        08:38:39   Log-Likelihood:                 603.51
# No. Observations:                1305   AIC:                            -909.0
# Df Residuals:                    1156   BIC:                            -138.1
# Df Model:                         148
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -5.3356      2.314     -2.305      0.021      -9.872      -0.799
# C(Mention_country)[T.ago]    -0.8461      0.089     -9.531      0.000      -1.020      -0.672
# C(Mention_country)[T.alb]    -0.1927      0.296     -0.650      0.516      -0.774       0.388
# C(Mention_country)[T.are]     0.3837      0.291      1.320      0.187      -0.186       0.953
# C(Mention_country)[T.arg]     0.4355      0.146      2.983      0.003       0.149       0.722
# C(Mention_country)[T.arm]    -0.6163      0.290     -2.126      0.034      -1.185      -0.048
# C(Mention_country)[T.aus]     1.5622      0.211      7.411      0.000       1.149       1.975
# C(Mention_country)[T.aut]     0.3751      0.256      1.464      0.143      -0.127       0.877
# C(Mention_country)[T.aze]    -0.9035      0.165     -5.465      0.000      -1.228      -0.580
# C(Mention_country)[T.bdi]    -1.6271      0.162    -10.024      0.000      -1.945      -1.309
# C(Mention_country)[T.bel]     0.1331      0.238      0.560      0.576      -0.333       0.599
# C(Mention_country)[T.ben]    -0.2204      0.151     -1.463      0.143      -0.516       0.075
# C(Mention_country)[T.bfa]     0.0017      0.076      0.023      0.982      -0.147       0.150
# C(Mention_country)[T.bgd]    -0.2166      0.235     -0.920      0.358      -0.678       0.245
# C(Mention_country)[T.bgr]     0.0637      0.194      0.328      0.743      -0.316       0.444
# C(Mention_country)[T.bhr]    -0.6299      0.311     -2.028      0.043      -1.239      -0.021
# C(Mention_country)[T.bih]     0.0967      0.260      0.372      0.710      -0.413       0.607
# C(Mention_country)[T.blr]    -0.9448      0.163     -5.797      0.000      -1.264      -0.625
# C(Mention_country)[T.bol]     0.7824      0.140      5.582      0.000       0.508       1.057
# C(Mention_country)[T.bra]     0.4065      0.305      1.331      0.183      -0.192       1.005
# C(Mention_country)[T.bwa]     0.7314      0.358      2.043      0.041       0.030       1.433
# C(Mention_country)[T.caf]    -1.0095      0.235     -4.292      0.000      -1.470      -0.549
# C(Mention_country)[T.can]     1.2884      0.217      5.931      0.000       0.863       1.714
# C(Mention_country)[T.che]     0.8680      0.277      3.129      0.002       0.324       1.412
# C(Mention_country)[T.chl]     0.9064      0.153      5.917      0.000       0.606       1.207
# C(Mention_country)[T.chn]     0.6067      0.542      1.120      0.263      -0.455       1.668
# C(Mention_country)[T.civ]    -3.1894      0.073    -43.472      0.000      -3.333      -3.046
# C(Mention_country)[T.cmr]     0.3884      0.074      5.277      0.000       0.244       0.533
# C(Mention_country)[T.col]    -0.1332      0.136     -0.978      0.328      -0.400       0.134
# C(Mention_country)[T.cri]     1.3281      0.260      5.103      0.000       0.818       1.838
# C(Mention_country)[T.cub]    -0.0388      0.153     -0.253      0.801      -0.340       0.262
# C(Mention_country)[T.cyp]     0.9021      0.459      1.967      0.049       0.003       1.801
# C(Mention_country)[T.cze]     0.0226      0.204      0.111      0.912      -0.377       0.422
# C(Mention_country)[T.deu]     0.8495      0.271      3.135      0.002       0.318       1.381
# C(Mention_country)[T.dji]    -0.9489      0.454     -2.091      0.037      -1.838      -0.059
# C(Mention_country)[T.dnk]     0.8088      0.297      2.724      0.006       0.227       1.391
# C(Mention_country)[T.dom]    -0.5009      0.170     -2.953      0.003      -0.833      -0.168
# C(Mention_country)[T.dza]    -0.6801      0.114     -5.981      0.000      -0.903      -0.457
# C(Mention_country)[T.ecu]     0.5070      0.128      3.971      0.000       0.257       0.757
# C(Mention_country)[T.egy]     0.1733      0.288      0.602      0.547      -0.391       0.737
# C(Mention_country)[T.eri]    -0.4398      0.289     -1.522      0.128      -1.006       0.127
# C(Mention_country)[T.esp]     0.6223      0.216      2.877      0.004       0.198       1.046
# C(Mention_country)[T.est]     0.5198      0.415      1.253      0.210      -0.293       1.333
# C(Mention_country)[T.eth]     0.2020      0.156      1.296      0.195      -0.103       0.508
# C(Mention_country)[T.fin]     0.8945      0.293      3.049      0.002       0.320       1.469
# C(Mention_country)[T.fra]     0.7356      0.250      2.938      0.003       0.245       1.226
# C(Mention_country)[T.gab]     0.2019      0.393      0.513      0.608      -0.569       0.973
# C(Mention_country)[T.gbr]     1.5732      0.252      6.242      0.000       1.079       2.067
# C(Mention_country)[T.gha]     0.4896      0.037     13.323      0.000       0.418       0.562
# C(Mention_country)[T.gmb]    -0.6469      0.358     -1.807      0.071      -1.349       0.055
# C(Mention_country)[T.grc]     0.7653      0.217      3.523      0.000       0.340       1.191
# C(Mention_country)[T.gtm]     0.0208      0.120      0.174      0.862      -0.214       0.256
# C(Mention_country)[T.hkg]     1.4784      0.258      5.726      0.000       0.972       1.984
# C(Mention_country)[T.hnd]    -0.1814      0.168     -1.079      0.281      -0.511       0.148
# C(Mention_country)[T.hrv]    -0.0540      0.278     -0.195      0.846      -0.598       0.490
# C(Mention_country)[T.hti]    -0.6418      0.138     -4.639      0.000      -0.913      -0.371
# C(Mention_country)[T.hun]     0.1763      0.196      0.899      0.368      -0.208       0.561
# C(Mention_country)[T.idn]    -0.0380      0.311     -0.122      0.903      -0.647       0.571
# C(Mention_country)[T.ind]     0.0993      0.519      0.191      0.848      -0.918       1.116
# C(Mention_country)[T.irn]    -0.1774      0.183     -0.969      0.333      -0.536       0.182
# C(Mention_country)[T.irq]     0.1246      0.091      1.376      0.169      -0.053       0.302
# C(Mention_country)[T.isr]     1.0667      0.250      4.258      0.000       0.576       1.558
# C(Mention_country)[T.ita]     0.5673      0.241      2.357      0.018       0.096       1.039
# C(Mention_country)[T.jam]     0.4009      0.315      1.272      0.203      -0.217       1.018
# C(Mention_country)[T.jor]     1.0362      0.064     16.157      0.000       0.911       1.162
# C(Mention_country)[T.jpn]     0.6709      0.313      2.145      0.032       0.058       1.284
# C(Mention_country)[T.kaz]    -0.1856      0.133     -1.398      0.162      -0.446       0.075
# C(Mention_country)[T.ken]     0.8466      0.065     13.093      0.000       0.720       0.973
# C(Mention_country)[T.kgz]    -0.3534      0.210     -1.684      0.092      -0.765       0.058
# C(Mention_country)[T.khm]     0.0130      0.085      0.153      0.878      -0.153       0.180
# C(Mention_country)[T.kor]     0.1113      0.207      0.538      0.591      -0.295       0.517
# C(Mention_country)[T.kwt]    -0.2103      0.203     -1.035      0.301      -0.609       0.188
# C(Mention_country)[T.lao]    -0.1756      0.192     -0.912      0.362      -0.553       0.202
# C(Mention_country)[T.lbn]     0.0798      0.251      0.318      0.750      -0.412       0.572
# C(Mention_country)[T.lbr]    -0.8303      0.269     -3.092      0.002      -1.357      -0.304
# C(Mention_country)[T.lby]    -0.5528      0.069     -8.039      0.000      -0.688      -0.418
# C(Mention_country)[T.lka]     0.0924      0.075      1.238      0.216      -0.054       0.239
# C(Mention_country)[T.lso]    -0.0629      0.338     -0.186      0.853      -0.726       0.600
# C(Mention_country)[T.ltu]    -0.2452      0.303     -0.808      0.419      -0.840       0.349
# C(Mention_country)[T.lva]    -0.3156      0.350     -0.901      0.368      -1.002       0.371
# C(Mention_country)[T.mar]     0.3943      0.158      2.492      0.013       0.084       0.704
# C(Mention_country)[T.mda]    -0.6666      0.292     -2.281      0.023      -1.240      -0.094
# C(Mention_country)[T.mdg]     0.8631      0.035     24.874      0.000       0.795       0.931
# C(Mention_country)[T.mex]     1.2254      0.251      4.883      0.000       0.734       1.717
# C(Mention_country)[T.mkd]    -0.0956      0.347     -0.276      0.783      -0.775       0.584
# C(Mention_country)[T.mli]    -0.0465      0.083     -0.561      0.575      -0.209       0.116
# C(Mention_country)[T.mmr]    -0.8377      0.089     -9.451      0.000      -1.011      -0.664
# C(Mention_country)[T.mng]     2.0262      0.306      6.613      0.000       1.426       2.627
# C(Mention_country)[T.moz]     0.0687      0.029      2.343      0.019       0.011       0.126
# C(Mention_country)[T.mrt]    -0.5287      0.282     -1.872      0.061      -1.082       0.025
# C(Mention_country)[T.mus]     0.0714      0.418      0.171      0.864      -0.747       0.890
# C(Mention_country)[T.mwi]     0.4600      0.087      5.280      0.000       0.289       0.631
# C(Mention_country)[T.mys]     0.2142      0.134      1.604      0.109      -0.047       0.476
# C(Mention_country)[T.nam]     1.0895      0.351      3.107      0.002       0.402       1.777
# C(Mention_country)[T.ner]    -0.9701      0.073    -13.212      0.000      -1.114      -0.826
# C(Mention_country)[T.nga]    -0.2811      0.248     -1.134      0.257      -0.767       0.205
# C(Mention_country)[T.nic]     0.2708      0.208      1.303      0.193      -0.136       0.678
# C(Mention_country)[T.nld]     0.4996      0.225      2.221      0.026       0.059       0.940
# C(Mention_country)[T.nor]     1.9370      0.321      6.042      0.000       1.309       2.565
# C(Mention_country)[T.npl]     0.5989      0.011     55.458      0.000       0.578       0.620
# C(Mention_country)[T.nzl]     2.8025      0.303      9.235      0.000       2.208       3.397
# C(Mention_country)[T.omn]     0.7928      0.181      4.386      0.000       0.439       1.147
# C(Mention_country)[T.pak]    -0.5115      0.269     -1.898      0.058      -1.040       0.017
# C(Mention_country)[T.pan]     0.9838      0.292      3.367      0.001       0.411       1.556
# C(Mention_country)[T.per]     0.6953      0.105      6.605      0.000       0.489       0.902
# C(Mention_country)[T.phl]     0.0134      0.186      0.072      0.942      -0.350       0.377
# C(Mention_country)[T.pol]     0.0651      0.162      0.402      0.688      -0.253       0.383
# C(Mention_country)[T.pri]     0.6474      0.309      2.095      0.036       0.042       1.253
# C(Mention_country)[T.prt]     0.3620      0.213      1.701      0.089      -0.055       0.779
# C(Mention_country)[T.pry]    -0.2026      0.218     -0.928      0.353      -0.631       0.225
# C(Mention_country)[T.pse]     0.2362      0.273      0.864      0.387      -0.299       0.772
# C(Mention_country)[T.qat]    -0.6946      0.470     -1.478      0.139      -1.615       0.226
# C(Mention_country)[T.rou]    -0.2578      0.128     -2.020      0.043      -0.508      -0.008
# C(Mention_country)[T.rus]     0.3198      0.274      1.166      0.244      -0.218       0.857
# C(Mention_country)[T.rwa]    -0.2898      0.132     -2.195      0.028      -0.549      -0.031
# C(Mention_country)[T.sau]    -0.3576      0.168     -2.131      0.033      -0.686      -0.029
# C(Mention_country)[T.sen]     0.2679      0.117      2.282      0.022       0.038       0.498
# C(Mention_country)[T.sgp]     0.7305      0.302      2.422      0.015       0.139       1.322
# C(Mention_country)[T.sle]    -0.3320      0.195     -1.702      0.089      -0.714       0.050
# C(Mention_country)[T.slv]    -0.5907      0.208     -2.843      0.004      -0.998      -0.183
# C(Mention_country)[T.som]    -0.4924      0.122     -4.034      0.000      -0.732      -0.253
# C(Mention_country)[T.svk]     0.1223      0.257      0.475      0.634      -0.382       0.626
# C(Mention_country)[T.svn]     0.1320      0.376      0.351      0.726      -0.605       0.869
# C(Mention_country)[T.swe]     1.1918      0.253      4.704      0.000       0.695       1.688
# C(Mention_country)[T.syr]    -0.7426      0.103     -7.219      0.000      -0.944      -0.541
# C(Mention_country)[T.tcd]    -0.7392      0.120     -6.148      0.000      -0.975      -0.504
# C(Mention_country)[T.tgo]    -1.1259      0.193     -5.824      0.000      -1.505      -0.747
# C(Mention_country)[T.tha]     0.4484      0.172      2.608      0.009       0.111       0.785
# C(Mention_country)[T.tjk]    -1.0674      0.169     -6.331      0.000      -1.398      -0.737
# C(Mention_country)[T.tkm]    -1.5615      0.228     -6.834      0.000      -2.009      -1.114
# C(Mention_country)[T.tto]    -0.8839      0.413     -2.138      0.033      -1.694      -0.074
# C(Mention_country)[T.tun]     0.2643      0.016     16.642      0.000       0.233       0.295
# C(Mention_country)[T.tur]     0.6882      0.201      3.421      0.001       0.294       1.083
# C(Mention_country)[T.tza]     0.7283      0.071     10.293      0.000       0.590       0.867
# C(Mention_country)[T.uga]     0.6580      0.023     28.108      0.000       0.612       0.704
# C(Mention_country)[T.ukr]    -0.4917      0.123     -4.009      0.000      -0.732      -0.251
# C(Mention_country)[T.ury]     0.2990      0.295      1.012      0.312      -0.280       0.878
# C(Mention_country)[T.usa]     1.7829      0.407      4.378      0.000       0.985       2.581
# C(Mention_country)[T.uzb]    -1.2016      0.040    -30.415      0.000      -1.279      -1.124
# C(Mention_country)[T.ven]    -0.1773      0.138     -1.283      0.199      -0.448       0.094
# C(Mention_country)[T.vnm]     0.4612      0.170      2.710      0.007       0.128       0.795
# C(Mention_country)[T.yem]    -0.7318      0.129     -5.661      0.000      -0.985      -0.478
# C(Mention_country)[T.zaf]     0.9076      0.161      5.627      0.000       0.592       1.224
# C(Mention_country)[T.zmb]     0.1069      0.106      1.012      0.312      -0.100       0.314
# C(Mention_country)[T.zwe]     0.6654      0.096      6.959      0.000       0.478       0.853
# time                          0.0695      0.005     14.194      0.000       0.060       0.079
# treated                      -0.2064      0.170     -1.216      0.224      -0.539       0.126
# treated:time                  0.0009      0.010      0.084      0.933      -0.019       0.021
# log_gdp                       0.1455      0.044      3.293      0.001       0.059       0.232
# log_population                0.5542      0.134      4.142      0.000       0.292       0.817
# ==============================================================================
# Omnibus:                      209.319   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2071.435
# Skew:                          -0.410   Prob(JB):                         0.00
# Kurtosis:                       9.118   Cond. No.                     6.26e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.2e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 149, but rank is 4
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ### Notice: Pre-parallel trend test is not significant at the target level so not an issue.

# %%
df_complete['treated:post']=df_complete['treated']*df_complete['post']
# Select the independent variables (excluding categorical variables handled by C())
independent_vars = df_complete[['treated', 'post', 'treated:post', 'log_gdp', 'log_population']]
# Compute VIF
vif_data = pd.DataFrame()
vif_data["Variable"] = independent_vars.columns
vif_data["VIF"] = [variance_inflation_factor(independent_vars.values, i) for i in range(len(independent_vars.columns))]
print(vif_data)
# Out:
#          Variable        VIF
# 0         treated   2.153278
# 1            post   2.210859
# 2    treated:post   2.150505
# 3         log_gdp  23.878211
# 4  log_population  23.153844

# %% [markdown]
# ### Notice: The VIF for treated:post is not high, so safe to go:)

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='treated')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foriegn attention')
# Out:
# Text(0, 0.5, 'log Foriegn attention')

# %% [markdown]
# ### Trends for the world is stable and linear. There exists a pattern change before and after the arab spring visually.

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ treated* post +log_gdp+log_population+ C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     51.39
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           2.26e-55
# Time:                        11:32:31   Log-Likelihood:                 745.59
# No. Observations:                2610   AIC:                            -1161.
# Df Residuals:                    2445   BIC:                            -193.1
# Df Model:                         164
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -3.9786      2.822     -1.410      0.159      -9.510       1.552
# C(Mention_country)[T.ago]    -1.0326      0.126     -8.196      0.000      -1.280      -0.786
# C(Mention_country)[T.alb]    -0.4809      0.361     -1.332      0.183      -1.188       0.226
# C(Mention_country)[T.are]     0.1622      0.349      0.464      0.643      -0.523       0.847
# C(Mention_country)[T.arg]     0.2736      0.231      1.186      0.236      -0.178       0.726
# C(Mention_country)[T.arm]    -0.7744      0.357     -2.170      0.030      -1.474      -0.075
# C(Mention_country)[T.aus]     1.3741      0.322      4.265      0.000       0.743       2.006
# C(Mention_country)[T.aut]     0.2056      0.341      0.603      0.546      -0.463       0.874
# C(Mention_country)[T.aze]    -0.8867      0.211     -4.212      0.000      -1.299      -0.474
# C(Mention_country)[T.bdi]    -1.6637      0.204     -8.156      0.000      -2.064      -1.264
# C(Mention_country)[T.bel]    -0.0281      0.324     -0.087      0.931      -0.664       0.608
# C(Mention_country)[T.ben]    -0.5190      0.172     -3.014      0.003      -0.857      -0.181
# C(Mention_country)[T.bfa]    -0.2663      0.088     -3.018      0.003      -0.439      -0.093
# C(Mention_country)[T.bgd]    -0.1131      0.277     -0.408      0.683      -0.656       0.430
# C(Mention_country)[T.bgr]    -0.2404      0.252     -0.953      0.341      -0.735       0.254
# C(Mention_country)[T.bhr]    -0.8813      0.351     -2.512      0.012      -1.569      -0.194
# C(Mention_country)[T.bih]    -0.1863      0.327     -0.571      0.568      -0.826       0.454
# C(Mention_country)[T.blr]    -1.1788      0.216     -5.456      0.000      -1.602      -0.755
# C(Mention_country)[T.bol]     0.3977      0.175      2.277      0.023       0.055       0.740
# C(Mention_country)[T.bra]     0.4810      0.404      1.192      0.233      -0.310       1.272
# C(Mention_country)[T.bwa]     0.2678      0.415      0.646      0.518      -0.545       1.081
# C(Mention_country)[T.caf]    -1.3155      0.294     -4.476      0.000      -1.892      -0.740
# C(Mention_country)[T.can]     1.1388      0.331      3.445      0.001       0.491       1.787
# C(Mention_country)[T.che]     0.6321      0.373      1.696      0.090      -0.098       1.363
# C(Mention_country)[T.chl]     0.7564      0.225      3.360      0.001       0.315       1.198
# C(Mention_country)[T.chn]     0.9026      0.666      1.355      0.175      -0.403       2.208
# C(Mention_country)[T.civ]    -3.4968      0.098    -35.797      0.000      -3.688      -3.305
# C(Mention_country)[T.cmr]     0.0949      0.088      1.073      0.283      -0.078       0.268
# C(Mention_country)[T.col]    -0.0363      0.205     -0.177      0.859      -0.438       0.365
# C(Mention_country)[T.cri]     0.7671      0.316      2.427      0.015       0.148       1.387
# C(Mention_country)[T.cub]    -0.2735      0.208     -1.316      0.188      -0.681       0.134
# C(Mention_country)[T.cyp]     0.5121      0.533      0.961      0.337      -0.533       1.557
# C(Mention_country)[T.cze]    -0.2191      0.275     -0.798      0.425      -0.757       0.319
# C(Mention_country)[T.deu]     0.9002      0.393      2.291      0.022       0.130       1.670
# C(Mention_country)[T.dji]    -1.4404      0.535     -2.691      0.007      -2.489      -0.391
# C(Mention_country)[T.dnk]     0.5398      0.380      1.420      0.156      -0.205       1.285
# C(Mention_country)[T.dom]    -0.7819      0.216     -3.613      0.000      -1.206      -0.358
# C(Mention_country)[T.dza]    -0.7372      0.169     -4.365      0.000      -1.068      -0.406
# C(Mention_country)[T.ecu]     0.3040      0.175      1.741      0.082      -0.038       0.646
# C(Mention_country)[T.egy]     0.3017      0.325      0.927      0.354      -0.336       0.939
# C(Mention_country)[T.eri]    -1.0072      0.352     -2.863      0.004      -1.697      -0.318
# C(Mention_country)[T.esp]     0.6864      0.319      2.154      0.031       0.062       1.311
# C(Mention_country)[T.est]     0.0298      0.496      0.060      0.952      -0.943       1.002
# C(Mention_country)[T.eth]     0.1887      0.179      1.054      0.292      -0.162       0.539
# C(Mention_country)[T.fin]     0.6256      0.372      1.680      0.093      -0.104       1.356
# C(Mention_country)[T.fra]     0.7420      0.368      2.018      0.044       0.021       1.463
# C(Mention_country)[T.gab]    -0.3303      0.446     -0.740      0.459      -1.205       0.544
# C(Mention_country)[T.gbr]     1.5740      0.371      4.243      0.000       0.847       2.301
# C(Mention_country)[T.gha]     0.4152      0.069      6.044      0.000       0.281       0.550
# C(Mention_country)[T.gmb]    -1.1763      0.422     -2.788      0.005      -2.003      -0.349
# C(Mention_country)[T.grc]     0.6805      0.286      2.382      0.017       0.121       1.241
# C(Mention_country)[T.gtm]    -0.2297      0.156     -1.470      0.142      -0.536       0.077
# C(Mention_country)[T.hkg]     1.2539      0.338      3.710      0.000       0.591       1.916
# C(Mention_country)[T.hnd]    -0.6200      0.199     -3.119      0.002      -1.010      -0.230
# C(Mention_country)[T.hrv]    -0.2488      0.342     -0.728      0.466      -0.918       0.421
# C(Mention_country)[T.hti]    -0.4865      0.169     -2.884      0.004      -0.817      -0.156
# C(Mention_country)[T.hun]    -0.0253      0.260     -0.097      0.923      -0.535       0.484
# C(Mention_country)[T.idn]     0.0259      0.387      0.067      0.947      -0.732       0.784
# C(Mention_country)[T.ind]     0.3510      0.619      0.567      0.570      -0.861       1.563
# C(Mention_country)[T.irn]     0.0562      0.252      0.223      0.824      -0.438       0.551
# C(Mention_country)[T.irq]    -0.0208      0.154     -0.135      0.893      -0.323       0.282
# C(Mention_country)[T.isr]     0.7871      0.325      2.421      0.015       0.150       1.424
# C(Mention_country)[T.ita]     0.6382      0.351      1.818      0.069      -0.050       1.326
# C(Mention_country)[T.jam]    -0.0862      0.375     -0.230      0.818      -0.821       0.649
# C(Mention_country)[T.jor]     0.8563      0.070     12.216      0.000       0.719       0.994
# C(Mention_country)[T.jpn]     0.7395      0.438      1.690      0.091      -0.118       1.597
# C(Mention_country)[T.kaz]    -0.3244      0.197     -1.645      0.100      -0.711       0.062
# C(Mention_country)[T.ken]     0.7264      0.094      7.730      0.000       0.542       0.911
# C(Mention_country)[T.kgz]    -0.5122      0.255     -2.009      0.045      -1.012      -0.012
# C(Mention_country)[T.khm]    -0.0231      0.110     -0.210      0.834      -0.238       0.192
# C(Mention_country)[T.kor]     0.1925      0.313      0.614      0.539      -0.422       0.807
# C(Mention_country)[T.kwt]    -0.4460      0.222     -2.011      0.044      -0.881      -0.011
# C(Mention_country)[T.lao]    -0.3510      0.235     -1.495      0.135      -0.811       0.109
# C(Mention_country)[T.lbn]    -0.1399      0.296     -0.473      0.636      -0.719       0.439
# C(Mention_country)[T.lbr]    -0.8654      0.316     -2.743      0.006      -1.484      -0.247
# C(Mention_country)[T.lby]    -0.3577      0.095     -3.757      0.000      -0.544      -0.171
# C(Mention_country)[T.lka]    -0.1196      0.122     -0.981      0.327      -0.359       0.119
# C(Mention_country)[T.lso]    -0.4927      0.411     -1.199      0.231      -1.298       0.313
# C(Mention_country)[T.ltu]    -0.5342      0.379     -1.409      0.159      -1.278       0.209
# C(Mention_country)[T.lva]    -0.6548      0.429     -1.525      0.127      -1.497       0.187
# C(Mention_country)[T.mar]     0.3455      0.170      2.029      0.042       0.012       0.679
# C(Mention_country)[T.mda]    -0.8393      0.360     -2.330      0.020      -1.545      -0.133
# C(Mention_country)[T.mdg]     0.5149      0.043     11.916      0.000       0.430       0.600
# C(Mention_country)[T.mex]     1.1298      0.342      3.299      0.001       0.459       1.801
# C(Mention_country)[T.mkd]    -0.3623      0.415     -0.873      0.383      -1.176       0.451
# C(Mention_country)[T.mli]    -0.3206      0.095     -3.390      0.001      -0.506      -0.135
# C(Mention_country)[T.mmr]    -0.6775      0.100     -6.794      0.000      -0.873      -0.482
# C(Mention_country)[T.mng]     1.7245      0.364      4.732      0.000       1.010       2.439
# C(Mention_country)[T.moz]    -0.0715      0.032     -2.237      0.025      -0.134      -0.009
# C(Mention_country)[T.mrt]    -0.9846      0.327     -3.007      0.003      -1.626      -0.343
# C(Mention_country)[T.mus]    -0.3932      0.495     -0.794      0.427      -1.364       0.578
# C(Mention_country)[T.mwi]     0.3389      0.103      3.300      0.001       0.138       0.540
# C(Mention_country)[T.mys]     0.1881      0.207      0.910      0.363      -0.217       0.593
# C(Mention_country)[T.nam]     0.5850      0.410      1.427      0.154      -0.219       1.389
# C(Mention_country)[T.ner]    -1.1449      0.084    -13.682      0.000      -1.309      -0.981
# C(Mention_country)[T.nga]    -0.0849      0.316     -0.269      0.788      -0.704       0.535
# C(Mention_country)[T.nic]    -0.1197      0.248     -0.482      0.630      -0.606       0.367
# C(Mention_country)[T.nld]     0.4198      0.323      1.300      0.194      -0.213       1.053
# C(Mention_country)[T.nor]     1.5143      0.408      3.712      0.000       0.715       2.314
# C(Mention_country)[T.npl]     0.5204      0.022     23.175      0.000       0.476       0.564
# C(Mention_country)[T.nzl]     2.3732      0.377      6.295      0.000       1.634       3.112
# C(Mention_country)[T.omn]     0.4965      0.195      2.549      0.011       0.115       0.878
# C(Mention_country)[T.pak]    -0.3133      0.325     -0.965      0.335      -0.950       0.323
# C(Mention_country)[T.pan]     0.4802      0.349      1.376      0.169      -0.204       1.164
# C(Mention_country)[T.per]     0.5320      0.168      3.172      0.002       0.203       0.861
# C(Mention_country)[T.phl]    -0.0727      0.242     -0.301      0.764      -0.546       0.401
# C(Mention_country)[T.pol]    -0.0262      0.243     -0.108      0.914      -0.503       0.451
# C(Mention_country)[T.pri]     0.3763      0.387      0.972      0.331      -0.382       1.135
# C(Mention_country)[T.prt]     0.3046      0.284      1.072      0.284      -0.252       0.862
# C(Mention_country)[T.pry]    -0.5064      0.267     -1.899      0.058      -1.029       0.016
# C(Mention_country)[T.pse]    -0.0007      0.317     -0.002      0.998      -0.623       0.621
# C(Mention_country)[T.qat]    -0.8758      0.513     -1.706      0.088      -1.882       0.130
# C(Mention_country)[T.rou]    -0.3294      0.196     -1.678      0.093      -0.714       0.055
# C(Mention_country)[T.rus]     0.3128      0.367      0.853      0.394      -0.406       1.031
# C(Mention_country)[T.rwa]    -0.2808      0.160     -1.760      0.078      -0.594       0.032
# C(Mention_country)[T.sau]    -0.2060      0.262     -0.788      0.431      -0.719       0.307
# C(Mention_country)[T.sen]    -0.0488      0.135     -0.362      0.717      -0.313       0.215
# C(Mention_country)[T.sgp]     0.4731      0.379      1.249      0.211      -0.269       1.215
# C(Mention_country)[T.sle]    -0.4407      0.237     -1.861      0.063      -0.905       0.024
# C(Mention_country)[T.slv]    -0.9235      0.255     -3.626      0.000      -1.423      -0.424
# C(Mention_country)[T.som]    -0.8346      0.154     -5.424      0.000      -1.136      -0.533
# C(Mention_country)[T.svk]    -0.1163      0.322     -0.361      0.718      -0.748       0.516
# C(Mention_country)[T.svn]    -0.2046      0.449     -0.456      0.648      -1.084       0.675
# C(Mention_country)[T.swe]     0.9411      0.342      2.751      0.006       0.271       1.612
# C(Mention_country)[T.syr]    -0.2985      0.094     -3.178      0.001      -0.483      -0.114
# C(Mention_country)[T.tcd]    -1.0503      0.135     -7.766      0.000      -1.315      -0.785
# C(Mention_country)[T.tgo]    -1.3853      0.229     -6.049      0.000      -1.834      -0.936
# C(Mention_country)[T.tha]     0.2750      0.238      1.153      0.249      -0.192       0.742
# C(Mention_country)[T.tjk]    -1.1382      0.205     -5.564      0.000      -1.539      -0.737
# C(Mention_country)[T.tkm]    -1.7695      0.277     -6.377      0.000      -2.313      -1.226
# C(Mention_country)[T.tto]    -1.2593      0.487     -2.583      0.010      -2.215      -0.304
# C(Mention_country)[T.tun]     0.2964      0.014     21.256      0.000       0.269       0.324
# C(Mention_country)[T.tur]     0.6889      0.288      2.390      0.017       0.124       1.254
# C(Mention_country)[T.tza]     0.5755      0.091      6.347      0.000       0.398       0.753
# C(Mention_country)[T.uga]     0.5600      0.034     16.524      0.000       0.494       0.626
# C(Mention_country)[T.ukr]    -0.4449      0.161     -2.771      0.006      -0.760      -0.130
# C(Mention_country)[T.ury]    -0.0442      0.365     -0.121      0.904      -0.759       0.671
# C(Mention_country)[T.usa]     1.9898      0.559      3.561      0.000       0.895       3.085
# C(Mention_country)[T.uzb]    -1.4568      0.078    -18.780      0.000      -1.609      -1.305
# C(Mention_country)[T.ven]    -0.4667      0.222     -2.106      0.035      -0.901      -0.032
# C(Mention_country)[T.vnm]     0.4303      0.215      2.002      0.045       0.009       0.851
# C(Mention_country)[T.yem]    -0.7110      0.149     -4.759      0.000      -1.004      -0.418
# C(Mention_country)[T.zaf]     0.8423      0.230      3.657      0.000       0.391       1.294
# C(Mention_country)[T.zmb]    -0.0694      0.121     -0.574      0.566      -0.306       0.168
# C(Mention_country)[T.zwe]     0.3388      0.123      2.753      0.006       0.098       0.580
# C(year)[T.2003.0]             0.0220      0.020      1.092      0.275      -0.017       0.061
# C(year)[T.2004.0]             0.0428      0.028      1.547      0.122      -0.011       0.097
# C(year)[T.2005.0]             0.1023      0.035      2.928      0.003       0.034       0.171
# C(year)[T.2006.0]             0.2214      0.042      5.262      0.000       0.139       0.304
# C(year)[T.2007.0]             0.2927      0.054      5.456      0.000       0.188       0.398
# C(year)[T.2008.0]             0.3527      0.064      5.487      0.000       0.227       0.479
# C(year)[T.2009.0]             0.4879      0.061      8.021      0.000       0.369       0.607
# C(year)[T.2010.0]             0.5545      0.069      8.047      0.000       0.419       0.690
# C(year)[T.2011.0]            -0.1620      0.011    -15.228      0.000      -0.183      -0.141
# C(year)[T.2012.0]            -0.1082      0.012     -9.267      0.000      -0.131      -0.085
# C(year)[T.2013.0]            -0.0022      0.012     -0.183      0.855      -0.026       0.021
# C(year)[T.2014.0]             0.0419      0.013      3.238      0.001       0.017       0.067
# C(year)[T.2015.0]             0.1021      0.011      9.058      0.000       0.080       0.124
# C(year)[T.2016.0]             0.1457      0.012     11.958      0.000       0.122       0.170
# C(year)[T.2017.0]             0.1820      0.013     13.550      0.000       0.156       0.208
# C(year)[T.2018.0]             0.2443      0.018     13.724      0.000       0.209       0.279
# C(year)[T.2019.0]             0.3385      0.021     16.162      0.000       0.297       0.380
# treated                      -0.3981      0.207     -1.927      0.054      -0.803       0.007
# post                          0.7820      0.075     10.421      0.000       0.635       0.929
# treated:post                  0.1355      0.106      1.280      0.200      -0.072       0.343
# log_gdp                       0.1215      0.070      1.737      0.082      -0.016       0.259
# log_population                0.4588      0.159      2.886      0.004       0.147       0.771
# ==============================================================================
# Omnibus:                      213.997   Durbin-Watson:                   0.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1076.812
# Skew:                          -0.204   Prob(JB):                    1.49e-234
# Kurtosis:                       6.120   Cond. No.                     7.76e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.48e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 166, but rank is 20
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ###  Durbin-Watson: 0.937, it is close to 1 so the autocorrelation is residuals are not highly problematic.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
#funding
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df_fund=pd.read_csv(r"C:\Users\Yasaman\Downloads\Mentioned-Funding-fractional counting.csv")
df_fund.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'funding_country': 'Source'}, inplace=True)
df_fund=df_fund[~(df_fund['subjarea'].isin(physical_sciences))]
df_fund=df_fund[df_fund['Mention_country']==df_fund['Source']]
df_fund=df_fund.groupby(['year', 'Mention_country'])['count'].sum().reset_index()
df_fund=df_fund[(df_fund['year'].isin(np.arange(2002,2020,1)))].reset_index(drop=True)
df=df_fund.copy()

data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))

# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "incomelevel": country_data["incomelevel"].iloc[0] if not country_data.empty else np.nan,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# afg
# ago
# alb
# arm
# aze
# bdi
# ben
# bfa
# bhr
# bih
# blr
# bol
# caf
# civ
# cmr
# dji
# dom
# dza
# eri
# gab
# gmb
# gtm
# hnd
# hti
# irq
# jam
# kaz
# kgz
# khm
# lao
# lbr
# lby
# lso
# mda
# mdg
# mkd
# mli
# mmr
# mng
# moz
# mrt
# mus
# mwi
# nam
# ner
# nic
# pan
# pry
# pse
# qat
# rwa
# sen
# sle
# slv
# som
# syr
# tcd
# tgo
# tjk
# tkm
# tto
# uzb
# yem
# zmb
# 64

# %%
df_complete['hue']=df_complete['treated_CW']*2 +df_complete['treated_GC']*3+df_complete['treated_GO']

# %%
df_p=df_complete[df_complete['year']<2011].reset_index(drop=True)
df_p['time']=df_p['year'].min()-df_p['year']
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * time + treated_GO * time +treated_CW * time +log_gdp +C(Mention_country) + C(year)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     1132.
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):          5.68e-136
# Time:                        21:38:21   Log-Likelihood:                -361.22
# No. Observations:                1305   AIC:                             1036.
# Df Residuals:                    1148   BIC:                             1849.
# Df Model:                         156
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -0.7054      0.567     -1.243      0.214      -1.817       0.407
# C(Mention_country)[T.ago]    -0.1343      0.207     -0.649      0.516      -0.540       0.271
# C(Mention_country)[T.alb]    -0.1563      0.241     -0.649      0.516      -0.628       0.316
# C(Mention_country)[T.are]     1.4113      0.516      2.734      0.006       0.400       2.423
# C(Mention_country)[T.arg]     4.7455      0.314     15.135      0.000       4.131       5.360
# C(Mention_country)[T.arm]     0.0079      0.196      0.040      0.968      -0.376       0.392
# C(Mention_country)[T.aus]     5.7659      0.509     11.326      0.000       4.768       6.764
# C(Mention_country)[T.aut]     2.9052      0.523      5.557      0.000       1.880       3.930
# C(Mention_country)[T.aze]    -0.1158      0.217     -0.535      0.593      -0.540       0.309
# C(Mention_country)[T.bdi]     0.0478      0.074      0.649      0.516      -0.096       0.192
# C(Mention_country)[T.bel]     3.3151      0.517      6.414      0.000       2.302       4.328
# C(Mention_country)[T.ben]     0.0051      0.111      0.046      0.963      -0.212       0.222
# C(Mention_country)[T.bfa]    -0.0303      0.047     -0.649      0.516      -0.122       0.061
# C(Mention_country)[T.bgd]     1.4228      0.062     22.796      0.000       1.301       1.545
# C(Mention_country)[T.bgr]     1.2462      0.288      4.328      0.000       0.682       1.811
# C(Mention_country)[T.bhr]    -1.1385      0.137     -8.282      0.000      -1.408      -0.869
# C(Mention_country)[T.bih]    -0.1619      0.249     -0.649      0.516      -0.651       0.327
# C(Mention_country)[T.blr]     0.3054      0.261      1.168      0.243      -0.207       0.818
# C(Mention_country)[T.bol]    -0.0982      0.151     -0.649      0.516      -0.394       0.198
# C(Mention_country)[T.bra]     5.9496      0.312     19.049      0.000       5.337       6.562
# C(Mention_country)[T.bwa]     0.2864      0.296      0.967      0.333      -0.294       0.867
# C(Mention_country)[T.caf]    -0.0111      0.017     -0.649      0.516      -0.045       0.022
# C(Mention_country)[T.can]     5.8026      0.514     11.284      0.000       4.795       6.811
# C(Mention_country)[T.che]     3.6939      0.566      6.530      0.000       2.585       4.803
# C(Mention_country)[T.chl]     3.6823      0.351     10.494      0.000       2.995       4.370
# C(Mention_country)[T.chn]     6.9326      0.214     32.450      0.000       6.514       7.351
# C(Mention_country)[T.civ]    -0.1049      0.162     -0.649      0.516      -0.421       0.212
# C(Mention_country)[T.cmr]    -0.0946      0.146     -0.649      0.516      -0.380       0.191
# C(Mention_country)[T.col]     2.5068      0.272      9.220      0.000       1.974       3.040
# C(Mention_country)[T.cri]     1.2498      0.309      4.050      0.000       0.645       1.855
# C(Mention_country)[T.cub]     0.4445      0.280      1.589      0.112      -0.104       0.993
# C(Mention_country)[T.cyp]     0.8846      0.477      1.855      0.064      -0.050       1.819
# C(Mention_country)[T.cze]     3.7154      0.415      8.946      0.000       2.901       4.529
# C(Mention_country)[T.deu]     4.9470      0.512      9.665      0.000       3.944       5.950
# C(Mention_country)[T.dji]    -0.0774      0.119     -0.649      0.516      -0.311       0.156
# C(Mention_country)[T.dnk]     3.6436      0.547      6.665      0.000       2.572       4.715
# C(Mention_country)[T.dom]    -0.1769      0.272     -0.649      0.516      -0.711       0.357
# C(Mention_country)[T.dza]     0.3050      0.253      1.205      0.228      -0.191       0.801
# C(Mention_country)[T.ecu]     0.2411      0.255      0.946      0.344      -0.259       0.741
# C(Mention_country)[T.egy]     0.5843      0.108      5.416      0.000       0.373       0.796
# C(Mention_country)[T.eri]    -0.0226      0.035     -0.649      0.516      -0.091       0.046
# C(Mention_country)[T.esp]     5.4683      0.481     11.376      0.000       4.526       6.410
# C(Mention_country)[T.est]     2.9261      0.387      7.558      0.000       2.167       3.685
# C(Mention_country)[T.eth]     2.4462      0.044     55.967      0.000       2.361       2.532
# C(Mention_country)[T.fin]     4.5130      0.524      8.605      0.000       3.485       5.541
# C(Mention_country)[T.fra]     4.4709      0.511      8.752      0.000       3.470       5.472
# C(Mention_country)[T.gab]     0.0669      0.329      0.203      0.839      -0.578       0.712
# C(Mention_country)[T.gbr]     6.2966      0.523     12.028      0.000       5.271       7.323
# C(Mention_country)[T.gha]     0.7599      0.087      8.778      0.000       0.590       0.930
# C(Mention_country)[T.gmb]    -0.0479      0.074     -0.649      0.516      -0.192       0.097
# C(Mention_country)[T.grc]     2.9947      0.467      6.418      0.000       2.080       3.909
# C(Mention_country)[T.gtm]    -0.0369      0.214     -0.173      0.863      -0.456       0.382
# C(Mention_country)[T.hkg]     4.2622      0.484      8.799      0.000       3.313       5.212
# C(Mention_country)[T.hnd]    -0.1079      0.166     -0.649      0.516      -0.434       0.218
# C(Mention_country)[T.hrv]     2.2079      0.385      5.728      0.000       1.452       2.963
# C(Mention_country)[T.hti]    -0.0732      0.113     -0.649      0.516      -0.294       0.148
# C(Mention_country)[T.hun]     3.1645      0.387      8.186      0.000       2.407       3.922
# C(Mention_country)[T.idn]     1.5680      0.176      8.900      0.000       1.223       1.913
# C(Mention_country)[T.ind]     5.3484      0.104     51.191      0.000       5.144       5.553
# C(Mention_country)[T.irn]     3.8418      0.269     14.285      0.000       3.315       4.369
# C(Mention_country)[T.irq]    -0.0243      0.212     -0.115      0.909      -0.440       0.392
# C(Mention_country)[T.isr]     3.3814      0.467      7.237      0.000       2.466       4.297
# C(Mention_country)[T.ita]     4.7184      0.501      9.418      0.000       3.736       5.700
# C(Mention_country)[T.jam]     0.2703      0.284      0.953      0.340      -0.285       0.826
# C(Mention_country)[T.jor]     1.1960      0.075     16.034      0.000       1.050       1.342
# C(Mention_country)[T.jpn]     5.7676      0.517     11.165      0.000       4.755       6.780
# C(Mention_country)[T.kaz]    -0.0333      0.289     -0.115      0.908      -0.599       0.532
# C(Mention_country)[T.ken]     1.6147      0.085     18.999      0.000       1.448       1.781
# C(Mention_country)[T.kgz]    -0.0453      0.070     -0.649      0.516      -0.182       0.091
# C(Mention_country)[T.khm]    -0.0396      0.061     -0.649      0.516      -0.159       0.080
# C(Mention_country)[T.kor]     4.8759      0.442     11.027      0.000       4.009       5.743
# C(Mention_country)[T.kwt]     0.9683      0.207      4.685      0.000       0.563       1.373
# C(Mention_country)[T.lao]    -0.0461      0.071     -0.649      0.516      -0.185       0.093
# C(Mention_country)[T.lbn]     1.6746      0.306      5.469      0.000       1.075       2.275
# C(Mention_country)[T.lbr]    -0.0054      0.008     -0.649      0.516      -0.022       0.011
# C(Mention_country)[T.lby]     0.1074      0.147      0.730      0.465      -0.181       0.396
# C(Mention_country)[T.lka]     1.6927      0.168     10.048      0.000       1.363       2.023
# C(Mention_country)[T.lso]    -0.0630      0.097     -0.649      0.516      -0.253       0.127
# C(Mention_country)[T.ltu]     0.9830      0.359      2.735      0.006       0.279       1.688
# C(Mention_country)[T.lva]     0.3015      0.361      0.835      0.404      -0.406       1.009
# C(Mention_country)[T.mar]    -0.2825      0.080     -3.524      0.000      -0.440      -0.125
# C(Mention_country)[T.mda]    -0.0727      0.150     -0.484      0.628      -0.367       0.222
# C(Mention_country)[T.mdg]    -0.0153      0.024     -0.649      0.516      -0.061       0.031
# C(Mention_country)[T.mex]     4.5419      0.362     12.550      0.000       3.833       5.251
# C(Mention_country)[T.mkd]    -0.1678      0.258     -0.649      0.516      -0.674       0.339
# C(Mention_country)[T.mli]    -0.0365      0.056     -0.649      0.516      -0.147       0.074
# C(Mention_country)[T.mmr]    -0.0131      0.020     -0.649      0.516      -0.053       0.026
# C(Mention_country)[T.mng]     0.0385      0.149      0.258      0.796      -0.253       0.330
# C(Mention_country)[T.moz]    -0.0274      0.042     -0.649      0.516      -0.110       0.055
# C(Mention_country)[T.mrt]    -0.0896      0.138     -0.649      0.516      -0.360       0.181
# C(Mention_country)[T.mus]     0.3112      0.319      0.975      0.329      -0.314       0.937
# C(Mention_country)[T.mwi]     0.0122      0.051      0.242      0.809      -0.087       0.111
# C(Mention_country)[T.mys]     2.9309      0.322      9.116      0.000       2.301       3.561
# C(Mention_country)[T.nam]     0.0705      0.265      0.266      0.790      -0.449       0.590
# C(Mention_country)[T.ner]    -0.0092      0.014     -0.649      0.516      -0.037       0.019
# C(Mention_country)[T.nga]     0.9234      0.164      5.616      0.000       0.601       1.246
# C(Mention_country)[T.nic]    -0.0976      0.150     -0.649      0.516      -0.392       0.197
# C(Mention_country)[T.nld]     4.0452      0.533      7.588      0.000       3.000       5.090
# C(Mention_country)[T.nor]     4.2772      0.581      7.360      0.000       3.138       5.416
# C(Mention_country)[T.npl]     0.6612      0.017     38.429      0.000       0.627       0.695
# C(Mention_country)[T.nzl]     4.8427      0.479     10.113      0.000       3.904       5.781
# C(Mention_country)[T.omn]     0.4132      0.111      3.723      0.000       0.196       0.631
# C(Mention_country)[T.pak]     2.2829      0.112     20.359      0.000       2.063       2.503
# C(Mention_country)[T.pan]     0.0901      0.314      0.287      0.774      -0.525       0.705
# C(Mention_country)[T.per]     0.5575      0.249      2.236      0.025       0.069       1.046
# C(Mention_country)[T.phl]     1.8008      0.169     10.639      0.000       1.469       2.133
# C(Mention_country)[T.pol]     3.1251      0.361      8.658      0.000       2.418       3.832
# C(Mention_country)[T.pri]     1.1853      0.462      2.568      0.010       0.281       2.090
# C(Mention_country)[T.prt]     3.6004      0.446      8.079      0.000       2.727       4.474
# C(Mention_country)[T.pry]    -0.1476      0.227     -0.649      0.516      -0.593       0.298
# C(Mention_country)[T.pse]     0.0446      0.182      0.245      0.807      -0.313       0.402
# C(Mention_country)[T.qat]     0.3277      0.549      0.597      0.551      -0.749       1.404
# C(Mention_country)[T.rou]     0.8377      0.306      2.734      0.006       0.237       1.438
# C(Mention_country)[T.rus]     3.9267      0.320     12.273      0.000       3.300       4.554
# C(Mention_country)[T.rwa]    -0.0148      0.023     -0.649      0.516      -0.059       0.030
# C(Mention_country)[T.sau]     2.1624      0.405      5.334      0.000       1.368       2.957
# C(Mention_country)[T.sen]    -0.0871      0.134     -0.649      0.516      -0.350       0.176
# C(Mention_country)[T.sgp]     3.0339      0.501      6.058      0.000       2.052       4.016
# C(Mention_country)[T.sle]    -0.0035      0.005     -0.649      0.516      -0.014       0.007
# C(Mention_country)[T.slv]    -0.1488      0.229     -0.649      0.516      -0.598       0.300
# C(Mention_country)[T.som]     0.0579      0.089      0.649      0.516      -0.117       0.232
# C(Mention_country)[T.svk]     2.4828      0.399      6.224      0.000       1.701       3.265
# C(Mention_country)[T.svn]     2.1346      0.446      4.789      0.000       1.261       3.008
# C(Mention_country)[T.swe]     5.0366      0.534      9.423      0.000       3.989       6.084
# C(Mention_country)[T.syr]    -0.0057      0.143     -0.040      0.968      -0.286       0.275
# C(Mention_country)[T.tcd]    -0.0460      0.071     -0.649      0.516      -0.185       0.093
# C(Mention_country)[T.tgo]    -0.0353      0.054     -0.649      0.516      -0.142       0.071
# C(Mention_country)[T.tha]     3.9183      0.255     15.355      0.000       3.418       4.418
# C(Mention_country)[T.tjk]    -0.0211      0.033     -0.649      0.516      -0.085       0.043
# C(Mention_country)[T.tkm]    -0.1325      0.204     -0.649      0.516      -0.533       0.268
# C(Mention_country)[T.tto]    -0.0254      0.395     -0.064      0.949      -0.799       0.749
# C(Mention_country)[T.tun]     0.0187      0.153      0.123      0.902      -0.281       0.318
# C(Mention_country)[T.tur]     4.4842      0.341     13.146      0.000       3.816       5.153
# C(Mention_country)[T.tza]     1.7374      0.060     29.169      0.000       1.621       1.854
# C(Mention_country)[T.uga]     1.7233      0.030     57.699      0.000       1.665       1.782
# C(Mention_country)[T.ukr]     0.6540      0.205      3.183      0.001       0.251       1.057
# C(Mention_country)[T.ury]     1.2693      0.325      3.907      0.000       0.632       1.906
# C(Mention_country)[T.usa]     7.6955      0.534     14.416      0.000       6.649       8.742
# C(Mention_country)[T.uzb]     0.2163      0.092      2.349      0.019       0.036       0.397
# C(Mention_country)[T.ven]     1.9570      0.332      5.895      0.000       1.306       2.608
# C(Mention_country)[T.vnm]     0.8661      0.105      8.270      0.000       0.661       1.071
# C(Mention_country)[T.yem]     0.0718      0.095      0.752      0.452      -0.115       0.259
# C(Mention_country)[T.zaf]     4.3658      0.310     14.071      0.000       3.758       4.974
# C(Mention_country)[T.zmb]     0.0759      0.109      0.694      0.488      -0.138       0.290
# C(Mention_country)[T.zwe]     0.7790      0.058     13.496      0.000       0.666       0.892
# C(year)[T.2003.0]            -0.0248      0.026     -0.974      0.330      -0.075       0.025
# C(year)[T.2004.0]             0.0046      0.027      0.168      0.866      -0.049       0.058
# C(year)[T.2005.0]            -0.0056      0.027     -0.205      0.837      -0.059       0.048
# C(year)[T.2006.0]             0.0254      0.025      1.007      0.314      -0.024       0.075
# C(year)[T.2007.0]            -0.0205      0.023     -0.895      0.371      -0.065       0.024
# C(year)[T.2008.0]             0.0115      0.020      0.575      0.565      -0.028       0.051
# C(year)[T.2009.0]             0.0270      0.023      1.166      0.244      -0.018       0.072
# C(year)[T.2010.0]            -0.0184      0.023     -0.808      0.419      -0.063       0.026
# treated_GC                    1.1566      0.319      3.627      0.000       0.532       1.781
# time                         -0.0773      0.014     -5.636      0.000      -0.104      -0.050
# treated_GC:time              -0.0030      0.031     -0.095      0.924      -0.064       0.058
# treated_GO                    0.6030      0.250      2.415      0.016       0.114       1.092
# treated_GO:time              -0.1113      0.079     -1.408      0.159      -0.266       0.044
# treated_CW                    0.1736      0.196      0.883      0.377      -0.212       0.559
# treated_CW:time               0.0791      0.009      8.714      0.000       0.061       0.097
# log_gdp                       0.0694      0.107      0.649      0.516      -0.140       0.279
# ==============================================================================
# Omnibus:                       55.086   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              142.376
# Skew:                          -0.173   Prob(JB):                     1.21e-31
# Kurtosis:                       4.581   Cond. No.                     9.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.38e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 160, but rank is 12
#   warnings.warn('covariance of constraints does not have full '

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='hue')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foreign attention')
# Out:
# Text(0, 0.5, 'log Foreign attention')

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * post + treated_GO * post +treated_CW * post +log_gdp+C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     43.69
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           6.65e-52
# Time:                        21:38:38   Log-Likelihood:                -1974.0
# No. Observations:                2610   AIC:                             4280.
# Df Residuals:                    2444   BIC:                             5254.
# Df Model:                         165
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -0.9861      0.723     -1.364      0.173      -2.403       0.431
# C(Mention_country)[T.ago]    -0.0579      0.247     -0.234      0.815      -0.542       0.426
# C(Mention_country)[T.alb]    -0.0453      0.289     -0.157      0.876      -0.613       0.522
# C(Mention_country)[T.are]     2.3127      0.614      3.769      0.000       1.110       3.515
# C(Mention_country)[T.arg]     5.3822      0.404     13.339      0.000       4.591       6.173
# C(Mention_country)[T.arm]     0.5637      0.252      2.237      0.025       0.070       1.058
# C(Mention_country)[T.aus]     6.6312      0.629     10.545      0.000       5.399       7.864
# C(Mention_country)[T.aut]     3.6617      0.625      5.860      0.000       2.437       4.886
# C(Mention_country)[T.aze]     0.2669      0.290      0.920      0.358      -0.302       0.835
# C(Mention_country)[T.bdi]     0.2806      0.102      2.737      0.006       0.080       0.481
# C(Mention_country)[T.bel]     4.0673      0.616      6.604      0.000       2.860       5.274
# C(Mention_country)[T.ben]     0.0339      0.116      0.294      0.769      -0.193       0.261
# C(Mention_country)[T.bfa]    -0.0107      0.046     -0.234      0.815      -0.100       0.079
# C(Mention_country)[T.bgd]     2.2643      0.096     23.653      0.000       2.077       2.452
# C(Mention_country)[T.bgr]     2.1062      0.358      5.888      0.000       1.405       2.807
# C(Mention_country)[T.bhr]    -1.1767      0.168     -7.020      0.000      -1.505      -0.848
# C(Mention_country)[T.bih]     0.1177      0.304      0.387      0.698      -0.478       0.713
# C(Mention_country)[T.blr]     0.5430      0.327      1.659      0.097      -0.098       1.184
# C(Mention_country)[T.bol]    -0.0096      0.205     -0.047      0.963      -0.412       0.393
# C(Mention_country)[T.bra]     6.8037      0.390     17.448      0.000       6.039       7.568
# C(Mention_country)[T.bwa]     0.7736      0.349      2.216      0.027       0.089       1.458
# C(Mention_country)[T.caf]     0.0023      0.010      0.234      0.815      -0.017       0.022
# C(Mention_country)[T.can]     6.5948      0.618     10.670      0.000       5.383       7.806
# C(Mention_country)[T.che]     4.6119      0.689      6.694      0.000       3.262       5.962
# C(Mention_country)[T.chl]     4.5377      0.437     10.374      0.000       3.680       5.395
# C(Mention_country)[T.chn]     8.0256      0.309     25.979      0.000       7.420       8.631
# C(Mention_country)[T.civ]    -0.0433      0.185     -0.234      0.815      -0.406       0.319
# C(Mention_country)[T.cmr]     0.1150      0.156      0.736      0.462      -0.191       0.421
# C(Mention_country)[T.col]     3.6053      0.338     10.658      0.000       2.942       4.268
# C(Mention_country)[T.cri]     1.9336      0.392      4.930      0.000       1.165       2.702
# C(Mention_country)[T.cub]     0.7823      0.348      2.247      0.025       0.100       1.465
# C(Mention_country)[T.cyp]     1.6857      0.558      3.021      0.003       0.592       2.779
# C(Mention_country)[T.cze]     4.5635      0.500      9.132      0.000       3.584       5.543
# C(Mention_country)[T.deu]     5.6855      0.613      9.280      0.000       4.485       6.886
# C(Mention_country)[T.dji]    -0.0386      0.165     -0.234      0.815      -0.361       0.284
# C(Mention_country)[T.dnk]     4.5144      0.652      6.923      0.000       3.236       5.793
# C(Mention_country)[T.dom]     0.0943      0.337      0.280      0.780      -0.566       0.755
# C(Mention_country)[T.dza]     1.3479      0.299      4.502      0.000       0.761       1.935
# C(Mention_country)[T.ecu]     1.5459      0.317      4.871      0.000       0.924       2.168
# C(Mention_country)[T.egy]     0.9631      0.050     19.110      0.000       0.864       1.062
# C(Mention_country)[T.eri]    -0.0071      0.030     -0.234      0.815      -0.066       0.052
# C(Mention_country)[T.esp]     6.1916      0.563     10.999      0.000       5.088       7.295
# C(Mention_country)[T.est]     3.4878      0.479      7.287      0.000       2.550       4.426
# C(Mention_country)[T.eth]     3.6678      0.024    151.971      0.000       3.621       3.715
# C(Mention_country)[T.fin]     5.1332      0.624      8.223      0.000       3.910       6.357
# C(Mention_country)[T.fra]     5.2254      0.605      8.642      0.000       4.040       6.411
# C(Mention_country)[T.gab]     0.7416      0.384      1.932      0.053      -0.011       1.494
# C(Mention_country)[T.gbr]     7.1595      0.617     11.609      0.000       5.951       8.368
# C(Mention_country)[T.gha]     1.7339      0.135     12.870      0.000       1.470       1.998
# C(Mention_country)[T.gmb]    -0.0130      0.056     -0.234      0.815      -0.122       0.096
# C(Mention_country)[T.grc]     3.4166      0.531      6.433      0.000       2.376       4.457
# C(Mention_country)[T.gtm]     0.0526      0.263      0.200      0.841      -0.463       0.568
# C(Mention_country)[T.hkg]     4.8219      0.591      8.165      0.000       3.665       5.979
# C(Mention_country)[T.hnd]     0.1182      0.196      0.603      0.547      -0.266       0.503
# C(Mention_country)[T.hrv]     3.0843      0.454      6.788      0.000       2.194       3.975
# C(Mention_country)[T.hti]    -0.0305      0.130     -0.234      0.815      -0.286       0.225
# C(Mention_country)[T.hun]     3.7956      0.457      8.301      0.000       2.899       4.692
# C(Mention_country)[T.idn]     2.8279      0.235     12.031      0.000       2.367       3.289
# C(Mention_country)[T.ind]     6.1801      0.137     44.953      0.000       5.911       6.450
# C(Mention_country)[T.irn]     5.1673      0.321     16.122      0.000       4.539       5.795
# C(Mention_country)[T.irq]     0.8057      0.284      2.836      0.005       0.249       1.362
# C(Mention_country)[T.isr]     4.0392      0.573      7.044      0.000       2.915       5.163
# C(Mention_country)[T.ita]     5.4100      0.587      9.219      0.000       4.260       6.560
# C(Mention_country)[T.jam]     0.8418      0.326      2.581      0.010       0.203       1.481
# C(Mention_country)[T.jor]     1.3154      0.081     16.149      0.000       1.156       1.475
# C(Mention_country)[T.jpn]     6.7832      0.609     11.137      0.000       5.589       7.977
# C(Mention_country)[T.kaz]     1.2126      0.377      3.218      0.001       0.474       1.951
# C(Mention_country)[T.ken]     2.3579      0.119     19.865      0.000       2.125       2.591
# C(Mention_country)[T.kgz]    -0.0223      0.095     -0.234      0.815      -0.209       0.165
# C(Mention_country)[T.khm]     0.0467      0.088      0.531      0.596      -0.126       0.219
# C(Mention_country)[T.kor]     5.9696      0.539     11.067      0.000       4.912       7.027
# C(Mention_country)[T.kwt]     1.0584      0.238      4.451      0.000       0.592       1.524
# C(Mention_country)[T.lao]     0.0291      0.130      0.224      0.823      -0.226       0.284
# C(Mention_country)[T.lbn]     2.2674      0.371      6.110      0.000       1.540       2.995
# C(Mention_country)[T.lbr]    -0.0041      0.017     -0.234      0.815      -0.038       0.030
# C(Mention_country)[T.lby]     0.1249      0.227      0.550      0.582      -0.320       0.570
# C(Mention_country)[T.lka]     2.4583      0.234     10.515      0.000       2.000       2.917
# C(Mention_country)[T.lso]    -0.0250      0.107     -0.234      0.815      -0.234       0.184
# C(Mention_country)[T.ltu]     1.9548      0.448      4.359      0.000       1.076       2.834
# C(Mention_country)[T.lva]     1.0158      0.446      2.280      0.023       0.143       1.889
# C(Mention_country)[T.mar]    -0.0479      0.101     -0.476      0.634      -0.245       0.149
# C(Mention_country)[T.mda]     0.0532      0.212      0.251      0.802      -0.362       0.469
# C(Mention_country)[T.mdg]    -0.0015      0.006     -0.234      0.815      -0.014       0.011
# C(Mention_country)[T.mex]     5.2626      0.421     12.506      0.000       4.438       6.087
# C(Mention_country)[T.mkd]    -0.0730      0.311     -0.234      0.815      -0.683       0.537
# C(Mention_country)[T.mli]    -0.0134      0.057     -0.234      0.815      -0.126       0.099
# C(Mention_country)[T.mmr]    -0.0153      0.065     -0.234      0.815      -0.143       0.112
# C(Mention_country)[T.mng]     0.4075      0.225      1.813      0.070      -0.033       0.848
# C(Mention_country)[T.moz]     0.0418      0.027      1.570      0.116      -0.010       0.094
# C(Mention_country)[T.mrt]    -0.0378      0.161     -0.234      0.815      -0.354       0.279
# C(Mention_country)[T.mus]     0.8837      0.393      2.251      0.024       0.114       1.653
# C(Mention_country)[T.mwi]     0.2318      0.029      7.890      0.000       0.174       0.289
# C(Mention_country)[T.mys]     4.4326      0.396     11.203      0.000       3.657       5.208
# C(Mention_country)[T.nam]     0.5151      0.316      1.629      0.103      -0.105       1.135
# C(Mention_country)[T.ner]    -0.0009      0.004     -0.234      0.815      -0.009       0.007
# C(Mention_country)[T.nga]     2.0504      0.202     10.174      0.000       1.655       2.445
# C(Mention_country)[T.nic]    -0.0410      0.175     -0.234      0.815      -0.384       0.302
# C(Mention_country)[T.nld]     4.9645      0.633      7.839      0.000       3.723       6.206
# C(Mention_country)[T.nor]     5.0294      0.699      7.192      0.000       3.659       6.400
# C(Mention_country)[T.npl]     1.3720      0.043     31.959      0.000       1.288       1.456
# C(Mention_country)[T.nzl]     5.4417      0.586      9.282      0.000       4.293       6.591
# C(Mention_country)[T.omn]     0.5242      0.140      3.756      0.000       0.251       0.798
# C(Mention_country)[T.pak]     3.4165      0.129     26.389      0.000       3.163       3.670
# C(Mention_country)[T.pan]     0.7705      0.407      1.895      0.058      -0.026       1.567
# C(Mention_country)[T.per]     1.2412      0.319      3.893      0.000       0.616       1.866
# C(Mention_country)[T.phl]     2.6006      0.216     12.048      0.000       2.178       3.024
# C(Mention_country)[T.pol]     4.3137      0.439      9.827      0.000       3.453       5.174
# C(Mention_country)[T.pri]     1.7190      0.553      3.106      0.002       0.634       2.804
# C(Mention_country)[T.prt]     4.5928      0.522      8.798      0.000       3.570       5.616
# C(Mention_country)[T.pry]     0.1131      0.300      0.377      0.706      -0.475       0.701
# C(Mention_country)[T.pse]     0.3720      0.233      1.599      0.110      -0.084       0.828
# C(Mention_country)[T.qat]     1.9333      0.670      2.884      0.004       0.619       3.247
# C(Mention_country)[T.rou]     2.1005      0.385      5.460      0.000       1.347       2.855
# C(Mention_country)[T.rus]     4.8728      0.405     12.041      0.000       4.080       5.666
# C(Mention_country)[T.rwa]     0.1544      0.031      4.967      0.000       0.093       0.215
# C(Mention_country)[T.sau]     3.6885      0.500      7.384      0.000       2.709       4.668
# C(Mention_country)[T.sen]     0.2643      0.143      1.848      0.065      -0.016       0.545
# C(Mention_country)[T.sgp]     3.9518      0.623      6.339      0.000       2.730       5.174
# C(Mention_country)[T.sle]    -0.0003      0.001     -0.234      0.815      -0.003       0.003
# C(Mention_country)[T.slv]    -0.0632      0.270     -0.234      0.815      -0.592       0.466
# C(Mention_country)[T.som]     0.0192      0.082      0.234      0.815      -0.141       0.180
# C(Mention_country)[T.svk]     3.5232      0.481      7.331      0.000       2.581       4.465
# C(Mention_country)[T.svn]     3.0019      0.528      5.684      0.000       1.967       4.037
# C(Mention_country)[T.swe]     5.7404      0.641      8.956      0.000       4.484       6.997
# C(Mention_country)[T.syr]     0.3469      0.082      4.206      0.000       0.185       0.508
# C(Mention_country)[T.tcd]    -0.0162      0.069     -0.234      0.815      -0.152       0.119
# C(Mention_country)[T.tgo]    -0.0138      0.059     -0.234      0.815      -0.129       0.101
# C(Mention_country)[T.tha]     4.8423      0.319     15.181      0.000       4.217       5.467
# C(Mention_country)[T.tjk]    -0.0123      0.052     -0.234      0.815      -0.115       0.090
# C(Mention_country)[T.tkm]    -0.0683      0.291     -0.234      0.815      -0.639       0.503
# C(Mention_country)[T.tto]     0.3402      0.477      0.713      0.476      -0.595       1.275
# C(Mention_country)[T.tun]     0.3071      0.123      2.506      0.012       0.067       0.547
# C(Mention_country)[T.tur]     5.1444      0.411     12.507      0.000       4.338       5.951
# C(Mention_country)[T.tza]     2.2963      0.071     32.310      0.000       2.157       2.436
# C(Mention_country)[T.uga]     2.4083      0.043     56.069      0.000       2.324       2.492
# C(Mention_country)[T.ukr]     1.3001      0.242      5.370      0.000       0.826       1.775
# C(Mention_country)[T.ury]     2.1285      0.432      4.926      0.000       1.282       2.975
# C(Mention_country)[T.usa]     8.4319      0.642     13.141      0.000       7.174       9.690
# C(Mention_country)[T.uzb]     0.3088      0.148      2.084      0.037       0.018       0.599
# C(Mention_country)[T.ven]     2.3346      0.424      5.501      0.000       1.503       3.166
# C(Mention_country)[T.vnm]     2.2894      0.168     13.596      0.000       1.959       2.619
# C(Mention_country)[T.yem]    -0.1039      0.079     -1.313      0.189      -0.259       0.051
# C(Mention_country)[T.zaf]     5.2013      0.362     14.358      0.000       4.491       5.911
# C(Mention_country)[T.zmb]     0.3076      0.134      2.297      0.022       0.045       0.570
# C(Mention_country)[T.zwe]     1.1020      0.097     11.393      0.000       0.912       1.292
# C(year)[T.2003.0]             0.0571      0.031      1.818      0.069      -0.004       0.119
# C(year)[T.2004.0]             0.1694      0.046      3.703      0.000       0.080       0.259
# C(year)[T.2005.0]             0.2412      0.063      3.801      0.000       0.117       0.366
# C(year)[T.2006.0]             0.3540      0.077      4.608      0.000       0.203       0.505
# C(year)[T.2007.0]             0.3912      0.092      4.251      0.000       0.211       0.572
# C(year)[T.2008.0]             0.5063      0.114      4.452      0.000       0.283       0.729
# C(year)[T.2009.0]             0.5968      0.106      5.626      0.000       0.389       0.805
# C(year)[T.2010.0]             0.6325      0.119      5.311      0.000       0.399       0.866
# C(year)[T.2011.0]            -0.3915      0.036    -10.808      0.000      -0.462      -0.320
# C(year)[T.2012.0]            -0.3158      0.035     -9.090      0.000      -0.384      -0.248
# C(year)[T.2013.0]            -0.1816      0.033     -5.467      0.000      -0.247      -0.116
# C(year)[T.2014.0]            -0.0804      0.029     -2.786      0.005      -0.137      -0.024
# C(year)[T.2015.0]            -0.0876      0.025     -3.558      0.000      -0.136      -0.039
# C(year)[T.2016.0]             0.1214      0.022      5.396      0.000       0.077       0.165
# C(year)[T.2017.0]             0.3963      0.033     11.832      0.000       0.331       0.462
# C(year)[T.2018.0]             0.7493      0.046     16.166      0.000       0.658       0.840
# C(year)[T.2019.0]             0.9303      0.055     17.065      0.000       0.823       1.037
# treated_GC                    1.6734      0.367      4.559      0.000       0.954       2.393
# post                          1.1404      0.131      8.730      0.000       0.884       1.396
# treated_GC:post               0.1081      0.128      0.842      0.400      -0.143       0.359
# treated_GO                    1.2702      0.172      7.383      0.000       0.933       1.607
# treated_GO:post               1.0938      0.112      9.789      0.000       0.875       1.313
# treated_CW                    0.3679      0.245      1.504      0.133      -0.112       0.847
# treated_CW:post              -0.4725      0.245     -1.926      0.054      -0.954       0.008
# log_gdp                       0.0313      0.134      0.234      0.815      -0.231       0.293
# ==============================================================================
# Omnibus:                       82.383   Durbin-Watson:                   0.691
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              178.344
# Skew:                          -0.177   Prob(JB):                     1.88e-39
# Kurtosis:                       4.231   Cond. No.                     3.71e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.4e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 169, but rank is 21
#   warnings.warn('covariance of constraints does not have full '

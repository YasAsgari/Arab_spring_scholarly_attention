# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
df = pd.read_csv(r"C:\Users\Yasaman\Downloads\Attention-fractional counting.csv")
df.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'affiliation_country': 'Aff_country'}, inplace=True)
df=df[(df['Mention_country'].isin(possible_iso))&(df['Aff_country'].isin(possible_iso))]
df = df[df['year'].isin(np.arange(2002, 2020))]
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df=df[~df['subjarea'].isin(physical_sciences)]
df=df[df['Mention_country']==df['Aff_country']]
df=df.groupby(['year', 'Mention_country'])['count'].sum().reset_index()


data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))


# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# tkm
# 1

# %%
df_complete['hue']=df_complete['treated_CW']*2 +df_complete['treated_GC']*3+df_complete['treated_GO']

# %%
df_p=df_complete[df_complete['year']<2011].reset_index(drop=True)
df_p['time']=df_p['year'].min()-df_p['year']
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * time + treated_GO * time +treated_CW * time +log_gdp+log_Rpop +C(Mention_country) + C(year)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                     13.30
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           5.95e-19
# Time:                        21:22:32   Log-Likelihood:                 168.04
# No. Observations:                1305   AIC:                            -20.08
# Df Residuals:                    1147   BIC:                             797.4
# Df Model:                         157
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -2.0417      0.409     -4.993      0.000      -2.843      -1.240
# C(Mention_country)[T.ago]    -0.4438      0.120     -3.712      0.000      -0.678      -0.209
# C(Mention_country)[T.alb]    -0.5533      0.181     -3.053      0.002      -0.908      -0.198
# C(Mention_country)[T.are]    -0.6228      0.389     -1.602      0.109      -1.385       0.139
# C(Mention_country)[T.arg]    -0.2701      0.530     -0.509      0.611      -1.310       0.770
# C(Mention_country)[T.arm]    -2.1381      0.291     -7.354      0.000      -2.708      -1.568
# C(Mention_country)[T.aus]     0.0198      0.653      0.030      0.976      -1.259       1.299
# C(Mention_country)[T.aut]    -1.4631      0.567     -2.578      0.010      -2.575      -0.351
# C(Mention_country)[T.aze]    -1.6508      0.283     -5.835      0.000      -2.205      -1.096
# C(Mention_country)[T.bdi]    -0.2430      0.069     -3.501      0.000      -0.379      -0.107
# C(Mention_country)[T.bel]    -1.4694      0.589     -2.493      0.013      -2.625      -0.314
# C(Mention_country)[T.ben]    -0.2715      0.190     -1.429      0.153      -0.644       0.101
# C(Mention_country)[T.bfa]     0.1649      0.219      0.753      0.452      -0.264       0.594
# C(Mention_country)[T.bgd]     0.1197      0.359      0.334      0.738      -0.583       0.823
# C(Mention_country)[T.bgr]    -1.0386      0.422     -2.458      0.014      -1.867      -0.211
# C(Mention_country)[T.bhr]    -0.0705      0.113     -0.621      0.535      -0.293       0.152
# C(Mention_country)[T.bih]    -0.9926      0.282     -3.520      0.000      -1.545      -0.440
# C(Mention_country)[T.blr]    -2.1144      0.370     -5.722      0.000      -2.839      -1.390
# C(Mention_country)[T.bol]    -0.0221      0.180     -0.122      0.903      -0.376       0.331
# C(Mention_country)[T.bra]    -0.0319      0.647     -0.049      0.961      -1.301       1.237
# C(Mention_country)[T.bwa]     0.3550      0.248      1.429      0.153      -0.132       0.842
# C(Mention_country)[T.caf]    -0.1306      0.036     -3.606      0.000      -0.202      -0.060
# C(Mention_country)[T.can]    -0.6380      0.685     -0.932      0.351      -1.980       0.704
# C(Mention_country)[T.che]    -1.4400      0.616     -2.337      0.019      -2.648      -0.232
# C(Mention_country)[T.chl]    -0.2768      0.480     -0.576      0.564      -1.218       0.665
# C(Mention_country)[T.chn]    -0.7822      0.762     -1.026      0.305      -2.276       0.712
# C(Mention_country)[T.civ]    -2.5024      0.261     -9.592      0.000      -3.014      -1.991
# C(Mention_country)[T.cmr]     0.1343      0.291      0.462      0.644      -0.436       0.704
# C(Mention_country)[T.col]    -0.2614      0.416     -0.629      0.530      -1.076       0.554
# C(Mention_country)[T.cri]     0.1058      0.283      0.373      0.709      -0.450       0.661
# C(Mention_country)[T.cub]    -0.9214      0.422     -2.184      0.029      -1.748      -0.095
# C(Mention_country)[T.cyp]    -0.6491      0.342     -1.896      0.058      -1.320       0.022
# C(Mention_country)[T.cze]    -0.8075      0.539     -1.500      0.134      -1.863       0.248
# C(Mention_country)[T.deu]    -1.2699      0.730     -1.741      0.082      -2.700       0.160
# C(Mention_country)[T.dji]     0.0237      0.132      0.180      0.857      -0.234       0.282
# C(Mention_country)[T.dnk]    -0.9296      0.569     -1.634      0.102      -2.045       0.185
# C(Mention_country)[T.dom]    -0.5501      0.159     -3.452      0.001      -0.862      -0.238
# C(Mention_country)[T.dza]    -1.2432      0.393     -3.163      0.002      -2.013      -0.473
# C(Mention_country)[T.ecu]    -0.2729      0.244     -1.119      0.263      -0.751       0.205
# C(Mention_country)[T.egy]    -0.3087      0.177     -1.742      0.081      -0.656       0.039
# C(Mention_country)[T.eri]     0.1360      0.028      4.845      0.000       0.081       0.191
# C(Mention_country)[T.esp]    -0.7746      0.685     -1.131      0.258      -2.117       0.567
# C(Mention_country)[T.est]    -0.5222      0.383     -1.364      0.173      -1.273       0.228
# C(Mention_country)[T.eth]     0.7649      0.282      2.717      0.007       0.213       1.317
# C(Mention_country)[T.fin]    -0.5638      0.569     -0.991      0.322      -1.679       0.551
# C(Mention_country)[T.fra]    -1.3626      0.712     -1.913      0.056      -2.758       0.033
# C(Mention_country)[T.gab]    -0.4244      0.216     -1.961      0.050      -0.849      -0.000
# C(Mention_country)[T.gbr]    -0.3324      0.733     -0.453      0.650      -1.770       1.105
# C(Mention_country)[T.gha]     0.2870      0.271      1.058      0.290      -0.245       0.819
# C(Mention_country)[T.gmb]    -1.1420      0.118     -9.660      0.000      -1.374      -0.910
# C(Mention_country)[T.grc]    -0.7539      0.565     -1.335      0.182      -1.861       0.353
# C(Mention_country)[T.gtm]    -0.2815      0.158     -1.776      0.076      -0.592       0.029
# C(Mention_country)[T.hkg]    -0.1800      0.522     -0.345      0.730      -1.204       0.843
# C(Mention_country)[T.hnd]    -0.3986      0.099     -4.012      0.000      -0.593      -0.204
# C(Mention_country)[T.hrv]    -0.5006      0.477     -1.049      0.294      -1.436       0.435
# C(Mention_country)[T.hti]    -0.2527      0.070     -3.635      0.000      -0.389      -0.116
# C(Mention_country)[T.hun]    -0.8716      0.509     -1.711      0.087      -1.870       0.127
# C(Mention_country)[T.idn]    -0.2915      0.355     -0.820      0.412      -0.988       0.405
# C(Mention_country)[T.ind]    -0.1848      0.657     -0.281      0.778      -1.472       1.103
# C(Mention_country)[T.irn]    -0.2851      0.537     -0.531      0.596      -1.338       0.768
# C(Mention_country)[T.irq]    -0.3188      0.241     -1.323      0.186      -0.791       0.154
# C(Mention_country)[T.isr]    -0.7884      0.569     -1.385      0.166      -1.904       0.327
# C(Mention_country)[T.ita]    -1.0117      0.703     -1.439      0.150      -2.390       0.367
# C(Mention_country)[T.jam]     0.0090      0.248      0.036      0.971      -0.477       0.495
# C(Mention_country)[T.jor]     0.3797      0.107      3.559      0.000       0.171       0.589
# C(Mention_country)[T.jpn]    -1.0949      0.755     -1.449      0.147      -2.575       0.386
# C(Mention_country)[T.kaz]    -1.4731      0.290     -5.071      0.000      -2.042      -0.904
# C(Mention_country)[T.ken]     0.3823      0.339      1.126      0.260      -0.283       1.047
# C(Mention_country)[T.kgz]    -0.7739      0.103     -7.523      0.000      -0.976      -0.572
# C(Mention_country)[T.khm]    -0.0439      0.144     -0.305      0.761      -0.326       0.238
# C(Mention_country)[T.kor]    -1.1110      0.649     -1.711      0.087      -2.383       0.161
# C(Mention_country)[T.kwt]     0.0941      0.127      0.741      0.459      -0.155       0.343
# C(Mention_country)[T.lao]    -0.7285      0.113     -6.435      0.000      -0.950      -0.507
# C(Mention_country)[T.lbn]    -0.6473      0.338     -1.917      0.055      -1.309       0.015
# C(Mention_country)[T.lbr]     0.1692      0.137      1.232      0.218      -0.100       0.438
# C(Mention_country)[T.lby]    -0.2590      0.088     -2.955      0.003      -0.431      -0.087
# C(Mention_country)[T.lka]     0.1780      0.282      0.632      0.527      -0.374       0.730
# C(Mention_country)[T.lso]    -0.0185      0.063     -0.295      0.768      -0.141       0.104
# C(Mention_country)[T.ltu]    -0.7486      0.414     -1.809      0.070      -1.560       0.062
# C(Mention_country)[T.lva]    -1.3743      0.332     -4.139      0.000      -2.025      -0.723
# C(Mention_country)[T.mar]    -0.6204      0.168     -3.686      0.000      -0.950      -0.291
# C(Mention_country)[T.mda]    -2.1327      0.208    -10.253      0.000      -2.540      -1.725
# C(Mention_country)[T.mdg]     0.1901      0.187      1.014      0.310      -0.177       0.558
# C(Mention_country)[T.mex]    -0.2880      0.558     -0.516      0.606      -1.381       0.805
# C(Mention_country)[T.mkd]    -1.2107      0.269     -4.502      0.000      -1.738      -0.684
# C(Mention_country)[T.mli]    -0.1481      0.176     -0.843      0.399      -0.493       0.196
# C(Mention_country)[T.mmr]    -0.2832      0.098     -2.895      0.004      -0.475      -0.092
# C(Mention_country)[T.mng]    -0.2483      0.160     -1.552      0.121      -0.562       0.065
# C(Mention_country)[T.moz]     0.0801      0.129      0.619      0.536      -0.174       0.334
# C(Mention_country)[T.mrt]    -0.6254      0.083     -7.572      0.000      -0.787      -0.464
# C(Mention_country)[T.mus]     0.0745      0.201      0.371      0.711      -0.320       0.469
# C(Mention_country)[T.mwi]     0.4262      0.197      2.166      0.030       0.041       0.812
# C(Mention_country)[T.mys]    -0.2917      0.465     -0.627      0.531      -1.204       0.620
# C(Mention_country)[T.nam]     0.0800      0.173      0.462      0.644      -0.259       0.419
# C(Mention_country)[T.ner]    -0.9153      0.103     -8.920      0.000      -1.116      -0.714
# C(Mention_country)[T.nga]     0.7510      0.438      1.714      0.087      -0.108       1.610
# C(Mention_country)[T.nic]    -0.1865      0.118     -1.576      0.115      -0.418       0.045
# C(Mention_country)[T.nld]    -0.9347      0.641     -1.459      0.145      -2.190       0.321
# C(Mention_country)[T.nor]    -0.4550      0.566     -0.804      0.422      -1.565       0.655
# C(Mention_country)[T.npl]     0.3573      0.277      1.292      0.196      -0.185       0.899
# C(Mention_country)[T.nzl]     0.3843      0.522      0.736      0.462      -0.640       1.408
# C(Mention_country)[T.omn]     0.0046      0.064      0.073      0.942      -0.120       0.130
# C(Mention_country)[T.pak]     0.0813      0.446      0.182      0.855      -0.793       0.956
# C(Mention_country)[T.pan]    -0.0816      0.216     -0.378      0.705      -0.504       0.341
# C(Mention_country)[T.per]    -0.1734      0.321     -0.540      0.589      -0.803       0.456
# C(Mention_country)[T.phl]    -0.0849      0.318     -0.267      0.790      -0.708       0.539
# C(Mention_country)[T.pol]    -0.7582      0.597     -1.270      0.204      -1.928       0.412
# C(Mention_country)[T.pri]    -0.6652      0.362     -1.839      0.066      -1.374       0.044
# C(Mention_country)[T.prt]    -0.8889      0.533     -1.669      0.095      -1.933       0.155
# C(Mention_country)[T.pry]    -0.8093      0.151     -5.354      0.000      -1.106      -0.513
# C(Mention_country)[T.pse]    -0.4709      0.185     -2.546      0.011      -0.833      -0.108
# C(Mention_country)[T.qat]    -0.6804      0.356     -1.910      0.056      -1.378       0.018
# C(Mention_country)[T.rou]    -1.5027      0.476     -3.154      0.002      -2.436      -0.569
# C(Mention_country)[T.rus]    -1.9092      0.638     -2.992      0.003      -3.160      -0.659
# C(Mention_country)[T.rwa]    -0.1808      0.065     -2.763      0.006      -0.309      -0.053
# C(Mention_country)[T.sau]    -0.1560      0.439     -0.355      0.722      -1.017       0.705
# C(Mention_country)[T.sen]    -0.2392      0.264     -0.905      0.365      -0.757       0.279
# C(Mention_country)[T.sgp]    -0.8959      0.522     -1.717      0.086      -1.919       0.127
# C(Mention_country)[T.sle]    -0.0451      0.017     -2.668      0.008      -0.078      -0.012
# C(Mention_country)[T.slv]    -0.5288      0.136     -3.888      0.000      -0.795      -0.262
# C(Mention_country)[T.som]     0.6894      0.170      4.060      0.000       0.357       1.022
# C(Mention_country)[T.svk]    -0.8084      0.461     -1.755      0.079      -1.711       0.094
# C(Mention_country)[T.svn]    -0.7886      0.456     -1.731      0.083      -1.682       0.104
# C(Mention_country)[T.swe]    -0.6150      0.614     -1.001      0.317      -1.819       0.589
# C(Mention_country)[T.syr]    -0.2069      0.103     -2.015      0.044      -0.408      -0.006
# C(Mention_country)[T.tcd]    -0.0913      0.045     -2.033      0.042      -0.179      -0.003
# C(Mention_country)[T.tgo]    -0.2611      0.128     -2.032      0.042      -0.513      -0.009
# C(Mention_country)[T.tha]    -0.3386      0.482     -0.703      0.482      -1.282       0.605
# C(Mention_country)[T.tjk]    -1.2161      0.076    -16.027      0.000      -1.365      -1.067
# C(Mention_country)[T.tkm]    -0.2021      0.166     -1.220      0.222      -0.527       0.123
# C(Mention_country)[T.tto]    -1.0025      0.285     -3.522      0.000      -1.560      -0.445
# C(Mention_country)[T.tun]    -0.3189      0.138     -2.306      0.021      -0.590      -0.048
# C(Mention_country)[T.tur]     0.0229      0.599      0.038      0.969      -1.152       1.198
# C(Mention_country)[T.tza]     0.5313      0.276      1.923      0.054      -0.010       1.073
# C(Mention_country)[T.uga]     0.4964      0.275      1.808      0.071      -0.042       1.035
# C(Mention_country)[T.ukr]    -2.2886      0.484     -4.730      0.000      -3.237      -1.340
# C(Mention_country)[T.ury]    -0.8642      0.332     -2.606      0.009      -1.514      -0.214
# C(Mention_country)[T.usa]    -0.7601      0.850     -0.894      0.371      -2.427       0.906
# C(Mention_country)[T.uzb]    -1.6389      0.270     -6.063      0.000      -2.169      -1.109
# C(Mention_country)[T.ven]    -0.2824      0.420     -0.672      0.501      -1.106       0.541
# C(Mention_country)[T.vnm]    -0.2570      0.314     -0.817      0.414      -0.873       0.359
# C(Mention_country)[T.yem]     0.2799      0.055      5.053      0.000       0.171       0.388
# C(Mention_country)[T.zaf]     0.3856      0.496      0.778      0.437      -0.586       1.357
# C(Mention_country)[T.zmb]     0.1423      0.171      0.831      0.406      -0.193       0.478
# C(Mention_country)[T.zwe]     0.3480      0.231      1.507      0.132      -0.105       0.800
# C(year)[T.2003.0]            -0.0250      0.024     -1.062      0.288      -0.071       0.021
# C(year)[T.2004.0]            -0.0530      0.026     -2.036      0.042      -0.104      -0.002
# C(year)[T.2005.0]            -0.0594      0.018     -3.245      0.001      -0.095      -0.024
# C(year)[T.2006.0]             0.0018      0.017      0.101      0.919      -0.032       0.036
# C(year)[T.2007.0]            -0.0149      0.019     -0.781      0.435      -0.052       0.022
# C(year)[T.2008.0]             0.0065      0.016      0.410      0.682      -0.024       0.037
# C(year)[T.2009.0]             0.0253      0.018      1.380      0.168      -0.011       0.061
# C(year)[T.2010.0]             0.0211      0.017      1.249      0.212      -0.012       0.054
# treated_GC                   -0.2124      0.285     -0.745      0.456      -0.771       0.346
# time                         -0.0080      0.011     -0.733      0.464      -0.029       0.013
# treated_GC:time               0.0097      0.008      1.244      0.213      -0.006       0.025
# treated_GO                   -0.6275      0.308     -2.034      0.042      -1.232      -0.023
# treated_GO:time              -0.0526      0.032     -1.657      0.097      -0.115       0.010
# treated_CW                   -0.1860      0.147     -1.268      0.205      -0.473       0.101
# treated_CW:time               0.0140      0.007      2.009      0.045       0.000       0.028
# log_gdp                       0.0749      0.062      1.199      0.230      -0.047       0.197
# log_Rpop                      0.8311      0.085      9.799      0.000       0.665       0.997
# ==============================================================================
# Omnibus:                      114.428   Durbin-Watson:                   1.712
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              695.488
# Skew:                          -0.035   Prob(JB):                    9.48e-152
# Kurtosis:                       6.576   Cond. No.                     1.27e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.21e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 161, but rank is 13
#   warnings.warn('covariance of constraints does not have full '

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='hue')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foreign attention')
# Out:
# Text(0, 0.5, 'log Foreign attention')

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * post + treated_GO * post +treated_CW * post +log_gdp+log_Rpop+C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                     24.82
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           2.17e-38
# Time:                        21:23:29   Log-Likelihood:                -3.6111
# No. Observations:                2610   AIC:                             341.2
# Df Residuals:                    2443   BIC:                             1321.
# Df Model:                         166
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -1.8856      0.313     -6.019      0.000      -2.500      -1.272
# C(Mention_country)[T.ago]    -0.2548      0.072     -3.530      0.000      -0.396      -0.113
# C(Mention_country)[T.alb]    -0.2428      0.123     -1.976      0.048      -0.484      -0.002
# C(Mention_country)[T.are]    -0.3694      0.261     -1.415      0.157      -0.881       0.142
# C(Mention_country)[T.arg]    -0.0003      0.380     -0.001      0.999      -0.746       0.745
# C(Mention_country)[T.arm]    -1.6529      0.188     -8.804      0.000      -2.021      -1.285
# C(Mention_country)[T.aus]     0.3328      0.470      0.708      0.479      -0.589       1.254
# C(Mention_country)[T.aut]    -1.1668      0.394     -2.961      0.003      -1.939      -0.395
# C(Mention_country)[T.aze]    -1.3318      0.190     -6.995      0.000      -1.705      -0.959
# C(Mention_country)[T.bdi]    -0.2823      0.052     -5.399      0.000      -0.385      -0.180
# C(Mention_country)[T.bel]    -1.1582      0.412     -2.812      0.005      -1.966      -0.351
# C(Mention_country)[T.ben]    -0.0948      0.130     -0.727      0.467      -0.350       0.161
# C(Mention_country)[T.bfa]     0.1729      0.149      1.162      0.245      -0.119       0.465
# C(Mention_country)[T.bgd]     0.2838      0.265      1.073      0.283      -0.235       0.802
# C(Mention_country)[T.bgr]    -0.6670      0.289     -2.306      0.021      -1.234      -0.100
# C(Mention_country)[T.bhr]    -0.0526      0.082     -0.639      0.523      -0.214       0.109
# C(Mention_country)[T.bih]    -0.7871      0.195     -4.037      0.000      -1.169      -0.405
# C(Mention_country)[T.blr]    -1.8064      0.243     -7.440      0.000      -2.282      -1.331
# C(Mention_country)[T.bol]    -0.0968      0.110     -0.879      0.379      -0.312       0.119
# C(Mention_country)[T.bra]     0.2483      0.485      0.512      0.608      -0.701       1.198
# C(Mention_country)[T.bwa]     0.3930      0.152      2.583      0.010       0.095       0.691
# C(Mention_country)[T.caf]    -0.1960      0.004    -45.102      0.000      -0.205      -0.187
# C(Mention_country)[T.can]    -0.2702      0.491     -0.551      0.582      -1.232       0.691
# C(Mention_country)[T.che]    -1.0983      0.433     -2.535      0.011      -1.947      -0.249
# C(Mention_country)[T.chl]     0.0340      0.346      0.098      0.922      -0.644       0.712
# C(Mention_country)[T.chn]    -0.4233      0.588     -0.719      0.472      -1.577       0.730
# C(Mention_country)[T.civ]    -2.6735      0.173    -15.498      0.000      -3.012      -2.335
# C(Mention_country)[T.cmr]     0.1846      0.209      0.885      0.376      -0.224       0.594
# C(Mention_country)[T.col]     0.0945      0.314      0.301      0.763      -0.520       0.709
# C(Mention_country)[T.cri]     0.1928      0.185      1.042      0.297      -0.170       0.556
# C(Mention_country)[T.cub]    -0.6177      0.286     -2.161      0.031      -1.178      -0.057
# C(Mention_country)[T.cyp]    -0.4051      0.222     -1.826      0.068      -0.840       0.030
# C(Mention_country)[T.cze]    -0.4740      0.382     -1.241      0.215      -1.222       0.274
# C(Mention_country)[T.deu]    -0.9282      0.526     -1.764      0.078      -1.959       0.103
# C(Mention_country)[T.dji]    -0.1673      0.109     -1.530      0.126      -0.382       0.047
# C(Mention_country)[T.dnk]    -0.5854      0.396     -1.478      0.139      -1.362       0.191
# C(Mention_country)[T.dom]    -0.5514      0.097     -5.682      0.000      -0.742      -0.361
# C(Mention_country)[T.dza]    -0.8290      0.293     -2.832      0.005      -1.403      -0.255
# C(Mention_country)[T.ecu]    -0.0629      0.182     -0.346      0.729      -0.419       0.293
# C(Mention_country)[T.egy]    -0.1634      0.134     -1.216      0.224      -0.427       0.100
# C(Mention_country)[T.eri]    -0.0179      0.030     -0.588      0.556      -0.077       0.042
# C(Mention_country)[T.esp]    -0.3988      0.494     -0.808      0.419      -1.366       0.569
# C(Mention_country)[T.est]    -0.3517      0.259     -1.360      0.174      -0.859       0.155
# C(Mention_country)[T.eth]     0.9185      0.218      4.208      0.000       0.491       1.346
# C(Mention_country)[T.fin]    -0.2736      0.391     -0.699      0.484      -1.040       0.493
# C(Mention_country)[T.fra]    -1.0161      0.509     -1.994      0.046      -2.015      -0.018
# C(Mention_country)[T.gab]    -0.2438      0.124     -1.967      0.049      -0.487      -0.001
# C(Mention_country)[T.gbr]    -0.0039      0.527     -0.007      0.994      -1.036       1.028
# C(Mention_country)[T.gha]     0.5132      0.207      2.481      0.013       0.108       0.919
# C(Mention_country)[T.gmb]    -1.0723      0.057    -18.839      0.000      -1.184      -0.961
# C(Mention_country)[T.grc]    -0.4575      0.390     -1.173      0.241      -1.222       0.307
# C(Mention_country)[T.gtm]    -0.2057      0.096     -2.139      0.032      -0.394      -0.017
# C(Mention_country)[T.hkg]    -0.0038      0.360     -0.011      0.992      -0.710       0.702
# C(Mention_country)[T.hnd]    -0.3398      0.056     -6.032      0.000      -0.450      -0.229
# C(Mention_country)[T.hrv]    -0.2566      0.330     -0.778      0.437      -0.904       0.390
# C(Mention_country)[T.hti]    -0.1706      0.039     -4.326      0.000      -0.248      -0.093
# C(Mention_country)[T.hun]    -0.5984      0.354     -1.690      0.091      -1.292       0.095
# C(Mention_country)[T.idn]    -0.0237      0.293     -0.081      0.936      -0.599       0.551
# C(Mention_country)[T.ind]     0.0652      0.498      0.131      0.896      -0.911       1.042
# C(Mention_country)[T.irn]     0.1384      0.416      0.333      0.740      -0.677       0.954
# C(Mention_country)[T.irq]    -0.2841      0.206     -1.378      0.168      -0.688       0.120
# C(Mention_country)[T.isr]    -0.5298      0.397     -1.336      0.182      -1.307       0.248
# C(Mention_country)[T.ita]    -0.5947      0.504     -1.179      0.238      -1.583       0.394
# C(Mention_country)[T.jam]     0.1329      0.144      0.920      0.357      -0.150       0.416
# C(Mention_country)[T.jor]     0.3351      0.079      4.227      0.000       0.180       0.491
# C(Mention_country)[T.jpn]    -0.7185      0.539     -1.333      0.183      -1.775       0.338
# C(Mention_country)[T.kaz]    -0.8075      0.232     -3.479      0.001      -1.262      -0.353
# C(Mention_country)[T.ken]     0.4930      0.244      2.022      0.043       0.015       0.971
# C(Mention_country)[T.kgz]    -0.5087      0.061     -8.342      0.000      -0.628      -0.389
# C(Mention_country)[T.khm]     0.0579      0.098      0.593      0.553      -0.133       0.249
# C(Mention_country)[T.kor]    -0.6143      0.476     -1.292      0.196      -1.547       0.318
# C(Mention_country)[T.kwt]     0.0778      0.071      1.094      0.274      -0.062       0.217
# C(Mention_country)[T.lao]    -0.6267      0.074     -8.519      0.000      -0.771      -0.483
# C(Mention_country)[T.lbn]    -0.4419      0.234     -1.891      0.059      -0.900       0.016
# C(Mention_country)[T.lbr]    -0.0432      0.074     -0.586      0.558      -0.188       0.101
# C(Mention_country)[T.lby]    -0.2184      0.066     -3.333      0.001      -0.347      -0.090
# C(Mention_country)[T.lka]     0.3213      0.200      1.607      0.108      -0.070       0.713
# C(Mention_country)[T.lso]     0.0520      0.048      1.072      0.284      -0.043       0.147
# C(Mention_country)[T.ltu]    -0.4934      0.285     -1.734      0.083      -1.051       0.064
# C(Mention_country)[T.lva]    -0.8357      0.225     -3.713      0.000      -1.277      -0.395
# C(Mention_country)[T.mar]    -0.5112      0.131     -3.914      0.000      -0.767      -0.255
# C(Mention_country)[T.mda]    -1.6153      0.130    -12.412      0.000      -1.870      -1.360
# C(Mention_country)[T.mdg]     0.1514      0.121      1.248      0.212      -0.086       0.389
# C(Mention_country)[T.mex]     0.0002      0.405      0.000      1.000      -0.793       0.794
# C(Mention_country)[T.mkd]    -0.7562      0.178     -4.239      0.000      -1.106      -0.407
# C(Mention_country)[T.mli]    -0.1922      0.109     -1.759      0.079      -0.406       0.022
# C(Mention_country)[T.mmr]    -0.2075      0.067     -3.116      0.002      -0.338      -0.077
# C(Mention_country)[T.mng]    -0.2448      0.111     -2.206      0.027      -0.462      -0.027
# C(Mention_country)[T.moz]     0.1388      0.088      1.581      0.114      -0.033       0.311
# C(Mention_country)[T.mrt]    -0.5661      0.054    -10.514      0.000      -0.672      -0.461
# C(Mention_country)[T.mus]     0.1958      0.121      1.625      0.104      -0.040       0.432
# C(Mention_country)[T.mwi]     0.4754      0.136      3.490      0.000       0.208       0.742
# C(Mention_country)[T.mys]     0.0916      0.359      0.255      0.799      -0.612       0.795
# C(Mention_country)[T.nam]     0.1113      0.104      1.074      0.283      -0.092       0.314
# C(Mention_country)[T.ner]    -0.9137      0.058    -15.697      0.000      -1.028      -0.800
# C(Mention_country)[T.nga]     0.8538      0.322      2.653      0.008       0.223       1.484
# C(Mention_country)[T.nic]    -0.1927      0.059     -3.283      0.001      -0.308      -0.078
# C(Mention_country)[T.nld]    -0.5767      0.453     -1.274      0.203      -1.464       0.310
# C(Mention_country)[T.nor]    -0.1430      0.390     -0.367      0.714      -0.908       0.622
# C(Mention_country)[T.npl]     0.4237      0.199      2.128      0.033       0.033       0.814
# C(Mention_country)[T.nzl]     0.6195      0.361      1.717      0.086      -0.088       1.327
# C(Mention_country)[T.omn]     0.1027      0.040      2.566      0.010       0.024       0.181
# C(Mention_country)[T.pak]     0.2669      0.341      0.782      0.434      -0.402       0.936
# C(Mention_country)[T.pan]     0.0278      0.139      0.200      0.841      -0.244       0.300
# C(Mention_country)[T.per]     0.0701      0.231      0.303      0.762      -0.383       0.524
# C(Mention_country)[T.phl]     0.1366      0.231      0.591      0.555      -0.316       0.589
# C(Mention_country)[T.pol]    -0.4015      0.432     -0.930      0.352      -1.247       0.444
# C(Mention_country)[T.pri]    -0.4558      0.223     -2.040      0.041      -0.894      -0.018
# C(Mention_country)[T.prt]    -0.5166      0.381     -1.357      0.175      -1.263       0.229
# C(Mention_country)[T.pry]    -0.6208      0.098     -6.360      0.000      -0.812      -0.430
# C(Mention_country)[T.pse]    -0.3341      0.126     -2.660      0.008      -0.580      -0.088
# C(Mention_country)[T.qat]    -0.4946      0.236     -2.095      0.036      -0.957      -0.032
# C(Mention_country)[T.rou]    -0.8621      0.346     -2.490      0.013      -1.541      -0.184
# C(Mention_country)[T.rus]    -1.2432      0.468     -2.654      0.008      -2.161      -0.325
# C(Mention_country)[T.rwa]    -0.0248      0.066     -0.377      0.706      -0.154       0.104
# C(Mention_country)[T.sau]     0.0375      0.325      0.116      0.908      -0.599       0.674
# C(Mention_country)[T.sen]    -0.1203      0.175     -0.688      0.492      -0.463       0.223
# C(Mention_country)[T.sgp]    -0.6283      0.367     -1.710      0.087      -1.348       0.092
# C(Mention_country)[T.sle]    -0.0872      0.000   -207.350      0.000      -0.088      -0.086
# C(Mention_country)[T.slv]    -0.5289      0.077     -6.846      0.000      -0.680      -0.377
# C(Mention_country)[T.som]     0.1734      0.123      1.411      0.158      -0.067       0.414
# C(Mention_country)[T.svk]    -0.4709      0.318     -1.479      0.139      -1.095       0.153
# C(Mention_country)[T.svn]    -0.4195      0.308     -1.361      0.173      -1.023       0.184
# C(Mention_country)[T.swe]    -0.2716      0.428     -0.634      0.526      -1.111       0.568
# C(Mention_country)[T.syr]    -0.1089      0.057     -1.914      0.056      -0.221       0.003
# C(Mention_country)[T.tcd]    -0.2636      0.040     -6.530      0.000      -0.343      -0.184
# C(Mention_country)[T.tgo]    -0.1720      0.081     -2.134      0.033      -0.330      -0.014
# C(Mention_country)[T.tha]    -0.0937      0.354     -0.265      0.791      -0.787       0.599
# C(Mention_country)[T.tjk]    -0.9841      0.035    -27.726      0.000      -1.054      -0.915
# C(Mention_country)[T.tkm]    -0.2006      0.160     -1.251      0.211      -0.515       0.114
# C(Mention_country)[T.tto]    -0.7831      0.171     -4.586      0.000      -1.118      -0.448
# C(Mention_country)[T.tun]    -0.1895      0.089     -2.138      0.033      -0.363      -0.016
# C(Mention_country)[T.tur]     0.2427      0.438      0.554      0.580      -0.616       1.102
# C(Mention_country)[T.tza]     0.6387      0.195      3.272      0.001       0.256       1.021
# C(Mention_country)[T.uga]     0.5839      0.200      2.921      0.003       0.192       0.976
# C(Mention_country)[T.ukr]    -1.5541      0.350     -4.446      0.000      -2.239      -0.869
# C(Mention_country)[T.ury]    -0.6107      0.227     -2.693      0.007      -1.055      -0.166
# C(Mention_country)[T.usa]    -0.3119      0.622     -0.502      0.616      -1.531       0.907
# C(Mention_country)[T.uzb]    -1.4461      0.174     -8.317      0.000      -1.787      -1.105
# C(Mention_country)[T.ven]    -0.2099      0.274     -0.765      0.444      -0.748       0.328
# C(Mention_country)[T.vnm]    -0.1533      0.249     -0.617      0.537      -0.641       0.334
# C(Mention_country)[T.yem]     0.2400      0.021     11.205      0.000       0.198       0.282
# C(Mention_country)[T.zaf]     0.7063      0.357      1.980      0.048       0.007       1.405
# C(Mention_country)[T.zmb]     0.2235      0.119      1.884      0.060      -0.009       0.456
# C(Mention_country)[T.zwe]     0.4960      0.153      3.250      0.001       0.197       0.795
# C(year)[T.2003.0]            -0.0114      0.026     -0.432      0.666      -0.063       0.040
# C(year)[T.2004.0]            -0.0249      0.034     -0.734      0.463      -0.092       0.042
# C(year)[T.2005.0]            -0.0177      0.033     -0.541      0.588      -0.082       0.046
# C(year)[T.2006.0]             0.0569      0.038      1.513      0.130      -0.017       0.131
# C(year)[T.2007.0]             0.0551      0.046      1.190      0.234      -0.036       0.146
# C(year)[T.2008.0]             0.0912      0.054      1.694      0.090      -0.014       0.197
# C(year)[T.2009.0]             0.1168      0.059      1.987      0.047       0.002       0.232
# C(year)[T.2010.0]             0.1252      0.061      2.066      0.039       0.006       0.244
# C(year)[T.2011.0]            -0.0510      0.020     -2.521      0.012      -0.091      -0.011
# C(year)[T.2012.0]            -0.0341      0.017     -2.042      0.041      -0.067      -0.001
# C(year)[T.2013.0]             0.0090      0.016      0.554      0.580      -0.023       0.041
# C(year)[T.2014.0]             0.0280      0.016      1.790      0.073      -0.003       0.059
# C(year)[T.2015.0]            -0.0070      0.012     -0.580      0.562      -0.031       0.017
# C(year)[T.2016.0]             0.0282      0.017      1.612      0.107      -0.006       0.062
# C(year)[T.2017.0]             0.0311      0.024      1.312      0.190      -0.015       0.077
# C(year)[T.2018.0]             0.0619      0.026      2.351      0.019       0.010       0.114
# C(year)[T.2019.0]             0.1612      0.034      4.807      0.000       0.095       0.227
# treated_GC                   -0.0482      0.190     -0.254      0.800      -0.420       0.324
# post                          0.2272      0.073      3.112      0.002       0.084       0.370
# treated_GC:post              -0.1056      0.073     -1.439      0.150      -0.250       0.038
# treated_GO                   -0.3530      0.221     -1.600      0.110      -0.785       0.079
# treated_GO:post               0.1607      0.040      4.044      0.000       0.083       0.239
# treated_CW                   -0.0873      0.093     -0.943      0.346      -0.269       0.094
# treated_CW:post              -0.2528      0.050     -5.096      0.000      -0.350      -0.156
# log_gdp                       0.0371      0.039      0.958      0.338      -0.039       0.113
# log_Rpop                      0.8215      0.067     12.254      0.000       0.690       0.953
# ==============================================================================
# Omnibus:                      249.611   Durbin-Watson:                   1.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1656.032
# Skew:                           0.155   Prob(JB):                         0.00
# Kurtosis:                       6.890   Cond. No.                     5.24e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.35e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 170, but rank is 22
#   warnings.warn('covariance of constraints does not have full '

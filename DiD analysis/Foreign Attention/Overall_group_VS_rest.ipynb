# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
df = pd.read_csv(r"C:\Users\Yasaman\Downloads\Attention-fractional counting.csv")
df.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'affiliation_country': 'Aff_country'}, inplace=True)
df=df[(df['Mention_country'].isin(possible_iso))&(df['Aff_country'].isin(possible_iso))]
df = df[df['year'].isin(np.arange(2002, 2020))]
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df=df[~df['subjarea'].isin(physical_sciences)]
df=df[df['Mention_country']!=df['Aff_country']]
df=df.groupby(['year', 'Mention_country'])['count'].sum().reset_index()


data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))


# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# 0

# %%
df_complete['hue']=df_complete['treated_CW']*2 +df_complete['treated_GC']*3+df_complete['treated_GO']

# %%
df_p=df_complete[df_complete['year']<2011].reset_index(drop=True)
df_p['time']=df_p['year'].min()-df_p['year']
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * time + treated_GO * time +treated_CW * time +log_gdp+ C(Mention_country) + C(year)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                     207.2
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           2.18e-84
# Time:                        21:17:33   Log-Likelihood:                 628.33
# No. Observations:                1305   AIC:                            -942.7
# Df Residuals:                    1148   BIC:                            -130.3
# Df Model:                         156
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     3.3093      0.249     13.270      0.000       2.821       3.798
# C(Mention_country)[T.ago]    -1.0368      0.090    -11.540      0.000      -1.213      -0.861
# C(Mention_country)[T.alb]    -1.4549      0.105    -13.916      0.000      -1.660      -1.250
# C(Mention_country)[T.are]    -0.6611      0.224     -2.949      0.003      -1.100      -0.222
# C(Mention_country)[T.arg]     0.5773      0.136      4.240      0.000       0.310       0.844
# C(Mention_country)[T.arm]    -1.8552      0.085    -21.798      0.000      -2.022      -1.688
# C(Mention_country)[T.aus]     1.2737      0.221      5.761      0.000       0.840       1.707
# C(Mention_country)[T.aut]    -0.4260      0.227     -1.876      0.061      -0.871       0.019
# C(Mention_country)[T.aze]    -1.5744      0.094    -16.744      0.000      -1.759      -1.390
# C(Mention_country)[T.bdi]    -2.2552      0.032    -70.582      0.000      -2.318      -2.193
# C(Mention_country)[T.bel]    -0.5278      0.224     -2.352      0.019      -0.968      -0.088
# C(Mention_country)[T.ben]    -0.8633      0.048    -17.946      0.000      -0.958      -0.769
# C(Mention_country)[T.bfa]    -0.3227      0.020    -15.949      0.000      -0.362      -0.283
# C(Mention_country)[T.bgd]     0.7254      0.027     26.761      0.000       0.672       0.779
# C(Mention_country)[T.bgr]    -0.6973      0.125     -5.576      0.000      -0.942      -0.452
# C(Mention_country)[T.bhr]    -1.9119      0.059    -32.265      0.000      -2.028      -1.796
# C(Mention_country)[T.bih]    -1.0020      0.108     -9.254      0.000      -1.214      -0.790
# C(Mention_country)[T.blr]    -1.5651      0.114    -13.784      0.000      -1.788      -1.343
# C(Mention_country)[T.bol]     0.1963      0.066      2.990      0.003       0.068       0.325
# C(Mention_country)[T.bra]     1.4160      0.136     10.440      0.000       1.150       1.682
# C(Mention_country)[T.bwa]    -0.7918      0.129     -6.158      0.000      -1.044      -0.540
# C(Mention_country)[T.caf]    -1.9906      0.007   -268.516      0.000      -2.005      -1.976
# C(Mention_country)[T.can]     1.2524      0.223      5.608      0.000       0.815       1.690
# C(Mention_country)[T.che]     0.0006      0.246      0.002      0.998      -0.481       0.482
# C(Mention_country)[T.chl]     0.5464      0.152      3.586      0.000       0.248       0.845
# C(Mention_country)[T.chn]     2.7261      0.093     29.384      0.000       2.544       2.908
# C(Mention_country)[T.civ]    -3.3869      0.070    -48.291      0.000      -3.524      -3.249
# C(Mention_country)[T.cmr]     0.1489      0.063      2.354      0.019       0.025       0.273
# C(Mention_country)[T.col]     0.0676      0.118      0.572      0.567      -0.164       0.299
# C(Mention_country)[T.cri]     0.2530      0.134      1.887      0.059      -0.010       0.516
# C(Mention_country)[T.cub]    -0.5800      0.121     -4.775      0.000      -0.818      -0.342
# C(Mention_country)[T.cyp]    -1.0221      0.207     -4.935      0.000      -1.428      -0.616
# C(Mention_country)[T.cze]    -0.6167      0.180     -3.419      0.001      -0.970      -0.263
# C(Mention_country)[T.deu]     1.3275      0.222      5.972      0.000       0.892       1.763
# C(Mention_country)[T.dji]    -2.8696      0.052    -55.438      0.000      -2.971      -2.768
# C(Mention_country)[T.dnk]    -0.2302      0.237     -0.970      0.332      -0.695       0.235
# C(Mention_country)[T.dom]    -1.1461      0.118     -9.687      0.000      -1.378      -0.914
# C(Mention_country)[T.dza]    -0.6061      0.110     -5.511      0.000      -0.822      -0.391
# C(Mention_country)[T.ecu]     0.0962      0.111      0.869      0.385      -0.121       0.313
# C(Mention_country)[T.egy]     0.5312      0.019     28.675      0.000       0.495       0.567
# C(Mention_country)[T.eri]    -1.6507      0.015   -109.207      0.000      -1.680      -1.621
# C(Mention_country)[T.esp]     0.7680      0.209      3.679      0.000       0.359       1.177
# C(Mention_country)[T.est]    -1.2349      0.168     -7.345      0.000      -1.564      -0.905
# C(Mention_country)[T.eth]     0.8625      0.019     45.440      0.000       0.825       0.900
# C(Mention_country)[T.fin]    -0.1548      0.228     -0.680      0.497      -0.601       0.292
# C(Mention_country)[T.fra]     1.0705      0.222      4.826      0.000       0.636       1.505
# C(Mention_country)[T.gab]    -1.4708      0.143    -10.291      0.000      -1.751      -1.191
# C(Mention_country)[T.gbr]     1.8805      0.227      8.272      0.000       1.435       2.326
# C(Mention_country)[T.gha]     0.4163      0.038     11.074      0.000       0.343       0.490
# C(Mention_country)[T.gmb]    -2.1566      0.032    -67.319      0.000      -2.219      -2.094
# C(Mention_country)[T.grc]     0.1452      0.203      0.716      0.474      -0.252       0.542
# C(Mention_country)[T.gtm]    -0.4082      0.093     -4.400      0.000      -0.590      -0.226
# C(Mention_country)[T.hkg]     0.5898      0.210      2.804      0.005       0.178       1.002
# C(Mention_country)[T.hnd]    -0.8898      0.072    -12.328      0.000      -1.031      -0.748
# C(Mention_country)[T.hrv]    -1.1655      0.167     -6.963      0.000      -1.494      -0.837
# C(Mention_country)[T.hti]    -1.2308      0.049    -25.145      0.000      -1.327      -1.135
# C(Mention_country)[T.hun]    -0.4645      0.168     -2.767      0.006      -0.794      -0.135
# C(Mention_country)[T.idn]     1.1351      0.077     14.837      0.000       0.985       1.285
# C(Mention_country)[T.ind]     2.1955      0.045     48.390      0.000       2.107       2.284
# C(Mention_country)[T.irn]     0.3079      0.117      2.636      0.008       0.079       0.537
# C(Mention_country)[T.irq]     0.1260      0.092      1.367      0.172      -0.055       0.307
# C(Mention_country)[T.isr]     0.2001      0.203      0.986      0.324      -0.198       0.598
# C(Mention_country)[T.ita]     0.8572      0.218      3.940      0.000       0.431       1.284
# C(Mention_country)[T.jam]    -0.9351      0.123     -7.595      0.000      -1.176      -0.694
# C(Mention_country)[T.jor]     0.8489      0.035     24.504      0.000       0.781       0.917
# C(Mention_country)[T.jpn]     1.3915      0.224      6.203      0.000       0.952       1.831
# C(Mention_country)[T.kaz]    -0.5549      0.125     -4.429      0.000      -0.800      -0.309
# C(Mention_country)[T.ken]     1.0342      0.037     28.022      0.000       0.962       1.107
# C(Mention_country)[T.kgz]    -1.2452      0.030    -41.097      0.000      -1.305      -1.186
# C(Mention_country)[T.khm]    -0.3498      0.026    -13.200      0.000      -0.402      -0.298
# C(Mention_country)[T.kor]     0.3219      0.192      1.676      0.094      -0.054       0.698
# C(Mention_country)[T.kwt]    -1.0097      0.089    -11.335      0.000      -1.184      -0.835
# C(Mention_country)[T.lao]    -0.9945      0.031    -32.251      0.000      -1.055      -0.934
# C(Mention_country)[T.lbn]    -0.9520      0.133     -7.159      0.000      -1.213      -0.691
# C(Mention_country)[T.lbr]    -1.9459      0.004   -541.752      0.000      -1.953      -1.939
# C(Mention_country)[T.lby]    -0.7218      0.065    -11.142      0.000      -0.849      -0.595
# C(Mention_country)[T.lka]    -0.0931      0.073     -1.273      0.203      -0.236       0.050
# C(Mention_country)[T.lso]    -1.4970      0.042    -35.520      0.000      -1.580      -1.414
# C(Mention_country)[T.ltu]    -1.4985      0.156     -9.600      0.000      -1.804      -1.193
# C(Mention_country)[T.lva]    -1.7870      0.157    -11.398      0.000      -2.094      -1.480
# C(Mention_country)[T.mar]     1.1111      0.037     30.033      0.000       1.039       1.184
# C(Mention_country)[T.mda]    -1.9156      0.065    -29.375      0.000      -2.043      -1.788
# C(Mention_country)[T.mdg]     0.7148      0.010     69.948      0.000       0.695       0.735
# C(Mention_country)[T.mex]     1.9017      0.157     12.100      0.000       1.594       2.210
# C(Mention_country)[T.mkd]    -1.5756      0.112    -14.040      0.000      -1.796      -1.356
# C(Mention_country)[T.mli]    -0.4010      0.024    -16.412      0.000      -0.449      -0.353
# C(Mention_country)[T.mmr]    -0.4811      0.009    -54.796      0.000      -0.498      -0.464
# C(Mention_country)[T.mng]     0.7178      0.065     11.097      0.000       0.591       0.845
# C(Mention_country)[T.moz]    -0.0475      0.018     -2.594      0.009      -0.083      -0.012
# C(Mention_country)[T.mrt]    -1.7347      0.060    -28.933      0.000      -1.852      -1.617
# C(Mention_country)[T.mus]    -1.7100      0.139    -12.339      0.000      -1.982      -1.438
# C(Mention_country)[T.mwi]     0.0875      0.022      3.989      0.000       0.045       0.131
# C(Mention_country)[T.mys]     0.1316      0.140      0.943      0.346      -0.142       0.405
# C(Mention_country)[T.nam]    -0.4067      0.115     -3.534      0.000      -0.632      -0.181
# C(Mention_country)[T.ner]    -1.2795      0.006   -207.930      0.000      -1.292      -1.267
# C(Mention_country)[T.nga]     0.6338      0.071      8.876      0.000       0.494       0.774
# C(Mention_country)[T.nic]    -0.6164      0.065     -9.447      0.000      -0.744      -0.489
# C(Mention_country)[T.nld]     0.0749      0.232      0.324      0.746      -0.379       0.529
# C(Mention_country)[T.nor]     0.8017      0.252      3.176      0.001       0.307       1.296
# C(Mention_country)[T.npl]     0.6251      0.007     83.659      0.000       0.610       0.640
# C(Mention_country)[T.nzl]     1.6391      0.208      7.882      0.000       1.232       2.047
# C(Mention_country)[T.omn]     0.0665      0.048      1.387      0.165      -0.027       0.160
# C(Mention_country)[T.pak]     0.5387      0.049     11.063      0.000       0.443       0.634
# C(Mention_country)[T.pan]    -0.2383      0.136     -1.749      0.080      -0.505       0.029
# C(Mention_country)[T.per]     0.6770      0.108      6.253      0.000       0.465       0.889
# C(Mention_country)[T.phl]     0.6511      0.074      8.857      0.000       0.507       0.795
# C(Mention_country)[T.pol]     0.1716      0.157      1.095      0.274      -0.136       0.479
# C(Mention_country)[T.pri]    -0.5623      0.200     -2.806      0.005      -0.955      -0.169
# C(Mention_country)[T.prt]    -0.2764      0.194     -1.428      0.153      -0.656       0.103
# C(Mention_country)[T.pry]    -1.1187      0.099    -11.328      0.000      -1.312      -0.925
# C(Mention_country)[T.pse]    -0.9314      0.079    -11.770      0.000      -1.087      -0.776
# C(Mention_country)[T.qat]    -2.6396      0.239    -11.067      0.000      -3.107      -2.172
# C(Mention_country)[T.rou]    -0.4619      0.133     -3.471      0.001      -0.723      -0.201
# C(Mention_country)[T.rus]     1.1753      0.139      8.459      0.000       0.903       1.448
# C(Mention_country)[T.rwa]    -0.8452      0.010    -85.516      0.000      -0.865      -0.826
# C(Mention_country)[T.sau]    -0.4891      0.176     -2.778      0.005      -0.834      -0.144
# C(Mention_country)[T.sen]    -0.2195      0.058     -3.768      0.000      -0.334      -0.105
# C(Mention_country)[T.sgp]    -0.3982      0.217     -1.831      0.067      -0.824       0.028
# C(Mention_country)[T.sle]    -1.1423      0.002   -484.539      0.000      -1.147      -1.138
# C(Mention_country)[T.slv]    -1.4573      0.100    -14.644      0.000      -1.652      -1.262
# C(Mention_country)[T.som]    -0.9353      0.039    -24.172      0.000      -1.011      -0.859
# C(Mention_country)[T.svk]    -0.8709      0.173     -5.027      0.000      -1.210      -0.531
# C(Mention_country)[T.svn]    -1.4225      0.194     -7.349      0.000      -1.802      -1.043
# C(Mention_country)[T.swe]     0.4421      0.232      1.905      0.057      -0.013       0.897
# C(Mention_country)[T.syr]    -0.2490      0.063     -3.948      0.000      -0.373      -0.125
# C(Mention_country)[T.tcd]    -1.2533      0.031    -40.695      0.000      -1.314      -1.193
# C(Mention_country)[T.tgo]    -1.9449      0.024    -82.465      0.000      -1.991      -1.899
# C(Mention_country)[T.tha]     0.8991      0.111      8.113      0.000       0.682       1.116
# C(Mention_country)[T.tjk]    -1.7778      0.014   -125.738      0.000      -1.806      -1.750
# C(Mention_country)[T.tkm]    -2.5306      0.089    -28.552      0.000      -2.704      -2.357
# C(Mention_country)[T.tto]    -2.6306      0.172    -15.338      0.000      -2.967      -2.294
# C(Mention_country)[T.tun]    -0.5397      0.051    -10.576      0.000      -0.640      -0.440
# C(Mention_country)[T.tur]     1.1338      0.148      7.654      0.000       0.843       1.424
# C(Mention_country)[T.tza]     0.9769      0.026     37.766      0.000       0.926       1.028
# C(Mention_country)[T.uga]     0.7273      0.013     56.077      0.000       0.702       0.753
# C(Mention_country)[T.ukr]    -0.2149      0.089     -2.409      0.016      -0.390      -0.040
# C(Mention_country)[T.ury]    -0.9338      0.141     -6.618      0.000      -1.210      -0.657
# C(Mention_country)[T.usa]     2.9669      0.232     12.798      0.000       2.512       3.421
# C(Mention_country)[T.uzb]    -1.1975      0.040    -29.948      0.000      -1.276      -1.119
# C(Mention_country)[T.ven]    -0.2511      0.144     -1.742      0.082      -0.534       0.031
# C(Mention_country)[T.vnm]     1.0970      0.045     24.121      0.000       1.008       1.186
# C(Mention_country)[T.yem]    -0.0885      0.043     -2.051      0.040      -0.173      -0.004
# C(Mention_country)[T.zaf]     1.1775      0.135      8.740      0.000       0.913       1.442
# C(Mention_country)[T.zmb]    -0.3369      0.047     -7.094      0.000      -0.430      -0.244
# C(Mention_country)[T.zwe]     0.2566      0.025     10.236      0.000       0.207       0.306
# C(year)[T.2003.0]            -0.0411      0.016     -2.573      0.010      -0.072      -0.010
# C(year)[T.2004.0]            -0.0846      0.015     -5.489      0.000      -0.115      -0.054
# C(year)[T.2005.0]            -0.0880      0.015     -5.678      0.000      -0.118      -0.058
# C(year)[T.2006.0]            -0.0301      0.013     -2.391      0.017      -0.055      -0.005
# C(year)[T.2007.0]            -0.0224      0.012     -1.849      0.065      -0.046       0.001
# C(year)[T.2008.0]            -0.0259      0.014     -1.903      0.057      -0.053       0.001
# C(year)[T.2009.0]             0.0585      0.009      6.431      0.000       0.041       0.076
# C(year)[T.2010.0]             0.0643      0.012      5.521      0.000       0.041       0.087
# treated_GC                   -0.8951      0.140     -6.377      0.000      -1.170      -0.620
# time                         -0.0612      0.005    -11.482      0.000      -0.072      -0.051
# treated_GC:time              -0.0014      0.019     -0.073      0.942      -0.039       0.036
# treated_GO                   -0.0085      0.067     -0.128      0.898      -0.139       0.122
# treated_GO:time              -0.0075      0.011     -0.661      0.509      -0.030       0.015
# treated_CW                   -1.0593      0.092    -11.570      0.000      -1.239      -0.880
# treated_CW:time              -0.0243      0.012     -2.012      0.044      -0.048      -0.001
# log_gdp                       0.1840      0.046      3.964      0.000       0.093       0.275
# ==============================================================================
# Omnibus:                      258.817   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3028.523
# Skew:                          -0.558   Prob(JB):                         0.00
# Kurtosis:                      10.379   Cond. No.                     9.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.38e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 160, but rank is 12
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ### Notice: Pre-parallel trend test is significant at the Civil War level.

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='hue')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foreign attention')
# Out:
# Text(0, 0.5, 'log Foreign attention')

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * post + treated_GO * post +treated_CW * post +log_gdp+ C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     120.6
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           1.89e-80
# Time:                        21:19:50   Log-Likelihood:                 737.33
# No. Observations:                2610   AIC:                            -1143.
# Df Residuals:                    2444   BIC:                            -168.7
# Df Model:                         165
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     3.6684      0.247     14.827      0.000       3.184       4.153
# C(Mention_country)[T.ago]    -1.1834      0.085    -13.932      0.000      -1.350      -1.017
# C(Mention_country)[T.alb]    -1.6031      0.099    -16.118      0.000      -1.798      -1.408
# C(Mention_country)[T.are]    -0.6519      0.211     -3.091      0.002      -1.065      -0.239
# C(Mention_country)[T.arg]     0.3353      0.139      2.418      0.016       0.063       0.607
# C(Mention_country)[T.arm]    -1.8847      0.087    -21.766      0.000      -2.054      -1.715
# C(Mention_country)[T.aus]     1.0940      0.216      5.062      0.000       0.670       1.518
# C(Mention_country)[T.aut]    -0.5164      0.215     -2.405      0.016      -0.937      -0.096
# C(Mention_country)[T.aze]    -1.4913      0.100    -14.960      0.000      -1.687      -1.296
# C(Mention_country)[T.bdi]    -2.1719      0.035    -61.660      0.000      -2.241      -2.103
# C(Mention_country)[T.bel]    -0.6298      0.212     -2.975      0.003      -1.045      -0.215
# C(Mention_country)[T.ben]    -1.0546      0.040    -26.546      0.000      -1.132      -0.977
# C(Mention_country)[T.bfa]    -0.5390      0.016    -34.399      0.000      -0.570      -0.508
# C(Mention_country)[T.bgd]     0.6176      0.033     18.774      0.000       0.553       0.682
# C(Mention_country)[T.bgr]    -0.9563      0.123     -7.779      0.000      -1.197      -0.715
# C(Mention_country)[T.bhr]    -1.8410      0.058    -31.846      0.000      -1.954      -1.728
# C(Mention_country)[T.bih]    -1.1966      0.104    -11.458      0.000      -1.401      -0.992
# C(Mention_country)[T.blr]    -1.7693      0.112    -15.732      0.000      -1.990      -1.549
# C(Mention_country)[T.bol]    -0.1279      0.071     -1.813      0.070      -0.266       0.010
# C(Mention_country)[T.bra]     1.2629      0.134      9.424      0.000       1.000       1.526
# C(Mention_country)[T.bwa]    -1.0202      0.120     -8.505      0.000      -1.255      -0.785
# C(Mention_country)[T.caf]    -2.1575      0.003   -633.461      0.000      -2.164      -2.151
# C(Mention_country)[T.can]     1.0604      0.212      4.992      0.000       0.644       1.477
# C(Mention_country)[T.che]    -0.1373      0.237     -0.580      0.562      -0.601       0.327
# C(Mention_country)[T.chl]     0.4066      0.150      2.705      0.007       0.112       0.701
# C(Mention_country)[T.chn]     2.5868      0.106     24.365      0.000       2.379       2.795
# C(Mention_country)[T.civ]    -3.6808      0.064    -57.932      0.000      -3.805      -3.556
# C(Mention_country)[T.cmr]    -0.1084      0.054     -2.018      0.044      -0.214      -0.003
# C(Mention_country)[T.col]     0.0817      0.116      0.702      0.482      -0.146       0.310
# C(Mention_country)[T.cri]    -0.1723      0.135     -1.278      0.201      -0.436       0.092
# C(Mention_country)[T.cub]    -0.7923      0.120     -6.623      0.000      -1.027      -0.558
# C(Mention_country)[T.cyp]    -1.1201      0.192     -5.842      0.000      -1.496      -0.744
# C(Mention_country)[T.cze]    -0.8124      0.172     -4.731      0.000      -1.149      -0.476
# C(Mention_country)[T.deu]     1.2245      0.211      5.815      0.000       0.812       1.637
# C(Mention_country)[T.dji]    -3.0636      0.057    -54.125      0.000      -3.175      -2.953
# C(Mention_country)[T.dnk]    -0.3798      0.224     -1.695      0.090      -0.819       0.059
# C(Mention_country)[T.dom]    -1.3617      0.116    -11.754      0.000      -1.589      -1.135
# C(Mention_country)[T.dza]    -0.7063      0.103     -6.863      0.000      -0.908      -0.505
# C(Mention_country)[T.ecu]    -0.0743      0.109     -0.681      0.496      -0.288       0.139
# C(Mention_country)[T.egy]     0.4451      0.019     24.010      0.000       0.409       0.481
# C(Mention_country)[T.eri]    -2.0393      0.010   -196.338      0.000      -2.060      -2.019
# C(Mention_country)[T.esp]     0.7527      0.193      3.891      0.000       0.374       1.132
# C(Mention_country)[T.est]    -1.5012      0.165     -9.126      0.000      -1.824      -1.179
# C(Mention_country)[T.eth]     0.7181      0.008     86.574      0.000       0.702       0.734
# C(Mention_country)[T.fin]    -0.3036      0.215     -1.415      0.157      -0.724       0.117
# C(Mention_country)[T.fra]     0.9616      0.208      4.627      0.000       0.554       1.369
# C(Mention_country)[T.gab]    -1.7155      0.132    -13.002      0.000      -1.974      -1.457
# C(Mention_country)[T.gbr]     1.7762      0.212      8.381      0.000       1.361       2.192
# C(Mention_country)[T.gha]     0.3293      0.046      7.112      0.000       0.239       0.420
# C(Mention_country)[T.gmb]    -2.4240      0.019   -127.037      0.000      -2.461      -2.387
# C(Mention_country)[T.grc]     0.1014      0.183      0.555      0.579      -0.256       0.459
# C(Mention_country)[T.gtm]    -0.6177      0.090     -6.836      0.000      -0.795      -0.441
# C(Mention_country)[T.hkg]     0.4597      0.203      2.265      0.024       0.062       0.857
# C(Mention_country)[T.hnd]    -1.2323      0.067    -18.286      0.000      -1.364      -1.100
# C(Mention_country)[T.hrv]    -1.2429      0.156     -7.960      0.000      -1.549      -0.937
# C(Mention_country)[T.hti]    -1.0114      0.045    -22.578      0.000      -1.099      -0.924
# C(Mention_country)[T.hun]    -0.6289      0.157     -4.002      0.000      -0.937      -0.321
# C(Mention_country)[T.idn]     0.9475      0.081     11.730      0.000       0.789       1.106
# C(Mention_country)[T.ind]     2.0428      0.047     43.235      0.000       1.950       2.135
# C(Mention_country)[T.irn]     0.4204      0.110      3.816      0.000       0.204       0.636
# C(Mention_country)[T.irq]    -0.0355      0.098     -0.363      0.716      -0.227       0.156
# C(Mention_country)[T.isr]     0.0358      0.197      0.181      0.856      -0.350       0.422
# C(Mention_country)[T.ita]     0.8197      0.202      4.064      0.000       0.424       1.215
# C(Mention_country)[T.jam]    -1.2494      0.112    -11.149      0.000      -1.469      -1.030
# C(Mention_country)[T.jor]     0.8146      0.028     29.229      0.000       0.760       0.869
# C(Mention_country)[T.jpn]     1.2675      0.209      6.056      0.000       0.857       1.678
# C(Mention_country)[T.kaz]    -0.6778      0.129     -5.235      0.000      -0.932      -0.424
# C(Mention_country)[T.ken]     0.8634      0.041     21.166      0.000       0.783       0.943
# C(Mention_country)[T.kgz]    -1.2911      0.033    -39.399      0.000      -1.355      -1.227
# C(Mention_country)[T.khm]    -0.3646      0.030    -12.052      0.000      -0.424      -0.305
# C(Mention_country)[T.kor]     0.3057      0.185      1.649      0.099      -0.058       0.669
# C(Mention_country)[T.kwt]    -0.9739      0.082    -11.889      0.000      -1.134      -0.813
# C(Mention_country)[T.lao]    -1.0781      0.045    -24.143      0.000      -1.166      -0.991
# C(Mention_country)[T.lbn]    -1.0157      0.128     -7.965      0.000      -1.266      -0.766
# C(Mention_country)[T.lbr]    -1.7859      0.006   -298.833      0.000      -1.798      -1.774
# C(Mention_country)[T.lby]    -0.7010      0.077     -9.084      0.000      -0.852      -0.550
# C(Mention_country)[T.lka]    -0.3337      0.080     -4.154      0.000      -0.491      -0.176
# C(Mention_country)[T.lso]    -1.7316      0.037    -47.263      0.000      -1.803      -1.660
# C(Mention_country)[T.ltu]    -1.6738      0.154    -10.861      0.000      -1.976      -1.372
# C(Mention_country)[T.lva]    -1.9712      0.153    -12.874      0.000      -2.271      -1.671
# C(Mention_country)[T.mar]     0.9924      0.034     28.802      0.000       0.925       1.060
# C(Mention_country)[T.mda]    -1.9567      0.073    -26.867      0.000      -2.099      -1.814
# C(Mention_country)[T.mdg]     0.3867      0.002    175.669      0.000       0.382       0.391
# C(Mention_country)[T.mex]     1.6503      0.145     11.412      0.000       1.367       1.934
# C(Mention_country)[T.mkd]    -1.6536      0.107    -15.451      0.000      -1.863      -1.444
# C(Mention_country)[T.mli]    -0.6142      0.020    -31.144      0.000      -0.653      -0.576
# C(Mention_country)[T.mmr]    -0.4448      0.022    -19.874      0.000      -0.489      -0.401
# C(Mention_country)[T.mng]     0.5926      0.077      7.670      0.000       0.441       0.744
# C(Mention_country)[T.moz]    -0.1708      0.009    -18.659      0.000      -0.189      -0.153
# C(Mention_country)[T.mrt]    -1.9948      0.055    -35.960      0.000      -2.104      -1.886
# C(Mention_country)[T.mus]    -1.9343      0.135    -14.337      0.000      -2.199      -1.670
# C(Mention_country)[T.mwi]     0.0282      0.010      2.798      0.005       0.008       0.048
# C(Mention_country)[T.mys]     0.0846      0.136      0.622      0.534      -0.182       0.351
# C(Mention_country)[T.nam]    -0.6907      0.109     -6.354      0.000      -0.904      -0.478
# C(Mention_country)[T.ner]    -1.3887      0.001  -1015.939      0.000      -1.391      -1.386
# C(Mention_country)[T.nga]     0.6580      0.069      9.501      0.000       0.522       0.794
# C(Mention_country)[T.nic]    -0.8921      0.060    -14.833      0.000      -1.010      -0.774
# C(Mention_country)[T.nld]     0.0081      0.218      0.037      0.970      -0.419       0.435
# C(Mention_country)[T.nor]     0.5262      0.240      2.190      0.029       0.055       0.997
# C(Mention_country)[T.npl]     0.4803      0.015     32.557      0.000       0.451       0.509
# C(Mention_country)[T.nzl]     1.3617      0.201      6.758      0.000       0.967       1.757
# C(Mention_country)[T.omn]     0.0226      0.048      0.468      0.640      -0.072       0.117
# C(Mention_country)[T.pak]     0.5275      0.044     11.856      0.000       0.440       0.615
# C(Mention_country)[T.pan]    -0.5715      0.140     -4.090      0.000      -0.845      -0.298
# C(Mention_country)[T.per]     0.4627      0.110      4.223      0.000       0.248       0.677
# C(Mention_country)[T.phl]     0.4201      0.074      5.664      0.000       0.275       0.566
# C(Mention_country)[T.pol]    -0.0099      0.151     -0.066      0.947      -0.306       0.286
# C(Mention_country)[T.pri]    -0.7169      0.190     -3.769      0.000      -1.090      -0.344
# C(Mention_country)[T.prt]    -0.2934      0.179     -1.635      0.102      -0.645       0.058
# C(Mention_country)[T.pry]    -1.3151      0.103    -12.754      0.000      -1.517      -1.113
# C(Mention_country)[T.pse]    -0.9883      0.080    -12.359      0.000      -1.145      -0.832
# C(Mention_country)[T.qat]    -2.3791      0.230    -10.326      0.000      -2.831      -1.928
# C(Mention_country)[T.rou]    -0.5859      0.132     -4.432      0.000      -0.845      -0.327
# C(Mention_country)[T.rus]     0.9471      0.139      6.810      0.000       0.675       1.220
# C(Mention_country)[T.rwa]    -0.7574      0.011    -70.886      0.000      -0.778      -0.736
# C(Mention_country)[T.sau]    -0.3306      0.172     -1.926      0.054      -0.667       0.006
# C(Mention_country)[T.sen]    -0.4610      0.049     -9.378      0.000      -0.557      -0.365
# C(Mention_country)[T.sgp]    -0.4913      0.214     -2.293      0.022      -0.911      -0.071
# C(Mention_country)[T.sle]    -1.1249      0.001  -2227.650      0.000      -1.126      -1.124
# C(Mention_country)[T.slv]    -1.7022      0.093    -18.356      0.000      -1.884      -1.520
# C(Mention_country)[T.som]    -1.2132      0.028    -43.052      0.000      -1.268      -1.158
# C(Mention_country)[T.svk]    -1.0066      0.165     -6.095      0.000      -1.330      -0.683
# C(Mention_country)[T.svn]    -1.5539      0.182     -8.561      0.000      -1.910      -1.198
# C(Mention_country)[T.swe]     0.2677      0.220      1.215      0.224      -0.164       0.699
# C(Mention_country)[T.syr]    -0.0591      0.032     -1.854      0.064      -0.122       0.003
# C(Mention_country)[T.tcd]    -1.4682      0.024    -61.783      0.000      -1.515      -1.422
# C(Mention_country)[T.tgo]    -2.0754      0.020   -102.760      0.000      -2.115      -2.036
# C(Mention_country)[T.tha]     0.5889      0.110      5.372      0.000       0.374       0.804
# C(Mention_country)[T.tjk]    -1.7546      0.018    -97.467      0.000      -1.790      -1.719
# C(Mention_country)[T.tkm]    -2.6189      0.100    -26.165      0.000      -2.815      -2.423
# C(Mention_country)[T.tto]    -2.7618      0.164    -16.846      0.000      -3.083      -2.440
# C(Mention_country)[T.tun]    -0.5361      0.043    -12.544      0.000      -0.620      -0.452
# C(Mention_country)[T.tur]     1.0152      0.141      7.182      0.000       0.738       1.292
# C(Mention_country)[T.tza]     0.7731      0.024     31.651      0.000       0.725       0.821
# C(Mention_country)[T.uga]     0.6091      0.015     41.264      0.000       0.580       0.638
# C(Mention_country)[T.ukr]    -0.2924      0.083     -3.514      0.000      -0.455      -0.129
# C(Mention_country)[T.ury]    -1.1397      0.148     -7.676      0.000      -1.431      -0.849
# C(Mention_country)[T.usa]     2.9160      0.221     13.223      0.000       2.484       3.348
# C(Mention_country)[T.uzb]    -1.4941      0.051    -29.330      0.000      -1.594      -1.394
# C(Mention_country)[T.ven]    -0.5806      0.146     -3.981      0.000      -0.866      -0.295
# C(Mention_country)[T.vnm]     0.8987      0.058     15.530      0.000       0.785       1.012
# C(Mention_country)[T.yem]    -0.3301      0.036     -9.127      0.000      -0.401      -0.259
# C(Mention_country)[T.zaf]     1.0243      0.125      8.227      0.000       0.780       1.268
# C(Mention_country)[T.zmb]    -0.4369      0.046     -9.493      0.000      -0.527      -0.347
# C(Mention_country)[T.zwe]    -0.0440      0.033     -1.323      0.186      -0.109       0.021
# C(year)[T.2003.0]             0.0243      0.019      1.310      0.190      -0.012       0.061
# C(year)[T.2004.0]             0.0468      0.022      2.173      0.030       0.005       0.089
# C(year)[T.2005.0]             0.1089      0.026      4.227      0.000       0.058       0.159
# C(year)[T.2006.0]             0.2321      0.030      7.827      0.000       0.174       0.290
# C(year)[T.2007.0]             0.3061      0.037      8.326      0.000       0.234       0.378
# C(year)[T.2008.0]             0.3688      0.042      8.790      0.000       0.287       0.451
# C(year)[T.2009.0]             0.5134      0.039     13.185      0.000       0.437       0.590
# C(year)[T.2010.0]             0.5839      0.044     13.395      0.000       0.498       0.669
# C(year)[T.2011.0]            -0.1816      0.011    -17.244      0.000      -0.202      -0.161
# C(year)[T.2012.0]            -0.1220      0.011    -10.640      0.000      -0.144      -0.100
# C(year)[T.2013.0]            -0.0104      0.011     -0.992      0.321      -0.031       0.010
# C(year)[T.2014.0]             0.0400      0.011      3.770      0.000       0.019       0.061
# C(year)[T.2015.0]             0.1100      0.010     10.505      0.000       0.089       0.131
# C(year)[T.2016.0]             0.1602      0.011     14.244      0.000       0.138       0.182
# C(year)[T.2017.0]             0.2003      0.011     18.642      0.000       0.179       0.221
# C(year)[T.2018.0]             0.2664      0.013     20.454      0.000       0.241       0.292
# C(year)[T.2019.0]             0.3664      0.014     25.798      0.000       0.339       0.394
# treated_GC                   -0.9854      0.127     -7.741      0.000      -1.235      -0.736
# post                          0.8293      0.047     17.771      0.000       0.738       0.921
# treated_GC:post              -0.0001      0.049     -0.003      0.998      -0.096       0.096
# treated_GO                   -0.0911      0.061     -1.499      0.134      -0.210       0.028
# treated_GO:post               0.1549      0.053      2.907      0.004       0.050       0.259
# treated_CW                   -1.0902      0.095    -11.484      0.000      -1.276      -0.904
# treated_CW:post               0.5690      0.176      3.239      0.001       0.225       0.913
# log_gdp                       0.1552      0.046      3.379      0.001       0.065       0.245
# ==============================================================================
# Omnibus:                      235.131   Durbin-Watson:                   0.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1217.189
# Skew:                          -0.258   Prob(JB):                    4.91e-265
# Kurtosis:                       6.306   Cond. No.                     3.71e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.4e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 169, but rank is 21
#   warnings.warn('covariance of constraints does not have full '

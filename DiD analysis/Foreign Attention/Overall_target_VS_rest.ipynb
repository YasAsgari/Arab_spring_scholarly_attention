# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
df = pd.read_csv(r"C:\Users\Yasaman\Downloads\Attention-fractional counting.csv")
df.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'affiliation_country': 'Aff_country'}, inplace=True)
df=df[(df['Mention_country'].isin(possible_iso))&(df['Aff_country'].isin(possible_iso))]
df = df[df['year'].isin(np.arange(2002, 2020))]
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df=df[~df['subjarea'].isin(physical_sciences)]
df=df[df['Mention_country']!=df['Aff_country']]
df=df.groupby(['year', 'Mention_country'])['count'].sum().reset_index()


data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))


# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[[ 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# 0

# %%
df_p=df_complete[df_complete['year']<2011].reset_index(drop=True)
df_p['time']=df_p['year'].min()-df_p['year']
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ treated * time +log_gdp+ C(Mention_country) + C(year)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                     166.7
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           6.28e-74
# Time:                        21:14:19   Log-Likelihood:                 626.99
# No. Observations:                1305   AIC:                            -944.0
# Df Residuals:                    1150   BIC:                            -142.0
# Df Model:                         154
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     3.3005      0.249     13.249      0.000       2.812       3.789
# C(Mention_country)[T.ago]    -1.0401      0.090    -11.590      0.000      -1.216      -0.864
# C(Mention_country)[T.alb]    -1.4587      0.104    -13.968      0.000      -1.663      -1.254
# C(Mention_country)[T.are]    -0.6693      0.224     -2.989      0.003      -1.108      -0.230
# C(Mention_country)[T.arg]     0.5723      0.136      4.208      0.000       0.306       0.839
# C(Mention_country)[T.arm]    -1.8583      0.085    -21.860      0.000      -2.025      -1.692
# C(Mention_country)[T.aus]     1.2656      0.221      5.731      0.000       0.833       1.698
# C(Mention_country)[T.aut]    -0.4343      0.227     -1.915      0.055      -0.879       0.010
# C(Mention_country)[T.aze]    -1.5779      0.094    -16.799      0.000      -1.762      -1.394
# C(Mention_country)[T.bdi]    -2.2541      0.032    -70.624      0.000      -2.317      -2.192
# C(Mention_country)[T.bel]    -0.5360      0.224     -2.391      0.017      -0.975      -0.097
# C(Mention_country)[T.ben]    -0.8651      0.048    -18.003      0.000      -0.959      -0.771
# C(Mention_country)[T.bfa]    -0.3235      0.020    -16.003      0.000      -0.363      -0.284
# C(Mention_country)[T.bgd]     0.7244      0.027     26.754      0.000       0.671       0.777
# C(Mention_country)[T.bgr]    -0.7019      0.125     -5.619      0.000      -0.947      -0.457
# C(Mention_country)[T.bhr]    -1.9662      0.069    -28.353      0.000      -2.102      -1.830
# C(Mention_country)[T.bih]    -1.0060      0.108     -9.301      0.000      -1.218      -0.794
# C(Mention_country)[T.blr]    -1.5693      0.113    -13.836      0.000      -1.792      -1.347
# C(Mention_country)[T.bol]     0.1939      0.066      2.957      0.003       0.065       0.322
# C(Mention_country)[T.bra]     1.4111      0.135     10.415      0.000       1.146       1.677
# C(Mention_country)[T.bwa]    -0.7965      0.128     -6.202      0.000      -1.048      -0.545
# C(Mention_country)[T.caf]    -1.9908      0.007   -268.855      0.000      -2.005      -1.976
# C(Mention_country)[T.can]     1.2442      0.223      5.578      0.000       0.807       1.681
# C(Mention_country)[T.che]    -0.0084      0.245     -0.034      0.973      -0.489       0.473
# C(Mention_country)[T.chl]     0.5408      0.152      3.553      0.000       0.243       0.839
# C(Mention_country)[T.chn]     2.7227      0.093     29.381      0.000       2.541       2.904
# C(Mention_country)[T.civ]    -3.3895      0.070    -48.382      0.000      -3.527      -3.252
# C(Mention_country)[T.cmr]     0.1466      0.063      2.320      0.020       0.023       0.271
# C(Mention_country)[T.col]     0.0632      0.118      0.536      0.592      -0.168       0.294
# C(Mention_country)[T.cri]     0.2480      0.134      1.853      0.064      -0.014       0.510
# C(Mention_country)[T.cub]    -0.5845      0.121     -4.817      0.000      -0.822      -0.347
# C(Mention_country)[T.cyp]    -1.0297      0.207     -4.977      0.000      -1.435      -0.624
# C(Mention_country)[T.cze]    -0.6233      0.180     -3.460      0.001      -0.976      -0.270
# C(Mention_country)[T.deu]     1.3193      0.222      5.942      0.000       0.884       1.754
# C(Mention_country)[T.dji]    -2.8715      0.052    -55.537      0.000      -2.973      -2.770
# C(Mention_country)[T.dnk]    -0.2388      0.237     -1.007      0.314      -0.704       0.226
# C(Mention_country)[T.dom]    -1.1505      0.118     -9.734      0.000      -1.382      -0.919
# C(Mention_country)[T.dza]    -0.6102      0.110     -5.554      0.000      -0.825      -0.395
# C(Mention_country)[T.ecu]     0.0921      0.111      0.833      0.405      -0.125       0.309
# C(Mention_country)[T.egy]     1.3921      0.047     29.609      0.000       1.300       1.484
# C(Mention_country)[T.eri]    -1.6513      0.015   -109.366      0.000      -1.681      -1.622
# C(Mention_country)[T.esp]     0.7603      0.209      3.646      0.000       0.352       1.169
# C(Mention_country)[T.est]    -1.2410      0.168     -7.389      0.000      -1.570      -0.912
# C(Mention_country)[T.eth]     0.8632      0.019     45.528      0.000       0.826       0.900
# C(Mention_country)[T.fin]    -0.1632      0.227     -0.717      0.473      -0.609       0.283
# C(Mention_country)[T.fra]     1.0624      0.222      4.794      0.000       0.628       1.497
# C(Mention_country)[T.gab]    -1.4760      0.143    -10.339      0.000      -1.756      -1.196
# C(Mention_country)[T.gbr]     1.8722      0.227      8.244      0.000       1.427       2.317
# C(Mention_country)[T.gha]     0.4149      0.038     11.049      0.000       0.341       0.489
# C(Mention_country)[T.gmb]    -2.1577      0.032    -67.431      0.000      -2.220      -2.095
# C(Mention_country)[T.grc]     0.1378      0.202      0.681      0.496      -0.259       0.534
# C(Mention_country)[T.gtm]    -0.4116      0.093     -4.442      0.000      -0.593      -0.230
# C(Mention_country)[T.hkg]     0.5821      0.210      2.770      0.006       0.170       0.994
# C(Mention_country)[T.hnd]    -0.8924      0.072    -12.378      0.000      -1.034      -0.751
# C(Mention_country)[T.hrv]    -1.1717      0.167     -7.007      0.000      -1.499      -0.844
# C(Mention_country)[T.hti]    -1.2326      0.049    -25.210      0.000      -1.328      -1.137
# C(Mention_country)[T.hun]    -0.4707      0.168     -2.807      0.005      -0.799      -0.142
# C(Mention_country)[T.idn]     1.1323      0.076     14.817      0.000       0.983       1.282
# C(Mention_country)[T.ind]     2.1939      0.045     48.407      0.000       2.105       2.283
# C(Mention_country)[T.irn]     0.3036      0.117      2.603      0.009       0.075       0.532
# C(Mention_country)[T.irq]     0.1226      0.092      1.332      0.183      -0.058       0.303
# C(Mention_country)[T.isr]     0.1926      0.203      0.951      0.342      -0.205       0.590
# C(Mention_country)[T.ita]     0.8493      0.217      3.908      0.000       0.423       1.275
# C(Mention_country)[T.jam]    -0.9397      0.123     -7.641      0.000      -1.181      -0.699
# C(Mention_country)[T.jor]     0.7979      0.021     37.646      0.000       0.756       0.839
# C(Mention_country)[T.jpn]     1.3833      0.224      6.173      0.000       0.944       1.822
# C(Mention_country)[T.kaz]    -0.5595      0.125     -4.471      0.000      -0.805      -0.314
# C(Mention_country)[T.ken]     1.0329      0.037     28.017      0.000       0.961       1.105
# C(Mention_country)[T.kgz]    -1.2463      0.030    -41.180      0.000      -1.306      -1.187
# C(Mention_country)[T.khm]    -0.3508      0.026    -13.252      0.000      -0.403      -0.299
# C(Mention_country)[T.kor]     0.3148      0.192      1.641      0.101      -0.061       0.691
# C(Mention_country)[T.kwt]    -1.0652      0.100    -10.698      0.000      -1.260      -0.870
# C(Mention_country)[T.lao]    -0.9956      0.031    -32.324      0.000      -1.056      -0.935
# C(Mention_country)[T.lbn]    -0.9569      0.133     -7.204      0.000      -1.217      -0.697
# C(Mention_country)[T.lbr]    -1.9460      0.004   -542.397      0.000      -1.953      -1.939
# C(Mention_country)[T.lby]    -0.8471      0.032    -26.078      0.000      -0.911      -0.783
# C(Mention_country)[T.lka]    -0.0958      0.073     -1.311      0.190      -0.239       0.047
# C(Mention_country)[T.lso]    -1.4986      0.042    -35.597      0.000      -1.581      -1.416
# C(Mention_country)[T.ltu]    -1.5043      0.156     -9.647      0.000      -1.810      -1.199
# C(Mention_country)[T.lva]    -1.7927      0.157    -11.448      0.000      -2.100      -1.486
# C(Mention_country)[T.mar]     1.0602      0.024     44.800      0.000       1.014       1.107
# C(Mention_country)[T.mda]    -1.9179      0.065    -29.444      0.000      -2.046      -1.790
# C(Mention_country)[T.mdg]     0.7145      0.010     69.990      0.000       0.694       0.734
# C(Mention_country)[T.mex]     1.8959      0.157     12.077      0.000       1.588       2.204
# C(Mention_country)[T.mkd]    -1.5797      0.112    -14.092      0.000      -1.799      -1.360
# C(Mention_country)[T.mli]    -0.4019      0.024    -16.467      0.000      -0.450      -0.354
# C(Mention_country)[T.mmr]    -0.4814      0.009    -54.894      0.000      -0.499      -0.464
# C(Mention_country)[T.mng]     0.7154      0.065     11.073      0.000       0.589       0.842
# C(Mention_country)[T.moz]    -0.0482      0.018     -2.633      0.008      -0.084      -0.012
# C(Mention_country)[T.mrt]    -1.7369      0.060    -29.002      0.000      -1.854      -1.620
# C(Mention_country)[T.mus]    -1.7151      0.138    -12.389      0.000      -1.986      -1.444
# C(Mention_country)[T.mwi]     0.0867      0.022      3.957      0.000       0.044       0.130
# C(Mention_country)[T.mys]     0.1265      0.139      0.907      0.364      -0.147       0.400
# C(Mention_country)[T.nam]    -0.4109      0.115     -3.575      0.000      -0.636      -0.186
# C(Mention_country)[T.ner]    -1.2797      0.006   -208.200      0.000      -1.292      -1.268
# C(Mention_country)[T.nga]     0.6312      0.071      8.849      0.000       0.491       0.771
# C(Mention_country)[T.nic]    -0.6188      0.065     -9.494      0.000      -0.747      -0.491
# C(Mention_country)[T.nld]     0.0664      0.231      0.287      0.774      -0.387       0.520
# C(Mention_country)[T.nor]     0.7924      0.252      3.143      0.002       0.298       1.287
# C(Mention_country)[T.npl]     0.6248      0.007     83.716      0.000       0.610       0.639
# C(Mention_country)[T.nzl]     1.6315      0.208      7.854      0.000       1.224       2.039
# C(Mention_country)[T.omn]     0.0126      0.058      0.218      0.827      -0.101       0.126
# C(Mention_country)[T.pak]     0.5369      0.049     11.039      0.000       0.442       0.632
# C(Mention_country)[T.pan]    -0.2433      0.136     -1.788      0.074      -0.510       0.023
# C(Mention_country)[T.per]     0.6731      0.108      6.223      0.000       0.461       0.885
# C(Mention_country)[T.phl]     0.6484      0.073      8.830      0.000       0.504       0.792
# C(Mention_country)[T.pol]     0.1658      0.157      1.059      0.289      -0.141       0.473
# C(Mention_country)[T.pri]    -0.5697      0.200     -2.845      0.004      -0.962      -0.177
# C(Mention_country)[T.prt]    -0.2835      0.193     -1.466      0.143      -0.662       0.095
# C(Mention_country)[T.pry]    -1.1223      0.099    -11.378      0.000      -1.316      -0.929
# C(Mention_country)[T.pse]    -0.9343      0.079    -11.820      0.000      -1.089      -0.779
# C(Mention_country)[T.qat]    -2.6484      0.238    -11.116      0.000      -3.115      -2.181
# C(Mention_country)[T.rou]    -0.4668      0.133     -3.512      0.000      -0.727      -0.206
# C(Mention_country)[T.rus]     1.1702      0.139      8.432      0.000       0.898       1.442
# C(Mention_country)[T.rwa]    -0.8455      0.010    -85.649      0.000      -0.865      -0.826
# C(Mention_country)[T.sau]    -0.4956      0.176     -2.818      0.005      -0.840      -0.151
# C(Mention_country)[T.sen]    -0.2216      0.058     -3.808      0.000      -0.336      -0.108
# C(Mention_country)[T.sgp]    -0.4061      0.217     -1.869      0.062      -0.832       0.020
# C(Mention_country)[T.sle]    -1.1424      0.002   -485.120      0.000      -1.147      -1.138
# C(Mention_country)[T.slv]    -1.4609      0.099    -14.697      0.000      -1.656      -1.266
# C(Mention_country)[T.som]    -0.9338      0.039    -24.162      0.000      -1.010      -0.858
# C(Mention_country)[T.svk]    -0.8772      0.173     -5.069      0.000      -1.216      -0.538
# C(Mention_country)[T.svn]    -1.4296      0.193     -7.394      0.000      -1.809      -1.051
# C(Mention_country)[T.swe]     0.4336      0.232      1.870      0.061      -0.021       0.888
# C(Mention_country)[T.syr]    -0.3743      0.031    -12.168      0.000      -0.435      -0.314
# C(Mention_country)[T.tcd]    -1.2544      0.031    -40.777      0.000      -1.315      -1.194
# C(Mention_country)[T.tgo]    -1.9458      0.024    -82.595      0.000      -1.992      -1.900
# C(Mention_country)[T.tha]     0.8950      0.111      8.086      0.000       0.678       1.112
# C(Mention_country)[T.tjk]    -1.7783      0.014   -125.916      0.000      -1.806      -1.751
# C(Mention_country)[T.tkm]    -2.5339      0.089    -28.621      0.000      -2.707      -2.360
# C(Mention_country)[T.tto]    -2.6369      0.171    -15.392      0.000      -2.973      -2.301
# C(Mention_country)[T.tun]     0.3199      0.010     32.747      0.000       0.301       0.339
# C(Mention_country)[T.tur]     1.1284      0.148      7.626      0.000       0.838       1.418
# C(Mention_country)[T.tza]     0.9760      0.026     37.772      0.000       0.925       1.027
# C(Mention_country)[T.uga]     0.7269      0.013     56.104      0.000       0.701       0.752
# C(Mention_country)[T.ukr]    -0.2182      0.089     -2.448      0.014      -0.393      -0.044
# C(Mention_country)[T.ury]    -0.9390      0.141     -6.662      0.000      -1.215      -0.663
# C(Mention_country)[T.usa]     2.9584      0.232     12.776      0.000       2.505       3.412
# C(Mention_country)[T.uzb]    -1.1990      0.040    -30.018      0.000      -1.277      -1.121
# C(Mention_country)[T.ven]    -0.2563      0.144     -1.780      0.075      -0.539       0.026
# C(Mention_country)[T.vnm]     1.0954      0.045     24.111      0.000       1.006       1.184
# C(Mention_country)[T.yem]    -0.2100      0.073     -2.883      0.004      -0.353      -0.067
# C(Mention_country)[T.zaf]     1.1726      0.135      8.713      0.000       0.909       1.436
# C(Mention_country)[T.zmb]    -0.3387      0.047     -7.139      0.000      -0.432      -0.246
# C(Mention_country)[T.zwe]     0.2557      0.025     10.210      0.000       0.207       0.305
# C(year)[T.2003.0]            -0.0411      0.016     -2.577      0.010      -0.072      -0.010
# C(year)[T.2004.0]            -0.0847      0.015     -5.502      0.000      -0.115      -0.055
# C(year)[T.2005.0]            -0.0881      0.015     -5.689      0.000      -0.118      -0.058
# C(year)[T.2006.0]            -0.0302      0.013     -2.402      0.016      -0.055      -0.006
# C(year)[T.2007.0]            -0.0226      0.012     -1.860      0.063      -0.046       0.001
# C(year)[T.2008.0]            -0.0261      0.014     -1.920      0.055      -0.053       0.001
# C(year)[T.2009.0]             0.0586      0.009      6.452      0.000       0.041       0.076
# C(year)[T.2010.0]             0.0644      0.012      5.545      0.000       0.042       0.087
# treated                      -0.8802      0.123     -7.138      0.000      -1.122      -0.639
# time                         -0.0610      0.005    -11.458      0.000      -0.071      -0.051
# treated:time                 -0.0095      0.011     -0.848      0.396      -0.031       0.012
# log_gdp                       0.1857      0.046      4.006      0.000       0.095       0.277
# ==============================================================================
# Omnibus:                      258.358   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2983.797
# Skew:                          -0.561   Prob(JB):                         0.00
# Kurtosis:                      10.322   Cond. No.                     3.69e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 8.39e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 156, but rank is 10
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ### Notice: Pre-parallel trend test is not significant at the target level so not an issue.

# %%
df_complete['treated:post']=df_complete['treated']*df_complete['post']
# Select the independent variables (excluding categorical variables handled by C())
independent_vars = df_complete[['treated', 'post', 'treated:post', 'log_gdp', 'log_population']]
# Compute VIF
vif_data = pd.DataFrame()
vif_data["Variable"] = independent_vars.columns
vif_data["VIF"] = [variance_inflation_factor(independent_vars.values, i) for i in range(len(independent_vars.columns))]
print(vif_data)
# Out:
#          Variable        VIF
# 0         treated   2.153278
# 1            post   2.210859
# 2    treated:post   2.150505
# 3         log_gdp  23.878211
# 4  log_population  23.153844

# %% [markdown]
# ### Notice: The VIF for treated:post is not high, so safe to go:)

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='treated')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foriegn attention')
# Out:
# Text(0, 0.5, 'log Foriegn attention')

# %% [markdown]
# ### Trends for the world is stable and linear. There exists a pattern change before and after the arab spring visually.

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ treated* post +log_gdp+ C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     90.69
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           3.39e-70
# Time:                        21:13:56   Log-Likelihood:                 698.20
# No. Observations:                2610   AIC:                            -1068.
# Df Residuals:                    2446   BIC:                            -106.2
# Df Model:                         163
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     3.8237      0.342     11.166      0.000       3.153       4.495
# C(Mention_country)[T.ago]    -1.1290      0.119     -9.498      0.000      -1.362      -0.896
# C(Mention_country)[T.alb]    -1.5394      0.139    -11.060      0.000      -1.812      -1.267
# C(Mention_country)[T.are]    -0.5168      0.295     -1.751      0.080      -1.095       0.062
# C(Mention_country)[T.arg]     0.4241      0.194      2.185      0.029       0.044       0.804
# C(Mention_country)[T.arm]    -1.8293      0.121    -15.096      0.000      -2.067      -1.592
# C(Mention_country)[T.aus]     1.2324      0.302      4.075      0.000       0.640       1.825
# C(Mention_country)[T.aut]    -0.3789      0.301     -1.261      0.207      -0.968       0.210
# C(Mention_country)[T.aze]    -1.4275      0.140    -10.232      0.000      -1.701      -1.154
# C(Mention_country)[T.bdi]    -2.1944      0.049    -44.519      0.000      -2.291      -2.098
# C(Mention_country)[T.bel]    -0.4942      0.296     -1.668      0.095      -1.075       0.086
# C(Mention_country)[T.ben]    -1.0292      0.056    -18.512      0.000      -1.138      -0.920
# C(Mention_country)[T.bfa]    -0.5289      0.022    -24.123      0.000      -0.572      -0.486
# C(Mention_country)[T.bgd]     0.6387      0.046     13.873      0.000       0.548       0.729
# C(Mention_country)[T.bgr]    -0.8776      0.172     -5.101      0.000      -1.215      -0.540
# C(Mention_country)[T.bhr]    -1.9214      0.101    -19.115      0.000      -2.118      -1.724
# C(Mention_country)[T.bih]    -1.1297      0.146     -7.730      0.000      -1.416      -0.843
# C(Mention_country)[T.blr]    -1.6973      0.157    -10.784      0.000      -2.006      -1.389
# C(Mention_country)[T.bol]    -0.0827      0.099     -0.838      0.402      -0.276       0.111
# C(Mention_country)[T.bra]     1.3488      0.188      7.192      0.000       0.981       1.716
# C(Mention_country)[T.bwa]    -0.9434      0.168     -5.620      0.000      -1.272      -0.614
# C(Mention_country)[T.caf]    -2.1597      0.005   -453.122      0.000      -2.169      -2.150
# C(Mention_country)[T.can]     1.1964      0.297      4.025      0.000       0.614       1.779
# C(Mention_country)[T.che]     0.0144      0.331      0.043      0.965      -0.635       0.664
# C(Mention_country)[T.chl]     0.5029      0.210      2.390      0.017       0.091       0.915
# C(Mention_country)[T.chn]     2.6548      0.149     17.869      0.000       2.364       2.946
# C(Mention_country)[T.civ]    -3.6401      0.089    -40.940      0.000      -3.814      -3.466
# C(Mention_country)[T.cmr]    -0.0740      0.075     -0.984      0.325      -0.221       0.073
# C(Mention_country)[T.col]     0.1561      0.163      0.960      0.337      -0.163       0.475
# C(Mention_country)[T.cri]    -0.0860      0.189     -0.456      0.649      -0.456       0.284
# C(Mention_country)[T.cub]    -0.7157      0.167     -4.275      0.000      -1.044      -0.388
# C(Mention_country)[T.cyp]    -0.9973      0.268     -3.717      0.000      -1.523      -0.471
# C(Mention_country)[T.cze]    -0.7024      0.240     -2.923      0.003      -1.173      -0.231
# C(Mention_country)[T.deu]     1.3594      0.295      4.613      0.000       0.782       1.937
# C(Mention_country)[T.dji]    -3.0274      0.079    -38.220      0.000      -3.183      -2.872
# C(Mention_country)[T.dnk]    -0.2362      0.314     -0.753      0.451      -0.851       0.378
# C(Mention_country)[T.dom]    -1.2875      0.162     -7.941      0.000      -1.605      -0.970
# C(Mention_country)[T.dza]    -0.6403      0.144     -4.447      0.000      -0.923      -0.358
# C(Mention_country)[T.ecu]    -0.0045      0.153     -0.029      0.977      -0.304       0.295
# C(Mention_country)[T.egy]     1.2684      0.048     26.239      0.000       1.174       1.363
# C(Mention_country)[T.eri]    -2.0327      0.015   -139.843      0.000      -2.061      -2.004
# C(Mention_country)[T.esp]     0.8767      0.271      3.238      0.001       0.346       1.407
# C(Mention_country)[T.est]    -1.3959      0.230     -6.064      0.000      -1.847      -0.945
# C(Mention_country)[T.eth]     0.7128      0.012     61.407      0.000       0.690       0.736
# C(Mention_country)[T.fin]    -0.1662      0.300     -0.554      0.580      -0.755       0.422
# C(Mention_country)[T.fra]     1.0947      0.291      3.764      0.000       0.525       1.665
# C(Mention_country)[T.gab]    -1.6310      0.185     -8.833      0.000      -1.993      -1.269
# C(Mention_country)[T.gbr]     1.9120      0.297      6.446      0.000       1.331       2.493
# C(Mention_country)[T.gha]     0.3590      0.065      5.540      0.000       0.232       0.486
# C(Mention_country)[T.gmb]    -2.4118      0.027    -90.321      0.000      -2.464      -2.359
# C(Mention_country)[T.grc]     0.2183      0.255      0.855      0.393      -0.282       0.719
# C(Mention_country)[T.gtm]    -0.5598      0.126     -4.427      0.000      -0.808      -0.312
# C(Mention_country)[T.hkg]     0.5897      0.284      2.076      0.038       0.033       1.146
# C(Mention_country)[T.hnd]    -1.1891      0.094    -12.609      0.000      -1.374      -1.004
# C(Mention_country)[T.hrv]    -1.1428      0.219     -5.230      0.000      -1.571      -0.715
# C(Mention_country)[T.hti]    -0.9827      0.063    -15.676      0.000      -1.106      -0.860
# C(Mention_country)[T.hun]    -0.5282      0.220     -2.402      0.016      -0.959      -0.097
# C(Mention_country)[T.idn]     0.9993      0.113      8.840      0.000       0.778       1.221
# C(Mention_country)[T.ind]     2.0730      0.066     31.353      0.000       1.943       2.203
# C(Mention_country)[T.irn]     0.4909      0.154      3.185      0.001       0.189       0.793
# C(Mention_country)[T.irq]     0.0271      0.137      0.198      0.843      -0.241       0.295
# C(Mention_country)[T.isr]     0.1620      0.276      0.587      0.557      -0.379       0.702
# C(Mention_country)[T.ita]     0.9489      0.282      3.362      0.001       0.396       1.502
# C(Mention_country)[T.jam]    -1.1777      0.157     -7.509      0.000      -1.485      -0.870
# C(Mention_country)[T.jor]     0.6796      0.019     35.400      0.000       0.642       0.717
# C(Mention_country)[T.jpn]     1.4016      0.293      4.785      0.000       0.827       1.976
# C(Mention_country)[T.kaz]    -0.5949      0.181     -3.283      0.001      -0.950      -0.240
# C(Mention_country)[T.ken]     0.8895      0.057     15.583      0.000       0.778       1.001
# C(Mention_country)[T.kgz]    -1.2701      0.046    -27.696      0.000      -1.360      -1.180
# C(Mention_country)[T.khm]    -0.3453      0.042     -8.155      0.000      -0.428      -0.262
# C(Mention_country)[T.kor]     0.4245      0.259      1.636      0.102      -0.084       0.933
# C(Mention_country)[T.kwt]    -1.0388      0.134     -7.735      0.000      -1.302      -0.776
# C(Mention_country)[T.lao]    -1.0495      0.062    -16.794      0.000      -1.172      -0.927
# C(Mention_country)[T.lbn]    -0.9340      0.178     -5.234      0.000      -1.284      -0.584
# C(Mention_country)[T.lbr]    -1.7821      0.008   -213.085      0.000      -1.799      -1.766
# C(Mention_country)[T.lby]    -0.6263      0.047    -13.417      0.000      -0.718      -0.535
# C(Mention_country)[T.lka]    -0.2823      0.112     -2.511      0.012      -0.503      -0.062
# C(Mention_country)[T.lso]    -1.7081      0.051    -33.316      0.000      -1.809      -1.608
# C(Mention_country)[T.ltu]    -1.5751      0.216     -7.303      0.000      -1.998      -1.152
# C(Mention_country)[T.lva]    -1.8731      0.214     -8.742      0.000      -2.293      -1.453
# C(Mention_country)[T.mar]     0.8532      0.028     30.066      0.000       0.798       0.909
# C(Mention_country)[T.mda]    -1.9100      0.102    -18.741      0.000      -2.110      -1.710
# C(Mention_country)[T.mdg]     0.3881      0.003    125.989      0.000       0.382       0.394
# C(Mention_country)[T.mex]     1.7429      0.202      8.612      0.000       1.346       2.140
# C(Mention_country)[T.mkd]    -1.5851      0.150    -10.583      0.000      -1.879      -1.292
# C(Mention_country)[T.mli]    -0.6016      0.028    -21.797      0.000      -0.656      -0.547
# C(Mention_country)[T.mmr]    -0.4305      0.031    -13.744      0.000      -0.492      -0.369
# C(Mention_country)[T.mng]     0.6421      0.108      5.939      0.000       0.430       0.854
# C(Mention_country)[T.moz]    -0.1650      0.013    -12.876      0.000      -0.190      -0.140
# C(Mention_country)[T.mrt]    -1.9593      0.078    -25.239      0.000      -2.111      -1.807
# C(Mention_country)[T.mus]    -1.8479      0.189     -9.787      0.000      -2.218      -1.478
# C(Mention_country)[T.mwi]     0.0347      0.014      2.457      0.014       0.007       0.062
# C(Mention_country)[T.mys]     0.1717      0.190      0.902      0.367      -0.201       0.545
# C(Mention_country)[T.nam]    -0.6211      0.152     -4.083      0.000      -0.919      -0.323
# C(Mention_country)[T.ner]    -1.3878      0.002   -725.522      0.000      -1.392      -1.384
# C(Mention_country)[T.nga]     0.7024      0.097      7.247      0.000       0.512       0.892
# C(Mention_country)[T.nic]    -0.8536      0.084    -10.142      0.000      -1.019      -0.689
# C(Mention_country)[T.nld]     0.1475      0.305      0.484      0.628      -0.449       0.744
# C(Mention_country)[T.nor]     0.6802      0.336      2.022      0.043       0.021       1.339
# C(Mention_country)[T.npl]     0.4898      0.021     23.723      0.000       0.449       0.530
# C(Mention_country)[T.nzl]     1.4908      0.282      5.287      0.000       0.938       2.043
# C(Mention_country)[T.omn]    -0.0640      0.087     -0.736      0.462      -0.235       0.106
# C(Mention_country)[T.pak]     0.5560      0.062      8.930      0.000       0.434       0.678
# C(Mention_country)[T.pan]    -0.4820      0.196     -2.465      0.014      -0.865      -0.099
# C(Mention_country)[T.per]     0.5328      0.153      3.475      0.001       0.232       0.833
# C(Mention_country)[T.phl]     0.4676      0.104      4.505      0.000       0.264       0.671
# C(Mention_country)[T.pol]     0.0867      0.211      0.411      0.681      -0.327       0.500
# C(Mention_country)[T.pri]    -0.5951      0.266     -2.236      0.025      -1.117      -0.073
# C(Mention_country)[T.prt]    -0.1784      0.251     -0.711      0.477      -0.671       0.314
# C(Mention_country)[T.pry]    -1.2491      0.144     -8.656      0.000      -1.532      -0.966
# C(Mention_country)[T.pse]    -0.9371      0.112     -8.374      0.000      -1.156      -0.718
# C(Mention_country)[T.qat]    -2.2315      0.322     -6.921      0.000      -2.863      -1.600
# C(Mention_country)[T.rou]    -0.5012      0.185     -2.709      0.007      -0.864      -0.139
# C(Mention_country)[T.rus]     1.0362      0.195      5.324      0.000       0.655       1.418
# C(Mention_country)[T.rwa]    -0.7506      0.015    -50.196      0.000      -0.780      -0.721
# C(Mention_country)[T.sau]    -0.2206      0.240     -0.918      0.358      -0.692       0.250
# C(Mention_country)[T.sen]    -0.4295      0.069     -6.244      0.000      -0.564      -0.295
# C(Mention_country)[T.sgp]    -0.3540      0.300     -1.181      0.238      -0.942       0.234
# C(Mention_country)[T.sle]    -1.1246      0.001  -1591.397      0.000      -1.126      -1.123
# C(Mention_country)[T.slv]    -1.6428      0.130    -12.659      0.000      -1.897      -1.388
# C(Mention_country)[T.som]    -1.2313      0.039    -31.222      0.000      -1.309      -1.154
# C(Mention_country)[T.svk]    -0.9008      0.231     -3.897      0.000      -1.354      -0.448
# C(Mention_country)[T.svn]    -1.4376      0.254     -5.660      0.000      -1.935      -0.940
# C(Mention_country)[T.swe]     0.4089      0.308      1.326      0.185      -0.195       1.013
# C(Mention_country)[T.syr]    -0.0170      0.025     -0.684      0.494      -0.066       0.032
# C(Mention_country)[T.tcd]    -1.4530      0.033    -43.692      0.000      -1.518      -1.388
# C(Mention_country)[T.tgo]    -2.0625      0.028    -72.973      0.000      -2.118      -2.007
# C(Mention_country)[T.tha]     0.6592      0.153      4.297      0.000       0.358       0.960
# C(Mention_country)[T.tjk]    -1.7430      0.025    -69.191      0.000      -1.792      -1.694
# C(Mention_country)[T.tkm]    -2.5548      0.140    -18.240      0.000      -2.829      -2.280
# C(Mention_country)[T.tto]    -2.6568      0.229    -11.580      0.000      -3.106      -2.207
# C(Mention_country)[T.tun]     0.3036      0.013     23.351      0.000       0.278       0.329
# C(Mention_country)[T.tur]     1.1058      0.198      5.590      0.000       0.718       1.493
# C(Mention_country)[T.tza]     0.7887      0.034     23.075      0.000       0.722       0.856
# C(Mention_country)[T.uga]     0.6186      0.021     29.945      0.000       0.578       0.659
# C(Mention_country)[T.ukr]    -0.2391      0.116     -2.053      0.040      -0.467      -0.011
# C(Mention_country)[T.ury]    -1.0446      0.208     -5.027      0.000      -1.452      -0.637
# C(Mention_country)[T.usa]     3.0572      0.309      9.907      0.000       2.452       3.662
# C(Mention_country)[T.uzb]    -1.4615      0.071    -20.501      0.000      -1.601      -1.322
# C(Mention_country)[T.ven]    -0.4872      0.204     -2.387      0.017      -0.887      -0.087
# C(Mention_country)[T.vnm]     0.9358      0.081     11.555      0.000       0.777       1.095
# C(Mention_country)[T.yem]    -0.3213      0.097     -3.303      0.001      -0.512      -0.131
# C(Mention_country)[T.zaf]     1.1040      0.174      6.337      0.000       0.763       1.446
# C(Mention_country)[T.zmb]    -0.4074      0.064     -6.326      0.000      -0.534      -0.281
# C(Mention_country)[T.zwe]    -0.0227      0.047     -0.487      0.626      -0.114       0.069
# C(year)[T.2003.0]             0.0279      0.020      1.428      0.153      -0.010       0.066
# C(year)[T.2004.0]             0.0546      0.025      2.160      0.031       0.005       0.104
# C(year)[T.2005.0]             0.1203      0.031      3.827      0.000       0.059       0.182
# C(year)[T.2006.0]             0.2469      0.037      6.614      0.000       0.174       0.320
# C(year)[T.2007.0]             0.3255      0.047      6.860      0.000       0.232       0.418
# C(year)[T.2008.0]             0.3926      0.056      6.983      0.000       0.282       0.503
# C(year)[T.2009.0]             0.5354      0.052     10.335      0.000       0.434       0.637
# C(year)[T.2010.0]             0.6089      0.059     10.403      0.000       0.494       0.724
# C(year)[T.2011.0]            -0.1795      0.010    -17.248      0.000      -0.200      -0.159
# C(year)[T.2012.0]            -0.1193      0.012    -10.255      0.000      -0.142      -0.096
# C(year)[T.2013.0]            -0.0066      0.012     -0.555      0.579      -0.030       0.017
# C(year)[T.2014.0]             0.0443      0.012      3.641      0.000       0.020       0.068
# C(year)[T.2015.0]             0.1114      0.011     10.235      0.000       0.090       0.133
# C(year)[T.2016.0]             0.1613      0.011     14.073      0.000       0.139       0.184
# C(year)[T.2017.0]             0.2030      0.012     17.527      0.000       0.180       0.226
# C(year)[T.2018.0]             0.2708      0.015     18.120      0.000       0.242       0.300
# C(year)[T.2019.0]             0.3707      0.016     23.254      0.000       0.339       0.402
# treated                      -0.8840      0.144     -6.160      0.000      -1.165      -0.603
# post                          0.8562      0.063     13.691      0.000       0.734       0.979
# treated:post                  0.1891      0.086      2.209      0.027       0.021       0.357
# log_gdp                       0.1258      0.064      1.957      0.050      -0.000       0.252
# ==============================================================================
# Omnibus:                      223.731   Durbin-Watson:                   0.937
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1141.265
# Skew:                          -0.230   Prob(JB):                    1.50e-248
# Kurtosis:                       6.207   Cond. No.                     3.48e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.59e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 165, but rank is 19
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ###  Durbin-Watson: 0.937, it is close to 1 so the autocorrelation is residuals are not highly problematic.

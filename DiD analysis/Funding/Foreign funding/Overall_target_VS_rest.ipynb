# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
#funding
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df_fund=pd.read_csv(r"C:\Users\Yasaman\Downloads\Mentioned-Funding-fractional counting.csv")
df_fund.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'funding_country': 'Source'}, inplace=True)
df_fund=df_fund[~(df_fund['subjarea'].isin(physical_sciences))]
df_fund=df_fund[df_fund['Mention_country']!=df_fund['Source']]
df_fund=df_fund.groupby(['year', 'Mention_country'])['count'].sum().reset_index()
df_fund=df_fund[(df_fund['year'].isin(np.arange(2002,2020,1)))].reset_index(drop=True)
df=df_fund.copy()

data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))

# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "incomelevel": country_data["incomelevel"].iloc[0] if not country_data.empty else np.nan,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# 0

# %%
df_p=df_complete[df_complete['year']<2011].reset_index(drop=True)
df_p['time']=df_p['year'].min()-df_p['year']
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ treated * time +log_gdp+ C(Mention_country) + C(year)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     69.78
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           3.74e-50
# Time:                        21:58:52   Log-Likelihood:                -116.10
# No. Observations:                1305   AIC:                             542.2
# Df Residuals:                    1150   BIC:                             1344.
# Df Model:                         154
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     0.7695      0.400      1.922      0.055      -0.015       1.554
# C(Mention_country)[T.ago]    -0.3639      0.146     -2.493      0.013      -0.650      -0.078
# C(Mention_country)[T.alb]    -1.0627      0.170     -6.256      0.000      -1.396      -0.730
# C(Mention_country)[T.are]    -0.4386      0.364     -1.204      0.229      -1.152       0.275
# C(Mention_country)[T.arg]     1.6351      0.221      7.391      0.000       1.202       2.069
# C(Mention_country)[T.arm]    -0.9181      0.138     -6.640      0.000      -1.189      -0.647
# C(Mention_country)[T.aus]     2.0863      0.359      5.809      0.000       1.382       2.790
# C(Mention_country)[T.aut]    -0.0204      0.369     -0.055      0.956      -0.743       0.703
# C(Mention_country)[T.aze]    -1.0831      0.153     -7.090      0.000      -1.383      -0.784
# C(Mention_country)[T.bdi]    -1.6404      0.052    -31.601      0.000      -1.742      -1.539
# C(Mention_country)[T.bel]     0.2844      0.365      0.780      0.435      -0.430       0.999
# C(Mention_country)[T.ben]     0.0640      0.078      0.819      0.413      -0.089       0.217
# C(Mention_country)[T.bfa]     0.8496      0.033     25.843      0.000       0.785       0.914
# C(Mention_country)[T.bgd]     1.8599      0.044     42.234      0.000       1.774       1.946
# C(Mention_country)[T.bgr]     0.1753      0.203      0.863      0.388      -0.223       0.573
# C(Mention_country)[T.bhr]    -2.0537      0.113    -18.100      0.000      -2.276      -1.831
# C(Mention_country)[T.bih]    -0.7987      0.176     -4.540      0.000      -1.143      -0.454
# C(Mention_country)[T.blr]    -0.7129      0.184     -3.865      0.000      -1.074      -0.351
# C(Mention_country)[T.bol]     0.9427      0.107      8.837      0.000       0.734       1.152
# C(Mention_country)[T.bra]     2.3823      0.220     10.811      0.000       1.950       2.814
# C(Mention_country)[T.bwa]     0.2318      0.209      1.110      0.267      -0.178       0.641
# C(Mention_country)[T.caf]    -1.3952      0.012   -115.847      0.000      -1.419      -1.372
# C(Mention_country)[T.can]     2.0659      0.363      5.694      0.000       1.355       2.777
# C(Mention_country)[T.che]     0.4732      0.399      1.186      0.236      -0.309       1.255
# C(Mention_country)[T.chl]     1.4583      0.248      5.891      0.000       0.973       1.943
# C(Mention_country)[T.chn]     3.6675      0.151     24.332      0.000       3.372       3.963
# C(Mention_country)[T.civ]    -2.1712      0.114    -19.055      0.000      -2.395      -1.948
# C(Mention_country)[T.cmr]     1.3192      0.103     12.832      0.000       1.118       1.521
# C(Mention_country)[T.col]     0.9295      0.192      4.845      0.000       0.553       1.305
# C(Mention_country)[T.cri]     1.2576      0.218      5.776      0.000       0.831       1.684
# C(Mention_country)[T.cub]    -0.0514      0.197     -0.260      0.795      -0.438       0.335
# C(Mention_country)[T.cyp]    -0.5261      0.337     -1.563      0.118      -1.186       0.133
# C(Mention_country)[T.cze]     0.3409      0.293      1.164      0.245      -0.233       0.915
# C(Mention_country)[T.deu]     1.7312      0.361      4.794      0.000       1.023       2.439
# C(Mention_country)[T.dji]    -2.0065      0.084    -23.859      0.000      -2.171      -1.842
# C(Mention_country)[T.dnk]     0.7447      0.386      1.931      0.054      -0.011       1.501
# C(Mention_country)[T.dom]    -0.5308      0.192     -2.761      0.006      -0.908      -0.154
# C(Mention_country)[T.dza]    -0.5833      0.179     -3.264      0.001      -0.933      -0.233
# C(Mention_country)[T.ecu]     0.8903      0.180      4.949      0.000       0.538       1.243
# C(Mention_country)[T.egy]     1.6993      0.076     22.375      0.000       1.550       1.848
# C(Mention_country)[T.eri]    -0.7339      0.025    -29.885      0.000      -0.782      -0.686
# C(Mention_country)[T.esp]     2.2226      0.339      6.553      0.000       1.558       2.887
# C(Mention_country)[T.est]    -0.1763      0.273     -0.646      0.519      -0.712       0.359
# C(Mention_country)[T.eth]     1.9390      0.031     62.878      0.000       1.879       1.999
# C(Mention_country)[T.fin]     1.0469      0.370      2.829      0.005       0.322       1.772
# C(Mention_country)[T.fra]     1.6977      0.360      4.710      0.000       0.991       2.404
# C(Mention_country)[T.gab]    -0.5366      0.232     -2.311      0.021      -0.992      -0.081
# C(Mention_country)[T.gbr]     2.6558      0.369      7.191      0.000       1.932       3.380
# C(Mention_country)[T.gha]     1.3382      0.061     21.912      0.000       1.219       1.458
# C(Mention_country)[T.gmb]    -0.5442      0.052    -10.455      0.000      -0.646      -0.442
# C(Mention_country)[T.grc]     1.1352      0.329      3.448      0.001       0.490       1.780
# C(Mention_country)[T.gtm]     0.3631      0.151      2.409      0.016       0.068       0.659
# C(Mention_country)[T.hkg]     1.4285      0.342      4.180      0.000       0.759       2.098
# C(Mention_country)[T.hnd]    -0.0647      0.117     -0.552      0.581      -0.295       0.165
# C(Mention_country)[T.hrv]    -0.5575      0.272     -2.050      0.040      -1.091      -0.025
# C(Mention_country)[T.hti]    -0.3919      0.080     -4.928      0.000      -0.548      -0.236
# C(Mention_country)[T.hun]     0.4232      0.273      1.552      0.121      -0.111       0.958
# C(Mention_country)[T.idn]     1.9166      0.124     15.419      0.000       1.673       2.160
# C(Mention_country)[T.ind]     3.1509      0.074     42.746      0.000       3.006       3.295
# C(Mention_country)[T.irn]     0.6511      0.190      3.431      0.001       0.279       1.023
# C(Mention_country)[T.irq]    -0.2625      0.150     -1.753      0.080      -0.556       0.031
# C(Mention_country)[T.isr]     1.0521      0.330      3.192      0.001       0.406       1.698
# C(Mention_country)[T.ita]     1.9216      0.353      5.437      0.000       1.229       2.614
# C(Mention_country)[T.jam]     0.0797      0.200      0.398      0.690      -0.312       0.472
# C(Mention_country)[T.jor]     0.9852      0.034     28.920      0.000       0.918       1.052
# C(Mention_country)[T.jpn]     1.9936      0.364      5.470      0.000       1.279       2.708
# C(Mention_country)[T.kaz]     0.2518      0.204      1.237      0.216      -0.147       0.651
# C(Mention_country)[T.ken]     2.5363      0.060     42.299      0.000       2.419       2.654
# C(Mention_country)[T.kgz]    -0.3744      0.049     -7.607      0.000      -0.471      -0.278
# C(Mention_country)[T.khm]     0.6121      0.043     14.219      0.000       0.528       0.696
# C(Mention_country)[T.kor]     0.9695      0.312      3.108      0.002       0.358       1.581
# C(Mention_country)[T.kwt]    -1.7296      0.163    -10.638      0.000      -2.048      -1.411
# C(Mention_country)[T.lao]    -0.0453      0.050     -0.903      0.366      -0.143       0.053
# C(Mention_country)[T.lbn]    -0.5456      0.216     -2.526      0.012      -0.969      -0.122
# C(Mention_country)[T.lbr]    -1.4901      0.006   -255.354      0.000      -1.502      -1.479
# C(Mention_country)[T.lby]    -1.0228      0.054    -19.096      0.000      -1.128      -0.918
# C(Mention_country)[T.lka]     0.7720      0.119      6.496      0.000       0.539       1.005
# C(Mention_country)[T.lso]    -0.7635      0.068    -11.151      0.000      -0.898      -0.629
# C(Mention_country)[T.ltu]    -0.6531      0.254     -2.575      0.010      -1.150      -0.156
# C(Mention_country)[T.lva]    -0.8345      0.255     -3.276      0.001      -1.334      -0.335
# C(Mention_country)[T.mar]     1.3713      0.038     36.032      0.000       1.297       1.446
# C(Mention_country)[T.mda]    -1.1534      0.106    -10.887      0.000      -1.361      -0.946
# C(Mention_country)[T.mdg]     1.6643      0.017    100.238      0.000       1.632       1.697
# C(Mention_country)[T.mex]     2.7286      0.255     10.687      0.000       2.228       3.229
# C(Mention_country)[T.mkd]    -0.9212      0.182     -5.053      0.000      -1.279      -0.564
# C(Mention_country)[T.mli]     0.6741      0.040     16.981      0.000       0.596       0.752
# C(Mention_country)[T.mmr]     0.0835      0.014      5.857      0.000       0.056       0.111
# C(Mention_country)[T.mng]     1.5832      0.105     15.067      0.000       1.377       1.789
# C(Mention_country)[T.moz]     0.8328      0.030     27.982      0.000       0.774       0.891
# C(Mention_country)[T.mrt]    -1.2118      0.097    -12.440      0.000      -1.403      -1.021
# C(Mention_country)[T.mus]    -0.9169      0.225     -4.072      0.000      -1.358      -0.476
# C(Mention_country)[T.mwi]     1.4396      0.036     40.379      0.000       1.370       1.509
# C(Mention_country)[T.mys]     0.7917      0.227      3.490      0.000       0.347       1.236
# C(Mention_country)[T.nam]     0.5596      0.187      2.993      0.003       0.193       0.926
# C(Mention_country)[T.ner]    -0.3411      0.010    -34.116      0.000      -0.361      -0.321
# C(Mention_country)[T.nga]     1.5978      0.116     13.773      0.000       1.370       1.825
# C(Mention_country)[T.nic]     0.2750      0.106      2.594      0.009       0.067       0.483
# C(Mention_country)[T.nld]     1.1611      0.376      3.087      0.002       0.424       1.898
# C(Mention_country)[T.nor]     1.8423      0.410      4.493      0.000       1.039       2.646
# C(Mention_country)[T.npl]     1.5581      0.012    128.357      0.000       1.534       1.582
# C(Mention_country)[T.nzl]     2.2161      0.338      6.559      0.000       1.554       2.878
# C(Mention_country)[T.omn]     0.3667      0.095      3.878      0.000       0.181       0.552
# C(Mention_country)[T.pak]     1.2879      0.079     16.280      0.000       1.133       1.443
# C(Mention_country)[T.pan]     0.7140      0.221      3.226      0.001       0.280       1.148
# C(Mention_country)[T.per]     1.5705      0.176      8.928      0.000       1.226       1.915
# C(Mention_country)[T.phl]     1.6099      0.119     13.481      0.000       1.376       1.844
# C(Mention_country)[T.pol]     0.9306      0.255      3.655      0.000       0.432       1.430
# C(Mention_country)[T.pri]     0.7580      0.326      2.328      0.020       0.120       1.396
# C(Mention_country)[T.prt]     1.0916      0.314      3.472      0.001       0.475       1.708
# C(Mention_country)[T.pry]    -0.5369      0.160     -3.346      0.001      -0.851      -0.222
# C(Mention_country)[T.pse]    -1.1375      0.129     -8.847      0.000      -1.389      -0.885
# C(Mention_country)[T.qat]    -2.7065      0.388     -6.984      0.000      -3.466      -1.947
# C(Mention_country)[T.rou]     0.3031      0.216      1.402      0.161      -0.121       0.727
# C(Mention_country)[T.rus]     1.8868      0.226      8.358      0.000       1.444       2.329
# C(Mention_country)[T.rwa]    -0.3708      0.016    -23.092      0.000      -0.402      -0.339
# C(Mention_country)[T.sau]    -0.3256      0.286     -1.138      0.255      -0.886       0.235
# C(Mention_country)[T.sen]     0.8283      0.095      8.751      0.000       0.643       1.014
# C(Mention_country)[T.sgp]     0.0947      0.353      0.268      0.789      -0.598       0.787
# C(Mention_country)[T.sle]    -0.3938      0.004   -102.822      0.000      -0.401      -0.386
# C(Mention_country)[T.slv]    -0.7605      0.162     -4.704      0.000      -1.077      -0.444
# C(Mention_country)[T.som]    -0.4593      0.063     -7.306      0.000      -0.583      -0.336
# C(Mention_country)[T.svk]    -0.1713      0.281     -0.609      0.543      -0.723       0.380
# C(Mention_country)[T.svn]    -0.4766      0.314     -1.516      0.130      -1.093       0.140
# C(Mention_country)[T.swe]     1.4973      0.377      3.971      0.000       0.758       2.236
# C(Mention_country)[T.syr]    -0.2162      0.051     -4.257      0.000      -0.316      -0.117
# C(Mention_country)[T.tcd]    -0.4947      0.050     -9.887      0.000      -0.593      -0.397
# C(Mention_country)[T.tgo]    -1.1033      0.038    -28.794      0.000      -1.178      -1.028
# C(Mention_country)[T.tha]     1.8412      0.180     10.227      0.000       1.488       2.194
# C(Mention_country)[T.tjk]    -0.7997      0.023    -34.815      0.000      -0.845      -0.755
# C(Mention_country)[T.tkm]    -1.6538      0.144    -11.485      0.000      -1.936      -1.372
# C(Mention_country)[T.tto]    -2.0119      0.279     -7.221      0.000      -2.558      -1.466
# C(Mention_country)[T.tun]     0.6983      0.016     44.331      0.000       0.667       0.729
# C(Mention_country)[T.tur]     1.7473      0.241      7.260      0.000       1.276       2.219
# C(Mention_country)[T.tza]     2.2036      0.042     52.436      0.000       2.121       2.286
# C(Mention_country)[T.uga]     2.1542      0.021    102.234      0.000       2.113       2.196
# C(Mention_country)[T.ukr]     0.5885      0.145      4.060      0.000       0.304       0.873
# C(Mention_country)[T.ury]    -0.0591      0.229     -0.258      0.796      -0.508       0.390
# C(Mention_country)[T.usa]     3.1653      0.377      8.404      0.000       2.427       3.904
# C(Mention_country)[T.uzb]    -0.1979      0.065     -3.046      0.002      -0.325      -0.071
# C(Mention_country)[T.ven]     0.3883      0.234      1.658      0.097      -0.071       0.847
# C(Mention_country)[T.vnm]     2.0395      0.074     27.602      0.000       1.895       2.184
# C(Mention_country)[T.yem]    -0.4242      0.118     -3.597      0.000      -0.655      -0.193
# C(Mention_country)[T.zaf]     2.4707      0.219     11.287      0.000       2.042       2.900
# C(Mention_country)[T.zmb]     1.0470      0.077     13.571      0.000       0.896       1.198
# C(Mention_country)[T.zwe]     1.4179      0.041     34.814      0.000       1.338       1.498
# C(year)[T.2003.0]            -0.0487      0.029     -1.694      0.090      -0.105       0.008
# C(year)[T.2004.0]            -0.0745      0.029     -2.552      0.011      -0.132      -0.017
# C(year)[T.2005.0]            -0.0512      0.027     -1.862      0.063      -0.105       0.003
# C(year)[T.2006.0]            -0.0434      0.026     -1.688      0.091      -0.094       0.007
# C(year)[T.2007.0]             0.0015      0.018      0.082      0.934      -0.035       0.038
# C(year)[T.2008.0]             0.0156      0.019      0.803      0.422      -0.022       0.054
# C(year)[T.2009.0]             0.0420      0.016      2.633      0.008       0.011       0.073
# C(year)[T.2010.0]             0.0288      0.019      1.535      0.125      -0.008       0.066
# treated                      -0.3256      0.209     -1.554      0.120      -0.736       0.085
# time                         -0.1011      0.010    -10.480      0.000      -0.120      -0.082
# treated:time                  0.0323      0.021      1.559      0.119      -0.008       0.073
# log_gdp                       0.2001      0.075      2.653      0.008       0.052       0.348
# ==============================================================================
# Omnibus:                      111.038   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              354.019
# Skew:                          -0.399   Prob(JB):                     1.34e-77
# Kurtosis:                       5.424   Cond. No.                     3.69e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 8.39e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 156, but rank is 10
#   warnings.warn('covariance of constraints does not have full '

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='treated')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foriegn funding')
# Out:
# Text(0, 0.5, 'log Foriegn funding')

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ treated* post +log_gdp+ C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     233.9
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           3.87e-98
# Time:                        21:43:53   Log-Likelihood:                -352.18
# No. Observations:                2610   AIC:                             1032.
# Df Residuals:                    2446   BIC:                             1995.
# Df Model:                         163
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     1.6697      0.304      5.498      0.000       1.074       2.265
# C(Mention_country)[T.ago]    -0.6507      0.103     -6.312      0.000      -0.853      -0.449
# C(Mention_country)[T.alb]    -1.2649      0.121    -10.479      0.000      -1.502      -1.028
# C(Mention_country)[T.are]    -0.2655      0.256     -1.037      0.300      -0.767       0.236
# C(Mention_country)[T.arg]     1.3828      0.168      8.216      0.000       1.053       1.713
# C(Mention_country)[T.arm]    -1.1154      0.105    -10.614      0.000      -1.321      -0.909
# C(Mention_country)[T.aus]     2.0880      0.262      7.960      0.000       1.574       2.602
# C(Mention_country)[T.aut]     0.1071      0.261      0.411      0.681      -0.404       0.618
# C(Mention_country)[T.aze]    -1.2823      0.121    -10.598      0.000      -1.519      -1.045
# C(Mention_country)[T.bdi]    -1.7811      0.043    -41.662      0.000      -1.865      -1.697
# C(Mention_country)[T.bel]     0.3116      0.257      1.213      0.225      -0.192       0.815
# C(Mention_country)[T.ben]    -0.1859      0.048     -3.855      0.000      -0.280      -0.091
# C(Mention_country)[T.bfa]     0.4963      0.019     26.099      0.000       0.459       0.534
# C(Mention_country)[T.bgd]     1.5872      0.040     39.751      0.000       1.509       1.665
# C(Mention_country)[T.bgr]    -0.1808      0.149     -1.212      0.226      -0.473       0.112
# C(Mention_country)[T.bhr]    -2.0568      0.089    -23.137      0.000      -2.231      -1.883
# C(Mention_country)[T.bih]    -0.9406      0.127     -7.421      0.000      -1.189      -0.692
# C(Mention_country)[T.blr]    -1.1087      0.136     -8.123      0.000      -1.376      -0.841
# C(Mention_country)[T.bol]     0.5359      0.086      6.260      0.000       0.368       0.704
# C(Mention_country)[T.bra]     2.2060      0.163     13.563      0.000       1.887       2.525
# C(Mention_country)[T.bwa]     0.0620      0.146      0.426      0.670      -0.223       0.347
# C(Mention_country)[T.caf]    -1.5679      0.004   -379.283      0.000      -1.576      -1.560
# C(Mention_country)[T.can]     2.0198      0.258      7.835      0.000       1.515       2.525
# C(Mention_country)[T.che]     0.5273      0.287      1.835      0.067      -0.036       1.091
# C(Mention_country)[T.chl]     1.3202      0.182      7.236      0.000       0.963       1.678
# C(Mention_country)[T.chn]     3.4247      0.129     26.578      0.000       3.172       3.677
# C(Mention_country)[T.civ]    -2.6995      0.077    -35.007      0.000      -2.851      -2.548
# C(Mention_country)[T.cmr]     0.9162      0.065     14.051      0.000       0.788       1.044
# C(Mention_country)[T.col]     0.8873      0.141      6.289      0.000       0.611       1.164
# C(Mention_country)[T.cri]     0.7939      0.164      4.853      0.000       0.473       1.114
# C(Mention_country)[T.cub]    -0.2919      0.145     -2.011      0.044      -0.576      -0.007
# C(Mention_country)[T.cyp]    -0.5143      0.233     -2.210      0.027      -0.970      -0.058
# C(Mention_country)[T.cze]     0.2588      0.208      1.242      0.214      -0.150       0.667
# C(Mention_country)[T.deu]     1.7974      0.256      7.033      0.000       1.296       2.298
# C(Mention_country)[T.dji]    -2.4605      0.069    -35.817      0.000      -2.595      -2.326
# C(Mention_country)[T.dnk]     0.7892      0.272      2.902      0.004       0.256       1.322
# C(Mention_country)[T.dom]    -0.7502      0.141     -5.335      0.000      -1.026      -0.475
# C(Mention_country)[T.dza]    -0.5238      0.125     -4.194      0.000      -0.769      -0.279
# C(Mention_country)[T.ecu]     0.6309      0.132      4.766      0.000       0.371       0.890
# C(Mention_country)[T.egy]     1.4968      0.040     37.143      0.000       1.418       1.576
# C(Mention_country)[T.eri]    -1.4789      0.013   -117.308      0.000      -1.504      -1.454
# C(Mention_country)[T.esp]     2.2182      0.235      9.447      0.000       1.758       2.678
# C(Mention_country)[T.est]    -0.3136      0.200     -1.571      0.116      -0.705       0.078
# C(Mention_country)[T.eth]     1.6012      0.010    159.057      0.000       1.582       1.621
# C(Mention_country)[T.fin]     1.0337      0.260      3.970      0.000       0.523       1.544
# C(Mention_country)[T.fra]     1.7334      0.252      6.872      0.000       1.239       2.228
# C(Mention_country)[T.gab]    -0.7971      0.160     -4.978      0.000      -1.111      -0.483
# C(Mention_country)[T.gbr]     2.6344      0.257     10.241      0.000       2.130       3.139
# C(Mention_country)[T.gha]     1.1660      0.056     20.749      0.000       1.056       1.276
# C(Mention_country)[T.gmb]    -1.0221      0.023    -44.136      0.000      -1.068      -0.977
# C(Mention_country)[T.grc]     1.1215      0.222      5.063      0.000       0.687       1.556
# C(Mention_country)[T.gtm]     0.0949      0.110      0.865      0.387      -0.120       0.310
# C(Mention_country)[T.hkg]     1.3781      0.246      5.595      0.000       0.895       1.861
# C(Mention_country)[T.hnd]    -0.5692      0.082     -6.959      0.000      -0.729      -0.409
# C(Mention_country)[T.hrv]    -0.4931      0.190     -2.602      0.009      -0.865      -0.122
# C(Mention_country)[T.hti]    -0.3770      0.054     -6.935      0.000      -0.484      -0.270
# C(Mention_country)[T.hun]     0.3239      0.191      1.698      0.089      -0.050       0.698
# C(Mention_country)[T.idn]     1.6922      0.098     17.260      0.000       1.500       1.884
# C(Mention_country)[T.ind]     2.8916      0.057     50.425      0.000       2.779       3.004
# C(Mention_country)[T.irn]     0.7053      0.134      5.276      0.000       0.443       0.967
# C(Mention_country)[T.irq]    -0.1516      0.118     -1.279      0.201      -0.384       0.081
# C(Mention_country)[T.isr]     0.8530      0.239      3.567      0.000       0.384       1.322
# C(Mention_country)[T.ita]     1.9574      0.245      7.997      0.000       1.478       2.437
# C(Mention_country)[T.jam]    -0.4156      0.136     -3.055      0.002      -0.682      -0.149
# C(Mention_country)[T.jor]     0.8470      0.015     55.911      0.000       0.817       0.877
# C(Mention_country)[T.jpn]     1.9649      0.254      7.735      0.000       1.467       2.463
# C(Mention_country)[T.kaz]     0.0432      0.157      0.275      0.783      -0.265       0.351
# C(Mention_country)[T.ken]     2.1601      0.050     43.631      0.000       2.063       2.257
# C(Mention_country)[T.kgz]    -0.5829      0.040    -14.654      0.000      -0.661      -0.505
# C(Mention_country)[T.khm]     0.4792      0.037     13.050      0.000       0.407       0.551
# C(Mention_country)[T.kor]     0.9388      0.225      4.173      0.000       0.498       1.380
# C(Mention_country)[T.kwt]    -1.5528      0.118    -13.139      0.000      -1.784      -1.321
# C(Mention_country)[T.lao]    -0.3122      0.054     -5.760      0.000      -0.418      -0.206
# C(Mention_country)[T.lbn]    -0.5547      0.155     -3.584      0.000      -0.858      -0.251
# C(Mention_country)[T.lbr]    -1.3023      0.007   -179.535      0.000      -1.316      -1.288
# C(Mention_country)[T.lby]    -0.8344      0.042    -19.759      0.000      -0.917      -0.752
# C(Mention_country)[T.lka]     0.4670      0.098      4.789      0.000       0.276       0.658
# C(Mention_country)[T.lso]    -1.1677      0.044    -26.261      0.000      -1.255      -1.081
# C(Mention_country)[T.ltu]    -0.7963      0.187     -4.257      0.000      -1.163      -0.430
# C(Mention_country)[T.lva]    -0.9299      0.186     -5.004      0.000      -1.294      -0.566
# C(Mention_country)[T.mar]     1.1707      0.023     50.818      0.000       1.126       1.216
# C(Mention_country)[T.mda]    -1.5241      0.088    -17.243      0.000      -1.697      -1.351
# C(Mention_country)[T.mdg]     1.1107      0.003    415.703      0.000       1.105       1.116
# C(Mention_country)[T.mex]     2.5033      0.176     14.263      0.000       2.159       2.847
# C(Mention_country)[T.mkd]    -1.1053      0.130     -8.509      0.000      -1.360      -0.851
# C(Mention_country)[T.mli]     0.2882      0.024     12.041      0.000       0.241       0.335
# C(Mention_country)[T.mmr]     0.1389      0.027      5.115      0.000       0.086       0.192
# C(Mention_country)[T.mng]     1.3409      0.094     14.299      0.000       1.157       1.525
# C(Mention_country)[T.moz]     0.6482      0.011     58.343      0.000       0.626       0.670
# C(Mention_country)[T.mrt]    -1.4213      0.067    -21.110      0.000      -1.553      -1.289
# C(Mention_country)[T.mus]    -1.2489      0.164     -7.627      0.000      -1.570      -0.928
# C(Mention_country)[T.mwi]     1.1894      0.012     97.074      0.000       1.165       1.213
# C(Mention_country)[T.mys]     0.7710      0.165      4.671      0.000       0.447       1.094
# C(Mention_country)[T.nam]     0.1532      0.132      1.161      0.245      -0.105       0.412
# C(Mention_country)[T.ner]    -0.7674      0.002   -462.541      0.000      -0.771      -0.764
# C(Mention_country)[T.nga]     1.4300      0.084     17.011      0.000       1.265       1.595
# C(Mention_country)[T.nic]    -0.1156      0.073     -1.584      0.113      -0.259       0.027
# C(Mention_country)[T.nld]     1.2542      0.264      4.748      0.000       0.736       1.772
# C(Mention_country)[T.nor]     1.6748      0.292      5.742      0.000       1.103       2.246
# C(Mention_country)[T.npl]     1.2194      0.018     68.096      0.000       1.184       1.254
# C(Mention_country)[T.nzl]     2.0830      0.245      8.518      0.000       1.604       2.562
# C(Mention_country)[T.omn]     0.2015      0.077      2.611      0.009       0.050       0.353
# C(Mention_country)[T.pak]     1.1211      0.054     20.761      0.000       1.015       1.227
# C(Mention_country)[T.pan]     0.4252      0.170      2.507      0.012       0.093       0.758
# C(Mention_country)[T.per]     1.3819      0.133     10.392      0.000       1.121       1.643
# C(Mention_country)[T.phl]     1.2999      0.090     14.438      0.000       1.123       1.476
# C(Mention_country)[T.pol]     0.8627      0.183      4.712      0.000       0.504       1.222
# C(Mention_country)[T.pri]     0.6087      0.231      2.637      0.008       0.156       1.061
# C(Mention_country)[T.prt]     1.1256      0.218      5.169      0.000       0.699       1.552
# C(Mention_country)[T.pry]    -0.8088      0.125     -6.462      0.000      -1.054      -0.564
# C(Mention_country)[T.pse]    -1.2349      0.097    -12.723      0.000      -1.425      -1.045
# C(Mention_country)[T.qat]    -2.3518      0.280     -8.410      0.000      -2.900      -1.804
# C(Mention_country)[T.rou]     0.3056      0.160      1.905      0.057      -0.009       0.620
# C(Mention_country)[T.rus]     1.5792      0.169      9.356      0.000       1.248       1.910
# C(Mention_country)[T.rwa]    -0.2639      0.013    -20.347      0.000      -0.289      -0.238
# C(Mention_country)[T.sau]    -0.1415      0.208     -0.679      0.497      -0.550       0.267
# C(Mention_country)[T.sen]     0.4502      0.060      7.546      0.000       0.333       0.567
# C(Mention_country)[T.sgp]     0.1780      0.260      0.685      0.494      -0.332       0.688
# C(Mention_country)[T.sle]    -0.5512      0.001   -899.287      0.000      -0.552      -0.550
# C(Mention_country)[T.slv]    -1.1883      0.113    -10.558      0.000      -1.409      -0.968
# C(Mention_country)[T.som]    -1.0257      0.034    -29.988      0.000      -1.093      -0.959
# C(Mention_country)[T.svk]    -0.2072      0.200     -1.034      0.301      -0.600       0.186
# C(Mention_country)[T.svn]    -0.5389      0.220     -2.446      0.014      -0.971      -0.107
# C(Mention_country)[T.swe]     1.4181      0.267      5.304      0.000       0.894       1.942
# C(Mention_country)[T.syr]    -0.0714      0.020     -3.561      0.000      -0.111      -0.032
# C(Mention_country)[T.tcd]    -0.8397      0.029    -29.115      0.000      -0.896      -0.783
# C(Mention_country)[T.tgo]    -1.4179      0.025    -57.844      0.000      -1.466      -1.370
# C(Mention_country)[T.tha]     1.5377      0.133     11.558      0.000       1.277       1.798
# C(Mention_country)[T.tjk]    -1.0812      0.022    -49.486      0.000      -1.124      -1.038
# C(Mention_country)[T.tkm]    -2.1672      0.121    -17.840      0.000      -2.405      -1.929
# C(Mention_country)[T.tto]    -2.1937      0.199    -11.025      0.000      -2.584      -1.804
# C(Mention_country)[T.tun]     0.7667      0.010     77.396      0.000       0.747       0.786
# C(Mention_country)[T.tur]     1.5717      0.172      9.161      0.000       1.235       1.908
# C(Mention_country)[T.tza]     1.8682      0.030     63.019      0.000       1.810       1.926
# C(Mention_country)[T.uga]     1.8853      0.018    105.234      0.000       1.850       1.920
# C(Mention_country)[T.ukr]     0.2993      0.101      2.964      0.003       0.101       0.497
# C(Mention_country)[T.ury]    -0.3112      0.180     -1.727      0.084      -0.664       0.042
# C(Mention_country)[T.usa]     3.2929      0.268     12.303      0.000       2.768       3.817
# C(Mention_country)[T.uzb]    -0.6901      0.062    -11.163      0.000      -0.811      -0.569
# C(Mention_country)[T.ven]    -0.0258      0.177     -0.146      0.884      -0.373       0.321
# C(Mention_country)[T.vnm]     1.7380      0.070     24.744      0.000       1.600       1.876
# C(Mention_country)[T.yem]    -0.5438      0.083     -6.575      0.000      -0.706      -0.382
# C(Mention_country)[T.zaf]     2.3649      0.151     15.651      0.000       2.069       2.661
# C(Mention_country)[T.zmb]     0.7915      0.056     14.170      0.000       0.682       0.901
# C(Mention_country)[T.zwe]     0.7902      0.040     19.588      0.000       0.711       0.869
# C(year)[T.2003.0]             0.0614      0.032      1.931      0.053      -0.001       0.124
# C(year)[T.2004.0]             0.1477      0.038      3.906      0.000       0.074       0.222
# C(year)[T.2005.0]             0.2812      0.041      6.815      0.000       0.200       0.362
# C(year)[T.2006.0]             0.3987      0.047      8.394      0.000       0.306       0.492
# C(year)[T.2007.0]             0.5567      0.047     11.814      0.000       0.464       0.649
# C(year)[T.2008.0]             0.6836      0.055     12.456      0.000       0.576       0.791
# C(year)[T.2009.0]             0.8033      0.052     15.413      0.000       0.701       0.905
# C(year)[T.2010.0]             0.8981      0.058     15.480      0.000       0.784       1.012
# C(year)[T.2011.0]            -0.4198      0.018    -23.443      0.000      -0.455      -0.385
# C(year)[T.2012.0]            -0.3074      0.018    -16.626      0.000      -0.344      -0.271
# C(year)[T.2013.0]            -0.1106      0.016     -7.029      0.000      -0.141      -0.080
# C(year)[T.2014.0]            -0.0354      0.017     -2.060      0.039      -0.069      -0.002
# C(year)[T.2015.0]             0.0193      0.014      1.361      0.173      -0.008       0.047
# C(year)[T.2016.0]             0.1755      0.016     11.150      0.000       0.145       0.206
# C(year)[T.2017.0]             0.4041      0.015     26.387      0.000       0.374       0.434
# C(year)[T.2018.0]             0.8217      0.017     48.113      0.000       0.788       0.855
# C(year)[T.2019.0]             0.9250      0.019     47.731      0.000       0.887       0.963
# treated                      -0.5764      0.143     -4.044      0.000      -0.856      -0.297
# post                          1.4723      0.055     26.572      0.000       1.364       1.581
# treated:post                  0.0853      0.086      0.990      0.322      -0.084       0.254
# log_gdp                       0.1078      0.056      1.934      0.053      -0.001       0.217
# ==============================================================================
# Omnibus:                      274.969   Durbin-Watson:                   1.234
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1024.904
# Skew:                          -0.480   Prob(JB):                    2.79e-223
# Kurtosis:                       5.916   Cond. No.                     3.48e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.59e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 165, but rank is 19
#   warnings.warn('covariance of constraints does not have full '

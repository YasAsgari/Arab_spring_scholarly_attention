# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
#funding
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df_fund=pd.read_csv(r"C:\Users\Yasaman\Downloads\Mentioned-Funding-fractional counting.csv")
df_fund.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'funding_country': 'Source'}, inplace=True)
df_fund=df_fund[~(df_fund['subjarea'].isin(physical_sciences))]
df_fund=df_fund[df_fund['Mention_country']!=df_fund['Source']]
df_fund=df_fund.groupby(['year', 'Mention_country'])['count'].sum().reset_index()
df_fund=df_fund[(df_fund['year'].isin(np.arange(2002,2020,1)))].reset_index(drop=True)
df=df_fund.copy()

data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))

# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "incomelevel": country_data["incomelevel"].iloc[0] if not country_data.empty else np.nan,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# 0

# %%
df_p=df_complete[df_complete['year']<2011].reset_index(drop=True)
df_p['time']=df_p['year'].min()-df_p['year']
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ treated * time+log_population +log_gdp+ C(Mention_country) + C(year)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     38.75
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           1.31e-37
# Time:                        13:47:43   Log-Likelihood:                -116.00
# No. Observations:                1305   AIC:                             544.0
# Df Residuals:                    1149   BIC:                             1351.
# Df Model:                         155
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -0.4353      6.386     -0.068      0.946     -12.953      12.082
# C(Mention_country)[T.ago]    -0.3538      0.154     -2.304      0.021      -0.655      -0.053
# C(Mention_country)[T.alb]    -0.9192      0.773     -1.188      0.235      -2.435       0.597
# C(Mention_country)[T.are]    -0.3414      0.623     -0.548      0.583      -1.562       0.879
# C(Mention_country)[T.arg]     1.5957      0.305      5.225      0.000       0.997       2.194
# C(Mention_country)[T.arm]    -0.7745      0.768     -1.008      0.313      -2.280       0.731
# C(Mention_country)[T.aus]     2.0880      0.357      5.850      0.000       1.388       2.788
# C(Mention_country)[T.aut]     0.0454      0.501      0.091      0.928      -0.936       1.027
# C(Mention_country)[T.aze]    -1.0129      0.398     -2.544      0.011      -1.793      -0.232
# C(Mention_country)[T.bdi]    -1.5558      0.451     -3.451      0.001      -2.439      -0.672
# C(Mention_country)[T.bel]     0.3328      0.440      0.757      0.449      -0.529       1.195
# C(Mention_country)[T.ben]     0.1379      0.397      0.348      0.728      -0.639       0.915
# C(Mention_country)[T.bfa]     0.8875      0.202      4.385      0.000       0.491       1.284
# C(Mention_country)[T.bgd]     1.7362      0.655      2.650      0.008       0.452       3.020
# C(Mention_country)[T.bgr]     0.2520      0.450      0.560      0.575      -0.629       1.133
# C(Mention_country)[T.bhr]    -1.8957      0.840     -2.256      0.024      -3.542      -0.249
# C(Mention_country)[T.bih]    -0.6765      0.666     -1.016      0.309      -1.981       0.628
# C(Mention_country)[T.blr]    -0.6522      0.367     -1.779      0.075      -1.371       0.066
# C(Mention_country)[T.bol]     1.0066      0.352      2.859      0.004       0.317       1.697
# C(Mention_country)[T.bra]     2.2330      0.822      2.717      0.007       0.622       3.844
# C(Mention_country)[T.bwa]     0.4046      0.932      0.434      0.664      -1.422       2.232
# C(Mention_country)[T.caf]    -1.2721      0.650     -1.956      0.050      -2.547       0.002
# C(Mention_country)[T.can]     2.0353      0.398      5.117      0.000       1.256       2.815
# C(Mention_country)[T.che]     0.5445      0.542      1.005      0.315      -0.518       1.607
# C(Mention_country)[T.chl]     1.4799      0.269      5.492      0.000       0.952       2.008
# C(Mention_country)[T.chn]     3.3844      1.506      2.248      0.025       0.434       6.335
# C(Mention_country)[T.civ]    -2.1572      0.134    -16.084      0.000      -2.420      -1.894
# C(Mention_country)[T.cmr]     1.3396      0.147      9.105      0.000       1.051       1.628
# C(Mention_country)[T.col]     0.8854      0.303      2.919      0.004       0.291       1.480
# C(Mention_country)[T.cri]     1.3728      0.642      2.139      0.032       0.115       2.631
# C(Mention_country)[T.cub]    -0.0019      0.324     -0.006      0.995      -0.637       0.633
# C(Mention_country)[T.cyp]    -0.3148      1.159     -0.272      0.786      -2.586       1.957
# C(Mention_country)[T.cze]     0.3936      0.399      0.986      0.324      -0.388       1.176
# C(Mention_country)[T.deu]     1.6356      0.624      2.620      0.009       0.412       2.859
# C(Mention_country)[T.dji]    -1.7712      1.244     -1.424      0.154      -4.209       0.666
# C(Mention_country)[T.dnk]     0.8390      0.623      1.347      0.178      -0.382       2.060
# C(Mention_country)[T.dom]    -0.4677      0.381     -1.226      0.220      -1.215       0.280
# C(Mention_country)[T.dza]    -0.6099      0.229     -2.667      0.008      -1.058      -0.162
# C(Mention_country)[T.ecu]     0.9249      0.253      3.649      0.000       0.428       1.422
# C(Mention_country)[T.egy]     1.5523      0.778      1.994      0.046       0.027       3.078
# C(Mention_country)[T.eri]    -0.5828      0.798     -0.731      0.465      -2.146       0.981
# C(Mention_country)[T.esp]     2.1713      0.436      4.977      0.000       1.316       3.026
# C(Mention_country)[T.est]     0.0196      1.065      0.018      0.985      -2.068       2.107
# C(Mention_country)[T.eth]     1.8583      0.427      4.354      0.000       1.022       2.695
# C(Mention_country)[T.fin]     1.1441      0.626      1.828      0.068      -0.083       2.371
# C(Mention_country)[T.fra]     1.6203      0.548      2.956      0.003       0.546       2.695
# C(Mention_country)[T.gab]    -0.3471      1.023     -0.339      0.734      -2.352       1.658
# C(Mention_country)[T.gbr]     2.5811      0.544      4.748      0.000       1.516       3.647
# C(Mention_country)[T.gha]     1.3416      0.063     21.307      0.000       1.218       1.465
# C(Mention_country)[T.gmb]    -0.3579      0.984     -0.364      0.716      -2.287       1.571
# C(Mention_country)[T.grc]     1.1818      0.406      2.909      0.004       0.386       1.978
# C(Mention_country)[T.gtm]     0.4029      0.256      1.575      0.115      -0.098       0.904
# C(Mention_country)[T.hkg]     1.5079      0.535      2.817      0.005       0.459       2.557
# C(Mention_country)[T.hnd]     0.0137      0.428      0.032      0.975      -0.826       0.853
# C(Mention_country)[T.hrv]    -0.4430      0.658     -0.673      0.501      -1.733       0.847
# C(Mention_country)[T.hti]    -0.3250      0.361     -0.901      0.368      -1.032       0.382
# C(Mention_country)[T.hun]     0.4780      0.393      1.216      0.224      -0.292       1.248
# C(Mention_country)[T.idn]     1.7559      0.860      2.042      0.041       0.071       3.441
# C(Mention_country)[T.ind]     2.8781      1.444      1.994      0.046       0.049       5.708
# C(Mention_country)[T.irn]     0.5712      0.465      1.228      0.219      -0.340       1.483
# C(Mention_country)[T.irq]    -0.2772      0.169     -1.640      0.101      -0.609       0.054
# C(Mention_country)[T.isr]     1.1300      0.521      2.168      0.030       0.108       2.152
# C(Mention_country)[T.ita]     1.8506      0.518      3.571      0.000       0.835       2.866
# C(Mention_country)[T.jam]     0.2296      0.813      0.282      0.778      -1.364       1.823
# C(Mention_country)[T.jor]     1.0186      0.181      5.640      0.000       0.665       1.373
# C(Mention_country)[T.jpn]     1.8670      0.766      2.437      0.015       0.365       3.368
# C(Mention_country)[T.kaz]     0.2788      0.246      1.135      0.256      -0.203       0.760
# C(Mention_country)[T.ken]     2.5067      0.168     14.902      0.000       2.177       2.836
# C(Mention_country)[T.kgz]    -0.2662      0.573     -0.465      0.642      -1.389       0.856
# C(Mention_country)[T.khm]     0.6539      0.224      2.917      0.004       0.215       1.093
# C(Mention_country)[T.kor]     0.9126      0.436      2.095      0.036       0.059       1.766
# C(Mention_country)[T.kwt]    -1.6376      0.510     -3.212      0.001      -2.637      -0.638
# C(Mention_country)[T.lao]     0.0537      0.524      0.102      0.918      -0.973       1.080
# C(Mention_country)[T.lbn]    -0.4358      0.615     -0.709      0.479      -1.641       0.769
# C(Mention_country)[T.lbr]    -1.3493      0.744     -1.815      0.070      -2.807       0.108
# C(Mention_country)[T.lby]    -0.9909      0.176     -5.624      0.000      -1.336      -0.646
# C(Mention_country)[T.lka]     0.7840      0.133      5.893      0.000       0.523       1.045
# C(Mention_country)[T.lso]    -0.5884      0.926     -0.635      0.525      -2.403       1.227
# C(Mention_country)[T.ltu]    -0.5189      0.748     -0.693      0.488      -1.985       0.948
# C(Mention_country)[T.lva]    -0.6727      0.887     -0.759      0.448      -2.411       1.065
# C(Mention_country)[T.mar]     1.2906      0.427      3.022      0.003       0.453       2.128
# C(Mention_country)[T.mda]    -1.0054      0.787     -1.278      0.201      -2.548       0.537
# C(Mention_country)[T.mdg]     1.6814      0.092     18.288      0.000       1.501       1.862
# C(Mention_country)[T.mex]     2.6182      0.640      4.090      0.000       1.364       3.873
# C(Mention_country)[T.mkd]    -0.7513      0.912     -0.824      0.410      -2.539       1.036
# C(Mention_country)[T.mli]     0.7152      0.220      3.254      0.001       0.284       1.146
# C(Mention_country)[T.mmr]     0.0370      0.247      0.150      0.881      -0.446       0.520
# C(Mention_country)[T.mng]     1.7388      0.827      2.104      0.035       0.119       3.359
# C(Mention_country)[T.moz]     0.8447      0.069     12.288      0.000       0.710       0.979
# C(Mention_country)[T.mrt]    -1.0684      0.762     -1.403      0.161      -2.561       0.424
# C(Mention_country)[T.mus]    -0.7129      1.096     -0.650      0.515      -2.861       1.435
# C(Mention_country)[T.mwi]     1.4833      0.233      6.363      0.000       1.026       1.940
# C(Mention_country)[T.mys]     0.7802      0.235      3.326      0.001       0.320       1.240
# C(Mention_country)[T.nam]     0.7310      0.921      0.794      0.427      -1.075       2.537
# C(Mention_country)[T.ner]    -0.3028      0.202     -1.499      0.134      -0.699       0.093
# C(Mention_country)[T.nga]     1.4706      0.683      2.152      0.031       0.131       2.810
# C(Mention_country)[T.nic]     0.3772      0.548      0.688      0.491      -0.697       1.451
# C(Mention_country)[T.nld]     1.1785      0.383      3.074      0.002       0.427       1.930
# C(Mention_country)[T.nor]     1.9465      0.679      2.868      0.004       0.616       3.277
# C(Mention_country)[T.npl]     1.5537      0.027     57.993      0.000       1.501       1.606
# C(Mention_country)[T.nzl]     2.3308      0.687      3.391      0.001       0.984       3.678
# C(Mention_country)[T.omn]     0.4561      0.480      0.950      0.342      -0.485       1.397
# C(Mention_country)[T.pak]     1.1472      0.749      1.532      0.126      -0.320       2.615
# C(Mention_country)[T.pan]     0.8474      0.734      1.154      0.249      -0.592       2.287
# C(Mention_country)[T.per]     1.5558      0.193      8.078      0.000       1.178       1.933
# C(Mention_country)[T.phl]     1.5175      0.504      3.010      0.003       0.530       2.505
# C(Mention_country)[T.pol]     0.8925      0.326      2.735      0.006       0.253       1.532
# C(Mention_country)[T.pri]     0.8797      0.715      1.231      0.218      -0.521       2.281
# C(Mention_country)[T.prt]     1.1421      0.407      2.806      0.005       0.344       1.940
# C(Mention_country)[T.pry]    -0.4364      0.552     -0.791      0.429      -1.518       0.645
# C(Mention_country)[T.pse]    -1.0020      0.725     -1.383      0.167      -2.422       0.418
# C(Mention_country)[T.qat]    -2.4975      1.162     -2.149      0.032      -4.775      -0.220
# C(Mention_country)[T.rou]     0.3080      0.216      1.426      0.154      -0.115       0.731
# C(Mention_country)[T.rus]     1.7565      0.727      2.415      0.016       0.331       3.182
# C(Mention_country)[T.rwa]    -0.3020      0.363     -0.831      0.406      -1.014       0.410
# C(Mention_country)[T.sau]    -0.3367      0.291     -1.156      0.248      -0.907       0.234
# C(Mention_country)[T.sen]     0.8808      0.292      3.020      0.003       0.309       1.452
# C(Mention_country)[T.sgp]     0.2035      0.668      0.305      0.761      -1.106       1.513
# C(Mention_country)[T.sle]    -0.2915      0.540     -0.540      0.589      -1.350       0.767
# C(Mention_country)[T.slv]    -0.6664      0.520     -1.282      0.200      -1.685       0.352
# C(Mention_country)[T.som]    -0.3971      0.336     -1.183      0.237      -1.055       0.261
# C(Mention_country)[T.svk]    -0.0727      0.587     -0.124      0.901      -1.223       1.077
# C(Mention_country)[T.svn]    -0.3101      0.928     -0.334      0.738      -2.129       1.509
# C(Mention_country)[T.swe]     1.5558      0.481      3.232      0.001       0.612       2.499
# C(Mention_country)[T.syr]    -0.2679      0.279     -0.962      0.336      -0.814       0.278
# C(Mention_country)[T.tcd]    -0.4344      0.321     -1.351      0.177      -1.064       0.196
# C(Mention_country)[T.tgo]    -1.0032      0.529     -1.896      0.058      -2.040       0.034
# C(Mention_country)[T.tha]     1.7667      0.435      4.058      0.000       0.913       2.620
# C(Mention_country)[T.tjk]    -0.7119      0.464     -1.535      0.125      -1.621       0.197
# C(Mention_country)[T.tkm]    -1.5449      0.590     -2.619      0.009      -2.701      -0.389
# C(Mention_country)[T.tto]    -1.8176      1.058     -1.717      0.086      -3.892       0.257
# C(Mention_country)[T.tun]     0.6925      0.034     20.562      0.000       0.627       0.759
# C(Mention_country)[T.tur]     1.6675      0.488      3.416      0.001       0.711       2.624
# C(Mention_country)[T.tza]     2.1680      0.193     11.222      0.000       1.789       2.547
# C(Mention_country)[T.uga]     2.1434      0.061     35.005      0.000       2.023       2.263
# C(Mention_country)[T.ukr]     0.5394      0.299      1.804      0.071      -0.046       1.125
# C(Mention_country)[T.ury]     0.0749      0.740      0.101      0.919      -1.375       1.525
# C(Mention_country)[T.usa]     2.9788      1.060      2.810      0.005       0.901       5.056
# C(Mention_country)[T.uzb]    -0.2047      0.074     -2.748      0.006      -0.351      -0.059
# C(Mention_country)[T.ven]     0.3750      0.244      1.534      0.125      -0.104       0.854
# C(Mention_country)[T.vnm]     1.9518      0.470      4.149      0.000       1.030       2.874
# C(Mention_country)[T.yem]    -0.4787      0.308     -1.552      0.121      -1.083       0.126
# C(Mention_country)[T.zaf]     2.4153      0.368      6.569      0.000       1.695       3.136
# C(Mention_country)[T.zmb]     1.0958      0.267      4.097      0.000       0.572       1.620
# C(Mention_country)[T.zwe]     1.4657      0.255      5.742      0.000       0.965       1.966
# C(year)[T.2003.0]            -0.0486      0.029     -1.688      0.091      -0.105       0.008
# C(year)[T.2004.0]            -0.0744      0.029     -2.551      0.011      -0.132      -0.017
# C(year)[T.2005.0]            -0.0510      0.028     -1.853      0.064      -0.105       0.003
# C(year)[T.2006.0]            -0.0434      0.026     -1.685      0.092      -0.094       0.007
# C(year)[T.2007.0]             0.0013      0.018      0.072      0.942      -0.035       0.037
# C(year)[T.2008.0]             0.0152      0.019      0.785      0.433      -0.023       0.053
# C(year)[T.2009.0]             0.0421      0.016      2.637      0.008       0.011       0.073
# C(year)[T.2010.0]             0.0289      0.019      1.538      0.124      -0.008       0.066
# treated                      -0.2608      0.401     -0.650      0.516      -1.047       0.526
# time                         -0.0998      0.011     -8.987      0.000      -0.122      -0.078
# treated:time                  0.0333      0.022      1.518      0.129      -0.010       0.076
# log_population                0.0702      0.371      0.189      0.850      -0.657       0.797
# log_gdp                       0.2025      0.076      2.655      0.008       0.053       0.352
# ==============================================================================
# Omnibus:                      111.088   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              355.994
# Skew:                          -0.397   Prob(JB):                     4.98e-78
# Kurtosis:                       5.432   Cond. No.                     7.40e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 8.4e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 157, but rank is 11
#   warnings.warn('covariance of constraints does not have full '

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='treated')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foriegn funding')
# Out:
# Text(0, 0.5, 'log Foriegn funding')

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ treated* post+log_population +log_gdp+ C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     184.3
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           4.83e-92
# Time:                        13:48:01   Log-Likelihood:                -329.74
# No. Observations:                2610   AIC:                             989.5
# Df Residuals:                    2445   BIC:                             1958.
# Df Model:                         164
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -6.3985      2.774     -2.307      0.021     -11.835      -0.962
# C(Mention_country)[T.ago]    -0.5510      0.105     -5.236      0.000      -0.757      -0.345
# C(Mention_country)[T.alb]    -0.1704      0.360     -0.473      0.636      -0.877       0.536
# C(Mention_country)[T.are]     0.4367      0.316      1.383      0.167      -0.182       1.055
# C(Mention_country)[T.arg]     1.2272      0.192      6.392      0.000       0.851       1.603
# C(Mention_country)[T.arm]    -0.0246      0.357     -0.069      0.945      -0.725       0.675
# C(Mention_country)[T.aus]     2.2345      0.266      8.391      0.000       1.713       2.756
# C(Mention_country)[T.aut]     0.7115      0.302      2.356      0.018       0.120       1.303
# C(Mention_country)[T.aze]    -0.7231      0.202     -3.579      0.000      -1.119      -0.327
# C(Mention_country)[T.bdi]    -1.2323      0.197     -6.265      0.000      -1.618      -0.847
# C(Mention_country)[T.bel]     0.7935      0.281      2.820      0.005       0.242       1.345
# C(Mention_country)[T.ben]     0.3417      0.173      1.981      0.048       0.004       0.680
# C(Mention_country)[T.bfa]     0.7679      0.089      8.674      0.000       0.594       0.941
# C(Mention_country)[T.bgd]     0.8098      0.270      2.995      0.003       0.280       1.340
# C(Mention_country)[T.bgr]     0.4781      0.241      1.983      0.047       0.005       0.951
# C(Mention_country)[T.bhr]    -0.9812      0.351     -2.794      0.005      -1.669      -0.293
# C(Mention_country)[T.bih]     0.0349      0.324      0.108      0.914      -0.601       0.671
# C(Mention_country)[T.blr]    -0.5726      0.204     -2.809      0.005      -0.972      -0.173
# C(Mention_country)[T.bol]     1.0327      0.171      6.041      0.000       0.698       1.368
# C(Mention_country)[T.bra]     1.3087      0.372      3.517      0.000       0.579       2.038
# C(Mention_country)[T.bwa]     1.3144      0.413      3.179      0.001       0.504       2.125
# C(Mention_country)[T.caf]    -0.6949      0.292     -2.383      0.017      -1.266      -0.123
# C(Mention_country)[T.can]     1.9602      0.272      7.204      0.000       1.427       2.494
# C(Mention_country)[T.che]     1.1660      0.329      3.548      0.000       0.522       1.810
# C(Mention_country)[T.chl]     1.5823      0.191      8.267      0.000       1.207       1.957
# C(Mention_country)[T.chn]     1.6128      0.644      2.503      0.012       0.350       2.875
# C(Mention_country)[T.civ]    -2.5513      0.085    -30.046      0.000      -2.718      -2.385
# C(Mention_country)[T.cmr]     1.0908      0.080     13.701      0.000       0.935       1.247
# C(Mention_country)[T.col]     0.6883      0.173      3.989      0.000       0.350       1.027
# C(Mention_country)[T.cri]     1.6760      0.308      5.449      0.000       1.073       2.279
# C(Mention_country)[T.cub]     0.1653      0.191      0.866      0.386      -0.209       0.540
# C(Mention_country)[T.cyp]     1.0465      0.526      1.989      0.047       0.015       2.078
# C(Mention_country)[T.cze]     0.7586      0.244      3.106      0.002       0.280       1.237
# C(Mention_country)[T.deu]     1.3226      0.335      3.944      0.000       0.665       1.980
# C(Mention_country)[T.dji]    -0.8195      0.536     -1.528      0.127      -1.871       0.232
# C(Mention_country)[T.dnk]     1.5917      0.346      4.594      0.000       0.913       2.271
# C(Mention_country)[T.dom]    -0.2273      0.203     -1.121      0.263      -0.625       0.170
# C(Mention_country)[T.dza]    -0.6240      0.140     -4.450      0.000      -0.899      -0.349
# C(Mention_country)[T.ecu]     0.9499      0.155      6.113      0.000       0.645       1.254
# C(Mention_country)[T.egy]     0.4972      0.327      1.521      0.128      -0.143       1.138
# C(Mention_country)[T.eri]    -0.4184      0.351     -1.193      0.233      -1.106       0.269
# C(Mention_country)[T.esp]     2.0215      0.265      7.634      0.000       1.503       2.541
# C(Mention_country)[T.est]     1.1607      0.492      2.359      0.018       0.196       2.125
# C(Mention_country)[T.eth]     1.0593      0.179      5.930      0.000       0.709       1.409
# C(Mention_country)[T.fin]     1.8524      0.342      5.415      0.000       1.182       2.523
# C(Mention_country)[T.fra]     1.3686      0.310      4.412      0.000       0.761       1.976
# C(Mention_country)[T.gab]     0.5479      0.445      1.232      0.218      -0.323       1.419
# C(Mention_country)[T.gbr]     2.2849      0.312      7.319      0.000       1.673       2.897
# C(Mention_country)[T.gha]     1.2242      0.058     21.285      0.000       1.111       1.337
# C(Mention_country)[T.gmb]     0.2555      0.421      0.607      0.544      -0.570       1.081
# C(Mention_country)[T.grc]     1.5995      0.251      6.368      0.000       1.107       2.092
# C(Mention_country)[T.gtm]     0.4363      0.143      3.043      0.002       0.155       0.717
# C(Mention_country)[T.hkg]     2.0650      0.306      6.750      0.000       1.465       2.665
# C(Mention_country)[T.hnd]     0.0193      0.197      0.098      0.922      -0.367       0.405
# C(Mention_country)[T.hrv]     0.4314      0.330      1.309      0.190      -0.214       1.077
# C(Mention_country)[T.hti]     0.1360      0.169      0.807      0.420      -0.194       0.466
# C(Mention_country)[T.hun]     0.8440      0.235      3.597      0.000       0.384       1.304
# C(Mention_country)[T.idn]     0.6856      0.370      1.855      0.064      -0.039       1.410
# C(Mention_country)[T.ind]     1.1109      0.608      1.827      0.068      -0.081       2.303
# C(Mention_country)[T.irn]     0.2557      0.224      1.142      0.253      -0.183       0.695
# C(Mention_country)[T.irq]    -0.2011      0.127     -1.580      0.114      -0.451       0.048
# C(Mention_country)[T.isr]     1.4994      0.293      5.115      0.000       0.925       2.074
# C(Mention_country)[T.ita]     1.6361      0.295      5.546      0.000       1.058       2.214
# C(Mention_country)[T.jam]     0.7131      0.373      1.910      0.056      -0.019       1.445
# C(Mention_country)[T.jor]     1.0297      0.066     15.610      0.000       0.900       1.159
# C(Mention_country)[T.jpn]     1.2802      0.382      3.350      0.001       0.531       2.029
# C(Mention_country)[T.kaz]     0.3228      0.170      1.896      0.058      -0.011       0.657
# C(Mention_country)[T.ken]     1.9914      0.084     23.844      0.000       1.828       2.155
# C(Mention_country)[T.kgz]     0.2009      0.256      0.785      0.432      -0.300       0.702
# C(Mention_country)[T.khm]     0.8123      0.110      7.408      0.000       0.597       1.027
# C(Mention_country)[T.kor]     0.6989      0.262      2.671      0.008       0.186       1.212
# C(Mention_country)[T.kwt]    -0.9398      0.215     -4.361      0.000      -1.362      -0.517
# C(Mention_country)[T.lao]     0.4101      0.235      1.741      0.082      -0.051       0.872
# C(Mention_country)[T.lbn]     0.2665      0.287      0.928      0.354      -0.297       0.830
# C(Mention_country)[T.lbr]    -0.3543      0.314     -1.128      0.259      -0.970       0.261
# C(Mention_country)[T.lby]    -0.5566      0.094     -5.924      0.000      -0.741      -0.372
# C(Mention_country)[T.lka]     0.6352      0.105      6.046      0.000       0.429       0.841
# C(Mention_country)[T.lso]     0.0891      0.412      0.216      0.829      -0.718       0.896
# C(Mention_country)[T.ltu]     0.2800      0.371      0.755      0.450      -0.447       1.007
# C(Mention_country)[T.lva]     0.3299      0.424      0.778      0.437      -0.502       1.161
# C(Mention_country)[T.mar]     0.6457      0.172      3.765      0.000       0.310       0.982
# C(Mention_country)[T.mda]    -0.4169      0.361     -1.154      0.248      -1.125       0.291
# C(Mention_country)[T.mdg]     1.2417      0.043     28.776      0.000       1.157       1.326
# C(Mention_country)[T.mex]     1.8693      0.306      6.114      0.000       1.270       2.469
# C(Mention_country)[T.mkd]     0.1591      0.415      0.383      0.701      -0.654       0.972
# C(Mention_country)[T.mli]     0.5788      0.095      6.104      0.000       0.393       0.765
# C(Mention_country)[T.mmr]    -0.1165      0.095     -1.227      0.220      -0.303       0.070
# C(Mention_country)[T.mng]     2.4602      0.365      6.733      0.000       1.744       3.176
# C(Mention_country)[T.moz]     0.7449      0.032     23.365      0.000       0.682       0.807
# C(Mention_country)[T.mrt]    -0.4134      0.328     -1.258      0.208      -1.057       0.230
# C(Mention_country)[T.mus]     0.2553      0.495      0.516      0.606      -0.714       1.225
# C(Mention_country)[T.mwi]     1.5040      0.103     14.615      0.000       1.302       1.706
# C(Mention_country)[T.mys]     0.7880      0.170      4.633      0.000       0.455       1.121
# C(Mention_country)[T.nam]     1.4004      0.410      3.418      0.001       0.597       2.203
# C(Mention_country)[T.ner]    -0.5162      0.083     -6.197      0.000      -0.679      -0.353
# C(Mention_country)[T.nga]     0.6159      0.301      2.044      0.041       0.025       1.206
# C(Mention_country)[T.nic]     0.6433      0.248      2.589      0.010       0.156       1.130
# C(Mention_country)[T.nld]     1.5358      0.271      5.673      0.000       1.005       2.066
# C(Mention_country)[T.nor]     2.5374      0.372      6.822      0.000       1.808       3.266
# C(Mention_country)[T.npl]     1.2510      0.019     64.568      0.000       1.213       1.289
# C(Mention_country)[T.nzl]     2.9955      0.354      8.472      0.000       2.303       3.689
# C(Mention_country)[T.omn]     0.7811      0.193      4.042      0.000       0.402       1.160
# C(Mention_country)[T.pak]     0.2222      0.316      0.704      0.481      -0.396       0.841
# C(Mention_country)[T.pan]     1.4202      0.342      4.156      0.000       0.750       2.090
# C(Mention_country)[T.per]     1.3810      0.138     10.011      0.000       1.111       1.651
# C(Mention_country)[T.phl]     0.7411      0.225      3.299      0.001       0.301       1.181
# C(Mention_country)[T.pol]     0.7460      0.201      3.703      0.000       0.351       1.141
# C(Mention_country)[T.pri]     1.6132      0.369      4.369      0.000       0.890       2.337
# C(Mention_country)[T.prt]     1.6251      0.251      6.462      0.000       1.132       2.118
# C(Mention_country)[T.pry]    -0.0409      0.262     -0.156      0.876      -0.554       0.473
# C(Mention_country)[T.pse]    -0.2667      0.317     -0.840      0.401      -0.889       0.356
# C(Mention_country)[T.qat]    -0.9498      0.496     -1.913      0.056      -1.923       0.023
# C(Mention_country)[T.rou]     0.4833      0.165      2.933      0.003       0.160       0.806
# C(Mention_country)[T.rus]     0.8311      0.333      2.499      0.012       0.179       1.483
# C(Mention_country)[T.rwa]     0.2219      0.160      1.391      0.164      -0.091       0.535
# C(Mention_country)[T.sau]    -0.1264      0.215     -0.588      0.557      -0.548       0.295
# C(Mention_country)[T.sen]     0.8438      0.133      6.346      0.000       0.583       1.104
# C(Mention_country)[T.sgp]     1.0333      0.350      2.955      0.003       0.348       1.719
# C(Mention_country)[T.sle]     0.1561      0.235      0.663      0.507      -0.305       0.617
# C(Mention_country)[T.slv]    -0.4445      0.251     -1.770      0.077      -0.937       0.048
# C(Mention_country)[T.som]    -0.6155      0.148     -4.158      0.000      -0.906      -0.325
# C(Mention_country)[T.svk]     0.6040      0.305      1.979      0.048       0.006       1.202
# C(Mention_country)[T.svn]     0.7360      0.439      1.677      0.094      -0.124       1.596
# C(Mention_country)[T.swe]     1.9685      0.299      6.577      0.000       1.382       2.555
# C(Mention_country)[T.syr]    -0.3625      0.095     -3.820      0.000      -0.548      -0.176
# C(Mention_country)[T.tcd]    -0.4234      0.136     -3.120      0.002      -0.689      -0.157
# C(Mention_country)[T.tgo]    -0.7177      0.229     -3.130      0.002      -1.167      -0.268
# C(Mention_country)[T.tha]     1.1404      0.210      5.435      0.000       0.729       1.552
# C(Mention_country)[T.tjk]    -0.4557      0.205     -2.225      0.026      -0.857      -0.054
# C(Mention_country)[T.tkm]    -1.3552      0.274     -4.948      0.000      -1.892      -0.818
# C(Mention_country)[T.tto]    -0.7486      0.483     -1.549      0.121      -1.696       0.198
# C(Mention_country)[T.tun]     0.7592      0.010     72.553      0.000       0.739       0.780
# C(Mention_country)[T.tur]     1.1406      0.250      4.554      0.000       0.650       1.632
# C(Mention_country)[T.tza]     1.6476      0.085     19.330      0.000       1.481       1.815
# C(Mention_country)[T.uga]     1.8247      0.030     60.621      0.000       1.766       1.884
# C(Mention_country)[T.ukr]     0.0865      0.138      0.627      0.531      -0.184       0.357
# C(Mention_country)[T.ury]     0.7234      0.357      2.028      0.043       0.024       1.422
# C(Mention_country)[T.usa]     2.1891      0.504      4.344      0.000       1.201       3.177
# C(Mention_country)[T.uzb]    -0.6853      0.064    -10.741      0.000      -0.810      -0.560
# C(Mention_country)[T.ven]    -0.0046      0.182     -0.025      0.980      -0.362       0.353
# C(Mention_country)[T.vnm]     1.2152      0.202      6.015      0.000       0.819       1.611
# C(Mention_country)[T.yem]    -0.9468      0.144     -6.589      0.000      -1.228      -0.665
# C(Mention_country)[T.zaf]     2.0942      0.196     10.677      0.000       1.710       2.479
# C(Mention_country)[T.zmb]     1.1410      0.119      9.597      0.000       0.908       1.374
# C(Mention_country)[T.zwe]     1.1640      0.123      9.470      0.000       0.923       1.405
# C(year)[T.2003.0]             0.0553      0.032      1.736      0.083      -0.007       0.118
# C(year)[T.2004.0]             0.1354      0.038      3.535      0.000       0.060       0.210
# C(year)[T.2005.0]             0.2626      0.042      6.233      0.000       0.180       0.345
# C(year)[T.2006.0]             0.3723      0.049      7.543      0.000       0.276       0.469
# C(year)[T.2007.0]             0.5228      0.051     10.308      0.000       0.423       0.622
# C(year)[T.2008.0]             0.6423      0.059     10.840      0.000       0.526       0.758
# C(year)[T.2009.0]             0.7542      0.057     13.300      0.000       0.643       0.865
# C(year)[T.2010.0]             0.8419      0.063     13.393      0.000       0.719       0.965
# C(year)[T.2011.0]            -0.4017      0.019    -21.501      0.000      -0.438      -0.365
# C(year)[T.2012.0]            -0.2960      0.019    -15.740      0.000      -0.333      -0.259
# C(year)[T.2013.0]            -0.1061      0.016     -6.730      0.000      -0.137      -0.075
# C(year)[T.2014.0]            -0.0379      0.017     -2.193      0.028      -0.072      -0.004
# C(year)[T.2015.0]             0.0097      0.014      0.688      0.492      -0.018       0.037
# C(year)[T.2016.0]             0.1594      0.016      9.968      0.000       0.128       0.191
# C(year)[T.2017.0]             0.3823      0.016     23.901      0.000       0.351       0.414
# C(year)[T.2018.0]             0.7942      0.019     41.680      0.000       0.757       0.832
# C(year)[T.2019.0]             0.8917      0.023     38.751      0.000       0.847       0.937
# treated                      -0.0739      0.201     -0.367      0.714      -0.468       0.320
# post                          1.3956      0.062     22.505      0.000       1.274       1.517
# treated:post                  0.0299      0.103      0.291      0.771      -0.171       0.231
# log_population                0.4745      0.158      3.003      0.003       0.165       0.784
# log_gdp                       0.1034      0.058      1.797      0.072      -0.009       0.216
# ==============================================================================
# Omnibus:                      266.985   Durbin-Watson:                   1.247
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1009.030
# Skew:                          -0.459   Prob(JB):                    7.80e-220
# Kurtosis:                       5.904   Cond. No.                     7.80e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.47e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 166, but rank is 20
#   warnings.warn('covariance of constraints does not have full '

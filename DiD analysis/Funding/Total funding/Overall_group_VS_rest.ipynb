# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
#funding
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df_fund=pd.read_csv(r"C:\Users\Yasaman\Downloads\Mentioned-Funding-fractional counting.csv")
df_fund.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'funding_country': 'Source'}, inplace=True)
df_fund=df_fund[~(df_fund['subjarea'].isin(physical_sciences))]
df_fund=df_fund.groupby(['year', 'Mention_country'])['count'].sum().reset_index()
df_fund=df_fund[(df_fund['year'].isin(np.arange(2002,2020,1)))].reset_index(drop=True)
df=df_fund.copy()

data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))

# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "incomelevel": country_data["incomelevel"].iloc[0] if not country_data.empty else np.nan,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# 0

# %%
df_complete['hue']=df_complete['treated_CW']*2 +df_complete['treated_GC']*3+df_complete['treated_GO']

# %%
df_p=df_complete[df_complete['year']<2011].reset_index(drop=True)
df_p['time']=df_p['year']-2011
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~time+treated_GC * time + treated_GO * time +treated_CW * time+log_population +log_gdp +C(Mention_country)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                     72.22
# Date:                Tue, 18 Mar 2025   Prob (F-statistic):           5.83e-41
# Time:                        09:04:42   Log-Likelihood:                -75.834
# No. Observations:                1305   AIC:                             453.7
# Df Residuals:                    1154   BIC:                             1235.
# Df Model:                         150
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -2.8338      3.852     -0.736      0.462     -10.385       4.717
# C(Mention_country)[T.ago]    -0.3924      0.136     -2.887      0.004      -0.659      -0.126
# C(Mention_country)[T.alb]    -0.6216      0.479     -1.298      0.194      -1.560       0.317
# C(Mention_country)[T.are]    -0.0093      0.451     -0.021      0.984      -0.894       0.875
# C(Mention_country)[T.arg]     2.3223      0.235      9.889      0.000       1.862       2.783
# C(Mention_country)[T.arm]    -0.4440      0.471     -0.944      0.345      -1.366       0.478
# C(Mention_country)[T.aus]     3.0725      0.325      9.457      0.000       2.436       3.709
# C(Mention_country)[T.aut]     0.7268      0.394      1.845      0.065      -0.045       1.499
# C(Mention_country)[T.aze]    -0.8955      0.262     -3.422      0.001      -1.408      -0.383
# C(Mention_country)[T.bdi]    -1.3129      0.271     -4.851      0.000      -1.843      -0.782
# C(Mention_country)[T.bel]     1.0277      0.364      2.821      0.005       0.314       1.742
# C(Mention_country)[T.ben]     0.3091      0.244      1.267      0.205      -0.169       0.787
# C(Mention_country)[T.bfa]     0.9715      0.123      7.871      0.000       0.730       1.213
# C(Mention_country)[T.bgd]     1.4447      0.392      3.689      0.000       0.677       2.212
# C(Mention_country)[T.bgr]     0.5171      0.305      1.697      0.090      -0.080       1.114
# C(Mention_country)[T.bhr]    -1.8364      0.383     -4.789      0.000      -2.588      -1.085
# C(Mention_country)[T.bih]    -0.4370      0.418     -1.046      0.296      -1.256       0.382
# C(Mention_country)[T.blr]    -0.4861      0.255     -1.908      0.056      -0.985       0.013
# C(Mention_country)[T.bol]     1.1255      0.224      5.023      0.000       0.686       1.565
# C(Mention_country)[T.bra]     2.9769      0.510      5.837      0.000       1.977       3.976
# C(Mention_country)[T.bwa]     0.7921      0.578      1.371      0.170      -0.340       1.925
# C(Mention_country)[T.caf]    -0.9574      0.389     -2.464      0.014      -1.719      -0.196
# C(Mention_country)[T.can]     2.9715      0.341      8.703      0.000       2.302       3.641
# C(Mention_country)[T.che]     1.3585      0.426      3.186      0.001       0.523       2.194
# C(Mention_country)[T.chl]     1.8936      0.234      8.077      0.000       1.434       2.353
# C(Mention_country)[T.chn]     3.6956      0.902      4.095      0.000       1.927       5.464
# C(Mention_country)[T.civ]    -2.1714      0.112    -19.328      0.000      -2.392      -1.951
# C(Mention_country)[T.cmr]     1.3470      0.113     11.882      0.000       1.125       1.569
# C(Mention_country)[T.col]     0.9728      0.222      4.391      0.000       0.539       1.407
# C(Mention_country)[T.cri]     1.6278      0.414      3.930      0.000       0.816       2.440
# C(Mention_country)[T.cub]     0.1100      0.238      0.462      0.644      -0.356       0.576
# C(Mention_country)[T.cyp]     0.2333      0.734      0.318      0.751      -1.206       1.672
# C(Mention_country)[T.cze]     1.4073      0.314      4.488      0.000       0.793       2.022
# C(Mention_country)[T.deu]     2.0775      0.443      4.690      0.000       1.209       2.946
# C(Mention_country)[T.dji]    -1.1972      0.746     -1.604      0.109      -2.660       0.265
# C(Mention_country)[T.dnk]     1.5744      0.460      3.424      0.001       0.673       2.476
# C(Mention_country)[T.dom]    -0.3888      0.265     -1.466      0.143      -0.908       0.131
# C(Mention_country)[T.dza]    -0.6782      0.182     -3.732      0.000      -1.034      -0.322
# C(Mention_country)[T.ecu]     0.9494      0.197      4.831      0.000       0.564       1.334
# C(Mention_country)[T.egy]     0.5498      0.249      2.211      0.027       0.062       1.037
# C(Mention_country)[T.eri]    -0.2011      0.477     -0.422      0.673      -1.136       0.734
# C(Mention_country)[T.esp]     2.7735      0.346      8.019      0.000       2.096       3.451
# C(Mention_country)[T.est]     1.2562      0.667      1.884      0.060      -0.051       2.563
# C(Mention_country)[T.eth]     1.8180      0.256      7.096      0.000       1.316       2.320
# C(Mention_country)[T.fin]     2.2191      0.455      4.877      0.000       1.327       3.111
# C(Mention_country)[T.fra]     1.8777      0.406      4.626      0.000       1.082       2.673
# C(Mention_country)[T.gab]     0.0767      0.635      0.121      0.904      -1.167       1.320
# C(Mention_country)[T.gbr]     3.3347      0.408      8.183      0.000       2.536       4.133
# C(Mention_country)[T.gha]     1.3542      0.056     24.047      0.000       1.244       1.465
# C(Mention_country)[T.gmb]     0.1031      0.590      0.175      0.861      -1.052       1.259
# C(Mention_country)[T.grc]     1.4608      0.333      4.387      0.000       0.808       2.113
# C(Mention_country)[T.gtm]     0.4446      0.186      2.393      0.017       0.080       0.809
# C(Mention_country)[T.hkg]     2.2241      0.399      5.572      0.000       1.442       3.007
# C(Mention_country)[T.hnd]     0.1655      0.270      0.614      0.539      -0.363       0.694
# C(Mention_country)[T.hrv]     0.3805      0.438      0.868      0.385      -0.478       1.239
# C(Mention_country)[T.hti]    -0.1863      0.223     -0.834      0.404      -0.624       0.252
# C(Mention_country)[T.hun]     1.1656      0.302      3.859      0.000       0.574       1.758
# C(Mention_country)[T.idn]     1.3310      0.518      2.568      0.010       0.315       2.347
# C(Mention_country)[T.ind]     2.7193      0.862      3.153      0.002       1.029       4.409
# C(Mention_country)[T.irn]     1.2962      0.304      4.265      0.000       0.701       1.892
# C(Mention_country)[T.irq]    -0.3761      0.143     -2.633      0.008      -0.656      -0.096
# C(Mention_country)[T.isr]     1.6364      0.387      4.224      0.000       0.877       2.396
# C(Mention_country)[T.ita]     2.1431      0.389      5.508      0.000       1.381       2.906
# C(Mention_country)[T.jam]     0.5680      0.507      1.120      0.263      -0.426       1.562
# C(Mention_country)[T.jor]     0.9991      0.053     18.683      0.000       0.894       1.104
# C(Mention_country)[T.jpn]     2.5763      0.516      4.991      0.000       1.565       3.588
# C(Mention_country)[T.kaz]     0.2703      0.203      1.329      0.184      -0.128       0.669
# C(Mention_country)[T.ken]     2.4349      0.108     22.624      0.000       2.224       2.646
# C(Mention_country)[T.kgz]    -0.0068      0.344     -0.020      0.984      -0.682       0.668
# C(Mention_country)[T.khm]     0.7435      0.138      5.399      0.000       0.474       1.013
# C(Mention_country)[T.kor]     1.9861      0.333      5.957      0.000       1.333       2.640
# C(Mention_country)[T.kwt]    -0.3923      0.212     -1.853      0.064      -0.807       0.023
# C(Mention_country)[T.lao]     0.2885      0.315      0.914      0.360      -0.330       0.907
# C(Mention_country)[T.lbn]     0.2314      0.399      0.580      0.562      -0.550       1.013
# C(Mention_country)[T.lbr]    -0.9860      0.444     -2.220      0.026      -1.856      -0.116
# C(Mention_country)[T.lby]    -0.5140      0.225     -2.281      0.023      -0.956      -0.072
# C(Mention_country)[T.lka]     0.9307      0.114      8.152      0.000       0.707       1.155
# C(Mention_country)[T.lso]    -0.1638      0.556     -0.295      0.768      -1.254       0.926
# C(Mention_country)[T.ltu]    -0.0215      0.483     -0.045      0.965      -0.968       0.925
# C(Mention_country)[T.lva]    -0.2770      0.561     -0.494      0.621      -1.377       0.823
# C(Mention_country)[T.mar]     0.6511      0.384      1.696      0.090      -0.101       1.404
# C(Mention_country)[T.mda]    -0.6632      0.477     -1.390      0.164      -1.598       0.272
# C(Mention_country)[T.mdg]     1.7187      0.056     30.519      0.000       1.608       1.829
# C(Mention_country)[T.mex]     2.5484      0.417      6.117      0.000       1.732       3.365
# C(Mention_country)[T.mkd]    -0.3907      0.561     -0.696      0.487      -1.491       0.710
# C(Mention_country)[T.mli]     0.8043      0.135      5.974      0.000       0.540       1.068
# C(Mention_country)[T.mmr]    -0.0904      0.147     -0.613      0.540      -0.379       0.198
# C(Mention_country)[T.mng]     2.0986      0.500      4.193      0.000       1.118       3.080
# C(Mention_country)[T.moz]     0.8623      0.046     18.670      0.000       0.772       0.953
# C(Mention_country)[T.mrt]    -0.7390      0.461     -1.602      0.109      -1.643       0.165
# C(Mention_country)[T.mus]    -0.1749      0.676     -0.259      0.796      -1.499       1.150
# C(Mention_country)[T.mwi]     1.5821      0.142     11.152      0.000       1.304       1.860
# C(Mention_country)[T.mys]     1.1187      0.208      5.376      0.000       0.711       1.527
# C(Mention_country)[T.nam]     1.1033      0.568      1.944      0.052      -0.009       2.216
# C(Mention_country)[T.ner]    -0.2079      0.121     -1.719      0.086      -0.445       0.029
# C(Mention_country)[T.nga]     1.1169      0.414      2.699      0.007       0.306       1.928
# C(Mention_country)[T.nic]     0.5957      0.337      1.769      0.077      -0.064       1.256
# C(Mention_country)[T.nld]     1.7151      0.345      4.973      0.000       1.039       2.391
# C(Mention_country)[T.nor]     2.4806      0.497      4.992      0.000       1.507       3.455
# C(Mention_country)[T.npl]     1.5573      0.018     87.200      0.000       1.522       1.592
# C(Mention_country)[T.nzl]     3.0492      0.475      6.420      0.000       2.118       3.980
# C(Mention_country)[T.omn]     0.4130      0.172      2.398      0.016       0.075       0.751
# C(Mention_country)[T.pak]     0.9535      0.449      2.123      0.034       0.073       1.834
# C(Mention_country)[T.pan]     1.1060      0.467      2.368      0.018       0.191       2.021
# C(Mention_country)[T.per]     1.4559      0.165      8.800      0.000       1.132       1.780
# C(Mention_country)[T.phl]     1.3085      0.310      4.221      0.000       0.701       1.916
# C(Mention_country)[T.pol]     1.1308      0.259      4.363      0.000       0.623       1.639
# C(Mention_country)[T.pri]     1.1199      0.485      2.308      0.021       0.169       2.071
# C(Mention_country)[T.prt]     1.6647      0.327      5.096      0.000       1.024       2.305
# C(Mention_country)[T.pry]    -0.2462      0.349     -0.704      0.481      -0.931       0.439
# C(Mention_country)[T.pse]    -0.6486      0.444     -1.462      0.144      -1.518       0.221
# C(Mention_country)[T.qat]    -1.6638      0.748     -2.224      0.026      -3.130      -0.197
# C(Mention_country)[T.rou]     0.3055      0.196      1.557      0.119      -0.079       0.690
# C(Mention_country)[T.rus]     1.7613      0.458      3.849      0.000       0.864       2.658
# C(Mention_country)[T.rwa]    -0.1302      0.218     -0.599      0.549      -0.557       0.296
# C(Mention_country)[T.sau]     0.0380      0.261      0.146      0.884      -0.473       0.549
# C(Mention_country)[T.sen]     0.9755      0.187      5.214      0.000       0.609       1.342
# C(Mention_country)[T.sgp]     1.0198      0.470      2.168      0.030       0.098       1.942
# C(Mention_country)[T.sle]    -0.0274      0.323     -0.085      0.932      -0.660       0.605
# C(Mention_country)[T.slv]    -0.4934      0.332     -1.487      0.137      -1.144       0.157
# C(Mention_country)[T.som]    -0.2076      0.204     -1.018      0.309      -0.607       0.192
# C(Mention_country)[T.svk]     0.7200      0.403      1.787      0.074      -0.070       1.510
# C(Mention_country)[T.svn]     0.5490      0.599      0.917      0.359      -0.625       1.723
# C(Mention_country)[T.swe]     2.5676      0.389      6.606      0.000       1.806       3.329
# C(Mention_country)[T.syr]    -0.0515      0.115     -0.448      0.654      -0.277       0.174
# C(Mention_country)[T.tcd]    -0.2999      0.196     -1.532      0.126      -0.684       0.084
# C(Mention_country)[T.tgo]    -0.7601      0.318     -2.393      0.017      -1.383      -0.137
# C(Mention_country)[T.tha]     1.9520      0.285      6.846      0.000       1.393       2.511
# C(Mention_country)[T.tjk]    -0.4940      0.278     -1.779      0.075      -1.038       0.050
# C(Mention_country)[T.tkm]    -1.3259      0.368     -3.604      0.000      -2.047      -0.605
# C(Mention_country)[T.tto]    -1.3167      0.664     -1.983      0.047      -2.618      -0.015
# C(Mention_country)[T.tun]     0.0478      0.227      0.210      0.833      -0.397       0.493
# C(Mention_country)[T.tur]     2.0584      0.332      6.207      0.000       1.408       2.708
# C(Mention_country)[T.tza]     2.1074      0.118     17.824      0.000       1.876       2.339
# C(Mention_country)[T.uga]     2.1576      0.039     55.337      0.000       2.081       2.234
# C(Mention_country)[T.ukr]     0.3956      0.202      1.956      0.051      -0.001       0.792
# C(Mention_country)[T.ury]     0.5321      0.472      1.128      0.259      -0.393       1.457
# C(Mention_country)[T.usa]     4.0912      0.678      6.036      0.000       2.763       5.420
# C(Mention_country)[T.uzb]    -0.1636      0.062     -2.621      0.009      -0.286      -0.041
# C(Mention_country)[T.ven]     0.5017      0.216      2.326      0.020       0.079       0.924
# C(Mention_country)[T.vnm]     1.7078      0.284      6.009      0.000       1.151       2.265
# C(Mention_country)[T.yem]    -0.2036      0.096     -2.124      0.034      -0.391      -0.016
# C(Mention_country)[T.zaf]     2.5519      0.263      9.696      0.000       2.036       3.068
# C(Mention_country)[T.zmb]     1.1920      0.169      7.041      0.000       0.860       1.524
# C(Mention_country)[T.zwe]     1.6084      0.156     10.339      0.000       1.304       1.913
# time                          0.1103      0.009     12.676      0.000       0.093       0.127
# treated_GC                   -0.1654      0.361     -0.458      0.647      -0.873       0.543
# treated_GC:time              -0.0670      0.021     -3.154      0.002      -0.109      -0.025
# treated_GO                    0.5975      0.157      3.798      0.000       0.289       0.906
# treated_GO:time               0.0338      0.037      0.919      0.358      -0.038       0.106
# treated_CW                   -0.7691      0.168     -4.583      0.000      -1.098      -0.440
# treated_CW:time              -0.0164      0.022     -0.761      0.447      -0.059       0.026
# log_population                0.2527      0.221      1.141      0.254      -0.181       0.687
# log_gdp                       0.2422      0.069      3.532      0.000       0.108       0.377
# ==============================================================================
# Omnibus:                      102.950   Durbin-Watson:                   1.742
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              345.611
# Skew:                          -0.342   Prob(JB):                     8.94e-76
# Kurtosis:                       5.426   Cond. No.                     1.96e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.22e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 153, but rank is 6
#   warnings.warn('covariance of constraints does not have full '

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='hue')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foreign funding')
# Out:
# Text(0, 0.5, 'log Foreign funding')

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * post + treated_GO * post +treated_CW * post+log_population +log_gdp+C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.974
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                     150.4
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           6.33e-88
# Time:                        13:18:23   Log-Likelihood:                -438.26
# No. Observations:                2610   AIC:                             1211.
# Df Residuals:                    2443   BIC:                             2190.
# Df Model:                         166
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                   -10.0618      4.343     -2.317      0.021     -18.573      -1.550
# C(Mention_country)[T.ago]    -0.6182      0.121     -5.099      0.000      -0.856      -0.381
# C(Mention_country)[T.alb]     0.1502      0.597      0.251      0.802      -1.021       1.321
# C(Mention_country)[T.are]     0.7067      0.460      1.535      0.125      -0.195       1.609
# C(Mention_country)[T.arg]     1.9109      0.199      9.597      0.000       1.521       2.301
# C(Mention_country)[T.arm]     0.3640      0.592      0.614      0.539      -0.797       1.525
# C(Mention_country)[T.aus]     3.2139      0.289     11.124      0.000       2.648       3.780
# C(Mention_country)[T.aut]     1.3001      0.422      3.078      0.002       0.472       2.128
# C(Mention_country)[T.aze]    -0.5962      0.324     -1.842      0.066      -1.231       0.038
# C(Mention_country)[T.bdi]    -0.9385      0.298     -3.149      0.002      -1.523      -0.354
# C(Mention_country)[T.bel]     1.4340      0.373      3.848      0.000       0.704       2.164
# C(Mention_country)[T.ben]     0.5134      0.286      1.795      0.073      -0.047       1.074
# C(Mention_country)[T.bfa]     0.8587      0.146      5.865      0.000       0.572       1.146
# C(Mention_country)[T.bgd]     0.5138      0.419      1.226      0.220      -0.308       1.335
# C(Mention_country)[T.bgr]     0.8282      0.384      2.156      0.031       0.075       1.581
# C(Mention_country)[T.bhr]    -0.9534      0.457     -2.087      0.037      -1.849      -0.058
# C(Mention_country)[T.bih]     0.3072      0.537      0.572      0.567      -0.745       1.359
# C(Mention_country)[T.blr]    -0.4216      0.319     -1.320      0.187      -1.048       0.204
# C(Mention_country)[T.bol]     1.1459      0.280      4.100      0.000       0.598       1.694
# C(Mention_country)[T.bra]     2.1073      0.514      4.103      0.000       1.101       3.114
# C(Mention_country)[T.bwa]     1.7059      0.685      2.489      0.013       0.363       3.049
# C(Mention_country)[T.caf]    -0.3348      0.467     -0.716      0.474      -1.251       0.581
# C(Mention_country)[T.can]     2.8881      0.277     10.421      0.000       2.345       3.431
# C(Mention_country)[T.che]     2.0015      0.455      4.401      0.000       1.110       2.893
# C(Mention_country)[T.chl]     2.0205      0.238      8.501      0.000       1.555       2.486
# C(Mention_country)[T.chn]     2.1281      0.982      2.167      0.030       0.203       4.053
# C(Mention_country)[T.civ]    -2.5716      0.113    -22.725      0.000      -2.793      -2.350
# C(Mention_country)[T.cmr]     1.0950      0.115      9.487      0.000       0.869       1.321
# C(Mention_country)[T.col]     0.8245      0.186      4.437      0.000       0.460       1.189
# C(Mention_country)[T.cri]     1.9488      0.500      3.895      0.000       0.968       2.929
# C(Mention_country)[T.cub]     0.2549      0.287      0.888      0.375      -0.308       0.818
# C(Mention_country)[T.cyp]     1.6111      0.867      1.858      0.063      -0.088       3.310
# C(Mention_country)[T.cze]     1.8231      0.345      5.291      0.000       1.148       2.498
# C(Mention_country)[T.deu]     1.6554      0.376      4.404      0.000       0.919       2.392
# C(Mention_country)[T.dji]    -0.2225      0.880     -0.253      0.800      -1.947       1.502
# C(Mention_country)[T.dnk]     2.3307      0.514      4.537      0.000       1.324       3.338
# C(Mention_country)[T.dom]    -0.1556      0.315     -0.494      0.621      -0.773       0.462
# C(Mention_country)[T.dza]    -0.6676      0.144     -4.623      0.000      -0.951      -0.385
# C(Mention_country)[T.ecu]     1.0266      0.219      4.677      0.000       0.596       1.457
# C(Mention_country)[T.egy]    -0.1329      0.270     -0.492      0.623      -0.663       0.397
# C(Mention_country)[T.eri]     0.0006      0.568      0.001      0.999      -1.112       1.113
# C(Mention_country)[T.esp]     2.5520      0.273      9.340      0.000       2.016       3.087
# C(Mention_country)[T.est]     2.3262      0.813      2.860      0.004       0.732       3.921
# C(Mention_country)[T.eth]     1.1146      0.290      3.842      0.000       0.546       1.683
# C(Mention_country)[T.fin]     2.8234      0.514      5.489      0.000       1.815       3.832
# C(Mention_country)[T.fra]     1.5518      0.335      4.631      0.000       0.895       2.209
# C(Mention_country)[T.gab]     0.9995      0.737      1.357      0.175      -0.445       2.444
# C(Mention_country)[T.gbr]     3.0674      0.335      9.165      0.000       2.411       3.723
# C(Mention_country)[T.gha]     1.2349      0.067     18.437      0.000       1.104       1.366
# C(Mention_country)[T.gmb]     0.7519      0.684      1.100      0.272      -0.588       2.092
# C(Mention_country)[T.grc]     1.7982      0.345      5.214      0.000       1.122       2.474
# C(Mention_country)[T.gtm]     0.4645      0.215      2.160      0.031       0.043       0.886
# C(Mention_country)[T.hkg]     2.6684      0.448      5.959      0.000       1.791       3.546
# C(Mention_country)[T.hnd]     0.1797      0.325      0.553      0.581      -0.458       0.817
# C(Mention_country)[T.hrv]     1.2615      0.531      2.376      0.018       0.221       2.302
# C(Mention_country)[T.hti]     0.2882      0.280      1.031      0.303      -0.260       0.836
# C(Mention_country)[T.hun]     1.4758      0.342      4.320      0.000       0.806       2.145
# C(Mention_country)[T.idn]     0.2995      0.551      0.544      0.586      -0.780       1.379
# C(Mention_country)[T.ind]     0.9513      0.956      0.995      0.320      -0.923       2.825
# C(Mention_country)[T.irn]     1.2133      0.282      4.305      0.000       0.661       1.766
# C(Mention_country)[T.irq]    -0.3116      0.129     -2.407      0.016      -0.565      -0.058
# C(Mention_country)[T.isr]     1.9851      0.426      4.661      0.000       1.150       2.820
# C(Mention_country)[T.ita]     1.8328      0.315      5.818      0.000       1.215       2.450
# C(Mention_country)[T.jam]     1.0970      0.619      1.773      0.076      -0.115       2.310
# C(Mention_country)[T.jor]     0.9438      0.044     21.379      0.000       0.857       1.030
# C(Mention_country)[T.jpn]     2.1468      0.460      4.671      0.000       1.246       3.048
# C(Mention_country)[T.kaz]     0.3612      0.223      1.623      0.105      -0.075       0.797
# C(Mention_country)[T.ken]     1.9084      0.105     18.105      0.000       1.702       2.115
# C(Mention_country)[T.kgz]     0.4787      0.421      1.137      0.255      -0.346       1.303
# C(Mention_country)[T.khm]     0.9102      0.182      5.005      0.000       0.554       1.267
# C(Mention_country)[T.kor]     1.9712      0.274      7.193      0.000       1.434       2.508
# C(Mention_country)[T.kwt]     0.0583      0.229      0.255      0.799      -0.390       0.506
# C(Mention_country)[T.lao]     0.6485      0.390      1.664      0.096      -0.116       1.412
# C(Mention_country)[T.lbn]     0.8255      0.467      1.769      0.077      -0.089       1.740
# C(Mention_country)[T.lbr]     0.0244      0.507      0.048      0.962      -0.970       1.019
# C(Mention_country)[T.lby]    -0.0146      0.286     -0.051      0.959      -0.575       0.546
# C(Mention_country)[T.lka]     0.8006      0.136      5.877      0.000       0.534       1.068
# C(Mention_country)[T.lso]     0.5548      0.673      0.824      0.410      -0.765       1.875
# C(Mention_country)[T.ltu]     0.8656      0.606      1.428      0.153      -0.322       2.054
# C(Mention_country)[T.lva]     0.7661      0.699      1.096      0.273      -0.604       2.137
# C(Mention_country)[T.mar]    -0.0221      0.406     -0.054      0.957      -0.818       0.774
# C(Mention_country)[T.mda]    -0.0453      0.598     -0.076      0.940      -1.218       1.127
# C(Mention_country)[T.mdg]     1.2923      0.070     18.425      0.000       1.155       1.430
# C(Mention_country)[T.mex]     1.7931      0.390      4.592      0.000       1.028       2.558
# C(Mention_country)[T.mkd]     0.5385      0.688      0.782      0.434      -0.810       1.888
# C(Mention_country)[T.mli]     0.6721      0.157      4.278      0.000       0.364       0.980
# C(Mention_country)[T.mmr]    -0.2489      0.140     -1.775      0.076      -0.524       0.026
# C(Mention_country)[T.mng]     2.8214      0.606      4.659      0.000       1.635       4.008
# C(Mention_country)[T.moz]     0.7729      0.053     14.623      0.000       0.669       0.876
# C(Mention_country)[T.mrt]    -0.0731      0.543     -0.135      0.893      -1.137       0.991
# C(Mention_country)[T.mus]     0.8463      0.821      1.031      0.302      -0.762       2.455
# C(Mention_country)[T.mwi]     1.6212      0.169      9.613      0.000       1.291       1.952
# C(Mention_country)[T.mys]     1.4196      0.176      8.069      0.000       1.075       1.764
# C(Mention_country)[T.nam]     1.7898      0.680      2.633      0.008       0.458       3.122
# C(Mention_country)[T.ner]    -0.4156      0.134     -3.092      0.002      -0.679      -0.152
# C(Mention_country)[T.nga]     0.2527      0.446      0.566      0.571      -0.622       1.128
# C(Mention_country)[T.nic]     0.8762      0.412      2.126      0.034       0.068       1.684
# C(Mention_country)[T.nld]     2.0658      0.317      6.520      0.000       1.445       2.687
# C(Mention_country)[T.nor]     3.1031      0.552      5.623      0.000       2.022       4.185
# C(Mention_country)[T.npl]     1.2736      0.025     50.403      0.000       1.224       1.323
# C(Mention_country)[T.nzl]     3.6554      0.549      6.654      0.000       2.579       4.732
# C(Mention_country)[T.omn]     0.6791      0.196      3.470      0.001       0.296       1.063
# C(Mention_country)[T.pak]     0.0856      0.486      0.176      0.860      -0.866       1.037
# C(Mention_country)[T.pan]     1.6700      0.559      2.986      0.003       0.574       2.766
# C(Mention_country)[T.per]     1.2630      0.142      8.913      0.000       0.985       1.541
# C(Mention_country)[T.phl]     0.5279      0.316      1.672      0.095      -0.091       1.147
# C(Mention_country)[T.pol]     1.1483      0.206      5.575      0.000       0.745       1.552
# C(Mention_country)[T.pri]     1.8474      0.587      3.147      0.002       0.697       2.998
# C(Mention_country)[T.prt]     2.2060      0.351      6.289      0.000       1.519       2.893
# C(Mention_country)[T.pry]     0.1481      0.430      0.345      0.730      -0.694       0.990
# C(Mention_country)[T.pse]     0.0795      0.527      0.151      0.880      -0.953       1.112
# C(Mention_country)[T.qat]     0.2192      0.802      0.273      0.785      -1.353       1.792
# C(Mention_country)[T.rou]     0.5394      0.194      2.779      0.005       0.159       0.920
# C(Mention_country)[T.rus]     0.9486      0.442      2.146      0.032       0.082       1.815
# C(Mention_country)[T.rwa]     0.4087      0.260      1.571      0.116      -0.101       0.919
# C(Mention_country)[T.sau]     0.4852      0.222      2.185      0.029       0.050       0.920
# C(Mention_country)[T.sen]     0.9467      0.219      4.324      0.000       0.518       1.376
# C(Mention_country)[T.sgp]     1.8278      0.531      3.444      0.001       0.788       2.868
# C(Mention_country)[T.sle]     0.4437      0.379      1.172      0.241      -0.298       1.186
# C(Mention_country)[T.slv]    -0.2591      0.414     -0.626      0.531      -1.070       0.552
# C(Mention_country)[T.som]    -0.4125      0.223     -1.848      0.065      -0.850       0.025
# C(Mention_country)[T.svk]     1.4993      0.480      3.121      0.002       0.558       2.441
# C(Mention_country)[T.svn]     1.6538      0.718      2.305      0.021       0.247       3.060
# C(Mention_country)[T.swe]     2.9538      0.406      7.275      0.000       2.158       3.750
# C(Mention_country)[T.syr] -9.051e-05      0.053     -0.002      0.999      -0.104       0.104
# C(Mention_country)[T.tcd]    -0.2839      0.224     -1.265      0.206      -0.724       0.156
# C(Mention_country)[T.tgo]    -0.4580      0.375     -1.221      0.222      -1.193       0.277
# C(Mention_country)[T.tha]     1.4457      0.258      5.610      0.000       0.941       1.951
# C(Mention_country)[T.tjk]    -0.2237      0.335     -0.668      0.504      -0.881       0.433
# C(Mention_country)[T.tkm]    -1.1513      0.451     -2.551      0.011      -2.036      -0.267
# C(Mention_country)[T.tto]    -0.2290      0.798     -0.287      0.774      -1.794       1.336
# C(Mention_country)[T.tun]     0.4711      0.268      1.755      0.079      -0.055       0.997
# C(Mention_country)[T.tur]     1.4741      0.297      4.963      0.000       0.892       2.056
# C(Mention_country)[T.tza]     1.5760      0.123     12.839      0.000       1.335       1.817
# C(Mention_country)[T.uga]     1.8320      0.038     48.298      0.000       1.758       1.906
# C(Mention_country)[T.ukr]    -0.0400      0.158     -0.253      0.801      -0.350       0.270
# C(Mention_country)[T.ury]     1.2244      0.583      2.101      0.036       0.082       2.367
# C(Mention_country)[T.usa]     3.1006      0.661      4.693      0.000       1.806       4.396
# C(Mention_country)[T.uzb]    -0.6913      0.066    -10.493      0.000      -0.820      -0.562
# C(Mention_country)[T.ven]     0.0627      0.189      0.332      0.740      -0.307       0.433
# C(Mention_country)[T.vnm]     0.9956      0.291      3.422      0.001       0.425       1.566
# C(Mention_country)[T.yem]    -0.5911      0.101     -5.860      0.000      -0.789      -0.393
# C(Mention_country)[T.zaf]     2.2278      0.219     10.193      0.000       1.799       2.656
# C(Mention_country)[T.zmb]     1.2294      0.195      6.296      0.000       0.847       1.612
# C(Mention_country)[T.zwe]     1.3086      0.204      6.419      0.000       0.909       1.708
# C(year)[T.2003.0]             0.0521      0.029      1.784      0.074      -0.005       0.109
# C(year)[T.2004.0]             0.1372      0.036      3.769      0.000       0.066       0.209
# C(year)[T.2005.0]             0.2758      0.040      6.951      0.000       0.198       0.354
# C(year)[T.2006.0]             0.3867      0.049      7.922      0.000       0.291       0.482
# C(year)[T.2007.0]             0.5114      0.053      9.649      0.000       0.408       0.615
# C(year)[T.2008.0]             0.6296      0.062     10.223      0.000       0.509       0.750
# C(year)[T.2009.0]             0.7449      0.062     12.052      0.000       0.624       0.866
# C(year)[T.2010.0]             0.8337      0.066     12.724      0.000       0.705       0.962
# C(year)[T.2011.0]            -0.4212      0.019    -22.236      0.000      -0.458      -0.384
# C(year)[T.2012.0]            -0.3106      0.020    -15.451      0.000      -0.350      -0.271
# C(year)[T.2013.0]            -0.1274      0.016     -7.912      0.000      -0.159      -0.096
# C(year)[T.2014.0]            -0.0533      0.017     -3.090      0.002      -0.087      -0.020
# C(year)[T.2015.0]            -0.0062      0.014     -0.441      0.659      -0.034       0.021
# C(year)[T.2016.0]             0.1637      0.017      9.596      0.000       0.130       0.197
# C(year)[T.2017.0]             0.4094      0.019     21.281      0.000       0.372       0.447
# C(year)[T.2018.0]             0.8147      0.022     37.031      0.000       0.772       0.858
# C(year)[T.2019.0]             0.9301      0.027     34.409      0.000       0.877       0.983
# treated_GC                    0.7058      0.442      1.596      0.110      -0.161       1.572
# post                          1.3994      0.068     20.725      0.000       1.267       1.532
# treated_GC:post              -0.3248      0.109     -2.991      0.003      -0.538      -0.112
# treated_GO                    0.3382      0.088      3.830      0.000       0.165       0.511
# treated_GO:post               0.2280      0.145      1.576      0.115      -0.056       0.511
# treated_CW                   -0.6058      0.178     -3.412      0.001      -0.954      -0.258
# treated_CW:post               0.3452      0.121      2.844      0.004       0.107       0.583
# log_population                0.6678      0.254      2.630      0.009       0.170       1.166
# log_gdp                       0.1599      0.059      2.692      0.007       0.043       0.276
# ==============================================================================
# Omnibus:                      172.516   Durbin-Watson:                   1.101
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              590.482
# Skew:                          -0.267   Prob(JB):                    6.00e-129
# Kurtosis:                       5.268   Cond. No.                     7.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.41e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 170, but rank is 22
#   warnings.warn('covariance of constraints does not have full '

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
#funding
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df_fund=pd.read_csv(r"C:\Users\Yasaman\Downloads\Mentioned-Funding-fractional counting.csv")
df_fund.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'funding_country': 'Source'}, inplace=True)
df_fund=df_fund[~(df_fund['subjarea'].isin(physical_sciences))]
df_fund=df_fund.groupby(['year', 'Mention_country'])['count'].sum().reset_index()
df_fund=df_fund[(df_fund['year'].isin(np.arange(2002,2020,1)))].reset_index(drop=True)
df=df_fund.copy()

data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))

# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "incomelevel": country_data["incomelevel"].iloc[0] if not country_data.empty else np.nan,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# 0

# %%
df_p=df_complete[df_complete['year']<=2011].reset_index(drop=True)
df_p['time']=df_p['year']-2011
df_p=df_p[df_p['time']<-1]
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ treated * time +log_gdp+log_population+ C(Mention_country) + C(year)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                 1.960e+04
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):          2.83e-220
# Time:                        14:39:35   Log-Likelihood:                -50.368
# No. Observations:                1160   AIC:                             410.7
# Df Residuals:                    1005   BIC:                             1194.
# Df Model:                         154
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     0.5211      3.050      0.171      0.864      -5.456       6.498
# C(Mention_country)[T.ago]    -0.3680      0.164     -2.241      0.025      -0.690      -0.046
# C(Mention_country)[T.alb]    -1.0395      0.593     -1.753      0.080      -2.202       0.123
# C(Mention_country)[T.are]    -0.4169      0.566     -0.736      0.462      -1.527       0.693
# C(Mention_country)[T.arg]     2.4855      0.284      8.738      0.000       1.928       3.043
# C(Mention_country)[T.arm]    -0.8387      0.583     -1.439      0.150      -1.981       0.303
# C(Mention_country)[T.aus]     3.0346      0.390      7.773      0.000       2.269       3.800
# C(Mention_country)[T.aut]     0.4737      0.481      0.986      0.324      -0.468       1.416
# C(Mention_country)[T.aze]    -1.0869      0.321     -3.384      0.001      -1.716      -0.457
# C(Mention_country)[T.bdi]    -1.4645      0.338     -4.330      0.000      -2.127      -0.802
# C(Mention_country)[T.bel]     0.8326      0.443      1.878      0.060      -0.036       1.701
# C(Mention_country)[T.ben]     0.0989      0.305      0.324      0.746      -0.499       0.697
# C(Mention_country)[T.bfa]     0.9356      0.155      6.055      0.000       0.633       1.238
# C(Mention_country)[T.bgd]     1.9245      0.492      3.914      0.000       0.961       2.888
# C(Mention_country)[T.bgr]     0.2996      0.373      0.802      0.422      -0.432       1.031
# C(Mention_country)[T.bhr]    -2.1593      0.638     -3.386      0.001      -3.409      -0.909
# C(Mention_country)[T.bih]    -0.8683      0.515     -1.685      0.092      -1.878       0.142
# C(Mention_country)[T.blr]    -0.6402      0.311     -2.060      0.039      -1.249      -0.031
# C(Mention_country)[T.bol]     1.0137      0.278      3.651      0.000       0.470       1.558
# C(Mention_country)[T.bra]     3.5086      0.633      5.545      0.000       2.268       4.749
# C(Mention_country)[T.bwa]     0.2881      0.720      0.400      0.689      -1.123       1.700
# C(Mention_country)[T.caf]    -1.0852      0.484     -2.243      0.025      -2.033      -0.137
# C(Mention_country)[T.can]     3.0381      0.413      7.365      0.000       2.230       3.847
# C(Mention_country)[T.che]     1.0885      0.520      2.094      0.036       0.069       2.107
# C(Mention_country)[T.chl]     1.8677      0.283      6.608      0.000       1.314       2.422
# C(Mention_country)[T.chn]     4.6502      1.128      4.124      0.000       2.440       6.860
# C(Mention_country)[T.civ]    -2.1890      0.139    -15.746      0.000      -2.461      -1.916
# C(Mention_country)[T.cmr]     1.3416      0.141      9.483      0.000       1.064       1.619
# C(Mention_country)[T.col]     1.1584      0.270      4.283      0.000       0.628       1.688
# C(Mention_country)[T.cri]     1.2914      0.513      2.516      0.012       0.285       2.297
# C(Mention_country)[T.cub]     0.0299      0.291      0.103      0.918      -0.541       0.600
# C(Mention_country)[T.cyp]    -0.4887      0.913     -0.535      0.593      -2.279       1.302
# C(Mention_country)[T.cze]     1.2232      0.382      3.203      0.001       0.475       1.972
# C(Mention_country)[T.deu]     2.3597      0.544      4.336      0.000       1.293       3.426
# C(Mention_country)[T.dji]    -1.9101      0.931     -2.051      0.040      -3.736      -0.085
# C(Mention_country)[T.dnk]     1.2427      0.564      2.204      0.028       0.138       2.348
# C(Mention_country)[T.dom]    -0.5560      0.326     -1.704      0.088      -1.196       0.084
# C(Mention_country)[T.dza]    -0.5553      0.222     -2.503      0.012      -0.990      -0.121
# C(Mention_country)[T.ecu]     0.8886      0.240      3.697      0.000       0.418       1.360
# C(Mention_country)[T.egy]     1.5352      0.590      2.601      0.009       0.378       2.692
# C(Mention_country)[T.eri]    -0.5732      0.595     -0.964      0.335      -1.739       0.593
# C(Mention_country)[T.esp]     2.9185      0.421      6.929      0.000       2.093       3.744
# C(Mention_country)[T.est]     0.5902      0.827      0.713      0.476      -1.031       2.212
# C(Mention_country)[T.eth]     2.1913      0.321      6.836      0.000       1.563       2.820
# C(Mention_country)[T.fin]     1.8746      0.559      3.355      0.001       0.779       2.970
# C(Mention_country)[T.fra]     2.0905      0.497      4.210      0.000       1.117       3.064
# C(Mention_country)[T.gab]    -0.4524      0.792     -0.571      0.568      -2.005       1.101
# C(Mention_country)[T.gbr]     3.5108      0.499      7.034      0.000       2.533       4.489
# C(Mention_country)[T.gha]     1.4009      0.067     20.783      0.000       1.269       1.533
# C(Mention_country)[T.gmb]    -0.4263      0.737     -0.579      0.563      -1.870       1.017
# C(Mention_country)[T.grc]     1.2978      0.406      3.199      0.001       0.503       2.093
# C(Mention_country)[T.gtm]     0.3445      0.229      1.503      0.133      -0.105       0.794
# C(Mention_country)[T.hkg]     1.9477      0.489      3.981      0.000       0.989       2.907
# C(Mention_country)[T.hnd]    -0.0464      0.336     -0.138      0.890      -0.704       0.612
# C(Mention_country)[T.hrv]    -0.0093      0.541     -0.017      0.986      -1.069       1.051
# C(Mention_country)[T.hti]    -0.4140      0.277     -1.493      0.135      -0.958       0.129
# C(Mention_country)[T.hun]     1.0148      0.369      2.750      0.006       0.292       1.738
# C(Mention_country)[T.idn]     1.9177      0.647      2.964      0.003       0.650       3.186
# C(Mention_country)[T.ind]     3.6786      1.078      3.411      0.001       1.565       5.792
# C(Mention_country)[T.irn]     1.5299      0.375      4.081      0.000       0.795       2.265
# C(Mention_country)[T.irq]    -0.3504      0.170     -2.056      0.040      -0.685      -0.016
# C(Mention_country)[T.isr]     1.3832      0.475      2.910      0.004       0.451       2.315
# C(Mention_country)[T.ita]     2.3458      0.476      4.928      0.000       1.413       3.279
# C(Mention_country)[T.jam]     0.0801      0.630      0.127      0.899      -1.155       1.315
# C(Mention_country)[T.jor]     1.1440      0.134      8.518      0.000       0.881       1.407
# C(Mention_country)[T.jpn]     2.9506      0.636      4.636      0.000       1.703       4.198
# C(Mention_country)[T.kaz]     0.2378      0.244      0.974      0.330      -0.241       0.717
# C(Mention_country)[T.ken]     2.6338      0.133     19.759      0.000       2.373       2.895
# C(Mention_country)[T.kgz]    -0.3481      0.428     -0.814      0.416      -1.187       0.490
# C(Mention_country)[T.khm]     0.6824      0.170      4.006      0.000       0.349       1.016
# C(Mention_country)[T.kor]     2.1269      0.407      5.223      0.000       1.329       2.925
# C(Mention_country)[T.kwt]    -0.5060      0.407     -1.244      0.213      -1.303       0.291
# C(Mention_country)[T.lao]     0.0321      0.392      0.082      0.935      -0.736       0.801
# C(Mention_country)[T.lbn]    -0.0878      0.494     -0.178      0.859      -1.056       0.880
# C(Mention_country)[T.lbr]    -1.3951      0.557     -2.506      0.012      -2.486      -0.304
# C(Mention_country)[T.lby]    -1.2987      0.136     -9.544      0.000      -1.565      -1.032
# C(Mention_country)[T.lka]     0.9772      0.136      7.178      0.000       0.710       1.244
# C(Mention_country)[T.lso]    -0.6804      0.691     -0.984      0.325      -2.035       0.674
# C(Mention_country)[T.ltu]    -0.4720      0.595     -0.793      0.428      -1.639       0.695
# C(Mention_country)[T.lva]    -0.8376      0.694     -1.207      0.227      -2.198       0.522
# C(Mention_country)[T.mar]     1.1703      0.326      3.586      0.000       0.531       1.810
# C(Mention_country)[T.mda]    -1.0418      0.592     -1.761      0.078      -2.201       0.118
# C(Mention_country)[T.mdg]     1.7563      0.071     24.784      0.000       1.617       1.895
# C(Mention_country)[T.mex]     2.9197      0.516      5.655      0.000       1.908       3.932
# C(Mention_country)[T.mkd]    -0.9538      0.698     -1.367      0.172      -2.321       0.413
# C(Mention_country)[T.mli]     0.7276      0.169      4.308      0.000       0.397       1.059
# C(Mention_country)[T.mmr]     0.1589      0.186      0.852      0.394      -0.207       0.524
# C(Mention_country)[T.mng]     1.6387      0.622      2.633      0.008       0.419       2.859
# C(Mention_country)[T.moz]     0.8679      0.059     14.612      0.000       0.751       0.984
# C(Mention_country)[T.mrt]    -1.1756      0.576     -2.042      0.041      -2.304      -0.047
# C(Mention_country)[T.mus]    -0.7930      0.840     -0.944      0.345      -2.440       0.854
# C(Mention_country)[T.mwi]     1.5124      0.177      8.535      0.000       1.165       1.860
# C(Mention_country)[T.mys]     1.1448      0.251      4.558      0.000       0.653       1.637
# C(Mention_country)[T.nam]     0.6345      0.706      0.898      0.369      -0.750       2.019
# C(Mention_country)[T.ner]    -0.2412      0.152     -1.588      0.112      -0.539       0.057
# C(Mention_country)[T.nga]     1.5970      0.515      3.100      0.002       0.587       2.607
# C(Mention_country)[T.nic]     0.2876      0.419      0.687      0.492      -0.533       1.108
# C(Mention_country)[T.nld]     1.5957      0.417      3.825      0.000       0.778       2.413
# C(Mention_country)[T.nor]     2.1060      0.610      3.455      0.001       0.911       3.301
# C(Mention_country)[T.npl]     1.6705      0.025     66.063      0.000       1.621       1.720
# C(Mention_country)[T.nzl]     2.6694      0.586      4.558      0.000       1.522       3.817
# C(Mention_country)[T.omn]     0.3495      0.365      0.957      0.339      -0.367       1.065
# C(Mention_country)[T.pak]     1.4546      0.562      2.589      0.010       0.353       2.556
# C(Mention_country)[T.pan]     0.7232      0.580      1.246      0.213      -0.414       1.861
# C(Mention_country)[T.per]     1.5395      0.200      7.699      0.000       1.148       1.931
# C(Mention_country)[T.phl]     1.6901      0.386      4.373      0.000       0.933       2.447
# C(Mention_country)[T.pol]     1.2481      0.316      3.953      0.000       0.629       1.867
# C(Mention_country)[T.pri]     0.7072      0.598      1.182      0.237      -0.465       1.880
# C(Mention_country)[T.prt]     1.4617      0.398      3.670      0.000       0.681       2.242
# C(Mention_country)[T.pry]    -0.4889      0.432     -1.131      0.258      -1.336       0.359
# C(Mention_country)[T.pse]    -1.0643      0.553     -1.923      0.055      -2.149       0.021
# C(Mention_country)[T.qat]    -2.4480      0.942     -2.600      0.009      -4.294      -0.602
# C(Mention_country)[T.rou]     0.2978      0.236      1.263      0.207      -0.164       0.760
# C(Mention_country)[T.rus]     2.2274      0.569      3.918      0.000       1.113       3.342
# C(Mention_country)[T.rwa]    -0.3111      0.271     -1.147      0.251      -0.843       0.221
# C(Mention_country)[T.sau]     0.0559      0.315      0.178      0.859      -0.560       0.672
# C(Mention_country)[T.sen]     0.8971      0.234      3.841      0.000       0.439       1.355
# C(Mention_country)[T.sgp]     0.6335      0.580      1.092      0.275      -0.504       1.771
# C(Mention_country)[T.sle]    -0.2842      0.402     -0.707      0.480      -1.072       0.504
# C(Mention_country)[T.slv]    -0.7728      0.411     -1.882      0.060      -1.578       0.032
# C(Mention_country)[T.som]    -0.2651      0.251     -1.056      0.291      -0.757       0.227
# C(Mention_country)[T.svk]     0.3768      0.496      0.760      0.447      -0.595       1.349
# C(Mention_country)[T.svn]    -0.0069      0.742     -0.009      0.993      -1.462       1.448
# C(Mention_country)[T.swe]     2.3507      0.474      4.964      0.000       1.423       3.279
# C(Mention_country)[T.syr]    -0.5376      0.212     -2.530      0.011      -0.954      -0.121
# C(Mention_country)[T.tcd]    -0.3596      0.245     -1.465      0.143      -0.841       0.121
# C(Mention_country)[T.tgo]    -0.9240      0.397     -2.330      0.020      -1.701      -0.147
# C(Mention_country)[T.tha]     2.2251      0.353      6.297      0.000       1.532       2.918
# C(Mention_country)[T.tjk]    -0.7162      0.345     -2.073      0.038      -1.393      -0.039
# C(Mention_country)[T.tkm]    -1.6477      0.456     -3.611      0.000      -2.542      -0.753
# C(Mention_country)[T.tto]    -1.9422      0.825     -2.353      0.019      -3.560      -0.325
# C(Mention_country)[T.tun]     0.4809      0.033     14.526      0.000       0.416       0.546
# C(Mention_country)[T.tur]     2.3300      0.408      5.711      0.000       1.530       3.130
# C(Mention_country)[T.tza]     2.2896      0.148     15.434      0.000       1.999       2.580
# C(Mention_country)[T.uga]     2.2636      0.048     47.540      0.000       2.170       2.357
# C(Mention_country)[T.ukr]     0.6404      0.252      2.539      0.011       0.146       1.135
# C(Mention_country)[T.ury]     0.1420      0.583      0.243      0.808      -1.001       1.285
# C(Mention_country)[T.usa]     4.6623      0.839      5.555      0.000       3.017       6.307
# C(Mention_country)[T.uzb]    -0.0632      0.073     -0.869      0.385      -0.206       0.079
# C(Mention_country)[T.ven]     0.6193      0.257      2.410      0.016       0.116       1.123
# C(Mention_country)[T.vnm]     2.0691      0.356      5.816      0.000       1.372       2.766
# C(Mention_country)[T.yem]    -0.6120      0.254     -2.410      0.016      -1.110      -0.114
# C(Mention_country)[T.zaf]     2.7433      0.323      8.499      0.000       2.111       3.376
# C(Mention_country)[T.zmb]     1.0917      0.211      5.164      0.000       0.677       1.506
# C(Mention_country)[T.zwe]     1.5957      0.191      8.335      0.000       1.220       1.971
# C(year)[T.2003.0]            -0.0164      0.195     -0.084      0.933      -0.399       0.366
# C(year)[T.2004.0]            -0.0021      0.391     -0.005      0.996      -0.768       0.764
# C(year)[T.2005.0]             0.0681      0.585      0.116      0.907      -1.078       1.215
# C(year)[T.2006.0]             0.1131      0.776      0.146      0.884      -1.408       1.634
# C(year)[T.2007.0]             0.1680      0.971      0.173      0.863      -1.736       2.072
# C(year)[T.2008.0]             0.2165      1.172      0.185      0.853      -2.080       2.513
# C(year)[T.2009.0]             0.2832      1.363      0.208      0.835      -2.389       2.955
# treated                      -0.4336      0.332     -1.304      0.192      -1.085       0.218
# time                          0.0677      0.190      0.357      0.721      -0.305       0.440
# treated:time                 -0.0383      0.020     -1.899      0.058      -0.078       0.001
# log_gdp                       0.2631      0.082      3.215      0.001       0.103       0.424
# log_population                0.0228      0.277      0.083      0.934      -0.519       0.565
# ==============================================================================
# Omnibus:                       70.558   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              206.347
# Skew:                          -0.268   Prob(JB):                     1.56e-45
# Kurtosis:                       4.996   Cond. No.                     7.05e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 8.53e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 156, but rank is 10
#   warnings.warn('covariance of constraints does not have full '

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='treated')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foriegn funding')
# Out:
# Text(0, 0.5, 'log Foriegn funding')

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ treated* post +log_population+log_gdp+ C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.974
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                     145.9
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           4.27e-85
# Time:                        13:15:38   Log-Likelihood:                -463.53
# No. Observations:                2610   AIC:                             1257.
# Df Residuals:                    2445   BIC:                             2225.
# Df Model:                         164
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -8.1257      4.586     -1.772      0.076     -17.115       0.863
# C(Mention_country)[T.ago]    -0.5917      0.132     -4.493      0.000      -0.850      -0.334
# C(Mention_country)[T.alb]    -0.0366      0.631     -0.058      0.954      -1.273       1.200
# C(Mention_country)[T.are]     0.6712      0.491      1.368      0.171      -0.291       1.633
# C(Mention_country)[T.arg]     2.0251      0.217      9.315      0.000       1.599       2.451
# C(Mention_country)[T.arm]     0.1707      0.625      0.273      0.785      -1.055       1.396
# C(Mention_country)[T.aus]     3.3052      0.315     10.478      0.000       2.687       3.923
# C(Mention_country)[T.aut]     1.2886      0.452      2.853      0.004       0.403       2.174
# C(Mention_country)[T.aze]    -0.6636      0.343     -1.936      0.053      -1.335       0.008
# C(Mention_country)[T.bdi]    -1.0809      0.315     -3.429      0.001      -1.699      -0.463
# C(Mention_country)[T.bel]     1.4480      0.400      3.619      0.000       0.664       2.232
# C(Mention_country)[T.ben]     0.4187      0.302      1.387      0.165      -0.173       1.010
# C(Mention_country)[T.bfa]     0.8072      0.154      5.226      0.000       0.504       1.110
# C(Mention_country)[T.bgd]     0.7058      0.443      1.594      0.111      -0.162       1.574
# C(Mention_country)[T.bgr]     0.7519      0.407      1.847      0.065      -0.046       1.550
# C(Mention_country)[T.bhr]    -0.8577      0.614     -1.397      0.162      -2.061       0.346
# C(Mention_country)[T.bih]     0.1498      0.567      0.264      0.792      -0.961       1.261
# C(Mention_country)[T.blr]    -0.4766      0.339     -1.407      0.159      -1.140       0.187
# C(Mention_country)[T.bol]     1.0757      0.296      3.640      0.000       0.497       1.655
# C(Mention_country)[T.bra]     2.3840      0.546      4.368      0.000       1.314       3.454
# C(Mention_country)[T.bwa]     1.4958      0.723      2.068      0.039       0.078       2.914
# C(Mention_country)[T.caf]    -0.5312      0.493     -1.077      0.281      -1.498       0.435
# C(Mention_country)[T.can]     3.0232      0.304      9.947      0.000       2.427       3.619
# C(Mention_country)[T.che]     1.9950      0.487      4.099      0.000       1.041       2.949
# C(Mention_country)[T.chl]     2.0483      0.257      7.985      0.000       1.546       2.551
# C(Mention_country)[T.chn]     2.5925      1.038      2.497      0.013       0.558       4.627
# C(Mention_country)[T.civ]    -2.5681      0.121    -21.146      0.000      -2.806      -2.330
# C(Mention_country)[T.cmr]     1.0869      0.123      8.829      0.000       0.846       1.328
# C(Mention_country)[T.col]     0.9355      0.202      4.635      0.000       0.540       1.331
# C(Mention_country)[T.cri]     1.8296      0.529      3.457      0.001       0.792       2.867
# C(Mention_country)[T.cub]     0.2216      0.305      0.726      0.468      -0.377       0.820
# C(Mention_country)[T.cyp]     1.3734      0.916      1.499      0.134      -0.422       3.169
# C(Mention_country)[T.cze]     1.8103      0.368      4.916      0.000       1.089       2.532
# C(Mention_country)[T.deu]     1.8819      0.406      4.632      0.000       1.086       2.678
# C(Mention_country)[T.dji]    -0.5556      0.928     -0.598      0.550      -2.375       1.264
# C(Mention_country)[T.dnk]     2.2805      0.547      4.169      0.000       1.208       3.353
# C(Mention_country)[T.dom]    -0.2056      0.334     -0.615      0.539      -0.861       0.450
# C(Mention_country)[T.dza]    -0.5862      0.158     -3.714      0.000      -0.896      -0.277
# C(Mention_country)[T.ecu]     1.0180      0.235      4.341      0.000       0.558       1.478
# C(Mention_country)[T.egy]     0.2729      0.565      0.483      0.629      -0.835       1.381
# C(Mention_country)[T.eri]    -0.2297      0.599     -0.384      0.701      -1.403       0.944
# C(Mention_country)[T.esp]     2.7067      0.299      9.066      0.000       2.122       3.292
# C(Mention_country)[T.est]     2.0922      0.859      2.435      0.015       0.408       3.776
# C(Mention_country)[T.eth]     1.2305      0.306      4.021      0.000       0.631       1.830
# C(Mention_country)[T.fin]     2.7641      0.547      5.052      0.000       1.692       3.837
# C(Mention_country)[T.fra]     1.7522      0.364      4.817      0.000       1.039       2.465
# C(Mention_country)[T.gab]     0.7756      0.778      0.997      0.319      -0.749       2.300
# C(Mention_country)[T.gbr]     3.2668      0.364      8.982      0.000       2.554       3.980
# C(Mention_country)[T.gha]     1.2485      0.073     17.178      0.000       1.106       1.391
# C(Mention_country)[T.gmb]     0.4783      0.721      0.663      0.507      -0.936       1.892
# C(Mention_country)[T.grc]     1.7964      0.369      4.864      0.000       1.073       2.520
# C(Mention_country)[T.gtm]     0.4403      0.229      1.924      0.054      -0.008       0.889
# C(Mention_country)[T.hkg]     2.6318      0.477      5.515      0.000       1.696       3.567
# C(Mention_country)[T.hnd]     0.0873      0.344      0.254      0.799      -0.586       0.761
# C(Mention_country)[T.hrv]     1.1451      0.562      2.037      0.042       0.043       2.247
# C(Mention_country)[T.hti]     0.1996      0.295      0.676      0.499      -0.379       0.778
# C(Mention_country)[T.hun]     1.4500      0.364      3.981      0.000       0.736       2.164
# C(Mention_country)[T.idn]     0.5700      0.583      0.978      0.328      -0.572       1.712
# C(Mention_country)[T.ind]     1.3750      1.010      1.362      0.173      -0.604       3.354
# C(Mention_country)[T.irn]     1.3766      0.301      4.567      0.000       0.786       1.967
# C(Mention_country)[T.irq]    -0.2446      0.142     -1.724      0.085      -0.523       0.034
# C(Mention_country)[T.isr]     1.9541      0.454      4.302      0.000       1.064       2.844
# C(Mention_country)[T.ita]     2.0200      0.343      5.898      0.000       1.349       2.691
# C(Mention_country)[T.jam]     0.9099      0.653      1.393      0.164      -0.370       2.190
# C(Mention_country)[T.jor]     1.1895      0.105     11.279      0.000       0.983       1.396
# C(Mention_country)[T.jpn]     2.4193      0.493      4.904      0.000       1.452       3.386
# C(Mention_country)[T.kaz]     0.3731      0.239      1.560      0.119      -0.096       0.842
# C(Mention_country)[T.ken]     1.9694      0.113     17.475      0.000       1.749       2.190
# C(Mention_country)[T.kgz]     0.3229      0.444      0.727      0.467      -0.547       1.193
# C(Mention_country)[T.khm]     0.8533      0.192      4.445      0.000       0.477       1.230
# C(Mention_country)[T.kor]     2.1310      0.299      7.133      0.000       1.545       2.717
# C(Mention_country)[T.kwt]     0.2709      0.370      0.733      0.464      -0.454       0.995
# C(Mention_country)[T.lao]     0.5132      0.411      1.248      0.212      -0.293       1.319
# C(Mention_country)[T.lbn]     0.7158      0.494      1.450      0.147      -0.252       1.683
# C(Mention_country)[T.lbr]    -0.1833      0.535     -0.343      0.732      -1.232       0.866
# C(Mention_country)[T.lby]    -0.7399      0.163     -4.528      0.000      -1.060      -0.420
# C(Mention_country)[T.lka]     0.8092      0.147      5.523      0.000       0.522       1.096
# C(Mention_country)[T.lso]     0.2958      0.711      0.416      0.677      -1.097       1.688
# C(Mention_country)[T.ltu]     0.7142      0.641      1.114      0.265      -0.542       1.970
# C(Mention_country)[T.lva]     0.5733      0.739      0.776      0.438      -0.875       2.021
# C(Mention_country)[T.mar]     0.3774      0.297      1.271      0.204      -0.204       0.959
# C(Mention_country)[T.mda]    -0.2501      0.631     -0.396      0.692      -1.488       0.987
# C(Mention_country)[T.mdg]     1.2644      0.074     17.086      0.000       1.119       1.409
# C(Mention_country)[T.mex]     2.0172      0.417      4.836      0.000       1.200       2.835
# C(Mention_country)[T.mkd]     0.3183      0.726      0.438      0.661      -1.106       1.742
# C(Mention_country)[T.mli]     0.6187      0.166      3.732      0.000       0.294       0.944
# C(Mention_country)[T.mmr]    -0.1792      0.148     -1.207      0.227      -0.470       0.112
# C(Mention_country)[T.mng]     2.6164      0.639      4.095      0.000       1.364       3.869
# C(Mention_country)[T.moz]     0.7566      0.056     13.561      0.000       0.647       0.866
# C(Mention_country)[T.mrt]    -0.2657      0.573     -0.464      0.643      -1.388       0.857
# C(Mention_country)[T.mus]     0.5887      0.866      0.680      0.497      -1.109       2.286
# C(Mention_country)[T.mwi]     1.5569      0.178      8.751      0.000       1.208       1.906
# C(Mention_country)[T.mys]     1.4938      0.193      7.747      0.000       1.116       1.872
# C(Mention_country)[T.nam]     1.5743      0.717      2.195      0.028       0.168       2.980
# C(Mention_country)[T.ner]    -0.4707      0.142     -3.319      0.001      -0.749      -0.193
# C(Mention_country)[T.nga]     0.4738      0.473      1.002      0.316      -0.453       1.400
# C(Mention_country)[T.nic]     0.7417      0.435      1.705      0.088      -0.111       1.594
# C(Mention_country)[T.nld]     2.1279      0.344      6.192      0.000       1.454       2.801
# C(Mention_country)[T.nor]     3.0488      0.588      5.189      0.000       1.897       4.200
# C(Mention_country)[T.npl]     1.2750      0.027     46.938      0.000       1.222       1.328
# C(Mention_country)[T.nzl]     3.5677      0.583      6.119      0.000       2.425       4.710
# C(Mention_country)[T.omn]     0.8797      0.338      2.606      0.009       0.218       1.541
# C(Mention_country)[T.pak]     0.3113      0.513      0.607      0.544      -0.695       1.317
# C(Mention_country)[T.pan]     1.5285      0.591      2.585      0.010       0.370       2.687
# C(Mention_country)[T.per]     1.3260      0.155      8.534      0.000       1.021       1.631
# C(Mention_country)[T.phl]     0.6949      0.335      2.073      0.038       0.038       1.352
# C(Mention_country)[T.pol]     1.2608      0.225      5.593      0.000       0.819       1.703
# C(Mention_country)[T.pri]     1.7327      0.622      2.785      0.005       0.513       2.952
# C(Mention_country)[T.prt]     2.1977      0.375      5.858      0.000       1.462       2.933
# C(Mention_country)[T.pry]     0.0362      0.454      0.080      0.936      -0.854       0.927
# C(Mention_country)[T.pse]    -0.0903      0.556     -0.162      0.871      -1.180       0.999
# C(Mention_country)[T.qat]     0.0391      0.849      0.046      0.963      -1.625       1.703
# C(Mention_country)[T.rou]     0.5757      0.210      2.736      0.006       0.163       0.988
# C(Mention_country)[T.rus]     1.1950      0.471      2.538      0.011       0.272       2.118
# C(Mention_country)[T.rwa]     0.3066      0.274      1.117      0.264      -0.231       0.845
# C(Mention_country)[T.sau]     0.5803      0.243      2.384      0.017       0.103       1.057
# C(Mention_country)[T.sen]     0.8872      0.231      3.835      0.000       0.434       1.341
# C(Mention_country)[T.sgp]     1.7601      0.564      3.120      0.002       0.654       2.866
# C(Mention_country)[T.sle]     0.2864      0.399      0.717      0.473      -0.497       1.069
# C(Mention_country)[T.slv]    -0.3716      0.437     -0.850      0.395      -1.228       0.485
# C(Mention_country)[T.som]    -0.5201      0.236     -2.203      0.028      -0.983      -0.057
# C(Mention_country)[T.svk]     1.4133      0.509      2.775      0.006       0.415       2.412
# C(Mention_country)[T.svn]     1.4739      0.759      1.943      0.052      -0.013       2.961
# C(Mention_country)[T.swe]     2.9576      0.435      6.796      0.000       2.105       3.811
# C(Mention_country)[T.syr]    -0.6278      0.165     -3.798      0.000      -0.952      -0.304
# C(Mention_country)[T.tcd]    -0.3630      0.237     -1.533      0.125      -0.827       0.101
# C(Mention_country)[T.tgo]    -0.6024      0.396     -1.522      0.128      -1.378       0.173
# C(Mention_country)[T.tha]     1.5970      0.276      5.783      0.000       1.056       2.138
# C(Mention_country)[T.tjk]    -0.3527      0.354     -0.998      0.319      -1.046       0.340
# C(Mention_country)[T.tkm]    -1.2747      0.477     -2.674      0.007      -2.209      -0.340
# C(Mention_country)[T.tto]    -0.4568      0.843     -0.542      0.588      -2.109       1.196
# C(Mention_country)[T.tun]     0.6706      0.013     52.495      0.000       0.646       0.696
# C(Mention_country)[T.tur]     1.6512      0.319      5.172      0.000       1.025       2.277
# C(Mention_country)[T.tza]     1.6391      0.130     12.597      0.000       1.384       1.894
# C(Mention_country)[T.uga]     1.8540      0.041     45.709      0.000       1.774       1.933
# C(Mention_country)[T.ukr]     0.0552      0.171      0.323      0.746      -0.279       0.389
# C(Mention_country)[T.ury]     1.0792      0.616      1.751      0.080      -0.128       2.287
# C(Mention_country)[T.usa]     3.4729      0.704      4.930      0.000       2.092       4.854
# C(Mention_country)[T.uzb]    -0.6632      0.072     -9.183      0.000      -0.805      -0.522
# C(Mention_country)[T.ven]     0.1416      0.207      0.685      0.494      -0.264       0.547
# C(Mention_country)[T.vnm]     1.1452      0.308      3.713      0.000       0.541       1.750
# C(Mention_country)[T.yem]    -1.2237      0.245     -4.994      0.000      -1.704      -0.743
# C(Mention_country)[T.zaf]     2.3595      0.236      9.980      0.000       1.896       2.823
# C(Mention_country)[T.zmb]     1.1779      0.206      5.708      0.000       0.773       1.582
# C(Mention_country)[T.zwe]     1.2444      0.215      5.783      0.000       0.823       1.666
# C(year)[T.2003.0]             0.0567      0.029      1.929      0.054      -0.001       0.114
# C(year)[T.2004.0]             0.1469      0.038      3.896      0.000       0.073       0.221
# C(year)[T.2005.0]             0.2901      0.042      6.912      0.000       0.208       0.372
# C(year)[T.2006.0]             0.4059      0.051      7.898      0.000       0.305       0.507
# C(year)[T.2007.0]             0.5364      0.056      9.534      0.000       0.426       0.647
# C(year)[T.2008.0]             0.6601      0.065     10.090      0.000       0.532       0.788
# C(year)[T.2009.0]             0.7755      0.065     11.974      0.000       0.649       0.902
# C(year)[T.2010.0]             0.8686      0.070     12.415      0.000       0.731       1.006
# C(year)[T.2011.0]            -0.4233      0.019    -22.417      0.000      -0.460      -0.386
# C(year)[T.2012.0]            -0.3107      0.020    -15.402      0.000      -0.350      -0.271
# C(year)[T.2013.0]            -0.1249      0.016     -7.642      0.000      -0.157      -0.093
# C(year)[T.2014.0]            -0.0489      0.017     -2.827      0.005      -0.083      -0.015
# C(year)[T.2015.0]            -0.0028      0.014     -0.193      0.847      -0.031       0.026
# C(year)[T.2016.0]             0.1682      0.017      9.695      0.000       0.134       0.202
# C(year)[T.2017.0]             0.4167      0.020     21.140      0.000       0.378       0.455
# C(year)[T.2018.0]             0.8248      0.023     35.669      0.000       0.779       0.870
# C(year)[T.2019.0]             0.9414      0.028     33.533      0.000       0.886       0.996
# treated                       0.2119      0.326      0.649      0.516      -0.428       0.852
# post                          1.4405      0.074     19.537      0.000       1.296       1.585
# treated:post                 -0.0121      0.119     -0.102      0.919      -0.245       0.220
# log_population                0.5622      0.268      2.098      0.036       0.037       1.087
# log_gdp                       0.1346      0.065      2.066      0.039       0.007       0.262
# ==============================================================================
# Omnibus:                      177.048   Durbin-Watson:                   1.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              608.172
# Skew:                          -0.278   Prob(JB):                    8.65e-133
# Kurtosis:                       5.298   Cond. No.                     7.80e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.47e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 166, but rank is 20
#   warnings.warn('covariance of constraints does not have full '

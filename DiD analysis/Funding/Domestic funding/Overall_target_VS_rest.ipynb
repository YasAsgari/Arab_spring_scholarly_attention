# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
#funding
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df_fund=pd.read_csv(r"C:\Users\Yasaman\Downloads\Mentioned-Funding-fractional counting.csv")
df_fund.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'funding_country': 'Source'}, inplace=True)
df_fund=df_fund[~(df_fund['subjarea'].isin(physical_sciences))]
df_fund=df_fund[df_fund['Mention_country']==df_fund['Source']]
df_fund=df_fund.groupby(['year', 'Mention_country'])['count'].sum().reset_index()
df_fund=df_fund[(df_fund['year'].isin(np.arange(2002,2020,1)))].reset_index(drop=True)
df=df_fund.copy()

data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))

# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "incomelevel": country_data["incomelevel"].iloc[0] if not country_data.empty else np.nan,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# afg
# ago
# alb
# arm
# aze
# bdi
# ben
# bfa
# bhr
# bih
# blr
# bol
# caf
# civ
# cmr
# dji
# dom
# dza
# eri
# gab
# gmb
# gtm
# hnd
# hti
# irq
# jam
# kaz
# kgz
# khm
# lao
# lbr
# lby
# lso
# mda
# mdg
# mkd
# mli
# mmr
# mng
# moz
# mrt
# mus
# mwi
# nam
# ner
# nic
# pan
# pry
# pse
# qat
# rwa
# sen
# sle
# slv
# som
# syr
# tcd
# tgo
# tjk
# tkm
# tto
# uzb
# yem
# zmb
# 64

# %%
df_p=df_complete[df_complete['year']<2011].reset_index(drop=True)
df_p['time']=df_p['year'].min()-df_p['year']
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ treated * time +log_gdp+ C(Mention_country) + C(year)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     15.08
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           3.65e-18
# Time:                        13:26:30   Log-Likelihood:                -373.93
# No. Observations:                1305   AIC:                             1058.
# Df Residuals:                    1150   BIC:                             1860.
# Df Model:                         154
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -0.6544      0.565     -1.158      0.247      -1.762       0.453
# C(Mention_country)[T.ago]    -0.1154      0.206     -0.560      0.576      -0.520       0.289
# C(Mention_country)[T.alb]    -0.1343      0.240     -0.560      0.576      -0.605       0.336
# C(Mention_country)[T.are]     1.4584      0.514      2.835      0.005       0.450       2.467
# C(Mention_country)[T.arg]     4.7741      0.312     15.278      0.000       4.162       5.387
# C(Mention_country)[T.arm]     0.0258      0.195      0.132      0.895      -0.357       0.409
# C(Mention_country)[T.aus]     5.8124      0.507     11.457      0.000       4.818       6.807
# C(Mention_country)[T.aut]     2.9530      0.521      5.667      0.000       1.932       3.974
# C(Mention_country)[T.aze]    -0.0960      0.216     -0.445      0.656      -0.519       0.327
# C(Mention_country)[T.bdi]     0.0411      0.073      0.560      0.576      -0.103       0.185
# C(Mention_country)[T.bel]     3.3623      0.515      6.528      0.000       2.353       4.372
# C(Mention_country)[T.ben]     0.0152      0.110      0.138      0.890      -0.201       0.232
# C(Mention_country)[T.bfa]    -0.0260      0.046     -0.560      0.576      -0.117       0.065
# C(Mention_country)[T.bgd]     1.4285      0.062     22.966      0.000       1.307       1.550
# C(Mention_country)[T.bgr]     1.2725      0.287      4.434      0.000       0.710       1.835
# C(Mention_country)[T.bhr]    -0.8139      0.159     -5.116      0.000      -1.126      -0.502
# C(Mention_country)[T.bih]    -0.1391      0.248     -0.560      0.576      -0.626       0.348
# C(Mention_country)[T.blr]     0.3293      0.261      1.264      0.206      -0.181       0.840
# C(Mention_country)[T.bol]    -0.0844      0.151     -0.560      0.576      -0.380       0.211
# C(Mention_country)[T.bra]     5.9781      0.311     19.207      0.000       5.368       6.588
# C(Mention_country)[T.bwa]     0.3134      0.295      1.062      0.288      -0.265       0.892
# C(Mention_country)[T.caf]    -0.0095      0.017     -0.560      0.576      -0.043       0.024
# C(Mention_country)[T.can]     5.8496      0.512     11.414      0.000       4.845       6.854
# C(Mention_country)[T.che]     3.7456      0.564      6.644      0.000       2.641       4.850
# C(Mention_country)[T.chl]     3.7143      0.350     10.622      0.000       3.029       4.400
# C(Mention_country)[T.chn]     6.9521      0.213     32.654      0.000       6.535       7.369
# C(Mention_country)[T.civ]    -0.0901      0.161     -0.560      0.576      -0.406       0.225
# C(Mention_country)[T.cmr]    -0.0813      0.145     -0.560      0.576      -0.366       0.203
# C(Mention_country)[T.col]     2.5316      0.271      9.343      0.000       2.001       3.063
# C(Mention_country)[T.cri]     1.2780      0.308      4.156      0.000       0.675       1.881
# C(Mention_country)[T.cub]     0.4700      0.279      1.686      0.092      -0.076       1.016
# C(Mention_country)[T.cyp]     0.9282      0.475      1.953      0.051      -0.003       1.860
# C(Mention_country)[T.cze]     3.7533      0.414      9.068      0.000       2.942       4.565
# C(Mention_country)[T.deu]     4.9937      0.510      9.790      0.000       3.994       5.993
# C(Mention_country)[T.dji]    -0.0665      0.119     -0.560      0.576      -0.299       0.166
# C(Mention_country)[T.dnk]     3.6935      0.545      6.780      0.000       2.626       4.761
# C(Mention_country)[T.dom]    -0.1520      0.272     -0.560      0.576      -0.684       0.380
# C(Mention_country)[T.dza]     0.3282      0.252      1.300      0.193      -0.166       0.823
# C(Mention_country)[T.ecu]     0.2644      0.254      1.041      0.298      -0.234       0.762
# C(Mention_country)[T.egy]     0.7644      0.109      7.038      0.000       0.552       0.977
# C(Mention_country)[T.eri]    -0.0194      0.035     -0.560      0.576      -0.087       0.049
# C(Mention_country)[T.esp]     5.5122      0.479     11.507      0.000       4.573       6.451
# C(Mention_country)[T.est]     2.9615      0.386      7.676      0.000       2.205       3.718
# C(Mention_country)[T.eth]     2.4422      0.044     56.069      0.000       2.357       2.528
# C(Mention_country)[T.fin]     4.5609      0.523      8.727      0.000       3.537       5.585
# C(Mention_country)[T.fra]     4.5175      0.509      8.874      0.000       3.520       5.515
# C(Mention_country)[T.gab]     0.0970      0.328      0.296      0.767      -0.546       0.740
# C(Mention_country)[T.gbr]     6.3444      0.522     12.161      0.000       5.322       7.367
# C(Mention_country)[T.gha]     0.7678      0.086      8.900      0.000       0.599       0.937
# C(Mention_country)[T.gmb]    -0.0412      0.074     -0.560      0.576      -0.185       0.103
# C(Mention_country)[T.grc]     3.0373      0.465      6.532      0.000       2.126       3.949
# C(Mention_country)[T.gtm]    -0.0174      0.213     -0.082      0.935      -0.435       0.400
# C(Mention_country)[T.hkg]     4.3064      0.483      8.921      0.000       3.360       5.253
# C(Mention_country)[T.hnd]    -0.0927      0.166     -0.560      0.576      -0.417       0.232
# C(Mention_country)[T.hrv]     2.2431      0.384      5.839      0.000       1.490       2.996
# C(Mention_country)[T.hti]    -0.0629      0.112     -0.560      0.576      -0.283       0.157
# C(Mention_country)[T.hun]     3.1998      0.385      8.306      0.000       2.445       3.955
# C(Mention_country)[T.idn]     1.5841      0.176      9.023      0.000       1.240       1.928
# C(Mention_country)[T.ind]     5.3579      0.104     51.460      0.000       5.154       5.562
# C(Mention_country)[T.irn]     3.8664      0.268     14.426      0.000       3.341       4.392
# C(Mention_country)[T.irq]    -0.0049      0.212     -0.023      0.981      -0.420       0.410
# C(Mention_country)[T.isr]     3.4241      0.466      7.354      0.000       2.512       4.337
# C(Mention_country)[T.ita]     4.7641      0.499      9.543      0.000       3.786       5.743
# C(Mention_country)[T.jam]     0.2962      0.283      1.048      0.294      -0.258       0.850
# C(Mention_country)[T.jor]     1.5017      0.050     30.303      0.000       1.405       1.599
# C(Mention_country)[T.jpn]     5.8148      0.515     11.295      0.000       4.806       6.824
# C(Mention_country)[T.kaz]    -0.0069      0.288     -0.024      0.981      -0.570       0.557
# C(Mention_country)[T.ken]     1.6225      0.085     19.156      0.000       1.456       1.788
# C(Mention_country)[T.kgz]    -0.0389      0.070     -0.560      0.576      -0.175       0.097
# C(Mention_country)[T.khm]    -0.0340      0.061     -0.560      0.576      -0.153       0.085
# C(Mention_country)[T.kor]     4.9163      0.441     11.156      0.000       4.053       5.780
# C(Mention_country)[T.kwt]     1.2993      0.228      5.687      0.000       0.852       1.747
# C(Mention_country)[T.lao]    -0.0396      0.071     -0.560      0.576      -0.178       0.099
# C(Mention_country)[T.lbn]     1.7026      0.305      5.580      0.000       1.105       2.301
# C(Mention_country)[T.lbr]    -0.0046      0.008     -0.560      0.576      -0.021       0.012
# C(Mention_country)[T.lby]    -0.8871      0.075    -11.895      0.000      -1.033      -0.741
# C(Mention_country)[T.lka]     1.7081      0.168     10.175      0.000       1.379       2.037
# C(Mention_country)[T.lso]    -0.0542      0.097     -0.560      0.576      -0.244       0.135
# C(Mention_country)[T.ltu]     1.0158      0.358      2.836      0.005       0.314       1.718
# C(Mention_country)[T.lva]     0.3344      0.360      0.930      0.353      -0.371       1.040
# C(Mention_country)[T.mar]     0.0227      0.055      0.411      0.681      -0.085       0.131
# C(Mention_country)[T.mda]    -0.0590      0.150     -0.394      0.693      -0.352       0.234
# C(Mention_country)[T.mdg]    -0.0131      0.023     -0.560      0.576      -0.059       0.033
# C(Mention_country)[T.mex]     4.5750      0.361     12.685      0.000       3.868       5.282
# C(Mention_country)[T.mkd]    -0.1442      0.258     -0.560      0.576      -0.649       0.361
# C(Mention_country)[T.mli]    -0.0314      0.056     -0.560      0.576      -0.141       0.079
# C(Mention_country)[T.mmr]    -0.0113      0.020     -0.560      0.576      -0.051       0.028
# C(Mention_country)[T.mng]     0.0521      0.148      0.351      0.726      -0.239       0.343
# C(Mention_country)[T.moz]    -0.0235      0.042     -0.560      0.576      -0.106       0.059
# C(Mention_country)[T.mrt]    -0.0770      0.138     -0.560      0.576      -0.347       0.193
# C(Mention_country)[T.mus]     0.3404      0.318      1.070      0.285      -0.283       0.964
# C(Mention_country)[T.mwi]     0.0169      0.050      0.335      0.738      -0.082       0.116
# C(Mention_country)[T.mys]     2.9603      0.320      9.239      0.000       2.332       3.588
# C(Mention_country)[T.nam]     0.0947      0.264      0.359      0.720      -0.423       0.612
# C(Mention_country)[T.ner]    -0.0079      0.014     -0.560      0.576      -0.036       0.020
# C(Mention_country)[T.nga]     0.9384      0.164      5.727      0.000       0.617       1.260
# C(Mention_country)[T.nic]    -0.0838      0.150     -0.560      0.576      -0.377       0.210
# C(Mention_country)[T.nld]     4.0938      0.531      7.706      0.000       3.053       5.135
# C(Mention_country)[T.nor]     4.3303      0.579      7.477      0.000       3.195       5.465
# C(Mention_country)[T.npl]     0.6628      0.017     38.653      0.000       0.629       0.696
# C(Mention_country)[T.nzl]     4.8864      0.477     10.239      0.000       3.951       5.822
# C(Mention_country)[T.omn]     0.7354      0.132      5.554      0.000       0.476       0.995
# C(Mention_country)[T.pak]     2.2931      0.112     20.521      0.000       2.074       2.512
# C(Mention_country)[T.pan]     0.1187      0.313      0.380      0.704      -0.494       0.731
# C(Mention_country)[T.per]     0.5802      0.248      2.335      0.020       0.093       1.067
# C(Mention_country)[T.phl]     1.8163      0.169     10.767      0.000       1.486       2.147
# C(Mention_country)[T.pol]     3.1580      0.360      8.780      0.000       2.453       3.863
# C(Mention_country)[T.pri]     1.2274      0.460      2.669      0.008       0.326       2.129
# C(Mention_country)[T.prt]     3.6411      0.444      8.199      0.000       2.771       4.512
# C(Mention_country)[T.pry]    -0.1269      0.227     -0.560      0.576      -0.571       0.317
# C(Mention_country)[T.pse]     0.0612      0.182      0.337      0.736      -0.295       0.417
# C(Mention_country)[T.qat]     0.3779      0.547      0.690      0.490      -0.695       1.451
# C(Mention_country)[T.rou]     0.8657      0.305      2.835      0.005       0.267       1.464
# C(Mention_country)[T.rus]     3.9559      0.319     12.407      0.000       3.331       4.581
# C(Mention_country)[T.rwa]    -0.0127      0.023     -0.560      0.576      -0.057       0.032
# C(Mention_country)[T.sau]     2.1994      0.404      5.444      0.000       1.408       2.991
# C(Mention_country)[T.sen]    -0.0749      0.134     -0.560      0.576      -0.337       0.187
# C(Mention_country)[T.sgp]     3.0797      0.499      6.170      0.000       2.101       4.058
# C(Mention_country)[T.sle]    -0.0030      0.005     -0.560      0.576      -0.014       0.008
# C(Mention_country)[T.slv]    -0.1279      0.228     -0.560      0.576      -0.575       0.320
# C(Mention_country)[T.som]     0.0497      0.089      0.560      0.576      -0.124       0.224
# C(Mention_country)[T.svk]     2.5193      0.398      6.337      0.000       1.740       3.298
# C(Mention_country)[T.svn]     2.1754      0.444      4.897      0.000       1.305       3.046
# C(Mention_country)[T.swe]     5.0854      0.533      9.548      0.000       4.041       6.129
# C(Mention_country)[T.syr]    -1.0006      0.071    -14.164      0.000      -1.139      -0.862
# C(Mention_country)[T.tcd]    -0.0396      0.071     -0.560      0.576      -0.178       0.099
# C(Mention_country)[T.tgo]    -0.0303      0.054     -0.560      0.576      -0.136       0.076
# C(Mention_country)[T.tha]     3.9416      0.254     15.500      0.000       3.443       4.440
# C(Mention_country)[T.tjk]    -0.0182      0.032     -0.560      0.576      -0.082       0.045
# C(Mention_country)[T.tkm]    -0.1139      0.203     -0.560      0.576      -0.513       0.285
# C(Mention_country)[T.tto]     0.0107      0.394      0.027      0.978      -0.761       0.782
# C(Mention_country)[T.tun]     0.2068      0.024      8.682      0.000       0.160       0.254
# C(Mention_country)[T.tur]     4.5154      0.340     13.283      0.000       3.849       5.182
# C(Mention_country)[T.tza]     1.7429      0.059     29.361      0.000       1.627       1.859
# C(Mention_country)[T.uga]     1.7260      0.030     57.990      0.000       1.668       1.784
# C(Mention_country)[T.ukr]     0.6728      0.205      3.286      0.001       0.271       1.074
# C(Mention_country)[T.ury]     1.2989      0.324      4.012      0.000       0.664       1.934
# C(Mention_country)[T.usa]     7.7443      0.532     14.557      0.000       6.702       8.787
# C(Mention_country)[T.uzb]     0.2247      0.092      2.449      0.014       0.045       0.405
# C(Mention_country)[T.ven]     1.9874      0.331      6.007      0.000       1.339       2.636
# C(Mention_country)[T.vnm]     0.8757      0.104      8.390      0.000       0.671       1.080
# C(Mention_country)[T.yem]    -0.9448      0.168     -5.628      0.000      -1.274      -0.616
# C(Mention_country)[T.zaf]     4.3941      0.309     14.212      0.000       3.788       5.000
# C(Mention_country)[T.zmb]     0.0858      0.109      0.788      0.431      -0.128       0.299
# C(Mention_country)[T.zwe]     0.7843      0.058     13.634      0.000       0.672       0.897
# C(year)[T.2003.0]            -0.0248      0.025     -0.974      0.330      -0.075       0.025
# C(year)[T.2004.0]             0.0049      0.027      0.180      0.857      -0.049       0.058
# C(year)[T.2005.0]            -0.0052      0.027     -0.192      0.847      -0.058       0.048
# C(year)[T.2006.0]             0.0258      0.025      1.020      0.308      -0.024       0.075
# C(year)[T.2007.0]            -0.0198      0.023     -0.861      0.389      -0.065       0.025
# C(year)[T.2008.0]             0.0126      0.020      0.632      0.527      -0.026       0.052
# C(year)[T.2009.0]             0.0263      0.023      1.136      0.256      -0.019       0.072
# C(year)[T.2010.0]            -0.0193      0.023     -0.845      0.398      -0.064       0.025
# treated                       0.8840      0.288      3.067      0.002       0.319       1.449
# time                         -0.0785      0.014     -5.717      0.000      -0.105      -0.052
# treated:time                6.56e-05      0.032      0.002      0.998      -0.063       0.063
# log_gdp                       0.0596      0.107      0.560      0.576      -0.149       0.268
# ==============================================================================
# Omnibus:                       53.546   Durbin-Watson:                   1.401
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.283
# Skew:                          -0.173   Prob(JB):                     4.21e-30
# Kurtosis:                       4.539   Cond. No.                     3.69e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 8.39e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 156, but rank is 10
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ### Notice: Pre-parallel trend test is not significant at the target level so not an issue.

# %%
df_complete['treated:post']=df_complete['treated']*df_complete['post']
# Select the independent variables (excluding categorical variables handled by C())
independent_vars = df_complete[['treated', 'post', 'treated:post', 'log_gdp', 'log_Rpop']]
# Compute VIF
vif_data = pd.DataFrame()
vif_data["Variable"] = independent_vars.columns
vif_data["VIF"] = [variance_inflation_factor(independent_vars.values, i) for i in range(len(independent_vars.columns))]
print(vif_data)
# Out:
#        Variable        VIF
# 0       treated   2.166810
# 1          post   2.215073
# 2  treated:post   2.151883
# 3       log_gdp  21.431421
# 4      log_Rpop  20.667171

# %% [markdown]
# ### Notice: The VIF for treated:post is not high, so safe to go:)

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='treated')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Domestic Funding')
# Out:
# Text(0, 0.5, 'log Domestic Funding')

# %% [markdown]
# ### Trends for the world is stable and linear. There exists a pattern change before and after the arab spring visually.

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~ treated* post +log_gdp+ C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     32.70
# Date:                Mon, 17 Mar 2025   Prob (F-statistic):           8.95e-43
# Time:                        13:26:40   Log-Likelihood:                -1998.0
# No. Observations:                2610   AIC:                             4324.
# Df Residuals:                    2446   BIC:                             5286.
# Df Model:                         163
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -1.2798      0.688     -1.861      0.063      -2.627       0.068
# C(Mention_country)[T.ago]    -0.1608      0.235     -0.685      0.493      -0.621       0.299
# C(Mention_country)[T.alb]    -0.1658      0.275     -0.603      0.546      -0.705       0.373
# C(Mention_country)[T.are]     2.0572      0.583      3.529      0.000       0.915       3.200
# C(Mention_country)[T.arg]     5.2142      0.383     13.604      0.000       4.463       5.965
# C(Mention_country)[T.arm]     0.4588      0.239      1.917      0.055      -0.010       0.928
# C(Mention_country)[T.aus]     6.3694      0.597     10.663      0.000       5.199       7.540
# C(Mention_country)[T.aut]     3.4016      0.594      5.731      0.000       2.238       4.565
# C(Mention_country)[T.aze]     0.1461      0.276      0.530      0.596      -0.394       0.686
# C(Mention_country)[T.bdi]     0.3232      0.097      3.320      0.001       0.132       0.514
# C(Mention_country)[T.bel]     3.8108      0.585      6.514      0.000       2.664       4.957
# C(Mention_country)[T.ben]    -0.0142      0.110     -0.129      0.897      -0.229       0.201
# C(Mention_country)[T.bfa]    -0.0297      0.043     -0.685      0.493      -0.115       0.055
# C(Mention_country)[T.bgd]     2.2244      0.091     24.463      0.000       2.046       2.403
# C(Mention_country)[T.bgr]     1.9573      0.340      5.761      0.000       1.291       2.623
# C(Mention_country)[T.bhr]    -0.9969      0.204     -4.893      0.000      -1.396      -0.598
# C(Mention_country)[T.bih]    -0.0088      0.289     -0.030      0.976      -0.574       0.557
# C(Mention_country)[T.blr]     0.4067      0.311      1.308      0.191      -0.203       1.016
# C(Mention_country)[T.bol]    -0.0950      0.195     -0.488      0.626      -0.477       0.287
# C(Mention_country)[T.bra]     6.6413      0.370     17.931      0.000       5.915       7.367
# C(Mention_country)[T.bwa]     0.6282      0.332      1.895      0.058      -0.022       1.278
# C(Mention_country)[T.caf]     0.0064      0.009      0.685      0.493      -0.012       0.025
# C(Mention_country)[T.can]     6.3375      0.587     10.795      0.000       5.187       7.488
# C(Mention_country)[T.che]     4.3250      0.654      6.609      0.000       3.042       5.608
# C(Mention_country)[T.chl]     4.3556      0.415     10.483      0.000       3.541       5.170
# C(Mention_country)[T.chn]     7.8969      0.293     26.912      0.000       7.322       8.472
# C(Mention_country)[T.civ]    -0.1203      0.176     -0.685      0.493      -0.464       0.224
# C(Mention_country)[T.cmr]     0.0499      0.148      0.336      0.737      -0.241       0.341
# C(Mention_country)[T.col]     3.4645      0.321     10.782      0.000       2.835       4.094
# C(Mention_country)[T.cri]     1.7703      0.373      4.752      0.000       1.040       2.500
# C(Mention_country)[T.cub]     0.6374      0.331      1.928      0.054      -0.011       1.285
# C(Mention_country)[T.cyp]     1.4534      0.530      2.743      0.006       0.415       2.492
# C(Mention_country)[T.cze]     4.3555      0.475      9.176      0.000       3.425       5.286
# C(Mention_country)[T.deu]     5.4304      0.582      9.331      0.000       4.290       6.571
# C(Mention_country)[T.dji]    -0.1072      0.156     -0.685      0.493      -0.414       0.199
# C(Mention_country)[T.dnk]     4.2429      0.619      6.850      0.000       3.029       5.457
# C(Mention_country)[T.dom]    -0.0461      0.320     -0.144      0.886      -0.674       0.582
# C(Mention_country)[T.dza]     1.2232      0.284      4.301      0.000       0.666       1.781
# C(Mention_country)[T.ecu]     1.4138      0.301      4.690      0.000       0.823       2.005
# C(Mention_country)[T.egy]     1.3614      0.091     15.030      0.000       1.184       1.539
# C(Mention_country)[T.eri]    -0.0197      0.029     -0.685      0.493      -0.076       0.037
# C(Mention_country)[T.esp]     5.9572      0.535     11.141      0.000       4.909       7.005
# C(Mention_country)[T.est]     3.2885      0.455      7.233      0.000       2.397       4.180
# C(Mention_country)[T.eth]     3.6779      0.023    160.431      0.000       3.633       3.723
# C(Mention_country)[T.fin]     4.8733      0.593      8.218      0.000       3.711       6.035
# C(Mention_country)[T.fra]     4.9737      0.574      8.659      0.000       3.848       6.099
# C(Mention_country)[T.gab]     0.5818      0.365      1.595      0.111      -0.133       1.297
# C(Mention_country)[T.gbr]     6.9028      0.586     11.784      0.000       5.755       8.051
# C(Mention_country)[T.gha]     1.6778      0.128     13.111      0.000       1.427       1.929
# C(Mention_country)[T.gmb]    -0.0361      0.053     -0.685      0.493      -0.139       0.067
# C(Mention_country)[T.grc]     3.1954      0.504      6.335      0.000       2.207       4.184
# C(Mention_country)[T.gtm]    -0.0569      0.250     -0.228      0.820      -0.546       0.433
# C(Mention_country)[T.hkg]     4.5761      0.561      8.158      0.000       3.477       5.675
# C(Mention_country)[T.hnd]     0.0366      0.186      0.196      0.844      -0.328       0.402
# C(Mention_country)[T.hrv]     2.8951      0.432      6.708      0.000       2.049       3.741
# C(Mention_country)[T.hti]    -0.0848      0.124     -0.685      0.493      -0.327       0.158
# C(Mention_country)[T.hun]     3.6053      0.434      8.301      0.000       2.754       4.457
# C(Mention_country)[T.idn]     2.7300      0.223     12.228      0.000       2.292       3.168
# C(Mention_country)[T.ind]     6.1228      0.131     46.887      0.000       5.867       6.379
# C(Mention_country)[T.irn]     5.0338      0.304     16.535      0.000       4.437       5.631
# C(Mention_country)[T.irq]     0.6874      0.270      2.548      0.011       0.159       1.216
# C(Mention_country)[T.isr]     3.8005      0.545      6.978      0.000       2.733       4.868
# C(Mention_country)[T.ita]     5.1657      0.557      9.267      0.000       4.073       6.258
# C(Mention_country)[T.jam]     0.7060      0.310      2.279      0.023       0.099       1.313
# C(Mention_country)[T.jor]     1.5985      0.033     47.764      0.000       1.533       1.664
# C(Mention_country)[T.jpn]     6.5296      0.579     11.287      0.000       5.396       7.663
# C(Mention_country)[T.kaz]     1.0557      0.358      2.950      0.003       0.354       1.757
# C(Mention_country)[T.ken]     2.3085      0.113     20.476      0.000       2.088       2.529
# C(Mention_country)[T.kgz]    -0.0620      0.091     -0.685      0.493      -0.240       0.115
# C(Mention_country)[T.khm]     0.0101      0.084      0.120      0.904      -0.154       0.174
# C(Mention_country)[T.kor]     5.7450      0.512     11.213      0.000       4.741       6.749
# C(Mention_country)[T.kwt]     1.2090      0.270      4.471      0.000       0.679       1.739
# C(Mention_country)[T.lao]    -0.0250      0.123     -0.203      0.839      -0.267       0.217
# C(Mention_country)[T.lbn]     2.1129      0.352      5.994      0.000       1.422       2.804
# C(Mention_country)[T.lbr]    -0.0113      0.017     -0.685      0.493      -0.044       0.021
# C(Mention_country)[T.lby]    -1.2443      0.097    -12.763      0.000      -1.435      -1.053
# C(Mention_country)[T.lka]     2.3610      0.222     10.632      0.000       1.926       2.796
# C(Mention_country)[T.lso]    -0.0694      0.101     -0.685      0.493      -0.268       0.129
# C(Mention_country)[T.ltu]     1.7681      0.426      4.151      0.000       0.933       2.603
# C(Mention_country)[T.lva]     0.8304      0.423      1.962      0.050       0.001       1.660
# C(Mention_country)[T.mar]     0.2433      0.051      4.739      0.000       0.143       0.344
# C(Mention_country)[T.mda]    -0.0350      0.201     -0.174      0.862      -0.430       0.359
# C(Mention_country)[T.mdg]    -0.0042      0.006     -0.685      0.493      -0.016       0.008
# C(Mention_country)[T.mex]     5.0874      0.400     12.728      0.000       4.304       5.871
# C(Mention_country)[T.mkd]    -0.2026      0.296     -0.685      0.493      -0.782       0.377
# C(Mention_country)[T.mli]    -0.0373      0.055     -0.685      0.493      -0.144       0.069
# C(Mention_country)[T.mmr]    -0.0424      0.062     -0.685      0.493      -0.164       0.079
# C(Mention_country)[T.mng]     0.3139      0.214      1.470      0.142      -0.105       0.732
# C(Mention_country)[T.moz]     0.0307      0.025      1.214      0.225      -0.019       0.080
# C(Mention_country)[T.mrt]    -0.1050      0.153     -0.685      0.493      -0.406       0.195
# C(Mention_country)[T.mus]     0.7203      0.373      1.932      0.053      -0.011       1.451
# C(Mention_country)[T.mwi]     0.2195      0.028      7.868      0.000       0.165       0.274
# C(Mention_country)[T.mys]     4.2678      0.376     11.356      0.000       3.531       5.004
# C(Mention_country)[T.nam]     0.3834      0.300      1.276      0.202      -0.205       0.972
# C(Mention_country)[T.ner]    -0.0026      0.004     -0.685      0.493      -0.010       0.005
# C(Mention_country)[T.nga]     1.9665      0.191     10.273      0.000       1.591       2.342
# C(Mention_country)[T.nic]    -0.1139      0.166     -0.685      0.493      -0.440       0.212
# C(Mention_country)[T.nld]     4.7008      0.602      7.814      0.000       3.522       5.880
# C(Mention_country)[T.nor]     4.7382      0.664      7.133      0.000       3.436       6.040
# C(Mention_country)[T.npl]     1.3541      0.041     33.207      0.000       1.274       1.434
# C(Mention_country)[T.nzl]     5.1976      0.557      9.333      0.000       4.106       6.289
# C(Mention_country)[T.omn]     0.7157      0.177      4.043      0.000       0.369       1.063
# C(Mention_country)[T.pak]     3.3626      0.123     27.344      0.000       3.122       3.604
# C(Mention_country)[T.pan]     0.6012      0.386      1.557      0.120      -0.156       1.358
# C(Mention_country)[T.per]     1.1085      0.303      3.660      0.000       0.515       1.702
# C(Mention_country)[T.phl]     2.5107      0.205     12.246      0.000       2.109       2.913
# C(Mention_country)[T.pol]     4.1309      0.417      9.907      0.000       3.314       4.948
# C(Mention_country)[T.pri]     1.4886      0.526      2.832      0.005       0.458       2.519
# C(Mention_country)[T.prt]     4.3755      0.496      8.824      0.000       3.404       5.347
# C(Mention_country)[T.pry]    -0.0119      0.285     -0.042      0.967      -0.570       0.547
# C(Mention_country)[T.pse]     0.2752      0.221      1.245      0.213      -0.158       0.708
# C(Mention_country)[T.qat]     1.6542      0.637      2.598      0.009       0.406       2.902
# C(Mention_country)[T.rou]     1.9404      0.365      5.310      0.000       1.224       2.657
# C(Mention_country)[T.rus]     4.7043      0.384     12.238      0.000       3.951       5.458
# C(Mention_country)[T.rwa]     0.1415      0.030      4.791      0.000       0.084       0.199
# C(Mention_country)[T.sau]     3.4805      0.475      7.335      0.000       2.551       4.411
# C(Mention_country)[T.sen]     0.2048      0.136      1.507      0.132      -0.062       0.471
# C(Mention_country)[T.sgp]     3.6923      0.592      6.236      0.000       2.532       4.853
# C(Mention_country)[T.sle]    -0.0010      0.001     -0.685      0.493      -0.004       0.002
# C(Mention_country)[T.slv]    -0.1756      0.256     -0.685      0.493      -0.678       0.327
# C(Mention_country)[T.som]     0.0534      0.078      0.685      0.493      -0.099       0.206
# C(Mention_country)[T.svk]     3.3231      0.456      7.280      0.000       2.428       4.218
# C(Mention_country)[T.svn]     2.7820      0.502      5.545      0.000       1.799       3.765
# C(Mention_country)[T.swe]     5.4735      0.609      8.990      0.000       4.280       6.667
# C(Mention_country)[T.syr]    -0.9608      0.045    -21.564      0.000      -1.048      -0.873
# C(Mention_country)[T.tcd]    -0.0450      0.066     -0.685      0.493      -0.174       0.084
# C(Mention_country)[T.tgo]    -0.0382      0.056     -0.685      0.493      -0.148       0.071
# C(Mention_country)[T.tha]     4.7095      0.303     15.544      0.000       4.116       5.303
# C(Mention_country)[T.tjk]    -0.0341      0.050     -0.685      0.493      -0.132       0.063
# C(Mention_country)[T.tkm]    -0.1895      0.277     -0.685      0.493      -0.732       0.353
# C(Mention_country)[T.tto]     0.1415      0.453      0.312      0.755      -0.747       1.030
# C(Mention_country)[T.tun]     0.6744      0.022     31.089      0.000       0.632       0.717
# C(Mention_country)[T.tur]     4.9731      0.391     12.729      0.000       4.207       5.739
# C(Mention_country)[T.tza]     2.2667      0.068     33.577      0.000       2.134       2.399
# C(Mention_country)[T.uga]     2.3904      0.041     58.591      0.000       2.310       2.470
# C(Mention_country)[T.ukr]     1.1993      0.230      5.215      0.000       0.749       1.650
# C(Mention_country)[T.ury]     1.9486      0.410      4.748      0.000       1.144       2.753
# C(Mention_country)[T.usa]     8.1648      0.609     13.396      0.000       6.970       9.359
# C(Mention_country)[T.uzb]     0.2471      0.141      1.755      0.079      -0.029       0.523
# C(Mention_country)[T.ven]     2.1579      0.403      5.353      0.000       1.368       2.948
# C(Mention_country)[T.vnm]     2.2193      0.160     13.875      0.000       1.906       2.533
# C(Mention_country)[T.yem]    -1.3487      0.187     -7.208      0.000      -1.715      -0.982
# C(Mention_country)[T.zaf]     5.0505      0.344     14.677      0.000       4.376       5.725
# C(Mention_country)[T.zmb]     0.2519      0.127      1.980      0.048       0.003       0.501
# C(Mention_country)[T.zwe]     1.0617      0.092     11.556      0.000       0.882       1.242
# C(year)[T.2003.0]             0.0504      0.031      1.632      0.103      -0.010       0.111
# C(year)[T.2004.0]             0.1546      0.045      3.443      0.001       0.067       0.243
# C(year)[T.2005.0]             0.2196      0.062      3.553      0.000       0.098       0.341
# C(year)[T.2006.0]             0.3259      0.074      4.383      0.000       0.180       0.472
# C(year)[T.2007.0]             0.3546      0.089      4.005      0.000       0.181       0.528
# C(year)[T.2008.0]             0.4613      0.109      4.224      0.000       0.247       0.675
# C(year)[T.2009.0]             0.5551      0.103      5.414      0.000       0.354       0.756
# C(year)[T.2010.0]             0.5853      0.115      5.101      0.000       0.360       0.810
# C(year)[T.2011.0]            -0.3954      0.037    -10.821      0.000      -0.467      -0.324
# C(year)[T.2012.0]            -0.3209      0.034     -9.331      0.000      -0.388      -0.253
# C(year)[T.2013.0]            -0.1889      0.033     -5.810      0.000      -0.253      -0.125
# C(year)[T.2014.0]            -0.0885      0.028     -3.147      0.002      -0.144      -0.033
# C(year)[T.2015.0]            -0.0903      0.024     -3.688      0.000      -0.138      -0.042
# C(year)[T.2016.0]             0.1194      0.022      5.325      0.000       0.075       0.163
# C(year)[T.2017.0]             0.3911      0.034     11.612      0.000       0.325       0.457
# C(year)[T.2018.0]             0.7409      0.046     16.136      0.000       0.651       0.831
# C(year)[T.2019.0]             0.9222      0.054     17.123      0.000       0.817       1.028
# treated                       1.2516      0.339      3.696      0.000       0.588       1.915
# post                          1.0897      0.126      8.643      0.000       0.843       1.337
# treated:post                  0.1547      0.217      0.711      0.477      -0.272       0.581
# log_gdp                       0.0870      0.127      0.685      0.493      -0.162       0.336
# ==============================================================================
# Omnibus:                       75.077   Durbin-Watson:                   0.678
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.180
# Skew:                          -0.181   Prob(JB):                     1.48e-33
# Kurtosis:                       4.122   Cond. No.                     3.48e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.59e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 165, but rank is 19
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ###  Durbin-Watson: 1.131, it is higher than 1 so the autocorrelation is residuals are not highly problematic.

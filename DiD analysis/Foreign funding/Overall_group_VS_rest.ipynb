# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
pop_df=pd.read_csv(r'C:\Users\Yasaman\Downloads\World_bank_population.csv',skiprows=3)
pop_df['Country Code']=pop_df['Country Code'].apply(lambda x: x.lower())
possible_countries=pop_df.query(" `2019` >=1000000")['Country Code'].values

excluded_iso3_codes = [
    "IRL",  # Ireland
    "SSD",  # South Sudan
    "SDN",  # Sudan
    "COG",  # Republic of the Congo
    "COD",  # Democratic Republic of the Congo
    "GIN",  # Guinea
    "GNB",  # Guinea-Bissau
    "GNQ",  # Equatorial Guinea
    "PNG",  # Papua New Guinea
    "XKX",  # Kosovo (unofficial)
    "MNE",  # Montenegro
    "SRB",  # Serbia
    "TLS",   # Timor-Leste
    "GEO", #Georgia
    'SWZ', 
    'PRK', #North Korea
]
excluded_iso3_codes=[c.lower() for c in excluded_iso3_codes]


possible_iso=list(set(possible_countries)-set(excluded_iso3_codes))

# %%
#funding
Country_list={'Egypt':'EGY', 'Tunisia':'TUN','Libya':'LBY','Syria':'SYR','Yemen':'YEM','Bahrain':'BHR','Jordan':'JOR','Kuwait':'KWT','Morocco':'MAR','Oman':'OMN'}
rev_Country_list={Country_list[key]: key for key in Country_list}
abbr=[country.lower() for country in Country_list.values()]
physical_sciences=['MATH', 'ENGI', 'PHYS', 'COMP', 'MUL']
df_fund=pd.read_csv(r"C:\Users\Yasaman\Downloads\Mentioned-Funding-fractional counting.csv")
df_fund.rename(columns={'aggregated_value': 'count', 'country': 'Mention_country', 'funding_country': 'Source'}, inplace=True)
df_fund=df_fund[~(df_fund['subjarea'].isin(physical_sciences))]
df_fund=df_fund[df_fund['Mention_country']!=df_fund['Source']]
df_fund=df_fund.groupby(['year', 'Mention_country'])['count'].sum().reset_index()
df_fund=df_fund[(df_fund['year'].isin(np.arange(2002,2020,1)))].reset_index(drop=True)
df=df_fund.copy()

data=pd.read_csv(r"C:\Users\Yasaman\Downloads\scopus_2024_V1_scholarlymigration_country_enriched.csv")
data=data[data['year'].isin(np.arange(2002, 2020))]
data=data[['iso3code', 'incomelevel', 'gdp_per_capita', 'year', 'population', 'region', 'padded_population_of_researchers']].dropna()
data.rename(columns={'iso3code':'Mention_country'}, inplace=True)
data['Mention_country']=data['Mention_country'].apply(lambda x: x.lower())
df=df.merge(data, on=['Mention_country', 'year'], how='outer')
df=df[df['Mention_country'].isin(possible_iso)]


countries_to_remove=[]
for c  in df['Mention_country'].unique():
    if ((~df['count'].isna()) & (df['Mention_country'] == c)).sum()<15:
        countries_to_remove.append(c)
        print(c)

print(len(countries_to_remove))

# Define the required year range
required_years = list(range(2002, 2020))

# Get the unique countries
unique_countries = df["Mention_country"].unique()

# Create a complete DataFrame with all country-year combinations
full_data = []
for country in unique_countries:
    country_data = df[df["Mention_country"] == country]
    existing_years = set(country_data["year"])
    
    for year in required_years:
        if year in existing_years:
            row = country_data[country_data["year"] == year].iloc[0].to_dict()
        else:
            row = {
                "year": year,
                "Mention_country": country,
                "count": 0,
                "incomelevel": country_data["incomelevel"].iloc[0] if not country_data.empty else np.nan,
                "gdp_per_capita": np.nan,
                "population": np.nan,
                "region": country_data["region"].iloc[0] if not country_data.empty else np.nan,
            }
        full_data.append(row)

# Convert to DataFrame
df_complete = pd.DataFrame(full_data)

df_complete['treated']=df_complete['Mention_country'].isin(abbr).astype(int)
df_complete['treated_CW']=df_complete['Mention_country'].isin(['yem', 'lby', 'syr']).astype(int)
df_complete['treated_GO']=df_complete['Mention_country'].isin(['egy', 'tun']).astype(int)
df_complete['treated_GC']=df_complete['Mention_country'].isin(['omn', 'kwt', 'bhr', 'mar','jor']).astype(int)
df_complete['post']=df_complete['year'].apply(lambda x: 0 if x>=2002 and x<=2010 else 1 )
df_complete['count']=df_complete['count'].fillna(0)
df_complete['log_count']=np.log(df_complete['count']+1)

df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].ffill()
df_complete[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']] = df_complete.groupby('Mention_country')[['incomelevel', 'region', 'gdp_per_capita', 'population','padded_population_of_researchers']].bfill()
df_complete['log_gdp']=np.log(df_complete['gdp_per_capita'])
df_complete['log_population']=np.log(df_complete['population'])
df_complete['log_Rpop']=np.log(df_complete['padded_population_of_researchers']+1)
df_complete=df_complete[df_complete['Mention_country'].isin(possible_iso)].reset_index(drop=True)
# Out:
# 0

# %%
df_complete['hue']=df_complete['treated_CW']*2 +df_complete['treated_GC']*3+df_complete['treated_GO']

# %%
df_p=df_complete[df_complete['year']<2011].reset_index(drop=True)
df_p['time']=df_p['year'].min()-df_p['year']
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * time + treated_GO * time +treated_CW * time+log_population +log_gdp +C(Mention_country) + C(year)", data=df_p).fit(cov_type='cluster', cov_kwds={'groups': df_p['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     72.32
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           2.52e-56
# Time:                        21:46:00   Log-Likelihood:                -108.17
# No. Observations:                1305   AIC:                             532.3
# Df Residuals:                    1147   BIC:                             1350.
# Df Model:                         157
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -1.6829      6.548     -0.257      0.797     -14.518      11.152
# C(Mention_country)[T.ago]    -0.3386      0.152     -2.233      0.026      -0.636      -0.041
# C(Mention_country)[T.alb]    -0.7636      0.788     -0.969      0.332      -2.308       0.781
# C(Mention_country)[T.are]    -0.2280      0.625     -0.365      0.715      -1.453       0.997
# C(Mention_country)[T.arg]     1.5616      0.310      5.032      0.000       0.953       2.170
# C(Mention_country)[T.arm]    -0.6198      0.784     -0.791      0.429      -2.156       0.916
# C(Mention_country)[T.aus]     2.1015      0.353      5.950      0.000       1.409       2.794
# C(Mention_country)[T.aut]     0.1261      0.499      0.253      0.800      -0.851       1.104
# C(Mention_country)[T.aze]    -0.9345      0.403     -2.318      0.020      -1.725      -0.144
# C(Mention_country)[T.bdi]    -1.4689      0.463     -3.176      0.001      -2.376      -0.562
# C(Mention_country)[T.bel]     0.3953      0.436      0.906      0.365      -0.460       1.250
# C(Mention_country)[T.ben]     0.2177      0.404      0.539      0.590      -0.575       1.010
# C(Mention_country)[T.bfa]     0.9283      0.207      4.495      0.000       0.523       1.333
# C(Mention_country)[T.bgd]     1.6083      0.672      2.394      0.017       0.291       2.925
# C(Mention_country)[T.bgr]     0.3389      0.454      0.746      0.455      -0.551       1.229
# C(Mention_country)[T.bhr]    -1.6552      0.656     -2.522      0.012      -2.942      -0.369
# C(Mention_country)[T.bih]    -0.5430      0.677     -0.802      0.423      -1.870       0.784
# C(Mention_country)[T.blr]    -0.5827      0.369     -1.578      0.115      -1.307       0.141
# C(Mention_country)[T.bol]     1.0770      0.358      3.011      0.003       0.376       1.778
# C(Mention_country)[T.bra]     2.0839      0.844      2.469      0.014       0.430       3.738
# C(Mention_country)[T.bwa]     0.5921      0.950      0.624      0.533      -1.269       2.453
# C(Mention_country)[T.caf]    -1.1428      0.666     -1.716      0.086      -2.448       0.162
# C(Mention_country)[T.can]     2.0150      0.399      5.049      0.000       1.233       2.797
# C(Mention_country)[T.che]     0.6320      0.540      1.171      0.242      -0.426       1.690
# C(Mention_country)[T.chl]     1.5106      0.266      5.673      0.000       0.989       2.032
# C(Mention_country)[T.chn]     3.0930      1.545      2.002      0.045       0.066       6.120
# C(Mention_country)[T.civ]    -2.1389      0.133    -16.094      0.000      -2.399      -1.878
# C(Mention_country)[T.cmr]     1.3643      0.147      9.291      0.000       1.076       1.652
# C(Mention_country)[T.col]     0.8456      0.309      2.733      0.006       0.239       1.452
# C(Mention_country)[T.cri]     1.5003      0.651      2.304      0.021       0.224       2.777
# C(Mention_country)[T.cub]     0.0562      0.325      0.173      0.863      -0.580       0.693
# C(Mention_country)[T.cyp]    -0.0829      1.178     -0.070      0.944      -2.391       2.225
# C(Mention_country)[T.cze]     0.4581      0.398      1.152      0.249      -0.321       1.237
# C(Mention_country)[T.deu]     1.5473      0.638      2.425      0.015       0.297       2.798
# C(Mention_country)[T.dji]    -1.5224      1.272     -1.197      0.231      -4.016       0.971
# C(Mention_country)[T.dnk]     0.9501      0.624      1.522      0.128      -0.274       2.174
# C(Mention_country)[T.dom]    -0.3954      0.384     -1.029      0.303      -1.148       0.358
# C(Mention_country)[T.dza]    -0.6321      0.232     -2.729      0.006      -1.086      -0.178
# C(Mention_country)[T.ecu]     0.9669      0.253      3.824      0.000       0.471       1.463
# C(Mention_country)[T.egy]     0.5545      0.412      1.347      0.178      -0.252       1.362
# C(Mention_country)[T.eri]    -0.4240      0.817     -0.519      0.604      -2.025       1.177
# C(Mention_country)[T.esp]     2.1286      0.442      4.816      0.000       1.262       2.995
# C(Mention_country)[T.est]     0.2333      1.083      0.215      0.829      -1.890       2.357
# C(Mention_country)[T.eth]     1.7728      0.437      4.061      0.000       0.917       2.628
# C(Mention_country)[T.fin]     1.2577      0.628      2.003      0.045       0.027       2.488
# C(Mention_country)[T.fra]     1.5510      0.559      2.777      0.005       0.456       2.646
# C(Mention_country)[T.gab]    -0.1413      1.042     -0.136      0.892      -2.183       1.901
# C(Mention_country)[T.gbr]     2.5149      0.554      4.543      0.000       1.430       3.600
# C(Mention_country)[T.gha]     1.3471      0.062     21.674      0.000       1.225       1.469
# C(Mention_country)[T.gmb]    -0.1613      1.007     -0.160      0.873      -2.135       1.812
# C(Mention_country)[T.grc]     1.2414      0.403      3.078      0.002       0.451       2.032
# C(Mention_country)[T.gtm]     0.4494      0.257      1.751      0.080      -0.054       0.952
# C(Mention_country)[T.hkg]     1.6022      0.536      2.990      0.003       0.552       2.653
# C(Mention_country)[T.hnd]     0.0995      0.435      0.229      0.819      -0.754       0.953
# C(Mention_country)[T.hrv]    -0.3144      0.666     -0.472      0.637      -1.619       0.990
# C(Mention_country)[T.hti]    -0.2524      0.368     -0.687      0.492      -0.973       0.468
# C(Mention_country)[T.hun]     0.5441      0.392      1.387      0.165      -0.225       1.313
# C(Mention_country)[T.idn]     1.5918      0.882      1.804      0.071      -0.138       3.321
# C(Mention_country)[T.ind]     2.5951      1.480      1.753      0.080      -0.306       5.496
# C(Mention_country)[T.irn]     0.4938      0.477      1.035      0.301      -0.441       1.429
# C(Mention_country)[T.irq]    -0.2877      0.170     -1.692      0.091      -0.621       0.046
# C(Mention_country)[T.isr]     1.2222      0.522      2.341      0.019       0.199       2.245
# C(Mention_country)[T.ita]     1.7878      0.528      3.388      0.001       0.754       2.822
# C(Mention_country)[T.jam]     0.3929      0.827      0.475      0.635      -1.229       2.015
# C(Mention_country)[T.jor]     1.1240      0.055     20.340      0.000       1.016       1.232
# C(Mention_country)[T.jpn]     1.7463      0.785      2.224      0.026       0.208       3.285
# C(Mention_country)[T.kaz]     0.3138      0.244      1.288      0.198      -0.164       0.791
# C(Mention_country)[T.ken]     2.4777      0.173     14.350      0.000       2.139       2.816
# C(Mention_country)[T.kgz]    -0.1514      0.586     -0.258      0.796      -1.299       0.997
# C(Mention_country)[T.khm]     0.6990      0.229      3.059      0.002       0.251       1.147
# C(Mention_country)[T.kor]     0.8632      0.443      1.949      0.051      -0.005       1.731
# C(Mention_country)[T.kwt]    -1.4645      0.325     -4.510      0.000      -2.101      -0.828
# C(Mention_country)[T.lao]     0.1588      0.536      0.296      0.767      -0.891       1.208
# C(Mention_country)[T.lbn]    -0.3139      0.623     -0.503      0.615      -1.536       0.908
# C(Mention_country)[T.lbr]    -1.2018      0.762     -1.578      0.115      -2.694       0.291
# C(Mention_country)[T.lby]    -0.5738      0.373     -1.537      0.124      -1.305       0.158
# C(Mention_country)[T.lka]     0.8004      0.132      6.082      0.000       0.542       1.058
# C(Mention_country)[T.lso]    -0.4030      0.947     -0.425      0.670      -2.259       1.453
# C(Mention_country)[T.ltu]    -0.3702      0.759     -0.488      0.626      -1.858       1.118
# C(Mention_country)[T.lva]    -0.4952      0.901     -0.549      0.583      -2.262       1.271
# C(Mention_country)[T.mar]     1.2764      0.639      1.998      0.046       0.024       2.529
# C(Mention_country)[T.mda]    -0.8472      0.804     -1.054      0.292      -2.422       0.728
# C(Mention_country)[T.mdg]     1.6999      0.094     18.128      0.000       1.516       1.884
# C(Mention_country)[T.mex]     2.5109      0.657      3.823      0.000       1.224       3.798
# C(Mention_country)[T.mkd]    -0.5677      0.930     -0.611      0.541      -2.390       1.255
# C(Mention_country)[T.mli]     0.7595      0.224      3.388      0.001       0.320       1.199
# C(Mention_country)[T.mmr]    -0.0113      0.253     -0.045      0.964      -0.507       0.484
# C(Mention_country)[T.mng]     1.9051      0.844      2.256      0.024       0.250       3.560
# C(Mention_country)[T.moz]     0.8580      0.069     12.352      0.000       0.722       0.994
# C(Mention_country)[T.mrt]    -0.9152      0.778     -1.176      0.239      -2.440       0.610
# C(Mention_country)[T.mus]    -0.4923      1.117     -0.441      0.659      -2.682       1.697
# C(Mention_country)[T.mwi]     1.5303      0.238      6.431      0.000       1.064       1.997
# C(Mention_country)[T.mys]     0.7755      0.234      3.314      0.001       0.317       1.234
# C(Mention_country)[T.nam]     0.9165      0.939      0.976      0.329      -0.924       2.757
# C(Mention_country)[T.ner]    -0.2625      0.207     -1.270      0.204      -0.668       0.143
# C(Mention_country)[T.nga]     1.3413      0.702      1.912      0.056      -0.034       2.716
# C(Mention_country)[T.nic]     0.4875      0.559      0.873      0.383      -0.607       1.582
# C(Mention_country)[T.nld]     1.2089      0.378      3.194      0.001       0.467       1.951
# C(Mention_country)[T.nor]     2.0687      0.681      3.040      0.002       0.735       3.403
# C(Mention_country)[T.npl]     1.5494      0.027     56.413      0.000       1.496       1.603
# C(Mention_country)[T.nzl]     2.4617      0.693      3.553      0.000       1.104       3.820
# C(Mention_country)[T.omn]     0.6242      0.290      2.155      0.031       0.056       1.192
# C(Mention_country)[T.pak]     1.0025      0.768      1.305      0.192      -0.503       2.508
# C(Mention_country)[T.pan]     0.9941      0.746      1.332      0.183      -0.468       2.456
# C(Mention_country)[T.per]     1.5461      0.193      8.001      0.000       1.167       1.925
# C(Mention_country)[T.phl]     1.4247      0.518      2.752      0.006       0.410       2.439
# C(Mention_country)[T.pol]     0.8608      0.331      2.604      0.009       0.213       1.509
# C(Mention_country)[T.pri]     1.0176      0.722      1.410      0.158      -0.397       2.432
# C(Mention_country)[T.prt]     1.2050      0.405      2.977      0.003       0.412       1.998
# C(Mention_country)[T.pry]    -0.3260      0.561     -0.581      0.561      -1.425       0.773
# C(Mention_country)[T.pse]    -0.8560      0.739     -1.158      0.247      -2.305       0.593
# C(Mention_country)[T.qat]    -2.2664      1.179     -1.922      0.055      -4.578       0.045
# C(Mention_country)[T.rou]     0.3201      0.213      1.500      0.134      -0.098       0.738
# C(Mention_country)[T.rus]     1.6275      0.747      2.179      0.029       0.164       3.091
# C(Mention_country)[T.rwa]    -0.2294      0.372     -0.617      0.537      -0.959       0.500
# C(Mention_country)[T.sau]    -0.3389      0.290     -1.169      0.242      -0.907       0.229
# C(Mention_country)[T.sen]     0.9389      0.296      3.172      0.002       0.359       1.519
# C(Mention_country)[T.sgp]     0.3287      0.672      0.489      0.625      -0.989       1.646
# C(Mention_country)[T.sle]    -0.1843      0.553     -0.333      0.739      -1.269       0.900
# C(Mention_country)[T.slv]    -0.5627      0.528     -1.066      0.286      -1.597       0.472
# C(Mention_country)[T.som]    -0.3340      0.344     -0.970      0.332      -1.009       0.341
# C(Mention_country)[T.svk]     0.0395      0.592      0.067      0.947      -1.120       1.199
# C(Mention_country)[T.svn]    -0.1257      0.941     -0.133      0.894      -1.971       1.720
# C(Mention_country)[T.swe]     1.6292      0.478      3.405      0.001       0.691       2.567
# C(Mention_country)[T.syr]     0.0616      0.138      0.445      0.657      -0.210       0.333
# C(Mention_country)[T.tcd]    -0.3697      0.328     -1.127      0.260      -1.013       0.273
# C(Mention_country)[T.tgo]    -0.8973      0.541     -1.658      0.097      -1.958       0.164
# C(Mention_country)[T.tha]     1.6945      0.447      3.794      0.000       0.819       2.570
# C(Mention_country)[T.tjk]    -0.6193      0.475     -1.305      0.192      -1.550       0.311
# C(Mention_country)[T.tkm]    -1.4264      0.601     -2.375      0.018      -2.603      -0.249
# C(Mention_country)[T.tto]    -1.6052      1.077     -1.491      0.136      -3.715       0.505
# C(Mention_country)[T.tun]    -0.1554      0.363     -0.428      0.668      -0.866       0.556
# C(Mention_country)[T.tur]     1.5918      0.500      3.184      0.001       0.612       2.572
# C(Mention_country)[T.tza]     2.1322      0.198     10.748      0.000       1.743       2.521
# C(Mention_country)[T.uga]     2.1328      0.063     33.931      0.000       2.010       2.256
# C(Mention_country)[T.ukr]     0.4927      0.306      1.609      0.108      -0.108       1.093
# C(Mention_country)[T.ury]     0.2225      0.751      0.296      0.767      -1.250       1.695
# C(Mention_country)[T.usa]     2.7958      1.088      2.570      0.010       0.664       4.928
# C(Mention_country)[T.uzb]    -0.2097      0.075     -2.797      0.005      -0.357      -0.063
# C(Mention_country)[T.ven]     0.3686      0.244      1.510      0.131      -0.110       0.847
# C(Mention_country)[T.vnm]     1.8624      0.483      3.857      0.000       0.916       2.809
# C(Mention_country)[T.yem]    -0.1575      0.124     -1.275      0.202      -0.400       0.085
# C(Mention_country)[T.zaf]     2.3645      0.376      6.295      0.000       1.628       3.101
# C(Mention_country)[T.zmb]     1.1493      0.272      4.228      0.000       0.617       1.682
# C(Mention_country)[T.zwe]     1.5171      0.260      5.824      0.000       1.007       2.028
# C(year)[T.2003.0]            -0.0485      0.029     -1.680      0.093      -0.105       0.008
# C(year)[T.2004.0]            -0.0742      0.029     -2.539      0.011      -0.132      -0.017
# C(year)[T.2005.0]            -0.0508      0.028     -1.837      0.066      -0.105       0.003
# C(year)[T.2006.0]            -0.0432      0.026     -1.676      0.094      -0.094       0.007
# C(year)[T.2007.0]             0.0013      0.018      0.072      0.942      -0.035       0.037
# C(year)[T.2008.0]             0.0151      0.019      0.779      0.436      -0.023       0.053
# C(year)[T.2009.0]             0.0419      0.016      2.621      0.009       0.011       0.073
# C(year)[T.2010.0]             0.0287      0.019      1.522      0.128      -0.008       0.066
# treated_GC                   -0.0951      0.608     -0.156      0.876      -1.287       1.097
# time                         -0.0987      0.011     -8.720      0.000      -0.121      -0.077
# treated_GC:time               0.0752      0.027      2.771      0.006       0.022       0.128
# treated_GO                    0.3991      0.134      2.974      0.003       0.136       0.662
# treated_GO:time              -0.0296      0.026     -1.116      0.264      -0.081       0.022
# treated_CW                   -0.6697      0.220     -3.046      0.002      -1.101      -0.239
# treated_CW:time               0.0091      0.021      0.425      0.671      -0.033       0.051
# log_population                0.1437      0.380      0.378      0.705      -0.601       0.888
# log_gdp                       0.2026      0.076      2.671      0.008       0.054       0.351
# ==============================================================================
# Omnibus:                      112.133   Durbin-Watson:                   1.797
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              342.158
# Skew:                          -0.419   Prob(JB):                     5.03e-75
# Kurtosis:                       5.364   Cond. No.                     1.95e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.2e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 161, but rank is 13
#   warnings.warn('covariance of constraints does not have full '

# %%
sns.lineplot(data=df_complete, x='year', y='log_count', hue='hue')
plt.axvline(2011, color='k', linestyle='--')
plt.ylabel('log Foreign attention')
# Out:
# Text(0, 0.5, 'log Foreign attention')

# %%
# Running the Difference-in-Differences regression
model = smf.ols("log_count ~treated_GC * post + treated_GO * post +treated_CW * post+log_population +log_gdp+C(Mention_country) + C(year)", data=df_complete).fit(cov_type='cluster', cov_kwds={'groups': df_complete['Mention_country']})
# Print summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_count   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     189.6
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           7.45e-95
# Time:                        21:46:45   Log-Likelihood:                -310.71
# No. Observations:                2610   AIC:                             955.4
# Df Residuals:                    2443   BIC:                             1935.
# Df Model:                         166
# Covariance Type:              cluster
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -7.9873      2.656     -3.008      0.003     -13.192      -2.782
# C(Mention_country)[T.ago]    -0.5802      0.100     -5.817      0.000      -0.776      -0.385
# C(Mention_country)[T.alb]    -0.0283      0.345     -0.082      0.935      -0.705       0.648
# C(Mention_country)[T.are]     0.4462      0.301      1.483      0.138      -0.143       1.036
# C(Mention_country)[T.arg]     1.1222      0.182      6.171      0.000       0.766       1.479
# C(Mention_country)[T.arm]     0.1239      0.342      0.362      0.717      -0.547       0.795
# C(Mention_country)[T.aus]     2.1410      0.252      8.490      0.000       1.647       2.635
# C(Mention_country)[T.aut]     0.7013      0.287      2.440      0.015       0.138       1.265
# C(Mention_country)[T.aze]    -0.6776      0.193     -3.507      0.000      -1.056      -0.299
# C(Mention_country)[T.bdi]    -1.1138      0.188     -5.923      0.000      -1.482      -0.745
# C(Mention_country)[T.bel]     0.7630      0.267      2.853      0.004       0.239       1.287
# C(Mention_country)[T.ben]     0.4147      0.165      2.509      0.012       0.091       0.739
# C(Mention_country)[T.bfa]     0.8082      0.085      9.526      0.000       0.642       0.974
# C(Mention_country)[T.bgd]     0.6514      0.259      2.518      0.012       0.144       1.159
# C(Mention_country)[T.bgr]     0.5286      0.231      2.293      0.022       0.077       0.980
# C(Mention_country)[T.bhr]    -0.9435      0.264     -3.574      0.000      -1.461      -0.426
# C(Mention_country)[T.bih]     0.1528      0.311      0.492      0.623      -0.456       0.762
# C(Mention_country)[T.blr]    -0.5383      0.195     -2.764      0.006      -0.920      -0.157
# C(Mention_country)[T.bol]     1.0831      0.164      6.619      0.000       0.762       1.404
# C(Mention_country)[T.bra]     1.0726      0.355      3.023      0.003       0.377       1.768
# C(Mention_country)[T.bwa]     1.4736      0.396      3.721      0.000       0.697       2.250
# C(Mention_country)[T.caf]    -0.5357      0.279     -1.918      0.055      -1.083       0.012
# C(Mention_country)[T.can]     1.8317      0.258      7.112      0.000       1.327       2.336
# C(Mention_country)[T.che]     1.1498      0.313      3.677      0.000       0.537       1.763
# C(Mention_country)[T.chl]     1.5462      0.182      8.512      0.000       1.190       1.902
# C(Mention_country)[T.chn]     1.2273      0.616      1.992      0.046       0.020       2.435
# C(Mention_country)[T.civ]    -2.5598      0.081    -31.716      0.000      -2.718      -2.402
# C(Mention_country)[T.cmr]     1.0925      0.076     14.403      0.000       0.944       1.241
# C(Mention_country)[T.col]     0.5880      0.164      3.594      0.000       0.267       0.909
# C(Mention_country)[T.cri]     1.7602      0.294      5.980      0.000       1.183       2.337
# C(Mention_country)[T.cub]     0.1814      0.182      0.996      0.319      -0.176       0.538
# C(Mention_country)[T.cyp]     1.2215      0.504      2.424      0.015       0.234       2.209
# C(Mention_country)[T.cze]     0.7535      0.233      3.241      0.001       0.298       1.209
# C(Mention_country)[T.deu]     1.1202      0.318      3.521      0.000       0.497       1.744
# C(Mention_country)[T.dji]    -0.5550      0.514     -1.080      0.280      -1.563       0.452
# C(Mention_country)[T.dnk]     1.6120      0.330      4.880      0.000       0.965       2.259
# C(Mention_country)[T.dom]    -0.1973      0.194     -1.019      0.308      -0.577       0.182
# C(Mention_country)[T.dza]    -0.6991      0.133     -5.265      0.000      -0.959      -0.439
# C(Mention_country)[T.ecu]     0.9469      0.148      6.401      0.000       0.657       1.237
# C(Mention_country)[T.egy]    -0.0667      0.167     -0.400      0.689      -0.394       0.260
# C(Mention_country)[T.eri]    -0.2330      0.336     -0.694      0.488      -0.891       0.425
# C(Mention_country)[T.esp]     1.8788      0.251      7.491      0.000       1.387       2.370
# C(Mention_country)[T.est]     1.3352      0.471      2.833      0.005       0.411       2.259
# C(Mention_country)[T.eth]     0.9662      0.171      5.646      0.000       0.631       1.302
# C(Mention_country)[T.fin]     1.8810      0.326      5.764      0.000       1.241       2.521
# C(Mention_country)[T.fra]     1.1875      0.294      4.038      0.000       0.611       1.764
# C(Mention_country)[T.gab]     0.7171      0.426      1.684      0.092      -0.118       1.552
# C(Mention_country)[T.gbr]     2.1043      0.296      7.111      0.000       1.524       2.684
# C(Mention_country)[T.gha]     1.2090      0.055     22.176      0.000       1.102       1.316
# C(Mention_country)[T.gmb]     0.4752      0.404      1.178      0.239      -0.316       1.266
# C(Mention_country)[T.grc]     1.5844      0.239      6.631      0.000       1.116       2.053
# C(Mention_country)[T.gtm]     0.4477      0.137      3.274      0.001       0.180       0.716
# C(Mention_country)[T.hkg]     2.0762      0.292      7.122      0.000       1.505       2.648
# C(Mention_country)[T.hnd]     0.0880      0.189      0.467      0.641      -0.282       0.458
# C(Mention_country)[T.hrv]     0.5114      0.315      1.623      0.105      -0.106       1.129
# C(Mention_country)[T.hti]     0.2036      0.162      1.261      0.207      -0.113       0.520
# C(Mention_country)[T.hun]     0.8505      0.224      3.804      0.000       0.412       1.289
# C(Mention_country)[T.idn]     0.4594      0.353      1.300      0.193      -0.233       1.152
# C(Mention_country)[T.ind]     0.7637      0.582      1.312      0.189      -0.377       1.904
# C(Mention_country)[T.irn]     0.1136      0.213      0.533      0.594      -0.304       0.531
# C(Mention_country)[T.irq]    -0.2641      0.120     -2.192      0.028      -0.500      -0.028
# C(Mention_country)[T.isr]     1.5066      0.279      5.394      0.000       0.959       2.054
# C(Mention_country)[T.ita]     1.4664      0.280      5.244      0.000       0.918       2.014
# C(Mention_country)[T.jam]     0.8544      0.358      2.388      0.017       0.153       1.555
# C(Mention_country)[T.jor]     0.9538      0.034     27.703      0.000       0.886       1.021
# C(Mention_country)[T.jpn]     1.0407      0.363      2.866      0.004       0.329       1.753
# C(Mention_country)[T.kaz]     0.3014      0.162      1.863      0.062      -0.016       0.619
# C(Mention_country)[T.ken]     1.9384      0.079     24.393      0.000       1.783       2.094
# C(Mention_country)[T.kgz]     0.3240      0.245      1.322      0.186      -0.156       0.804
# C(Mention_country)[T.khm]     0.8556      0.105      8.143      0.000       0.650       1.062
# C(Mention_country)[T.kor]     0.5528      0.248      2.230      0.026       0.067       1.039
# C(Mention_country)[T.kwt]    -0.9988      0.140     -7.155      0.000      -1.272      -0.725
# C(Mention_country)[T.lao]     0.5155      0.226      2.284      0.022       0.073       0.958
# C(Mention_country)[T.lbn]     0.3438      0.275      1.251      0.211      -0.195       0.883
# C(Mention_country)[T.lbr]    -0.1868      0.301     -0.621      0.535      -0.777       0.403
# C(Mention_country)[T.lby]    -0.1014      0.169     -0.599      0.549      -0.433       0.230
# C(Mention_country)[T.lka]     0.6210      0.100      6.222      0.000       0.425       0.817
# C(Mention_country)[T.lso]     0.2953      0.394      0.749      0.454      -0.478       1.068
# C(Mention_country)[T.ltu]     0.3886      0.355      1.095      0.274      -0.307       1.084
# C(Mention_country)[T.lva]     0.4720      0.406      1.162      0.245      -0.324       1.268
# C(Mention_country)[T.mar]     0.4459      0.237      1.884      0.060      -0.018       0.910
# C(Mention_country)[T.mda]    -0.2577      0.346     -0.744      0.457      -0.936       0.421
# C(Mention_country)[T.mdg]     1.2641      0.041     30.578      0.000       1.183       1.345
# C(Mention_country)[T.mex]     1.6748      0.291      5.756      0.000       1.105       2.245
# C(Mention_country)[T.mkd]     0.3276      0.398      0.824      0.410      -0.452       1.107
# C(Mention_country)[T.mli]     0.6202      0.091      6.825      0.000       0.442       0.798
# C(Mention_country)[T.mmr]    -0.1749      0.091     -1.929      0.054      -0.353       0.003
# C(Mention_country)[T.mng]     2.6191      0.350      7.480      0.000       1.933       3.305
# C(Mention_country)[T.moz]     0.7572      0.031     24.791      0.000       0.697       0.817
# C(Mention_country)[T.mrt]    -0.2625      0.315     -0.834      0.404      -0.880       0.355
# C(Mention_country)[T.mus]     0.4516      0.474      0.953      0.341      -0.478       1.381
# C(Mention_country)[T.mwi]     1.5551      0.099     15.771      0.000       1.362       1.748
# C(Mention_country)[T.mys]     0.7156      0.161      4.445      0.000       0.400       1.031
# C(Mention_country)[T.nam]     1.5649      0.393      3.986      0.000       0.795       2.334
# C(Mention_country)[T.ner]    -0.4717      0.080     -5.911      0.000      -0.628      -0.315
# C(Mention_country)[T.nga]     0.4307      0.288      1.496      0.135      -0.134       0.995
# C(Mention_country)[T.nic]     0.7467      0.238      3.136      0.002       0.280       1.213
# C(Mention_country)[T.nld]     1.4659      0.257      5.712      0.000       0.963       1.969
# C(Mention_country)[T.nor]     2.5595      0.355      7.217      0.000       1.864       3.255
# C(Mention_country)[T.npl]     1.2485      0.018     67.829      0.000       1.212       1.285
# C(Mention_country)[T.nzl]     3.0482      0.338      9.027      0.000       2.386       3.710
# C(Mention_country)[T.omn]     0.7348      0.114      6.435      0.000       0.511       0.959
# C(Mention_country)[T.pak]     0.0355      0.302      0.118      0.906      -0.556       0.627
# C(Mention_country)[T.pan]     1.5220      0.327      4.652      0.000       0.881       2.163
# C(Mention_country)[T.per]     1.3201      0.131     10.110      0.000       1.064       1.576
# C(Mention_country)[T.phl]     0.5993      0.214      2.796      0.005       0.179       1.019
# C(Mention_country)[T.pol]     0.6412      0.191      3.361      0.001       0.267       1.015
# C(Mention_country)[T.pri]     1.6888      0.353      4.785      0.000       0.997       2.381
# C(Mention_country)[T.prt]     1.6156      0.239      6.751      0.000       1.147       2.085
# C(Mention_country)[T.pry]     0.0404      0.251      0.161      0.872      -0.451       0.532
# C(Mention_country)[T.pse]    -0.1365      0.304     -0.449      0.654      -0.733       0.460
# C(Mention_country)[T.qat]    -0.8249      0.475     -1.737      0.082      -1.756       0.106
# C(Mention_country)[T.rou]     0.4420      0.156      2.829      0.005       0.136       0.748
# C(Mention_country)[T.rus]     0.6191      0.317      1.954      0.051      -0.002       1.240
# C(Mention_country)[T.rwa]     0.3035      0.153      1.986      0.047       0.004       0.603
# C(Mention_country)[T.sau]    -0.2189      0.204     -1.075      0.282      -0.618       0.180
# C(Mention_country)[T.sen]     0.8875      0.127      6.970      0.000       0.638       1.137
# C(Mention_country)[T.sgp]     1.0686      0.334      3.202      0.001       0.415       1.723
# C(Mention_country)[T.sle]     0.2833      0.225      1.257      0.209      -0.159       0.725
# C(Mention_country)[T.slv]    -0.3619      0.241     -1.504      0.133      -0.833       0.110
# C(Mention_country)[T.som]    -0.5259      0.141     -3.717      0.000      -0.803      -0.249
# C(Mention_country)[T.svk]     0.6586      0.292      2.258      0.024       0.087       1.230
# C(Mention_country)[T.svn]     0.8652      0.420      2.059      0.039       0.042       1.689
# C(Mention_country)[T.swe]     1.9456      0.285      6.835      0.000       1.388       2.503
# C(Mention_country)[T.syr]     0.0185      0.045      0.411      0.681      -0.070       0.107
# C(Mention_country)[T.tcd]    -0.3615      0.130     -2.780      0.005      -0.616      -0.107
# C(Mention_country)[T.tgo]    -0.6027      0.220     -2.743      0.006      -1.033      -0.172
# C(Mention_country)[T.tha]     1.0080      0.200      5.053      0.000       0.617       1.399
# C(Mention_country)[T.tjk]    -0.3530      0.196     -1.798      0.072      -0.738       0.032
# C(Mention_country)[T.tkm]    -1.2643      0.262     -4.820      0.000      -1.778      -0.750
# C(Mention_country)[T.tto]    -0.5790      0.463     -1.251      0.211      -1.486       0.328
# C(Mention_country)[T.tun]     0.3601      0.157      2.293      0.022       0.052       0.668
# C(Mention_country)[T.tur]     0.9845      0.238      4.137      0.000       0.518       1.451
# C(Mention_country)[T.tza]     1.5943      0.081     19.592      0.000       1.435       1.754
# C(Mention_country)[T.uga]     1.8056      0.029     63.049      0.000       1.749       1.862
# C(Mention_country)[T.ukr]     0.0020      0.131      0.015      0.988      -0.255       0.259
# C(Mention_country)[T.ury]     0.8275      0.341      2.424      0.015       0.158       1.497
# C(Mention_country)[T.usa]     1.8679      0.480      3.892      0.000       0.927       2.809
# C(Mention_country)[T.uzb]    -0.7127      0.060    -11.802      0.000      -0.831      -0.594
# C(Mention_country)[T.ven]    -0.0817      0.172     -0.474      0.636      -0.420       0.256
# C(Mention_country)[T.vnm]     1.0889      0.193      5.645      0.000       0.711       1.467
# C(Mention_country)[T.yem]    -0.5572      0.059     -9.418      0.000      -0.673      -0.441
# C(Mention_country)[T.zaf]     1.9763      0.186     10.620      0.000       1.612       2.341
# C(Mention_country)[T.zmb]     1.1785      0.114     10.353      0.000       0.955       1.402
# C(Mention_country)[T.zwe]     1.2130      0.118     10.299      0.000       0.982       1.444
# C(year)[T.2003.0]             0.0511      0.032      1.614      0.106      -0.011       0.113
# C(year)[T.2004.0]             0.1264      0.037      3.389      0.001       0.053       0.200
# C(year)[T.2005.0]             0.2493      0.040      6.161      0.000       0.170       0.329
# C(year)[T.2006.0]             0.3547      0.047      7.499      0.000       0.262       0.447
# C(year)[T.2007.0]             0.4999      0.049     10.268      0.000       0.404       0.595
# C(year)[T.2008.0]             0.6142      0.057     10.817      0.000       0.503       0.726
# C(year)[T.2009.0]             0.7262      0.055     13.304      0.000       0.619       0.833
# C(year)[T.2010.0]             0.8102      0.060     13.564      0.000       0.693       0.927
# C(year)[T.2011.0]            -0.4002      0.019    -21.214      0.000      -0.437      -0.363
# C(year)[T.2012.0]            -0.2962      0.019    -15.685      0.000      -0.333      -0.259
# C(year)[T.2013.0]            -0.1086      0.016     -6.911      0.000      -0.139      -0.078
# C(year)[T.2014.0]            -0.0421      0.017     -2.423      0.015      -0.076      -0.008
# C(year)[T.2015.0]             0.0067      0.014      0.488      0.626      -0.020       0.034
# C(year)[T.2016.0]             0.1556      0.016      9.884      0.000       0.125       0.187
# C(year)[T.2017.0]             0.3761      0.016     23.641      0.000       0.345       0.407
# C(year)[T.2018.0]             0.7855      0.019     42.440      0.000       0.749       0.822
# C(year)[T.2019.0]             0.8820      0.023     39.147      0.000       0.838       0.926
# treated_GC                    0.1921      0.262      0.734      0.463      -0.321       0.705
# post                          1.3586      0.058     23.599      0.000       1.246       1.471
# treated_GC:post              -0.2186      0.095     -2.297      0.022      -0.405      -0.032
# treated_GO                    0.2933      0.088      3.323      0.001       0.120       0.466
# treated_GO:post               0.1518      0.169      0.901      0.368      -0.179       0.482
# treated_CW                   -0.6401      0.121     -5.284      0.000      -0.878      -0.403
# treated_CW:post               0.3658      0.104      3.523      0.000       0.162       0.569
# log_population                0.5600      0.151      3.700      0.000       0.263       0.857
# log_gdp                       0.1281      0.054      2.352      0.019       0.021       0.235
# ==============================================================================
# Omnibus:                      265.116   Durbin-Watson:                   1.265
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              990.791
# Skew:                          -0.459   Prob(JB):                    7.12e-216
# Kurtosis:                       5.876   Cond. No.                     7.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.41e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\Yasaman\anaconda3\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 170, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
